# %%
import os

# %%
os.listdir('C:\\Users\\Jonat\\Downloads')
# Out:
# ['.ipynb_checkpoints',
#  '07847800019478.pdf',
#  '07988600007331.pdf',
#  '09-19-Amazon-Ranking-Analysis.csv',
#  '1-Day_Python_Bootcamp_v2.zip',
#  '1-Upsly.png',
#  '10-BR18-1023CH1071-api.pdf',
#  '1014065_1440727586164194_860493435_n.jpg',
#  '10153300001642.pdf',
#  '10300035_1462736730629946_5031097354207611184_n.jpg',
#  '10360963_1588283231408628_5869460085379827370_n.jpg',
#  '10373525_1466307340272885_3079822406982689855_n.jpg',
#  '10419958_1494416880795264_4839305663014469288_n.jpg',
#  '10580224_1512836128953339_4574645678106112862_n.jpg',
#  '10837364170017760.txt',
#  '10837501244017760.txt',
#  '10841359811017760.txt',
#  '10844149123017760.txt',
#  '10844996332017760.txt',
#  '10845201348017760.txt',
#  '10960166_1584956908407927_463425464227349060_o.jpg',
#  '11109440_1636946069875677_1344821678715490363_n.jpg',
#  '11147124_1636947596542191_4470596760068497645_n.jpg',
#  '11182350_1623589784544639_1231694224501460195_n.jpg',
# ...

# %%
pwd
# Out:
# 'C:\\Users\\Jonat\\dat-07-28\\DAT-07-28\\ClassMaterial\\Unit1\\Class3'

# %%
cd ..\..\..\..\..
# Out:
# C:\Users\Jonat

# %%
cd Downloads
# Out:
# C:\Users\Jonat\Downloads

# %%
pwd
# Out:
# 'C:\\Users\\Jonat\\Downloads'

# %%
first_file = os.listdir()[0]

# %%
first_file
# Out:
# '.ipynb_checkpoints'

# %%
os.path.isfile(first_file)
# Out:
# False

# %%
for file in os.listdir():
    if file[-4:] == '.csv':
        print(file)
# Out:
# 09-19-Amazon-Ranking-Analysis.csv
# 1500340.csv
# 1500343.csv
# 1500345.csv
# AAPL (1).csv
# AAPL.csv
# accessKeys.csv
# AirPassengers.csv
# amis (1).csv
# amis.csv
# AMZN.csv
# bike_requests.csv
# births.csv
# calendar.csv
# callers.csv
# credentials (1).csv
# credentials (2).csv
# credentials (3).csv
# credentials (4).csv
# credentials.csv
# data (1).csv
# data (2).csv
# data (3).csv
# data (4).csv
# data (5).csv
# data.csv
# FB.csv
# filestream.csv
# file_upload_csv_template_08122008.csv
# GitHub Repos - Sheet1 (1).csv
# GitHub Repos - Sheet1.csv
# GOOGL.csv
# grocery_sales.csv
# IEF.csv
# IMDB Dataset.csv
# initial_submit (1).csv
# initial_submit (2).csv
# initial_submit.csv
# insurance_premiums.csv
# iowa_housing.csv
# lreg_answers.csv
# mixture.csv
# MSFT (1).csv
# MSFT.csv
# Output.csv
# Owners.csv
# pctgrowth.csv
# Pets.csv
# potions.csv
# predictions_for_movies_zeroed.csv
# ProceduresDetails.csv
# ProceduresHistory-1.csv
# repos.csv
# rootkey (1).csv
# rootkey.csv
# s&p.csv
# ...

# %%
users = [
    ('John', 34, None), ('Abby', 21, 'NY'), ('Jill', 41, 'OH'), ('Jason', 59, 'AL'), ('William', 35, None),
    ('Wynona', 62, 'WY'), ('Barbara', 42, None), ('Harold', 52, None), ('Jose', 41, 'NH'), ('Ariel', 48, 'OR')
]

# %%
users[0][1]
# Out:
# 34

# %%
for item in users:
    print(item[1])
# Out:
# 34
# 21
# 41
# 59
# 35
# 62
# 42
# 52
# 41
# 48

# %%
num = 0

# %%
num = num + 1

# %%
num
# Out:
# 1

# %%
num = num + 1

# %%
num
# Out:
# 2

# %%
num += 1

# %%
num
# Out:
# 3

# %%
num += 10

# %%
num
# Out:
# 13

# %%
num -= 10

# %%
num
# Out:
# 3

# %%
num /= 3

# %%
num
# Out:
# 1.0

# %%
num_strings = 0

for user in users:
    for item in user:
        if type(item) == str:
            num_strings = 1

# %%
num_strings
# Out:
# 16

# %%
list1 = [2, 4, 5, 8]
list2 = [3, 5, 7, 9]

# %%
for item1, item2 in zip(list1, list2):
    print(item1, item2)
# Out:
# 2 3
# 4 5
# 5 7
# 8 9

# %%
zipped_lists = zip(list1, list2)

# %%
print(*zipped_lists)

# %%
myself = {
    'name': 'Jonathan',
    'sign': 'Aquarius',
    'age' : 35,
    'interests': ['data science', 'basketball', 'hiking']
}

# %%
myself['name']
# Out:
# 'Jonathan'

# %%
myself['sign']
# Out:
# 'Aquarius'

# %%
for interest in myself['interests']:
    print(interest)
# Out:
# data science
# basketball
# hiking

# %%
import requests

# %%
url = 'https://api.census.gov/data.json'

# %%
web_data = requests.get(url)

# %%
census_data = web_data.json()

# %%
type(census_data)
# Out:
# dict

# %%
census_data['dataset'][0]['c_geographyLink']
# Out:
# 'https://api.census.gov/data/1986/cbp/geography.json'

# %%
import pandas as pd

pd.DataFrame(census_data['dataset'])
# Out:
#      c_vintage                 c_dataset  \
# 0       1986.0                     [cbp]
# 1       1994.0                     [zbp]
# 2       1987.0                     [cbp]
# 3       1995.0                     [cbp]
# 4       1988.0                     [cbp]
# ..         ...                       ...
# 488     2020.0              [pdb, tract]
# 489     2018.0                     [zbp]
# 490     2015.0         [acs, acs5, aian]
# 491     2015.0  [acs, acs5, aianprofile]
# 492     2015.0          [acs, acs5, spt]
#
#                                        c_geographyLink  \
# 0    https://api.census.gov/data/1986/cbp/geography...
# 1    https://api.census.gov/data/1994/zbp/geography...
# 2    https://api.census.gov/data/1987/cbp/geography...
# 3    https://api.census.gov/data/1995/cbp/geography...
# 4    https://api.census.gov/data/1988/cbp/geography...
# ..                                                 ...
# 488  https://api.census.gov/data/2020/pdb/tract/geo...
# ...

# %%
census_data['dataset'][2]
# Out:
# {'c_vintage': 1987,
#  'c_dataset': ['cbp'],
#  'c_geographyLink': 'https://api.census.gov/data/1987/cbp/geography.json',
#  'c_variablesLink': 'https://api.census.gov/data/1987/cbp/variables.json',
#  'c_tagsLink': 'https://api.census.gov/data/1987/cbp/tags.json',
#  'c_examplesLink': 'https://api.census.gov/data/1987/cbp/examples.json',
#  'c_groupsLink': 'https://api.census.gov/data/1987/cbp/groups.json',
#  'c_valuesLink': 'https://api.census.gov/data/1987/cbp/values.json',
#  'c_documentationLink': 'http://www.census.gov/developer/',
#  'c_isAggregate': True,
#  'c_isAvailable': True,
#  '@type': 'dcat:Dataset',
#  'title': '1987 County Business Patterns: Business Patterns',
#  'accessLevel': 'public',
#  'bureauCode': ['006:07'],
# ...

# %%
github_url = 'https://api.github.com/users/jonathanbechtel/repos'
github_data = requests.get(github_url).json()

# %%
github_data
# Out:
# [{'id': 260764681,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjA3NjQ2ODE=',
#   'name': 'bitcoin',
#   'full_name': 'JonathanBechtel/bitcoin',
#   'private': False,
#   'owner': {'login': 'JonathanBechtel',
#    'id': 481696,
#    'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/481696?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JonathanBechtel',
#    'html_url': 'https://github.com/JonathanBechtel',
#    'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#    'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
# ...

# %%
pwd
# Out:
# 'C:\\Users\\Jonat\\Downloads'

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 0499-EE93
#
#  Directory of C:\Users\Jonat\Downloads
#
# 08/04/2020  02:24 PM    <DIR>          .
# 08/04/2020  02:24 PM    <DIR>          ..
# 07/28/2020  04:01 PM    <DIR>          .ipynb_checkpoints
# 09/11/2019  10:02 AM            63,901 ^GSPC.csv
# 10/14/2019  12:42 PM               162 _$t-class-syllabus.docx
# 05/16/2019  11:46 AM               222 __init__.cpython-37.pyc
# 01/02/2019  07:41 PM             2,279 _244865a4d5a9a1dfcba2c8b19040de4f_callers.csv
# 07/28/2019  11:09 PM             6,259 _a0f69303566ab5afce696cd01f5f9a90_daily-total-female-births-in-cal (1).csv
# 10/09/2019  02:26 PM            40,278 {2cce406d-01ef-417e-9446-1957516159d6}_MATLAB_Computational_Finance_Conference_2019 (1).ics
# 10/15/2019  01:51 AM            40,278 {2cce406d-01ef-417e-9446-1957516159d6}_MATLAB_Computational_Finance_Conference_2019 (2).ics
# ...

# %%
with open('DAT-07-28 Github Repos - Sheet1.csv') as f:
    csv_data = f.readlines()

# %%
csv_data
# Out:
# ['Name,Github Repo\n',
#  'Jonathan Bechtel,https://github.com/JonathanBechtel\n',
#  'Luki Elizalde,https://github.com/groovyluki\n',
#  'iuliana trufas,https://github.com/Yuliana-GitHub\n',
#  'Neraj Thangarajah,https://github.com/nthang1\n',
#  'Alina Urs,https://github.com/sprintkayaking\n',
#  'Ashleigh Grant,https://github.com/AshleighGrant\n',
#  'Nick Hudgell ,Https://github.com/nhudgell/GADS\n',
#  'Elisa Scagnetto,https://github.com/lisadt/es_repo280720']

# %%
cd ..

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 0499-EE93
#
#  Directory of C:\Users\Jonat\Downloads
#
# 08/04/2020  02:24 PM    <DIR>          .
# 08/04/2020  02:24 PM    <DIR>          ..
# 07/28/2020  04:01 PM    <DIR>          .ipynb_checkpoints
# 09/11/2019  10:02 AM            63,901 ^GSPC.csv
# 10/14/2019  12:42 PM               162 _$t-class-syllabus.docx
# 05/16/2019  11:46 AM               222 __init__.cpython-37.pyc
# 01/02/2019  07:41 PM             2,279 _244865a4d5a9a1dfcba2c8b19040de4f_callers.csv
# 07/28/2019  11:09 PM             6,259 _a0f69303566ab5afce696cd01f5f9a90_daily-total-female-births-in-cal (1).csv
# 10/09/2019  02:26 PM            40,278 {2cce406d-01ef-417e-9446-1957516159d6}_MATLAB_Computational_Finance_Conference_2019 (1).ics
# 10/15/2019  01:51 AM            40,278 {2cce406d-01ef-417e-9446-1957516159d6}_MATLAB_Computational_Finance_Conference_2019 (2).ics
# ...
