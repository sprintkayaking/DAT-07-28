# %% [markdown]
# ## Homework 1: Advanced Track -- Harvest the Twitter API

# %% [markdown]
# **Objective:** Write a series of functions that allow you to dynamically harvest Twitter data.
#
# **Estimated Time to Complete:** 4-12 hours
#
# #### Sections
#
#  - **Section 1:** Setting up your developer account, using OAuth1 authentication (approx 45-120 minutes)
#  - **Section 2:** Navigating the API documentation, getting your first query string (approx 45-120 minutes)
#  - **Section 3:** Writing your API calls (approx 90 - 360 minutes)
#
# #### What You'll Turn In:
#  - A `.py` (not a Notebook!) file that contains the functions that you were prompted to create.  These should contain comments demonstrating why your code does what it does, and after it's run, the instructor should be able to make the appropriate function calls in Spyder or any other IDE.

# %% [markdown]
# ## Section 1:  Setting Up Your Developer Account

# %% [markdown]
# Most API's require you to do a little pre-work in order to be able to use them, so the first part of this homework assignment will be spent setting up your developer account so you have API Access.

# %% [markdown]
# **Step 1:  Create a Twitter Developer Account**
#
#  - Make sure you have a regular twitter account before you do this
#  - You can apply for a developer account here:  https://developer.twitter.com/en/apply-for-access
#   - Choose either a student or hobbyist/personal account

# %% [markdown]
# **Step 2:  Create An App**
#
# You don't have to intend to build an official software program to have an app.....this is just a way for you to get authentication keys to use with the API.
#
#  - Go to the menu in the upper right hand corner and click on **Your Name** > **Apps**
#  - Choose **Create An App**
#  - You'll be prompted to enter some information about your app.  Don't worry too much about this, it can say almost anything.  You'll be prompted to list websites where it will be hosted...this can be anything for now.  Use https://generalassemb.ly if you're undecided about what to put.

# %% [markdown]
# **Step 3: Create Your API Tokens**
#
# Now that you have an app, you can use its API tokens to go ahead and make requests like we did in class 3.  Like a lot of API's, the Twitter API uses something called OAuth authentication.
#
# If you didn't wait until the night before this assignment was due and have a spare 30 minutes, you can read a little about it here: https://oauth.net/
#
# In any event, you need API tokens in order to make requests.  Do the following:
#
#  - Go to the **Apps** section of your developer portal
#  - Click on the **Details** button for the app that you just created
#  - Click on the **Keys & Tokens** tab
#   - Two keys should already be given to you:  **API Key** & **API Secret Key**
#   - Two you have to generate:  **Access token** & **Access token secret**
#  - Generate your Access Token and Access Token Secret keys.  You'll need to write these down when you're done
#
# Now you're ready to make requests to the Twitter api.  Everytime you make a request, you'll need to include the 4 tokens you just created.  (You can always regenerate them for whatever reason).

# %% [markdown]
# **Step 4:  Your First Request**
#
# To make requests to the Twitter API you're going to need a module which is **not** already pre-installed in Anaconda. You'll need to install it via PIP, which is python's package manager.  It's called `requests_oauthlib`.  You can install this via Anaconda Prompt or Terminal by simply typing in the command `pip install requests_oauthlib`, and then you'll be finished.
#
# The logistics of making an OAuth1 authenticated request are very similar to what was done in class 3, but with a few additional steps.  You can see how to do it here:  https://requests.readthedocs.io/en/master/user/authentication/#oauth-1-authentication.  The only thing you'll need to change is the info for your API tokens that are passed into the `OAuth1()` function.
#
# Try making a request to the following URL to confirm that it works: 'https://api.twitter.com/1.1/account/verify_credentials.json'

# %%
# your code here
import requests
from requests_oauthlib import OAuth1

# passing in my developer tokens to the OAuth1 function
tokens = OAuth1('NOZHm1aLT1AVmchGbCmiZOAga', 'nPyaYCt8L7ymqGZtU8EqC0a2ypI9aSJgVNIhtoZ0wGsaf3BJw9',
                '1079981876864008192-AlhO4yOa06oW2sXZpLpWPwnOxEERYS', 'o3E0AsKJfDoTBk77UQYExzOG7E46jPYvpWNGAKsD6lUBY')

# url that I'm going to connect to
url = 'https://api.twitter.com/1.1/account/verify_credentials.json'

# initiate the request
req = requests.get(url, auth=tokens).json()

# %%
# and here it is
req
# Out:
# {'id': 1079981876864008192,
#  'id_str': '1079981876864008192',
#  'name': 'Jonathan Bechtel',
#  'screen_name': 'JonathanBechte6',
#  'location': '',
#  'description': '',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 1,
#  'friends_count': 18,
#  'listed_count': 0,
#  'created_at': 'Tue Jan 01 06:05:19 +0000 2019',
#  'favourites_count': 1,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 1,
#  'lang': None,
#  'status': {'created_at': 'Fri Nov 29 23:27:52 +0000 2019',
#   'id': 1200557014067363843,
#   'id_str': '1200557014067363843',
#   'text': "@kunjanshah @paulg @Austen How do you define 'solved'?  I would define it as quality-adjusted real prices that go d… https://t.co/ghgIv3irn6",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'kunjanshah',
#      'name': 'Kunjan Shah',
#      'id': 14828205,
#      'id_str': '14828205',
#      'indices': [0, 11]},
#     {'screen_name': 'paulg',
#      'name': 'Paul Graham',
#      'id': 183749519,
#      'id_str': '183749519',
#      'indices': [12, 18]},
#     {'screen_name': 'Austen',
#      'name': 'Austen Allred',
#      'id': 221838349,
#      'id_str': '221838349',
#      'indices': [19, 26]}],
#    'urls': [{'url': 'https://t.co/ghgIv3irn6',
#      'expanded_url': 'https://twitter.com/i/web/status/1200557014067363843',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': 1200483467529740288,
#   'in_reply_to_status_id_str': '1200483467529740288',
#   'in_reply_to_user_id': 14828205,
#   'in_reply_to_user_id_str': '14828205',
#   'in_reply_to_screen_name': 'kunjanshah',
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#  'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': True,
#  'default_profile_image': True,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none',
#  'suspended': False,
#  'needs_phone_verification': False}

# %% [markdown]
# If you get your json object back, then you're good to go.

# %% [markdown]
# ## Section 2: Searching Tweets

# %% [markdown]
# Most websites you access will have a long string attached to the end of them that look something like this:  `http://thewebsite.com/?year=2019&color=golden%20yellow&user_id=48549395959438`.
#
# Most people have no reason to pay attention to any of this, but all the special symbols at the end are basically encoded commands that say 'return a website that displays x,y,z characteristics.'
#
# When accessing api data, it basically works the same way.

# %% [markdown]
# **Step 1:  Set Up Your First Query String**

# %% [markdown]
# If you go into Twitter and search for the term `Data Science`, you should be brought to a url that looks like this:  `https://twitter.com/search?q=Data%20Science&src=typed_query`
#
# If you'd like, you can drop the `&src=typed_query` from the url and still get the same results.
#
# There are some important details to pay attention to:
#
#  - Like class 3 when we worked with GitHub, there is a **base url**.  In this case it's `https://twitter.com/search`
#  - Whenever you enter a search for something, the base url will be followed by something that looks like `?q=My%20Search%20Term`
#   - The `?` marks the beginning of the query string.  This basically says 'initiate a request with whatever parameters that follow'
#   - The `q` is a **parameter**, essentially some condition to pass into the query string that determines what results will be given back to you.
#
# **Useful Thing To Do Right Now:** Go back to the Twitter search page, and just try searching for different things, and notice what shows up after the `q=`.  Here are some questions to ask yourself:
#
#  - How are white spaces encoded?  Ie, if you search for `Jonathan Bechtel` in the search box, what shows up to account for the space between the two words?
#  - What about hash symbols?  If you search for `#MeToo`, `#GirlsWhoCode` or `#DataScience`, what happens with that `#` symbol?
#  - Once you get the hang of this, see if you can just re-create some searches yourself by creating the url directly, and bypassing the search box altogether.
#
# Now, let's try and make a request for a search for `Data Science`.
#
# If you look at Twitter's docs, you'll see that the base url for the search API is `https://api.twitter.com/1.1/search/tweets.json`
#
# This means you have to add the `?q=Whatever%20Word%20%Goes%20Here` to the end to complete the search.
#
# So go ahead, and see if you can create your API call for a search for the term `Data Science`.
#
# If you did it correctly, you should have a dictionary with a key called `statuses`, and it'll be a list with all of the tweets returned by your search.

# %%
# your answer here
base_url = 'https://api.twitter.com/1.1/search/tweets.json'
search = '?q=Data%20Science'

req = requests.get(base_url + search, auth=tokens).json()

# %%
# and here's our dictionary, with our key that contains all the tweets returned by our response
req['statuses']
# Out:
# [{'created_at': 'Sat Aug 08 02:10:24 +0000 2020',
#   'id': 1291919659424534528,
#   'id_str': '1291919659424534528',
#   'text': 'How Data Science is Changing Media, Advertising, and Entertainment https://t.co/LYuw7vtQsF #entertainment',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'entertainment', 'indices': [91, 105]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/LYuw7vtQsF',
#      'expanded_url': 'https://hackernoon.com/how-data-science-is-changing-media-advertising-and-entertainment-j9193xph',
#      'display_url': 'hackernoon.com/how-data-scien…',
#      'indices': [67, 90]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://paper.li" rel="nofollow">Paper.li</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 798285993740763136,
#    'id_str': '798285993740763136',
#    'name': 'Rodrigo Gonzalez',
#    'screen_name': 'rodrigo_blogs',
#    'location': 'Cambridge, MA',
#    'description': 'Adventurer. AI Engineer. Founder & CEO at https://t.co/lE7ozB9v1z and AI Consulting LLC',
#    'url': 'https://t.co/urVGr0AlJu',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/urVGr0AlJu',
#        'expanded_url': 'http://rodrigo.ai',
#        'display_url': 'rodrigo.ai',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/lE7ozB9v1z',
#        'expanded_url': 'http://lendable.ai',
#        'display_url': 'lendable.ai',
#        'indices': [42, 65]}]}},
#    'protected': False,
#    'followers_count': 3736,
#    'friends_count': 416,
#    'listed_count': 2,
#    'created_at': 'Mon Nov 14 22:06:27 +0000 2016',
#    'favourites_count': 55,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1605,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/966738502816710656/DUSOXoFI_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/966738502816710656/DUSOXoFI_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/798285993740763136/1519323421',
#    'profile_link_color': '003153',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:08:53 +0000 2020',
#   'id': 1291919280213233666,
#   'id_str': '1291919280213233666',
#   'text': 'RT @byLilyV: #FEATURED #COURSES\nThe #Data #Science Course 2020: Complete #DataScience Bootcamp\nIn demand skills: #Statistical #analysis\n#Py…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'FEATURED', 'indices': [13, 22]},
#     {'text': 'COURSES', 'indices': [23, 31]},
#     {'text': 'Data', 'indices': [36, 41]},
#     {'text': 'Science', 'indices': [42, 50]},
#     {'text': 'DataScience', 'indices': [73, 85]},
#     {'text': 'Statistical', 'indices': [113, 125]},
#     {'text': 'analysis', 'indices': [126, 135]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'byLilyV',
#      'name': "Lily's Education4you.online",
#      'id': 134434122,
#      'id_str': '134434122',
#      'indices': [3, 11]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1276058041389953024,
#    'id_str': '1276058041389953024',
#    'name': 'The Data Science Bot',
#    'screen_name': 'datasciencebot_',
#    'location': '',
#    'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 627,
#    'friends_count': 1,
#    'listed_count': 16,
#    'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#    'favourites_count': 16,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 62780,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Aug 08 02:08:46 +0000 2020',
#    'id': 1291919247820689408,
#    'id_str': '1291919247820689408',
#    'text': '#FEATURED #COURSES\nThe #Data #Science Course 2020: Complete #DataScience Bootcamp\nIn demand skills: #Statistical… https://t.co/GfuxEqGjgD',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'FEATURED', 'indices': [0, 9]},
#      {'text': 'COURSES', 'indices': [10, 18]},
#      {'text': 'Data', 'indices': [23, 28]},
#      {'text': 'Science', 'indices': [29, 37]},
#      {'text': 'DataScience', 'indices': [60, 72]},
#      {'text': 'Statistical', 'indices': [100, 112]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/GfuxEqGjgD',
#       'expanded_url': 'https://twitter.com/i/web/status/1291919247820689408',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [114, 137]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://app.socialpilot.co/" rel="nofollow">SocialPilot.co</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 134434122,
#     'id_str': '134434122',
#     'name': "Lily's Education4you.online",
#     'screen_name': 'byLilyV',
#     'location': 'Bradford, Yorkshire',
#     'description': 'Education affiliate marketer & lifelong learning coach! I can coach you to a learning experience that strengthens your skills and enhances your personality.',
#     'url': 'https://t.co/s4SwMa3ILp',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/s4SwMa3ILp',
#         'expanded_url': 'https://media4you.social/career-development.html',
#         'display_url': 'media4you.social/career-develop…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 21700,
#     'friends_count': 16859,
#     'listed_count': 367,
#     'created_at': 'Sun Apr 18 11:58:09 +0000 2010',
#     'favourites_count': 3562,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 153364,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C3D4D1',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1286667414873276416/1J-cKwoj_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286667414873276416/1J-cKwoj_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/134434122/1596284600',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'EADEAA',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:08:53 +0000 2020',
#   'id': 1291919277646209024,
#   'id_str': '1291919277646209024',
#   'text': '@NYCNativeSon @kenjilopezalt science is not dogmatic but best when a discussion about data and realizing the truth… https://t.co/lGoi1l8WQF',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'NYCNativeSon',
#      'name': 'Primo',
#      'id': 45842108,
#      'id_str': '45842108',
#      'indices': [0, 13]},
#     {'screen_name': 'kenjilopezalt',
#      'name': 'J. Kenji WEAR A MASK López-Alt',
#      'id': 3793960033,
#      'id_str': '3793960033',
#      'indices': [14, 28]}],
#    'urls': [{'url': 'https://t.co/lGoi1l8WQF',
#      'expanded_url': 'https://twitter.com/i/web/status/1291919277646209024',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': 1291917725749649414,
#   'in_reply_to_status_id_str': '1291917725749649414',
#   'in_reply_to_user_id': 45842108,
#   'in_reply_to_user_id_str': '45842108',
#   'in_reply_to_screen_name': 'NYCNativeSon',
#   'user': {'id': 14420238,
#    'id_str': '14420238',
#    'name': 'Terry Simpson',
#    'screen_name': 'terrysimpson',
#    'location': 'Ventura, CA',
#    'description': 'Surgeon, Virologist // Host of https://t.co/Abv2yAXr96 Podcast // worse half of @producergirl, dad, chef, author, sybarite, skeptic, culinary med',
#    'url': 'https://t.co/PvnewMDLIo',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/PvnewMDLIo',
#        'expanded_url': 'http://yourdoctorsorders.com',
#        'display_url': 'yourdoctorsorders.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/Abv2yAXr96',
#        'expanded_url': 'http://YourDoctorOrders.com',
#        'display_url': 'YourDoctorOrders.com',
#        'indices': [31, 54]}]}},
#    'protected': False,
#    'followers_count': 5392,
#    'friends_count': 225,
#    'listed_count': 372,
#    'created_at': 'Thu Apr 17 13:09:02 +0000 2008',
#    'favourites_count': 1144,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 118496,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'ACDED6',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/925755770372796423/aCakrmEE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/925755770372796423/aCakrmEE_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14420238/1415915394',
#    'profile_link_color': '89C9FA',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:08:51 +0000 2020',
#   'id': 1291919270411218944,
#   'id_str': '1291919270411218944',
#   'text': 'RT @byLilyV: #FEATURED #COURSES\nThe #Data #Science Course 2020: Complete #DataScience Bootcamp\nIn demand skills: #Statistical #analysis\n#Py…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'FEATURED', 'indices': [13, 22]},
#     {'text': 'COURSES', 'indices': [23, 31]},
#     {'text': 'Data', 'indices': [36, 41]},
#     {'text': 'Science', 'indices': [42, 50]},
#     {'text': 'DataScience', 'indices': [73, 85]},
#     {'text': 'Statistical', 'indices': [113, 125]},
#     {'text': 'analysis', 'indices': [126, 135]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'byLilyV',
#      'name': "Lily's Education4you.online",
#      'id': 134434122,
#      'id_str': '134434122',
#      'indices': [3, 11]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://github.com/NTAKPE/trees_of_civ.git" rel="nofollow">trees_of_civ</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1010110483582652416,
#    'id_str': '1010110483582652416',
#    'name': 'Trending Now',
#    'screen_name': 'techtrendingnow',
#    'location': '',
#    'description': 'Follow me for update about what trend in tech right now : GPT-3 | AI | BlockChain etc... Like My Work? plz, Buy Me A coffee: https://t.co/UWL6Aa3dbq',
#    'url': 'https://t.co/UWL6Aa3dbq',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#        'expanded_url': 'https://ko-fi.com/techtrendingnow',
#        'display_url': 'ko-fi.com/techtrendingnow',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#        'expanded_url': 'https://ko-fi.com/techtrendingnow',
#        'display_url': 'ko-fi.com/techtrendingnow',
#        'indices': [125, 148]}]}},
#    'protected': False,
#    'followers_count': 646,
#    'friends_count': 82,
#    'listed_count': 26,
#    'created_at': 'Fri Jun 22 10:41:21 +0000 2018',
#    'favourites_count': 7892,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 52537,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1010110483582652416/1581356400',
#    'profile_link_color': '981CEB',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Aug 08 02:08:46 +0000 2020',
#    'id': 1291919247820689408,
#    'id_str': '1291919247820689408',
#    'text': '#FEATURED #COURSES\nThe #Data #Science Course 2020: Complete #DataScience Bootcamp\nIn demand skills: #Statistical… https://t.co/GfuxEqGjgD',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'FEATURED', 'indices': [0, 9]},
#      {'text': 'COURSES', 'indices': [10, 18]},
#      {'text': 'Data', 'indices': [23, 28]},
#      {'text': 'Science', 'indices': [29, 37]},
#      {'text': 'DataScience', 'indices': [60, 72]},
#      {'text': 'Statistical', 'indices': [100, 112]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/GfuxEqGjgD',
#       'expanded_url': 'https://twitter.com/i/web/status/1291919247820689408',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [114, 137]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://app.socialpilot.co/" rel="nofollow">SocialPilot.co</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 134434122,
#     'id_str': '134434122',
#     'name': "Lily's Education4you.online",
#     'screen_name': 'byLilyV',
#     'location': 'Bradford, Yorkshire',
#     'description': 'Education affiliate marketer & lifelong learning coach! I can coach you to a learning experience that strengthens your skills and enhances your personality.',
#     'url': 'https://t.co/s4SwMa3ILp',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/s4SwMa3ILp',
#         'expanded_url': 'https://media4you.social/career-development.html',
#         'display_url': 'media4you.social/career-develop…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 21700,
#     'friends_count': 16859,
#     'listed_count': 367,
#     'created_at': 'Sun Apr 18 11:58:09 +0000 2010',
#     'favourites_count': 3562,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 153364,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C3D4D1',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1286667414873276416/1J-cKwoj_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286667414873276416/1J-cKwoj_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/134434122/1596284600',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'EADEAA',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:08:46 +0000 2020',
#   'id': 1291919247820689408,
#   'id_str': '1291919247820689408',
#   'text': '#FEATURED #COURSES\nThe #Data #Science Course 2020: Complete #DataScience Bootcamp\nIn demand skills: #Statistical… https://t.co/GfuxEqGjgD',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'FEATURED', 'indices': [0, 9]},
#     {'text': 'COURSES', 'indices': [10, 18]},
#     {'text': 'Data', 'indices': [23, 28]},
#     {'text': 'Science', 'indices': [29, 37]},
#     {'text': 'DataScience', 'indices': [60, 72]},
#     {'text': 'Statistical', 'indices': [100, 112]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/GfuxEqGjgD',
#      'expanded_url': 'https://twitter.com/i/web/status/1291919247820689408',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [114, 137]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://app.socialpilot.co/" rel="nofollow">SocialPilot.co</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 134434122,
#    'id_str': '134434122',
#    'name': "Lily's Education4you.online",
#    'screen_name': 'byLilyV',
#    'location': 'Bradford, Yorkshire',
#    'description': 'Education affiliate marketer & lifelong learning coach! I can coach you to a learning experience that strengthens your skills and enhances your personality.',
#    'url': 'https://t.co/s4SwMa3ILp',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/s4SwMa3ILp',
#        'expanded_url': 'https://media4you.social/career-development.html',
#        'display_url': 'media4you.social/career-develop…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 21700,
#    'friends_count': 16859,
#    'listed_count': 367,
#    'created_at': 'Sun Apr 18 11:58:09 +0000 2010',
#    'favourites_count': 3562,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 153364,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C3D4D1',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1286667414873276416/1J-cKwoj_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286667414873276416/1J-cKwoj_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/134434122/1596284600',
#    'profile_link_color': 'E81C4F',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'EADEAA',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:08:39 +0000 2020',
#   'id': 1291919220234756098,
#   'id_str': '1291919220234756098',
#   'text': 'RT @tflinn1: @NathanMackBrown There are not enough people taking this seriously.  Had we had leadership  that embraced science, and followe…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'tflinn1',
#      'name': 'tflinn1 blue tsunami in Nov',
#      'id': 33032231,
#      'id_str': '33032231',
#      'indices': [3, 11]},
#     {'screen_name': 'NathanMackBrown',
#      'name': 'Nathan Mackenzie Brown 🌎',
#      'id': 993137216309383169,
#      'id_str': '993137216309383169',
#      'indices': [13, 29]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 830096770403278848,
#    'id_str': '830096770403278848',
#    'name': 'sheila leitham',
#    'screen_name': 'tip5063',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 41,
#    'friends_count': 79,
#    'listed_count': 0,
#    'created_at': 'Fri Feb 10 16:51:07 +0000 2017',
#    'favourites_count': 3103,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 3669,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': True,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Aug 07 15:42:33 +0000 2020',
#    'id': 1291761655626555392,
#    'id_str': '1291761655626555392',
#    'text': '@NathanMackBrown There are not enough people taking this seriously.  Had we had leadership  that embraced science,… https://t.co/BKgq3hTn7v',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'NathanMackBrown',
#       'name': 'Nathan Mackenzie Brown 🌎',
#       'id': 993137216309383169,
#       'id_str': '993137216309383169',
#       'indices': [0, 16]}],
#     'urls': [{'url': 'https://t.co/BKgq3hTn7v',
#       'expanded_url': 'https://twitter.com/i/web/status/1291761655626555392',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1291743388346322950,
#    'in_reply_to_status_id_str': '1291743388346322950',
#    'in_reply_to_user_id': 993137216309383169,
#    'in_reply_to_user_id_str': '993137216309383169',
#    'in_reply_to_screen_name': 'NathanMackBrown',
#    'user': {'id': 33032231,
#     'id_str': '33032231',
#     'name': 'tflinn1 blue tsunami in Nov',
#     'screen_name': 'tflinn1',
#     'location': 'Illinois, USA',
#     'description': '#Coronatrumpvirus  Time to turn America TRUE BLUE.  Flip the Senate and deep clean the WH in 2020  I unfollow if not followed back #FBR  🌊🌊🌊🌊',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 13124,
#     'friends_count': 13209,
#     'listed_count': 6,
#     'created_at': 'Sat Apr 18 22:20:47 +0000 2009',
#     'favourites_count': 8260,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 20448,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/828619157801361408/kB1BGoiR_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/828619157801361408/kB1BGoiR_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/33032231/1486393301',
#     'profile_link_color': '19CF86',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 48,
#    'favorite_count': 269,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 48,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:08:09 +0000 2020',
#   'id': 1291919095000993792,
#   'id_str': '1291919095000993792',
#   'text': 'RT @upGrad_edu: Fascinated by the world of Data Science and AI? You aren’t alone. Pursue online PG programs.',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'upGrad_edu',
#      'name': 'upGrad',
#      'id': 3246661627,
#      'id_str': '3246661627',
#      'indices': [3, 14]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1287262099958165505,
#    'id_str': '1287262099958165505',
#    'name': 'Durga prasad Govvala',
#    'screen_name': 'GovvalaPrasad',
#    'location': '',
#    'description': 'Mahesh babu',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 10,
#    'friends_count': 68,
#    'listed_count': 0,
#    'created_at': 'Sun Jul 26 05:43:27 +0000 2020',
#    'favourites_count': 5,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 385,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1287262285539373056/sJul6imb_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1287262285539373056/sJul6imb_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed May 13 09:59:32 +0000 2020',
#    'id': 1260509975681495040,
#    'id_str': '1260509975681495040',
#    'text': 'Fascinated by the world of Data Science and AI? You aren’t alone. Pursue online PG programs.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://ads-api.twitter.com" rel="nofollow">Twitter for Advertisers</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3246661627,
#     'id_str': '3246661627',
#     'name': 'upGrad',
#     'screen_name': 'upGrad_edu',
#     'location': 'Mumbai, Maharashtra',
#     'description': 'Online Programs for Working Professionals',
#     'url': 'https://t.co/JbP6IRZFYX',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/JbP6IRZFYX',
#         'expanded_url': 'http://bit.ly/upGrad_Now',
#         'display_url': 'bit.ly/upGrad_Now',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 80135,
#     'friends_count': 298,
#     'listed_count': 219,
#     'created_at': 'Tue Jun 16 08:23:05 +0000 2015',
#     'favourites_count': 2333,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 4923,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1087257195782246400/iMmsIvvQ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1087257195782246400/iMmsIvvQ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3246661627/1591860661',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 689,
#    'favorite_count': 5420,
#    'favorited': False,
#    'retweeted': False,
#    'scopes': {'followers': False},
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 689,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:08:01 +0000 2020',
#   'id': 1291919060146376704,
#   'id_str': '1291919060146376704',
#   'text': 'RT @machinelearnflx: The Data Science Process https://t.co/dQosuCUHiJ  #DataScience',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DataScience', 'indices': [71, 83]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'machinelearnflx',
#      'name': 'Machine Learning',
#      'id': 4820804277,
#      'id_str': '4820804277',
#      'indices': [3, 19]}],
#    'urls': [{'url': 'https://t.co/dQosuCUHiJ',
#      'expanded_url': 'https://towardsdatascience.com/the-data-science-process-a19eb7ebc41b',
#      'display_url': 'towardsdatascience.com/the-data-scien…',
#      'indices': [46, 69]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2201058138,
#    'id_str': '2201058138',
#    'name': 'Atiqah Nadhirah',
#    'screen_name': 'atiqahnadhirah7',
#    'location': '',
#    'description': 'Actuarial Science & Risk Management | USIM',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 112,
#    'friends_count': 179,
#    'listed_count': 0,
#    'created_at': 'Mon Nov 18 10:21:47 +0000 2013',
#    'favourites_count': 2627,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 2810,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942295251112177665/oC_lX8aw_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942295251112177665/oC_lX8aw_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2201058138/1509846546',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Aug 07 23:58:08 +0000 2020',
#    'id': 1291886374187085832,
#    'id_str': '1291886374187085832',
#    'text': 'The Data Science Process https://t.co/dQosuCUHiJ  #DataScience',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DataScience', 'indices': [50, 62]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/dQosuCUHiJ',
#       'expanded_url': 'https://towardsdatascience.com/the-data-science-process-a19eb7ebc41b',
#       'display_url': 'towardsdatascience.com/the-data-scien…',
#       'indices': [25, 48]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/pythonbot_" rel="nofollow">Postmatico</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 4820804277,
#     'id_str': '4820804277',
#     'name': 'Machine Learning',
#     'screen_name': 'machinelearnflx',
#     'location': '',
#     'description': 'Everything about #MachineLearning, #DeepLearning  #AI  #Bigdata  #Analytics #DataMining, #DataScience',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 83367,
#     'friends_count': 37521,
#     'listed_count': 2140,
#     'created_at': 'Sun Jan 17 11:55:58 +0000 2016',
#     'favourites_count': 147,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 437875,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/688735459892195329/v8sHaWSG_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/688735459892195329/v8sHaWSG_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4820804277/1504968657',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 9,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 6,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:07:45 +0000 2020',
#   'id': 1291918995042467841,
#   'id_str': '1291918995042467841',
#   'text': 'Data Science – 8 Powerful Applications https://t.co/iXsAYAgx9u',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/iXsAYAgx9u',
#      'expanded_url': 'https://is.gd/kHol9Y',
#      'display_url': 'is.gd/kHol9Y',
#      'indices': [39, 62]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://algorithmxlab.com" rel="nofollow">AlgoRevivePost</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 905083291778371584,
#    'id_str': '905083291778371584',
#    'name': 'Algorithm-X Lab - Official Site of AI Insights',
#    'screen_name': 'AlgorithmXLab',
#    'location': 'London, New York, Shanghai, Singapore',
#    'description': 'Algorithm-X Lab provides #ArtificialIntelligence #AI #MachineLearning #DataScience intelligence, insights, market research and events for business leaders.',
#    'url': 'https://t.co/c6TGDqF5kN',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/c6TGDqF5kN',
#        'expanded_url': 'https://algorithmxlab.com/',
#        'display_url': 'algorithmxlab.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1668,
#    'friends_count': 4800,
#    'listed_count': 26,
#    'created_at': 'Tue Sep 05 15:00:47 +0000 2017',
#    'favourites_count': 502,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 10806,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/905085018304724995/Tu0UEzCb_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/905085018304724995/Tu0UEzCb_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/905083291778371584/1527843205',
#    'profile_link_color': '00AA00',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:07:10 +0000 2020',
#   'id': 1291918845872152576,
#   'id_str': '1291918845872152576',
#   'text': '5 Essential Business-Oriented Critical Thinking Skills for Data Science https://t.co/nqpeJ7yyGC',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/nqpeJ7yyGC',
#      'expanded_url': 'https://builtin.com/data-science/five-essential-critical-thinking-skills-data-science',
#      'display_url': 'builtin.com/data-science/f…',
#      'indices': [72, 95]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 332011447,
#    'id_str': '332011447',
#    'name': 'Samuel Wong',
#    'screen_name': 'SamueL_WonG_',
#    'location': 'Melbourne + Hong Kong',
#    'description': 'Founder/Director @DATAFYiNG + Data Geek + Mentor. I help transform raw customer data into actionable insights for better decisions. #datascience #rstats',
#    'url': 'https://t.co/VS87FlFbv0',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/VS87FlFbv0',
#        'expanded_url': 'http://datafying.com.au',
#        'display_url': 'datafying.com.au',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3877,
#    'friends_count': 1096,
#    'listed_count': 400,
#    'created_at': 'Sat Jul 09 02:34:39 +0000 2011',
#    'favourites_count': 10685,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 13683,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838260063798095873/d8XT-HH9_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838260063798095873/d8XT-HH9_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/332011447/1538886946',
#    'profile_link_color': '2F2F2F',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:06:26 +0000 2020',
#   'id': 1291918660903161856,
#   'id_str': '1291918660903161856',
#   'text': 'RT @SitesCourse: #Tableau \nTableau 20 Advanced Training: Master Tableau in Data Science | Course =&gt; https://t.co/9qHUbH8xga\n\n#100DaysOfCode…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'Tableau', 'indices': [17, 25]},
#     {'text': '100DaysOfCode', 'indices': [128, 142]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'SitesCourse',
#      'name': 'Course Sites',
#      'id': 1144063003785961472,
#      'id_str': '1144063003785961472',
#      'indices': [3, 15]}],
#    'urls': [{'url': 'https://t.co/9qHUbH8xga',
# ...
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1148838161973334018/v81tArzc_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1148838161973334018/v81tArzc_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1148832517966798849/1562739255',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Aug 08 02:03:15 +0000 2020',
#    'id': 1291917860168585216,
#    'id_str': '1291917860168585216',
#    'text': '#Tableau \nTableau 20 Advanced Training: Master Tableau in Data Science | Course =&gt; https://t.co/9qHUbH8xga… https://t.co/wOCa0Genco',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Tableau', 'indices': [0, 8]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/9qHUbH8xga',
#       'expanded_url': 'https://cousesites.blogspot.com/2020/08/tableau-20-advanced-training-master.html',
#       'display_url': 'cousesites.blogspot.com/2020/08/tablea…',
#       'indices': [86, 109]},
#      {'url': 'https://t.co/wOCa0Genco',
#       'expanded_url': 'https://twitter.com/i/web/status/1291917860168585216',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [111, 134]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1144063003785961472,
#     'id_str': '1144063003785961472',
#     'name': 'Course Sites',
#     'screen_name': 'SitesCourse',
#     'location': '',
#     'description': 'Coupon Online Courses #udemycoupon #udemy 100% Off, Udemy courses, #udemydiscount, Tutorials Courses, Coupons App, Coupons, Discount Coupons, #udemyFree',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 445,
#     'friends_count': 273,
#     'listed_count': 9,
#     'created_at': 'Thu Jun 27 02:00:50 +0000 2019',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1339,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1144118140319629312/5pj0yCwy_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1144118140319629312/5pj0yCwy_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1144063003785961472/1562819194',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 12,
#    'favorite_count': 4,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 12,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:06:07 +0000 2020',
#   'id': 1291918581819740162,
#   'id_str': '1291918581819740162',
#   'text': 'RT @premiumwriters8: Hire the best company in the industry do your;\nPolitical science\nHealthcare\nEssay due\nBusiness\nMicroeconomics\nEcology…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'premiumwriters8',
#      'name': 'Premium Writers',
#      'id': 1265981955675488256,
#      'id_str': '1265981955675488256',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1265981955675488256,
#    'id_str': '1265981955675488256',
#    'name': 'Premium Writers',
#    'screen_name': 'premiumwriters8',
#    'location': 'New York, USA',
#    'description': '#Paper experts\n#100% legit\n#Plagriarism free\n#reliable 24/7 to handle your #Essays #Tests, #Projects, #Dissertations, #Discussions, #Assignments and more...',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 623,
#    'friends_count': 1555,
#    'listed_count': 0,
#    'created_at': 'Thu May 28 12:24:03 +0000 2020',
#    'favourites_count': 917,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 15213,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1285185537834463232/ohS10XQc_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285185537834463232/ohS10XQc_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1265981955675488256/1594618475',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Aug 07 03:34:03 +0000 2020',
#    'id': 1291578323433328641,
#    'id_str': '1291578323433328641',
#    'text': 'Hire the best company in the industry do your;\nPolitical science\nHealthcare\nEssay due\nBusiness\nMicroeconomics\nEcolo… https://t.co/qLcQtCZK0u',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/qLcQtCZK0u',
#       'expanded_url': 'https://twitter.com/i/web/status/1291578323433328641',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1265981955675488256,
#     'id_str': '1265981955675488256',
#     'name': 'Premium Writers',
#     'screen_name': 'premiumwriters8',
#     'location': 'New York, USA',
#     'description': '#Paper experts\n#100% legit\n#Plagriarism free\n#reliable 24/7 to handle your #Essays #Tests, #Projects, #Dissertations, #Discussions, #Assignments and more...',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 623,
#     'friends_count': 1555,
#     'listed_count': 0,
#     'created_at': 'Thu May 28 12:24:03 +0000 2020',
#     'favourites_count': 917,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 15213,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1285185537834463232/ohS10XQc_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285185537834463232/ohS10XQc_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1265981955675488256/1594618475',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:05:55 +0000 2020',
#   'id': 1291918532477935616,
#   'id_str': '1291918532477935616',
#   'text': 'RT @tflinn1: @NathanMackBrown There are not enough people taking this seriously.  Had we had leadership  that embraced science, and followe…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'tflinn1',
#      'name': 'tflinn1 blue tsunami in Nov',
#      'id': 33032231,
#      'id_str': '33032231',
#      'indices': [3, 11]},
#     {'screen_name': 'NathanMackBrown',
#      'name': 'Nathan Mackenzie Brown 🌎',
#      'id': 993137216309383169,
#      'id_str': '993137216309383169',
#      'indices': [13, 29]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 15050802,
#    'id_str': '15050802',
#    'name': 'jrobison🌊',
#    'screen_name': 'jrobison',
#    'location': 'West Virgina, USA',
#    'description': 'Retired Director of Technology, small private HS. Grandkids, gardening, knitting, pets, reading and social activism fill the days now',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 517,
#    'friends_count': 549,
#    'listed_count': 1,
#    'created_at': 'Sun Jun 08 22:25:04 +0000 2008',
#    'favourites_count': 51676,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 37452,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'EDECE9',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme3/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme3/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/63783439/Judy_normal.JPG',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/63783439/Judy_normal.JPG',
#    'profile_link_color': '088253',
#    'profile_sidebar_border_color': 'D3D2CF',
#    'profile_sidebar_fill_color': 'E3E2DE',
#    'profile_text_color': '634047',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Aug 07 15:42:33 +0000 2020',
#    'id': 1291761655626555392,
#    'id_str': '1291761655626555392',
#    'text': '@NathanMackBrown There are not enough people taking this seriously.  Had we had leadership  that embraced science,… https://t.co/BKgq3hTn7v',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'NathanMackBrown',
#       'name': 'Nathan Mackenzie Brown 🌎',
#       'id': 993137216309383169,
#       'id_str': '993137216309383169',
#       'indices': [0, 16]}],
#     'urls': [{'url': 'https://t.co/BKgq3hTn7v',
#       'expanded_url': 'https://twitter.com/i/web/status/1291761655626555392',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1291743388346322950,
#    'in_reply_to_status_id_str': '1291743388346322950',
#    'in_reply_to_user_id': 993137216309383169,
#    'in_reply_to_user_id_str': '993137216309383169',
#    'in_reply_to_screen_name': 'NathanMackBrown',
#    'user': {'id': 33032231,
#     'id_str': '33032231',
#     'name': 'tflinn1 blue tsunami in Nov',
#     'screen_name': 'tflinn1',
#     'location': 'Illinois, USA',
#     'description': '#Coronatrumpvirus  Time to turn America TRUE BLUE.  Flip the Senate and deep clean the WH in 2020  I unfollow if not followed back #FBR  🌊🌊🌊🌊',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 13124,
#     'friends_count': 13209,
#     'listed_count': 6,
#     'created_at': 'Sat Apr 18 22:20:47 +0000 2009',
#     'favourites_count': 8260,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 20448,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/828619157801361408/kB1BGoiR_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/828619157801361408/kB1BGoiR_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/33032231/1486393301',
#     'profile_link_color': '19CF86',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 48,
#    'favorite_count': 269,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 48,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'}]

# %% [markdown]
# For good measure, try doing a search for tweets relating to `#MeToo` as well.

# %%
# your answer here
query_string = '?q=%23MeToo'

req = requests.get(base_url + query_string, auth=tokens).json()

# %%
# and here are our returned tweets
req['statuses']
# Out:
# [{'created_at': 'Sat Aug 08 02:11:11 +0000 2020',
#   'id': 1291919859358498818,
#   'id_str': '1291919859358498818',
#   'text': '@w_terrence #metoo Do we get to choose the injection site?',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'metoo', 'indices': [12, 18]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'w_terrence',
#      'name': 'Terrence K. Williams',
#      'id': 47293791,
#      'id_str': '47293791',
#      'indices': [0, 11]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': 1291901485152735233,
#   'in_reply_to_status_id_str': '1291901485152735233',
#   'in_reply_to_user_id': 47293791,
#   'in_reply_to_user_id_str': '47293791',
#   'in_reply_to_screen_name': 'w_terrence',
#   'user': {'id': 1163840580788641793,
#    'id_str': '1163840580788641793',
#    'name': 'Katherine Who Believes in Freedom!',
#    'screen_name': 'Katheri60491537',
#    'location': 'USA',
#    'description': "Let's unite to protect our freedom, expose the darkness, embrace the light, and live in joy (our natural state).",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 325,
#    'friends_count': 120,
#    'listed_count': 0,
#    'created_at': 'Tue Aug 20 16:10:08 +0000 2019',
#    'favourites_count': 9796,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 2514,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1163884569701097472/Ih2vYdHK_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1163884569701097472/Ih2vYdHK_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1163840580788641793/1585506828',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:11:00 +0000 2020',
#   'id': 1291919813422587906,
#   'id_str': '1291919813422587906',
#   'text': 'RT @ObtainingBliss: Read this second part of how I got out of an abusive relationship. #metoo #abuse #domesticviolence https://t.co/KHz1vii…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'metoo', 'indices': [87, 93]},
#     {'text': 'abuse', 'indices': [94, 100]},
#     {'text': 'domesticviolence', 'indices': [101, 118]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ObtainingBliss',
#      'name': 'Kirsten from ObtainingBliss',
#      'id': 836700491065126913,
#      'id_str': '836700491065126913',
#      'indices': [3, 18]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://socialbee.io/" rel="nofollow">SocialBee.io v2</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 836700491065126913,
#    'id_str': '836700491065126913',
#    'name': 'Kirsten from ObtainingBliss',
#    'screen_name': 'ObtainingBliss',
#    'location': 'Minnesota, USA',
#    'description': '#TraumaInformedLifeCoach | #Blogger | #NarcAbuseSurvivor Helping Women find their #Bliss https://t.co/RCWjrLEWMU',
#    'url': 'https://t.co/3cZELwSaMA',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/3cZELwSaMA',
#        'expanded_url': 'http://www.ObtainingBliss.com',
#        'display_url': 'ObtainingBliss.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/RCWjrLEWMU',
#        'expanded_url': 'http://www.obtainingbliss.com',
#        'display_url': 'obtainingbliss.com',
#        'indices': [89, 112]}]}},
#    'protected': False,
#    'followers_count': 9697,
#    'friends_count': 10245,
#    'listed_count': 48,
#    'created_at': 'Tue Feb 28 22:11:57 +0000 2017',
#    'favourites_count': 2773,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 6392,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1050144118427406336/rRuUcchk_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1050144118427406336/rRuUcchk_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/836700491065126913/1550508919',
#    'profile_link_color': '211289',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Feb 06 20:44:01 +0000 2020',
#    'id': 1225520545376198661,
#    'id_str': '1225520545376198661',
#    'text': 'Read this second part of how I got out of an abusive relationship. #metoo #abuse #domesticviolence… https://t.co/np8E7AmPDW',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'metoo', 'indices': [67, 73]},
#      {'text': 'abuse', 'indices': [74, 80]},
#      {'text': 'domesticviolence', 'indices': [81, 98]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/np8E7AmPDW',
#       'expanded_url': 'https://twitter.com/i/web/status/1225520545376198661',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [100, 123]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://socialbee.io/" rel="nofollow">SocialBee.io v2</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 836700491065126913,
#     'id_str': '836700491065126913',
#     'name': 'Kirsten from ObtainingBliss',
#     'screen_name': 'ObtainingBliss',
#     'location': 'Minnesota, USA',
#     'description': '#TraumaInformedLifeCoach | #Blogger | #NarcAbuseSurvivor Helping Women find their #Bliss https://t.co/RCWjrLEWMU',
#     'url': 'https://t.co/3cZELwSaMA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/3cZELwSaMA',
#         'expanded_url': 'http://www.ObtainingBliss.com',
#         'display_url': 'ObtainingBliss.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/RCWjrLEWMU',
#         'expanded_url': 'http://www.obtainingbliss.com',
#         'display_url': 'obtainingbliss.com',
#         'indices': [89, 112]}]}},
#     'protected': False,
#     'followers_count': 9697,
#     'friends_count': 10245,
#     'listed_count': 48,
#     'created_at': 'Tue Feb 28 22:11:57 +0000 2017',
#     'favourites_count': 2773,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6392,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1050144118427406336/rRuUcchk_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1050144118427406336/rRuUcchk_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/836700491065126913/1550508919',
#     'profile_link_color': '211289',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:10:58 +0000 2020',
#   'id': 1291919803523846144,
#   'id_str': '1291919803523846144',
#   'text': 'RT @emcc_0611: 分割統治とは、ある者が統治を行うにあたり、被支配者を分割することで統治を容易にする手法。分断統治とも。被支配者同士を争わせ、統治者に矛先が向かうのを避けることができる。\n#竹島 #慰安婦問題 #尖閣諸島 #フェミニズム #MeToo #右翼 #左翼…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': '竹島', 'indices': [100, 103]},
#     {'text': '慰安婦問題', 'indices': [104, 110]},
#     {'text': '尖閣諸島', 'indices': [111, 116]},
#     {'text': 'フェミニズム', 'indices': [117, 124]},
#     {'text': 'MeToo', 'indices': [125, 131]},
#     {'text': '右翼', 'indices': [132, 135]},
#     {'text': '左翼', 'indices': [136, 139]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'emcc_0611',
#      'name': 'emcc_0611',
#      'id': 1198448549345710081,
#      'id_str': '1198448549345710081',
#      'indices': [3, 13]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Mobile Web (M2)</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 999242579458732033,
#    'id_str': '999242579458732033',
#    'name': 'アウトサイダー',
#    'screen_name': '1rAl0VSGi1DBjNi',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 127,
#    'friends_count': 144,
#    'listed_count': 1,
#    'created_at': 'Wed May 23 10:56:10 +0000 2018',
#    'favourites_count': 20047,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 29042,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': True,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Feb 15 01:51:20 +0000 2020',
#    'id': 1228496987479134209,
#    'id_str': '1228496987479134209',
#    'text': '分割統治とは、ある者が統治を行うにあたり、被支配者を分割することで統治を容易にする手法。分断統治とも。被支配者同士を争わせ、統治者に矛先が向かうのを避けることができる。\n#竹島 #慰安婦問題 #尖閣諸島 #フェミニズム… https://t.co/1teie85rRx',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': '竹島', 'indices': [85, 88]},
#      {'text': '慰安婦問題', 'indices': [89, 95]},
#      {'text': '尖閣諸島', 'indices': [96, 101]},
#      {'text': 'フェミニズム', 'indices': [102, 109]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/1teie85rRx',
#       'expanded_url': 'https://twitter.com/i/web/status/1228496987479134209',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [111, 134]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1198448549345710081,
#     'id_str': '1198448549345710081',
#     'name': 'emcc_0611',
#     'screen_name': 'emcc_0611',
#     'location': '',
#     'description': 'アメリカ崩壊→世界の中心はアジアへ\n集団ストーカー加害者勢力のトップが死んだので、書いてはいけないことを書きまくります。\nテクノロジー犯罪 統一教会 在日 イルミナティ ロスチャイルド Gang Stalking Electronic Harassment 日本頑張れ 中国加油 한국파이팅 サブ @emcc_0611s',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 263,
#     'friends_count': 167,
#     'listed_count': 2,
#     'created_at': 'Sun Nov 24 03:49:42 +0000 2019',
#     'favourites_count': 2294,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 410,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 8,
#    'favorite_count': 6,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': True,
#    'lang': 'ja'},
#   'is_quote_status': False,
#   'retweet_count': 8,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'ja'},
#  {'created_at': 'Sat Aug 08 02:10:50 +0000 2020',
#   'id': 1291919768354566145,
#   'id_str': '1291919768354566145',
#   'text': 'RT @AK52979491: #RheaArrestNext #Warriors4SSR #Bollywood #Metooindia \n\nSee how fake #Metoo was used as weapon against innocent #SushantSing…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'RheaArrestNext', 'indices': [16, 31]},
#     {'text': 'Warriors4SSR', 'indices': [32, 45]},
#     {'text': 'Bollywood', 'indices': [46, 56]},
#     {'text': 'Metooindia', 'indices': [57, 68]},
#     {'text': 'Metoo', 'indices': [84, 90]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'AK52979491',
#      'name': 'Nikita K',
#      'id': 1195792006649237504,
#      'id_str': '1195792006649237504',
#      'indices': [3, 14]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 971970549877391366,
#    'id_str': '971970549877391366',
#    'name': 'MRA Uday',
#    'screen_name': 'UdayMra',
#    'location': 'Pune, India',
#    'description': 'Human, Proud MRA member. fight against biased laws. Crime has no gender',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 912,
#    'friends_count': 1259,
#    'listed_count': 0,
#    'created_at': 'Fri Mar 09 04:46:52 +0000 2018',
#    'favourites_count': 3928,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 71003,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1018047762519056384/ZcdAf0Du_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1018047762519056384/ZcdAf0Du_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/971970549877391366/1520578462',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Aug 07 17:10:41 +0000 2020',
#    'id': 1291783836611670016,
#    'id_str': '1291783836611670016',
#    'text': '#RheaArrestNext #Warriors4SSR #Bollywood #Metooindia \n\nSee how fake #Metoo was used as weapon against innocent… https://t.co/WAmOeSGaQR',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'RheaArrestNext', 'indices': [0, 15]},
#      {'text': 'Warriors4SSR', 'indices': [16, 29]},
#      {'text': 'Bollywood', 'indices': [30, 40]},
#      {'text': 'Metooindia', 'indices': [41, 52]},
#      {'text': 'Metoo', 'indices': [68, 74]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/WAmOeSGaQR',
#       'expanded_url': 'https://twitter.com/i/web/status/1291783836611670016',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [112, 135]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1195792006649237504,
#     'id_str': '1195792006649237504',
#     'name': 'Nikita K',
#     'screen_name': 'AK52979491',
#     'location': 'Agra ',
#     'description': 'So grateful to be sharing my thoughts with you. I believe in God and freedom',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 653,
#     'friends_count': 829,
#     'listed_count': 0,
#     'created_at': 'Sat Nov 16 19:53:36 +0000 2019',
#     'favourites_count': 8491,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 10007,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1222972868796903429/NAC3oZWR_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1222972868796903429/NAC3oZWR_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1195792006649237504/1580321632',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 44,
#    'favorite_count': 55,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 44,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:10:16 +0000 2020',
#   'id': 1291919627728179200,
#   'id_str': '1291919627728179200',
#   'text': 'RT @EmG623: Hey whatever happened to that Tara Reade story about Biden #SexualAssualt ing her #Metoo anyone? @MSNBC_Breaking @CNN @ABC @CBS…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'SexualAssualt', 'indices': [71, 85]},
#     {'text': 'Metoo', 'indices': [94, 100]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'EmG623',
#      'name': '𝓔𝓶𝓖',
#      'id': 149705785,
#      'id_str': '149705785',
#      'indices': [3, 10]},
#     {'screen_name': 'MSNBC_Breaking',
#      'name': 'MSNBC Breaking News',
#      'id': 11857072,
#      'id_str': '11857072',
#      'indices': [109, 124]},
#     {'screen_name': 'CNN',
#      'name': 'CNN',
#      'id': 759251,
#      'id_str': '759251',
#      'indices': [125, 129]},
#     {'screen_name': 'ABC',
#      'name': 'ABC News',
#      'id': 28785486,
#      'id_str': '28785486',
#      'indices': [130, 134]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1030862214981410823,
#    'id_str': '1030862214981410823',
#    'name': 'mavalous',
#    'screen_name': 'missmavalous',
#    'location': 'Oxford, MS',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1628,
#    'friends_count': 2214,
#    'listed_count': 1,
#    'created_at': 'Sat Aug 18 17:01:19 +0000 2018',
#    'favourites_count': 33243,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 87723,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1285744641212649472/FSKz4OyF_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285744641212649472/FSKz4OyF_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1030862214981410823/1588953616',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Aug 08 00:55:38 +0000 2020',
#    'id': 1291900844401659904,
#    'id_str': '1291900844401659904',
#    'text': 'Hey whatever happened to that Tara Reade story about Biden #SexualAssualt ing her #Metoo anyone? @MSNBC_Breaking… https://t.co/uUp7bHfltI',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'SexualAssualt', 'indices': [59, 73]},
#      {'text': 'Metoo', 'indices': [82, 88]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'MSNBC_Breaking',
#       'name': 'MSNBC Breaking News',
#       'id': 11857072,
#       'id_str': '11857072',
#       'indices': [97, 112]}],
#     'urls': [{'url': 'https://t.co/uUp7bHfltI',
#       'expanded_url': 'https://twitter.com/i/web/status/1291900844401659904',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [114, 137]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 149705785,
#     'id_str': '149705785',
#     'name': '𝓔𝓶𝓖',
#     'screen_name': 'EmG623',
#     'location': 'AirForce1',
#     'description': '#WalkingSociety Founder. #CashAppInBio $Emilio1321 #TrumpTrain2020',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1682,
#     'friends_count': 5001,
#     'listed_count': 7,
#     'created_at': 'Sun May 30 00:59:30 +0000 2010',
#     'favourites_count': 67466,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 80115,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1282827915558899713/ildLJBAK_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1282827915558899713/ildLJBAK_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/149705785/1592747773',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:10:09 +0000 2020',
#   'id': 1291919598078406657,
#   'id_str': '1291919598078406657',
#   'text': 'RT @RebelSister81: @CaptainVG313 @latimes @RonWLATimes #MeToo #NoMasks',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'MeToo', 'indices': [55, 61]},
#     {'text': 'NoMasks', 'indices': [62, 70]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'RebelSister81',
#      'name': 'Rebel Sister 🇺🇸',
#      'id': 1112198245390925825,
#      'id_str': '1112198245390925825',
#      'indices': [3, 17]},
#     {'screen_name': 'CaptainVG313',
#      'name': '{~CaptainVG313~}',
#      'id': 1191600843683811328,
#      'id_str': '1191600843683811328',
#      'indices': [19, 32]},
#     {'screen_name': 'latimes',
#      'name': 'Los Angeles Times',
#      'id': 16664681,
#      'id_str': '16664681',
#      'indices': [33, 41]},
#     {'screen_name': 'RonWLATimes',
#      'name': 'Ronald D. White',
#      'id': 263938642,
#      'id_str': '263938642',
#      'indices': [42, 54]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 948236086194593794,
#    'id_str': '948236086194593794',
#    'name': 'Jed',
#    'screen_name': 'Jed42253333',
#    'location': '',
#    'description': 'MAGA',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 5440,
#    'friends_count': 5993,
#    'listed_count': 1,
#    'created_at': 'Tue Jan 02 16:54:35 +0000 2018',
#    'favourites_count': 72375,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 159148,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1122159193799028736/v_Z3VTs8_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1122159193799028736/v_Z3VTs8_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Aug 08 02:09:16 +0000 2020',
#    'id': 1291919375465840643,
#    'id_str': '1291919375465840643',
#    'text': '@CaptainVG313 @latimes @RonWLATimes #MeToo #NoMasks',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [36, 42]},
#      {'text': 'NoMasks', 'indices': [43, 51]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'CaptainVG313',
#       'name': '{~CaptainVG313~}',
#       'id': 1191600843683811328,
#       'id_str': '1191600843683811328',
#       'indices': [0, 13]},
#      {'screen_name': 'latimes',
#       'name': 'Los Angeles Times',
#       'id': 16664681,
#       'id_str': '16664681',
#       'indices': [14, 22]},
#      {'screen_name': 'RonWLATimes',
#       'name': 'Ronald D. White',
#       'id': 263938642,
#       'id_str': '263938642',
#       'indices': [23, 35]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': 1291918030470033410,
#    'in_reply_to_status_id_str': '1291918030470033410',
#    'in_reply_to_user_id': 1191600843683811328,
#    'in_reply_to_user_id_str': '1191600843683811328',
#    'in_reply_to_screen_name': 'CaptainVG313',
#    'user': {'id': 1112198245390925825,
#     'id_str': '1112198245390925825',
#     'name': 'Rebel Sister 🇺🇸',
#     'screen_name': 'RebelSister81',
#     'location': 'United States',
#     'description': 'I’m here to support our @POTUS 😊 Independent 🌞💕🇺🇸 Proud Pawnee 👊🏽 Golf Hack🏌🏽\u200d♀️ ND🍀 ‘Bama 🐘 🚫Lists 🚫DMs #MAGA #KAG 🦋 I use naughty words 🤭',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 29504,
#     'friends_count': 30208,
#     'listed_count': 0,
#     'created_at': 'Sun Mar 31 03:41:40 +0000 2019',
#     'favourites_count': 108095,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 116081,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1242415249858453506/eD-Pbwsl_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1242415249858453506/eD-Pbwsl_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1112198245390925825/1595462710',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'},
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'und'},
#  {'created_at': 'Sat Aug 08 02:09:55 +0000 2020',
#   'id': 1291919538565464064,
#   'id_str': '1291919538565464064',
#   'text': '@formerlydoc @munkys33 #metoo',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'metoo', 'indices': [23, 29]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'formerlydoc',
#      'name': 'Doc. Morty, Space Force. 🇺🇸',
#      'id': 2404953078,
#      'id_str': '2404953078',
#      'indices': [0, 12]},
#     {'screen_name': 'munkys33',
#      'name': 'The Pickle probably hates you',
#      'id': 251831341,
#      'id_str': '251831341',
#      'indices': [13, 22]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': 1291914516058562560,
#   'in_reply_to_status_id_str': '1291914516058562560',
#   'in_reply_to_user_id': 2404953078,
#   'in_reply_to_user_id_str': '2404953078',
#   'in_reply_to_screen_name': 'formerlydoc',
#   'user': {'id': 1290615456210935810,
#    'id_str': '1290615456210935810',
#    'name': 'Quick Draw McGraw',
#    'screen_name': 'QDrawMcGraw6',
#    'location': 'Arizona, USA',
#    'description': '#protectthesecond #2A #socialismkills #boogaloo',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 31,
#    'friends_count': 288,
#    'listed_count': 0,
#    'created_at': 'Tue Aug 04 11:48:09 +0000 2020',
#    'favourites_count': 692,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 227,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1290616841350471680/rVcp_gRI_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1290616841350471680/rVcp_gRI_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1290615456210935810/1596542057',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'und'},
#  {'created_at': 'Sat Aug 08 02:09:39 +0000 2020',
#   'id': 1291919471720968195,
#   'id_str': '1291919471720968195',
#   'text': 'RT @RebelSister81: @CaptainVG313 @latimes @RonWLATimes #MeToo #NoMasks',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'MeToo', 'indices': [55, 61]},
#     {'text': 'NoMasks', 'indices': [62, 70]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'RebelSister81',
#      'name': 'Rebel Sister 🇺🇸',
#      'id': 1112198245390925825,
#      'id_str': '1112198245390925825',
#      'indices': [3, 17]},
#     {'screen_name': 'CaptainVG313',
#      'name': '{~CaptainVG313~}',
#      'id': 1191600843683811328,
#      'id_str': '1191600843683811328',
#      'indices': [19, 32]},
#     {'screen_name': 'latimes',
#      'name': 'Los Angeles Times',
#      'id': 16664681,
#      'id_str': '16664681',
#      'indices': [33, 41]},
#     {'screen_name': 'RonWLATimes',
#      'name': 'Ronald D. White',
#      'id': 263938642,
#      'id_str': '263938642',
#      'indices': [42, 54]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1191600843683811328,
#    'id_str': '1191600843683811328',
#    'name': '{~CaptainVG313~}',
#    'screen_name': 'CaptainVG313',
#    'location': 'United States of America',
#    'description': 'Have you ever danced with the devil in the pale moonlight?',
#    'url': 'https://t.co/YUxFQXaMEI',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/YUxFQXaMEI',
#        'expanded_url': 'https://www.derwillezurmacht.com/profile/1-captainvg313/',
#        'display_url': 'derwillezurmacht.com/profile/1-capt…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1671,
#    'friends_count': 1717,
#    'listed_count': 2,
#    'created_at': 'Tue Nov 05 06:19:31 +0000 2019',
#    'favourites_count': 8195,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 38631,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1191601150711091201/N0ofiTn3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1191601150711091201/N0ofiTn3_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1191600843683811328/1572935212',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Aug 08 02:09:16 +0000 2020',
#    'id': 1291919375465840643,
#    'id_str': '1291919375465840643',
#    'text': '@CaptainVG313 @latimes @RonWLATimes #MeToo #NoMasks',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [36, 42]},
#      {'text': 'NoMasks', 'indices': [43, 51]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'CaptainVG313',
#       'name': '{~CaptainVG313~}',
#       'id': 1191600843683811328,
#       'id_str': '1191600843683811328',
#       'indices': [0, 13]},
#      {'screen_name': 'latimes',
#       'name': 'Los Angeles Times',
#       'id': 16664681,
#       'id_str': '16664681',
#       'indices': [14, 22]},
#      {'screen_name': 'RonWLATimes',
#       'name': 'Ronald D. White',
#       'id': 263938642,
#       'id_str': '263938642',
#       'indices': [23, 35]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': 1291918030470033410,
#    'in_reply_to_status_id_str': '1291918030470033410',
#    'in_reply_to_user_id': 1191600843683811328,
#    'in_reply_to_user_id_str': '1191600843683811328',
#    'in_reply_to_screen_name': 'CaptainVG313',
#    'user': {'id': 1112198245390925825,
#     'id_str': '1112198245390925825',
#     'name': 'Rebel Sister 🇺🇸',
#     'screen_name': 'RebelSister81',
#     'location': 'United States',
#     'description': 'I’m here to support our @POTUS 😊 Independent 🌞💕🇺🇸 Proud Pawnee 👊🏽 Golf Hack🏌🏽\u200d♀️ ND🍀 ‘Bama 🐘 🚫Lists 🚫DMs #MAGA #KAG 🦋 I use naughty words 🤭',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 29504,
#     'friends_count': 30208,
#     'listed_count': 0,
#     'created_at': 'Sun Mar 31 03:41:40 +0000 2019',
#     'favourites_count': 108095,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 116081,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1242415249858453506/eD-Pbwsl_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1242415249858453506/eD-Pbwsl_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1112198245390925825/1595462710',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'},
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'und'},
#  {'created_at': 'Sat Aug 08 02:09:20 +0000 2020',
#   'id': 1291919391878262786,
#   'id_str': '1291919391878262786',
#   'text': 'RT @DylanTweetin: Bill Clinton, seen at Epstein’s island with two young girls and credibly accused of rape, will be speaking at the Democra…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'DylanTweetin',
#      'name': 'smells like guillotine spirit🌹🚩🎭',
#      'id': 23404367,
#      'id_str': '23404367',
#      'indices': [3, 16]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2151953562,
#    'id_str': '2151953562',
#    'name': 'Nina Turner 2024',
#    'screen_name': 'RecoveredCons',
#    'location': 'Declare Independence Again',
#    'description': '#Progressives will change the world. Not neolibs & not conservatives. #NoMiddleGround #SocialistNow #DemExit2020 #DemocraticSocialism',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 991,
#    'friends_count': 927,
#    'listed_count': 172,
#    'created_at': 'Thu Oct 24 00:50:58 +0000 2013',
#    'favourites_count': 126749,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 152409,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1281707259677085704/l4NhVcAt_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1281707259677085704/l4NhVcAt_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2151953562/1594417798',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Aug 07 16:24:08 +0000 2020',
#    'id': 1291772120305790979,
#    'id_str': '1291772120305790979',
#    'text': 'Bill Clinton, seen at Epstein’s island with two young girls and credibly accused of rape, will be speaking at the D… https://t.co/m2tHljeAv4',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/m2tHljeAv4',
#       'expanded_url': 'https://twitter.com/i/web/status/1291772120305790979',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 23404367,
#     'id_str': '23404367',
#     'name': 'smells like guillotine spirit🌹🚩🎭',
#     'screen_name': 'DylanTweetin',
#     'location': 'Los Angeles',
#     'description': 'LA stereotype. Fernando Tatis Jr admirer. SAG-AFTRA. Socialist. #BlackLivesMatter #NoMoreWars #AbolishICE #Medicare4All #FreePalestine #DefundThePolice he/him',
#     'url': 'https://t.co/FI2FZi2QSl',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/FI2FZi2QSl',
#         'expanded_url': 'http://m.imdb.com/name/nm3198494/?ref=m_nv_sr_1',
#         'display_url': 'm.imdb.com/name/nm3198494…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4277,
#     'friends_count': 4999,
#     'listed_count': 53,
#     'created_at': 'Mon Mar 09 05:02:37 +0000 2009',
#     'favourites_count': 68443,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 47241,
#     'lang': None,
#     'contributors_enabled': False,
# ...
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': 1291916326051741696,
#   'in_reply_to_status_id_str': '1291916326051741696',
#   'in_reply_to_user_id': 1271261478298030082,
#   'in_reply_to_user_id_str': '1271261478298030082',
#   'in_reply_to_screen_name': 'TrumpLola',
#   'user': {'id': 1205129782603796483,
#    'id_str': '1205129782603796483',
#    'name': 'MAGA Rex',
#    'screen_name': 'AultmanRex',
#    'location': 'Fort Lauderdale, Florida',
#    'description': "#MAGA  America First/beer fueled tweets...excuse my typos\nA sinner who tries to walk straight/Mini 14 fan\nRet NAVY/voting RED till I'm DEAD/Come and Take it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4173,
#    'friends_count': 5000,
#    'listed_count': 0,
#    'created_at': 'Thu Dec 12 14:18:33 +0000 2019',
#    'favourites_count': 29512,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 25791,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1205130039467167746/yaodF5su_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1205130039467167746/yaodF5su_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1205129782603796483/1591065520',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'und'},
#  {'created_at': 'Sat Aug 08 02:07:04 +0000 2020',
#   'id': 1291918821339455489,
#   'id_str': '1291918821339455489',
#   'text': '@prayingmedic #MeToo',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'MeToo', 'indices': [14, 20]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'prayingmedic',
#      'name': 'Praying Medic',
#      'id': 83932539,
#      'id_str': '83932539',
#      'indices': [0, 13]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'in_reply_to_status_id': 1291830891757494273,
#   'in_reply_to_status_id_str': '1291830891757494273',
#   'in_reply_to_user_id': 83932539,
#   'in_reply_to_user_id_str': '83932539',
#   'in_reply_to_screen_name': 'prayingmedic',
#   'user': {'id': 456908065,
#    'id_str': '456908065',
#    'name': 'EveJustWantedToKnowShit⏳',
#    'screen_name': 'myfinewords',
#    'location': 'Wilseyville, CA',
#    'description': 'Writer, Editor, GenX Gal 😎 #MakeCaliforniaGreatAgain 😎 #SuckItGavin 😎#TheConspiracyTheoryOfEverything 😎 #Globalese 😎 #JohnCusackIsADouche',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 14821,
#    'friends_count': 16373,
#    'listed_count': 25,
#    'created_at': 'Fri Jan 06 20:16:19 +0000 2012',
#    'favourites_count': 126358,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 78806,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1216414375063388160/Ze_VfZ9p_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1216414375063388160/Ze_VfZ9p_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/456908065/1588454430',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'und'},
#  {'created_at': 'Sat Aug 08 02:06:43 +0000 2020',
#   'id': 1291918735138107392,
#   'id_str': '1291918735138107392',
#   'text': '@CC62235800 @xx55xx55_hi @shiikazuo 日本の恥は安倍晋三\nhttps://t.co/Ig0JSVywS7\n放送後の反響\nイブニング・スタンダードも番組を取り上げ「自分たちの居場所から、#MeToo… https://t.co/SYwmFOEJuQ',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'MeToo', 'indices': [109, 115]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'CC62235800',
#      'name': 'CC',
#      'id': 1255522056998920201,
#      'id_str': '1255522056998920201',
#      'indices': [0, 11]},
#     {'screen_name': 'xx55xx55_hi',
#      'name': 'hi',
#      'id': 3221939244,
#      'id_str': '3221939244',
#      'indices': [12, 24]},
#     {'screen_name': 'shiikazuo',
#      'name': '志位和夫',
#      'id': 1409223888,
#      'id_str': '1409223888',
#      'indices': [25, 35]}],
#    'urls': [{'url': 'https://t.co/Ig0JSVywS7',
#      'expanded_url': 'https://www.bbc.com/japanese/features-and-analysis-44638987',
#      'display_url': 'bbc.com/japanese/featu…',
#      'indices': [46, 69]},
#     {'url': 'https://t.co/SYwmFOEJuQ',
#      'expanded_url': 'https://twitter.com/i/web/status/1291918735138107392',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': 1291907930170601472,
#   'in_reply_to_status_id_str': '1291907930170601472',
#   'in_reply_to_user_id': 1255522056998920201,
#   'in_reply_to_user_id_str': '1255522056998920201',
#   'in_reply_to_screen_name': 'CC62235800',
#   'user': {'id': 1616583126,
#    'id_str': '1616583126',
#    'name': 't.takano',
#    'screen_name': 'kumitaka2',
#    'location': '',
#    'description': '古代史を語る方が好きなのだがいつの間にか政治垢になってしまった。\n歴史にも政治にもウソが多く、騙されている無知な人間が多い。',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 148,
#    'friends_count': 105,
#    'listed_count': 5,
#    'created_at': 'Wed Jul 24 02:26:20 +0000 2013',
#    'favourites_count': 12539,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 3487,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1275411214525317120/5URchD9S_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1275411214525317120/5URchD9S_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1616583126/1561626515',
#    'profile_link_color': '7FDBB6',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'ja'},
#  {'created_at': 'Sat Aug 08 02:05:50 +0000 2020',
#   'id': 1291918513624555520,
#   'id_str': '1291918513624555520',
#   'text': '#powercorrupts #selfrighteous #Hypocrites #GOPCorruption \n@GOP @Conservatives @cwima #MeToo @latimes @foxnews… https://t.co/bQ19VqO2on',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'powercorrupts', 'indices': [0, 14]},
#     {'text': 'selfrighteous', 'indices': [15, 29]},
#     {'text': 'Hypocrites', 'indices': [30, 41]},
#     {'text': 'GOPCorruption', 'indices': [42, 56]},
#     {'text': 'MeToo', 'indices': [85, 91]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'GOP',
#      'name': 'GOP',
#      'id': 11134252,
#      'id_str': '11134252',
#      'indices': [58, 62]},
#     {'screen_name': 'Conservatives',
#      'name': 'Conservatives #StayAlert',
#      'id': 14281853,
#      'id_str': '14281853',
#      'indices': [63, 77]},
#     {'screen_name': 'cwima',
#      'name': 'ChristianWomennMedia',
#      'id': 348510185,
#      'id_str': '348510185',
#      'indices': [78, 84]},
#     {'screen_name': 'latimes',
#      'name': 'Los Angeles Times',
#      'id': 16664681,
#      'id_str': '16664681',
#      'indices': [92, 100]},
#     {'screen_name': 'FoxNews',
#      'name': 'Fox News',
#      'id': 1367531,
#      'id_str': '1367531',
#      'indices': [101, 109]}],
#    'urls': [{'url': 'https://t.co/bQ19VqO2on',
#      'expanded_url': 'https://twitter.com/i/web/status/1291918513624555520',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [111, 134]}]},
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 859934392696938498,
#    'id_str': '859934392696938498',
#    'name': 'IMPEACHED Donald J Trump',
#    'screen_name': 'SVDINDICTTRUMP',
#    'location': '',
#    'description': 'Save Democracy Impeach Trump -Educational media/credible sources',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 32,
#    'friends_count': 15,
#    'listed_count': 0,
#    'created_at': 'Thu May 04 00:55:10 +0000 2017',
#    'favourites_count': 85,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4730,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1210396658581807105/Ij6PkSro_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1210396658581807105/Ij6PkSro_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/859934392696938498/1528162656',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'und'},
#  {'created_at': 'Sat Aug 08 02:05:22 +0000 2020',
#   'id': 1291918395944964098,
#   'id_str': '1291918395944964098',
#   'text': '@AngelHe33778004 @realDonaldTrump I second that!!!!  sick of this schitt!! @Reeseysnotsorry @TeresaBacon20… https://t.co/cMw7A4M6rZ',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'AngelHe33778004',
#      'name': 'Angel Heart',
#      'id': 1207138933894717440,
#      'id_str': '1207138933894717440',
#      'indices': [0, 16]},
#     {'screen_name': 'realDonaldTrump',
#      'name': 'Donald J. Trump',
#      'id': 25073877,
#      'id_str': '25073877',
#      'indices': [17, 33]},
#     {'screen_name': 'Reeseysnotsorry',
#      'name': '🦉Reesey Kaminski @Reeseysnotsorry Parler',
#      'id': 65825692,
#      'id_str': '65825692',
#      'indices': [75, 91]},
#     {'screen_name': 'TeresaBacon20',
#      'name': 'Teresa Bacon 🇺🇸 Trump 2020',
#      'id': 1244690585392463872,
#      'id_str': '1244690585392463872',
#      'indices': [92, 106]}],
#    'urls': [{'url': 'https://t.co/cMw7A4M6rZ',
#      'expanded_url': 'https://twitter.com/i/web/status/1291918395944964098',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [108, 131]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': 1291900656333262848,
#   'in_reply_to_status_id_str': '1291900656333262848',
#   'in_reply_to_user_id': 1207138933894717440,
#   'in_reply_to_user_id_str': '1207138933894717440',
#   'in_reply_to_screen_name': 'AngelHe33778004',
#   'user': {'id': 705885314,
#    'id_str': '705885314',
#    'name': 'Independence Flush',
#    'screen_name': 'flushthefouls',
#    'location': 'USA',
#    'description': 'Right wing, red neck, rifle rack, revolutionary\r\nGOD BLESS THE UNITED STATES OF AMERICA AND THE MEN AND WOMEN WHO PROTECT HER',
#    'url': 'https://t.co/Afvj0bCU1f',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/Afvj0bCU1f',
#        'expanded_url': 'http://iwflush.blogspot.com',
#        'display_url': 'iwflush.blogspot.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 16,
#    'friends_count': 80,
#    'listed_count': 0,
#    'created_at': 'Thu Jul 19 22:15:11 +0000 2012',
#    'favourites_count': 15,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 86,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2413516742/hm4dzy66avsr4e23r4j6_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2413516742/hm4dzy66avsr4e23r4j6_normal.jpeg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'}]

# %% [markdown]
# **Step 2:  Adding Parameters to Your Query String**

# %% [markdown]
# Query strings basically have two parts:
#
#  - What follows fhe `?` encodes the actual text to search for, using utf-8 encoding to account for special characters.  This is required.
#  - You can also add additional search parameters, which are encoded by `&`. They dictate what kinds of results are returned.
#   - For example, a parameter you can use in Twitter's search API is `count`, which tells you how many results to return.  The default is 15, but you can return up to 100.  So if we wanted to search for tweets and return 50 results our query string would look like the following:
#     `https://api.twitter.com/1.1/search/tweets.json?My%20Search%20String&count=50`
#   - You can add as many of these parameters to your string as you'd like.  So for example, if we wanted to include parameters for `count` and `result_type`, we could do the following: `https://api.twitter.com/1.1/search/tweets.json?My%20Search%20String&count=50&result_type=mixed`
#
# To get the hang of this, try searching for tweets that mention the hashtag `#DeepLearning`, and return 75 results.

# %%
# our search string
query_string = '?q=%23DeepLearning&count=75'
# initiate a request at this endpoint
results = requests.get(base_url+query_string, auth=tokens).json()

# %%
# and now we have our results!
results['statuses']
# Out:
# [{'created_at': 'Sat Aug 08 02:11:04 +0000 2020',
#   'id': 1291919829541302273,
#   'id_str': '1291919829541302273',
#   'text': 'RT @jamilahmed_16: #DeepLearning Review\n\nhttps://t.co/bZaPnOXEdZ\n\n#DataScience #dataviz #DataScientist #Python #rstats #100DaysOfCode #ML #…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [19, 32]},
#     {'text': 'DataScience', 'indices': [66, 78]},
#     {'text': 'dataviz', 'indices': [79, 87]},
#     {'text': 'DataScientist', 'indices': [88, 102]},
#     {'text': 'Python', 'indices': [103, 110]},
#     {'text': 'rstats', 'indices': [111, 118]},
#     {'text': '100DaysOfCode', 'indices': [119, 133]},
#     {'text': 'ML', 'indices': [134, 137]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'jamilahmed_16',
#      'name': 'Jamil Ahmed #BusinessIntelligence',
#      'id': 1142396855252205568,
#      'id_str': '1142396855252205568',
#      'indices': [3, 17]}],
#    'urls': [{'url': 'https://t.co/bZaPnOXEdZ',
#      'expanded_url': 'https://bit.ly/2Q8i3WB',
#      'display_url': 'bit.ly/2Q8i3WB',
#      'indices': [41, 64]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://github.com/NTAKPE/trees_of_civ.git" rel="nofollow">trees_of_civ</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1010110483582652416,
#    'id_str': '1010110483582652416',
#    'name': 'Trending Now',
#    'screen_name': 'techtrendingnow',
#    'location': '',
#    'description': 'Follow me for update about what trend in tech right now : GPT-3 | AI | BlockChain etc... Like My Work? plz, Buy Me A coffee: https://t.co/UWL6Aa3dbq',
#    'url': 'https://t.co/UWL6Aa3dbq',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#        'expanded_url': 'https://ko-fi.com/techtrendingnow',
#        'display_url': 'ko-fi.com/techtrendingnow',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#        'expanded_url': 'https://ko-fi.com/techtrendingnow',
#        'display_url': 'ko-fi.com/techtrendingnow',
#        'indices': [125, 148]}]}},
#    'protected': False,
#    'followers_count': 646,
#    'friends_count': 82,
#    'listed_count': 26,
#    'created_at': 'Fri Jun 22 10:41:21 +0000 2018',
#    'favourites_count': 7892,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 52539,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1010110483582652416/1581356400',
#    'profile_link_color': '981CEB',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Aug 07 12:50:45 +0000 2020',
#    'id': 1291718421197893632,
#    'id_str': '1291718421197893632',
#    'text': '#DeepLearning Review\n\nhttps://t.co/bZaPnOXEdZ\n\n#DataScience #dataviz #DataScientist #Python #rstats #100DaysOfCode… https://t.co/5zHRa4ljsH',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [0, 13]},
#      {'text': 'DataScience', 'indices': [47, 59]},
#      {'text': 'dataviz', 'indices': [60, 68]},
#      {'text': 'DataScientist', 'indices': [69, 83]},
#      {'text': 'Python', 'indices': [84, 91]},
#      {'text': 'rstats', 'indices': [92, 99]},
#      {'text': '100DaysOfCode', 'indices': [100, 114]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/bZaPnOXEdZ',
#       'expanded_url': 'https://bit.ly/2Q8i3WB',
#       'display_url': 'bit.ly/2Q8i3WB',
#       'indices': [22, 45]},
#      {'url': 'https://t.co/5zHRa4ljsH',
#       'expanded_url': 'https://twitter.com/i/web/status/1291718421197893632',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1142396855252205568,
#     'id_str': '1142396855252205568',
#     'name': 'Jamil Ahmed #BusinessIntelligence',
#     'screen_name': 'jamilahmed_16',
#     'location': '',
#     'description': 'CEO @reinforcelabtwt ¦ Pharmacist ¦ Personal Branding ¦ Social Media Marketing, Small Business & ecommerce Expert. No #3 #BI Marketing #Influencer by Onalytica.',
#     'url': 'https://t.co/0VuM3IrdpS',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/0VuM3IrdpS',
#         'expanded_url': 'http://reinforcelab.com',
#         'display_url': 'reinforcelab.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1427,
#     'friends_count': 1404,
#     'listed_count': 20,
#     'created_at': 'Sat Jun 22 11:40:09 +0000 2019',
#     'favourites_count': 3895,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 5505,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1269190715692642305/J9jFN4aA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1269190715692642305/J9jFN4aA_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1142396855252205568/1561549949',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 42,
#    'favorite_count': 11,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 42,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:11:04 +0000 2020',
#   'id': 1291919828769476610,
#   'id_str': '1291919828769476610',
#   'text': 'RT @jamilahmed_16: #DeepLearning Review\n\nhttps://t.co/bZaPnOXEdZ\n\n#DataScience #dataviz #DataScientist #Python #rstats #100DaysOfCode #ML #…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [19, 32]},
#     {'text': 'DataScience', 'indices': [66, 78]},
#     {'text': 'dataviz', 'indices': [79, 87]},
#     {'text': 'DataScientist', 'indices': [88, 102]},
#     {'text': 'Python', 'indices': [103, 110]},
#     {'text': 'rstats', 'indices': [111, 118]},
#     {'text': '100DaysOfCode', 'indices': [119, 133]},
#     {'text': 'ML', 'indices': [134, 137]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'jamilahmed_16',
#      'name': 'Jamil Ahmed #BusinessIntelligence',
#      'id': 1142396855252205568,
#      'id_str': '1142396855252205568',
#      'indices': [3, 17]}],
#    'urls': [{'url': 'https://t.co/bZaPnOXEdZ',
#      'expanded_url': 'https://bit.ly/2Q8i3WB',
#      'display_url': 'bit.ly/2Q8i3WB',
#      'indices': [41, 64]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://adam-spice.online" rel="nofollow">GnutsBot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1266133633389060097,
#    'id_str': '1266133633389060097',
#    'name': 'Gnuts about Code',
#    'screen_name': 'CodeGnuts',
#    'location': '',
#    'description': 'Just a bot helping coders show their progress. Automation built in #NodeJs by @AdamSpiceOnline. #100DaysOfCode',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1605,
#    'friends_count': 0,
#    'listed_count': 36,
#    'created_at': 'Thu May 28 22:26:07 +0000 2020',
#    'favourites_count': 32738,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 205191,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1266134298429517824/Gxv_xYd7_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1266134298429517824/Gxv_xYd7_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1266133633389060097/1590708060',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Aug 07 12:50:45 +0000 2020',
#    'id': 1291718421197893632,
#    'id_str': '1291718421197893632',
#    'text': '#DeepLearning Review\n\nhttps://t.co/bZaPnOXEdZ\n\n#DataScience #dataviz #DataScientist #Python #rstats #100DaysOfCode… https://t.co/5zHRa4ljsH',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [0, 13]},
#      {'text': 'DataScience', 'indices': [47, 59]},
#      {'text': 'dataviz', 'indices': [60, 68]},
#      {'text': 'DataScientist', 'indices': [69, 83]},
#      {'text': 'Python', 'indices': [84, 91]},
#      {'text': 'rstats', 'indices': [92, 99]},
#      {'text': '100DaysOfCode', 'indices': [100, 114]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/bZaPnOXEdZ',
#       'expanded_url': 'https://bit.ly/2Q8i3WB',
#       'display_url': 'bit.ly/2Q8i3WB',
#       'indices': [22, 45]},
#      {'url': 'https://t.co/5zHRa4ljsH',
#       'expanded_url': 'https://twitter.com/i/web/status/1291718421197893632',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1142396855252205568,
#     'id_str': '1142396855252205568',
#     'name': 'Jamil Ahmed #BusinessIntelligence',
#     'screen_name': 'jamilahmed_16',
#     'location': '',
#     'description': 'CEO @reinforcelabtwt ¦ Pharmacist ¦ Personal Branding ¦ Social Media Marketing, Small Business & ecommerce Expert. No #3 #BI Marketing #Influencer by Onalytica.',
#     'url': 'https://t.co/0VuM3IrdpS',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/0VuM3IrdpS',
#         'expanded_url': 'http://reinforcelab.com',
#         'display_url': 'reinforcelab.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1427,
#     'friends_count': 1404,
#     'listed_count': 20,
#     'created_at': 'Sat Jun 22 11:40:09 +0000 2019',
#     'favourites_count': 3895,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 5505,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1269190715692642305/J9jFN4aA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1269190715692642305/J9jFN4aA_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1142396855252205568/1561549949',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 42,
#    'favorite_count': 11,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 42,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:10:59 +0000 2020',
#   'id': 1291919807068008448,
#   'id_str': '1291919807068008448',
#   'text': 'RT @jamilahmed_16: #DeepLearning Review\n\nhttps://t.co/bZaPnOXEdZ\n\n#DataScience #dataviz #DataScientist #Python #rstats #100DaysOfCode #ML #…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [19, 32]},
#     {'text': 'DataScience', 'indices': [66, 78]},
#     {'text': 'dataviz', 'indices': [79, 87]},
#     {'text': 'DataScientist', 'indices': [88, 102]},
#     {'text': 'Python', 'indices': [103, 110]},
#     {'text': 'rstats', 'indices': [111, 118]},
#     {'text': '100DaysOfCode', 'indices': [119, 133]},
#     {'text': 'ML', 'indices': [134, 137]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'jamilahmed_16',
#      'name': 'Jamil Ahmed #BusinessIntelligence',
#      'id': 1142396855252205568,
#      'id_str': '1142396855252205568',
#      'indices': [3, 17]}],
#    'urls': [{'url': 'https://t.co/bZaPnOXEdZ',
#      'expanded_url': 'https://bit.ly/2Q8i3WB',
#      'display_url': 'bit.ly/2Q8i3WB',
#      'indices': [41, 64]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1142396855252205568,
#    'id_str': '1142396855252205568',
#    'name': 'Jamil Ahmed #BusinessIntelligence',
#    'screen_name': 'jamilahmed_16',
#    'location': '',
#    'description': 'CEO @reinforcelabtwt ¦ Pharmacist ¦ Personal Branding ¦ Social Media Marketing, Small Business & ecommerce Expert. No #3 #BI Marketing #Influencer by Onalytica.',
#    'url': 'https://t.co/0VuM3IrdpS',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/0VuM3IrdpS',
#        'expanded_url': 'http://reinforcelab.com',
#        'display_url': 'reinforcelab.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1427,
#    'friends_count': 1404,
#    'listed_count': 20,
#    'created_at': 'Sat Jun 22 11:40:09 +0000 2019',
#    'favourites_count': 3895,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 5505,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1269190715692642305/J9jFN4aA_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1269190715692642305/J9jFN4aA_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1142396855252205568/1561549949',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Aug 07 12:50:45 +0000 2020',
#    'id': 1291718421197893632,
#    'id_str': '1291718421197893632',
#    'text': '#DeepLearning Review\n\nhttps://t.co/bZaPnOXEdZ\n\n#DataScience #dataviz #DataScientist #Python #rstats #100DaysOfCode… https://t.co/5zHRa4ljsH',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [0, 13]},
#      {'text': 'DataScience', 'indices': [47, 59]},
#      {'text': 'dataviz', 'indices': [60, 68]},
#      {'text': 'DataScientist', 'indices': [69, 83]},
#      {'text': 'Python', 'indices': [84, 91]},
#      {'text': 'rstats', 'indices': [92, 99]},
#      {'text': '100DaysOfCode', 'indices': [100, 114]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/bZaPnOXEdZ',
#       'expanded_url': 'https://bit.ly/2Q8i3WB',
#       'display_url': 'bit.ly/2Q8i3WB',
#       'indices': [22, 45]},
#      {'url': 'https://t.co/5zHRa4ljsH',
#       'expanded_url': 'https://twitter.com/i/web/status/1291718421197893632',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1142396855252205568,
#     'id_str': '1142396855252205568',
#     'name': 'Jamil Ahmed #BusinessIntelligence',
#     'screen_name': 'jamilahmed_16',
#     'location': '',
#     'description': 'CEO @reinforcelabtwt ¦ Pharmacist ¦ Personal Branding ¦ Social Media Marketing, Small Business & ecommerce Expert. No #3 #BI Marketing #Influencer by Onalytica.',
#     'url': 'https://t.co/0VuM3IrdpS',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/0VuM3IrdpS',
#         'expanded_url': 'http://reinforcelab.com',
#         'display_url': 'reinforcelab.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1427,
#     'friends_count': 1404,
#     'listed_count': 20,
#     'created_at': 'Sat Jun 22 11:40:09 +0000 2019',
#     'favourites_count': 3895,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 5505,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1269190715692642305/J9jFN4aA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1269190715692642305/J9jFN4aA_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1142396855252205568/1561549949',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 42,
#    'favorite_count': 11,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 42,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:09:46 +0000 2020',
#   'id': 1291919503018938368,
#   'id_str': '1291919503018938368',
#   'text': 'RT @PawlowskiMario: According to #Google, as #AI becomes more advanced, it becomes more aggressive.\n\nMT @abhishek__AI #ML #GoogleAI  #IoT #…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'Google', 'indices': [33, 40]},
#     {'text': 'AI', 'indices': [45, 48]},
#     {'text': 'ML', 'indices': [118, 121]},
#     {'text': 'GoogleAI', 'indices': [122, 131]},
#     {'text': 'IoT', 'indices': [133, 137]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'PawlowskiMario',
#      'name': 'Mario Pawlowski 🇵🇱🇺🇸🇪🇺🌎⚽️',
#      'id': 968008274003005440,
#      'id_str': '968008274003005440',
#      'indices': [3, 18]},
#     {'screen_name': 'abhishek__AI',
#      'name': 'Abhishek Yadav',
#      'id': 715774453423206401,
#      'id_str': '715774453423206401',
#      'indices': [104, 117]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://github.com/NTAKPE/trees_of_civ.git" rel="nofollow">trees_of_civ</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1010110483582652416,
#    'id_str': '1010110483582652416',
#    'name': 'Trending Now',
#    'screen_name': 'techtrendingnow',
#    'location': '',
#    'description': 'Follow me for update about what trend in tech right now : GPT-3 | AI | BlockChain etc... Like My Work? plz, Buy Me A coffee: https://t.co/UWL6Aa3dbq',
#    'url': 'https://t.co/UWL6Aa3dbq',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#        'expanded_url': 'https://ko-fi.com/techtrendingnow',
#        'display_url': 'ko-fi.com/techtrendingnow',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#        'expanded_url': 'https://ko-fi.com/techtrendingnow',
#        'display_url': 'ko-fi.com/techtrendingnow',
#        'indices': [125, 148]}]}},
#    'protected': False,
#    'followers_count': 646,
#    'friends_count': 82,
#    'listed_count': 26,
#    'created_at': 'Fri Jun 22 10:41:21 +0000 2018',
#    'favourites_count': 7892,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 52539,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1010110483582652416/1581356400',
#    'profile_link_color': '981CEB',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Aug 05 00:32:27 +0000 2020',
#    'id': 1290807847949926404,
#    'id_str': '1290807847949926404',
#    'text': 'According to #Google, as #AI becomes more advanced, it becomes more aggressive.\n\nMT @abhishek__AI #ML #GoogleAI… https://t.co/n6BHbOKdQb',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Google', 'indices': [13, 20]},
#      {'text': 'AI', 'indices': [25, 28]},
#      {'text': 'ML', 'indices': [98, 101]},
#      {'text': 'GoogleAI', 'indices': [102, 111]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'abhishek__AI',
#       'name': 'Abhishek Yadav',
#       'id': 715774453423206401,
#       'id_str': '715774453423206401',
#       'indices': [84, 97]}],
#     'urls': [{'url': 'https://t.co/n6BHbOKdQb',
#       'expanded_url': 'https://twitter.com/i/web/status/1290807847949926404',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [113, 136]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 968008274003005440,
#     'id_str': '968008274003005440',
#     'name': 'Mario Pawlowski 🇵🇱🇺🇸🇪🇺🌎⚽️',
#     'screen_name': 'PawlowskiMario',
#     'location': 'Chicago IL',
#     'description': '#CEO @iTrucker_ |Social Media #Influencer #SMM #Chef #AI #AIEthics #Future #DigitalTransformation #SupplyChain #Drones #AR #VR #Megatrends #History',
#     'url': 'https://t.co/EF9lWTlKuW',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/EF9lWTlKuW',
#         'expanded_url': 'https://itrucker.com',
#         'display_url': 'itrucker.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 14976,
#     'friends_count': 8721,
#     'listed_count': 118,
#     'created_at': 'Mon Feb 26 06:22:12 +0000 2018',
#     'favourites_count': 33645,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 11638,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1235847748802375680/dtB9LH_T_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1235847748802375680/dtB9LH_T_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 87,
#    'favorite_count': 106,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 87,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:09:41 +0000 2020',
#   'id': 1291919479966965760,
#   'id_str': '1291919479966965760',
#   'text': 'RT @PawlowskiMario: According to #Google, as #AI becomes more advanced, it becomes more aggressive.\n\nMT @abhishek__AI #ML #GoogleAI  #IoT #…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'Google', 'indices': [33, 40]},
#     {'text': 'AI', 'indices': [45, 48]},
#     {'text': 'ML', 'indices': [118, 121]},
#     {'text': 'GoogleAI', 'indices': [122, 131]},
#     {'text': 'IoT', 'indices': [133, 137]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'PawlowskiMario',
#      'name': 'Mario Pawlowski 🇵🇱🇺🇸🇪🇺🌎⚽️',
#      'id': 968008274003005440,
#      'id_str': '968008274003005440',
#      'indices': [3, 18]},
#     {'screen_name': 'abhishek__AI',
#      'name': 'Abhishek Yadav',
#      'id': 715774453423206401,
#      'id_str': '715774453423206401',
#      'indices': [104, 117]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1095556823569051648,
#    'id_str': '1095556823569051648',
#    'name': 'staphylococcus aureus',
#    'screen_name': 'luxurytechappa1',
#    'location': 'Paradise',
#    'description': '#ux #ui #ai #vui #tech #fashionandtech #beautyandtech #digitalE #creativeE I am where the techn community live. #iamsilkqueen #iamsoftpowermode #familyfirst.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 84,
#    'friends_count': 1090,
#    'listed_count': 5,
#    'created_at': 'Wed Feb 13 05:34:35 +0000 2019',
#    'favourites_count': 2375,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 7064,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1217442756605480961/qyB2ybCu_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1217442756605480961/qyB2ybCu_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1095556823569051648/1586970598',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Aug 05 00:32:27 +0000 2020',
#    'id': 1290807847949926404,
#    'id_str': '1290807847949926404',
#    'text': 'According to #Google, as #AI becomes more advanced, it becomes more aggressive.\n\nMT @abhishek__AI #ML #GoogleAI… https://t.co/n6BHbOKdQb',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Google', 'indices': [13, 20]},
#      {'text': 'AI', 'indices': [25, 28]},
#      {'text': 'ML', 'indices': [98, 101]},
#      {'text': 'GoogleAI', 'indices': [102, 111]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'abhishek__AI',
#       'name': 'Abhishek Yadav',
#       'id': 715774453423206401,
#       'id_str': '715774453423206401',
#       'indices': [84, 97]}],
#     'urls': [{'url': 'https://t.co/n6BHbOKdQb',
#       'expanded_url': 'https://twitter.com/i/web/status/1290807847949926404',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [113, 136]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 968008274003005440,
#     'id_str': '968008274003005440',
#     'name': 'Mario Pawlowski 🇵🇱🇺🇸🇪🇺🌎⚽️',
#     'screen_name': 'PawlowskiMario',
#     'location': 'Chicago IL',
#     'description': '#CEO @iTrucker_ |Social Media #Influencer #SMM #Chef #AI #AIEthics #Future #DigitalTransformation #SupplyChain #Drones #AR #VR #Megatrends #History',
#     'url': 'https://t.co/EF9lWTlKuW',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/EF9lWTlKuW',
#         'expanded_url': 'https://itrucker.com',
#         'display_url': 'itrucker.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 14976,
#     'friends_count': 8721,
#     'listed_count': 118,
#     'created_at': 'Mon Feb 26 06:22:12 +0000 2018',
#     'favourites_count': 33645,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 11638,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1235847748802375680/dtB9LH_T_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1235847748802375680/dtB9LH_T_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 87,
#    'favorite_count': 106,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 87,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:08:53 +0000 2020',
#   'id': 1291919280213233666,
#   'id_str': '1291919280213233666',
#   'text': 'RT @byLilyV: #FEATURED #COURSES\nThe #Data #Science Course 2020: Complete #DataScience Bootcamp\nIn demand skills: #Statistical #analysis\n#Py…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'FEATURED', 'indices': [13, 22]},
#     {'text': 'COURSES', 'indices': [23, 31]},
#     {'text': 'Data', 'indices': [36, 41]},
#     {'text': 'Science', 'indices': [42, 50]},
#     {'text': 'DataScience', 'indices': [73, 85]},
#     {'text': 'Statistical', 'indices': [113, 125]},
#     {'text': 'analysis', 'indices': [126, 135]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'byLilyV',
#      'name': "Lily's Education4you.online",
#      'id': 134434122,
#      'id_str': '134434122',
#      'indices': [3, 11]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1276058041389953024,
#    'id_str': '1276058041389953024',
#    'name': 'The Data Science Bot',
#    'screen_name': 'datasciencebot_',
#    'location': '',
#    'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 627,
#    'friends_count': 1,
#    'listed_count': 16,
#    'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#    'favourites_count': 16,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 62782,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Aug 08 02:08:46 +0000 2020',
#    'id': 1291919247820689408,
#    'id_str': '1291919247820689408',
#    'text': '#FEATURED #COURSES\nThe #Data #Science Course 2020: Complete #DataScience Bootcamp\nIn demand skills: #Statistical… https://t.co/GfuxEqGjgD',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'FEATURED', 'indices': [0, 9]},
#      {'text': 'COURSES', 'indices': [10, 18]},
#      {'text': 'Data', 'indices': [23, 28]},
#      {'text': 'Science', 'indices': [29, 37]},
#      {'text': 'DataScience', 'indices': [60, 72]},
#      {'text': 'Statistical', 'indices': [100, 112]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/GfuxEqGjgD',
#       'expanded_url': 'https://twitter.com/i/web/status/1291919247820689408',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [114, 137]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://app.socialpilot.co/" rel="nofollow">SocialPilot.co</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 134434122,
#     'id_str': '134434122',
#     'name': "Lily's Education4you.online",
#     'screen_name': 'byLilyV',
#     'location': 'Bradford, Yorkshire',
#     'description': 'Education affiliate marketer & lifelong learning coach! I can coach you to a learning experience that strengthens your skills and enhances your personality.',
#     'url': 'https://t.co/s4SwMa3ILp',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/s4SwMa3ILp',
#         'expanded_url': 'https://media4you.social/career-development.html',
#         'display_url': 'media4you.social/career-develop…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 21700,
#     'friends_count': 16859,
#     'listed_count': 367,
#     'created_at': 'Sun Apr 18 11:58:09 +0000 2010',
#     'favourites_count': 3562,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 153364,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C3D4D1',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1286667414873276416/1J-cKwoj_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286667414873276416/1J-cKwoj_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/134434122/1596284600',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'EADEAA',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:08:51 +0000 2020',
#   'id': 1291919270411218944,
#   'id_str': '1291919270411218944',
#   'text': 'RT @byLilyV: #FEATURED #COURSES\nThe #Data #Science Course 2020: Complete #DataScience Bootcamp\nIn demand skills: #Statistical #analysis\n#Py…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'FEATURED', 'indices': [13, 22]},
#     {'text': 'COURSES', 'indices': [23, 31]},
#     {'text': 'Data', 'indices': [36, 41]},
#     {'text': 'Science', 'indices': [42, 50]},
#     {'text': 'DataScience', 'indices': [73, 85]},
#     {'text': 'Statistical', 'indices': [113, 125]},
#     {'text': 'analysis', 'indices': [126, 135]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'byLilyV',
#      'name': "Lily's Education4you.online",
#      'id': 134434122,
#      'id_str': '134434122',
#      'indices': [3, 11]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://github.com/NTAKPE/trees_of_civ.git" rel="nofollow">trees_of_civ</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1010110483582652416,
#    'id_str': '1010110483582652416',
#    'name': 'Trending Now',
#    'screen_name': 'techtrendingnow',
#    'location': '',
#    'description': 'Follow me for update about what trend in tech right now : GPT-3 | AI | BlockChain etc... Like My Work? plz, Buy Me A coffee: https://t.co/UWL6Aa3dbq',
#    'url': 'https://t.co/UWL6Aa3dbq',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#        'expanded_url': 'https://ko-fi.com/techtrendingnow',
#        'display_url': 'ko-fi.com/techtrendingnow',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#        'expanded_url': 'https://ko-fi.com/techtrendingnow',
#        'display_url': 'ko-fi.com/techtrendingnow',
#        'indices': [125, 148]}]}},
#    'protected': False,
#    'followers_count': 646,
#    'friends_count': 82,
#    'listed_count': 26,
#    'created_at': 'Fri Jun 22 10:41:21 +0000 2018',
#    'favourites_count': 7892,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 52539,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1010110483582652416/1581356400',
#    'profile_link_color': '981CEB',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Aug 08 02:08:46 +0000 2020',
#    'id': 1291919247820689408,
#    'id_str': '1291919247820689408',
#    'text': '#FEATURED #COURSES\nThe #Data #Science Course 2020: Complete #DataScience Bootcamp\nIn demand skills: #Statistical… https://t.co/GfuxEqGjgD',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'FEATURED', 'indices': [0, 9]},
#      {'text': 'COURSES', 'indices': [10, 18]},
#      {'text': 'Data', 'indices': [23, 28]},
#      {'text': 'Science', 'indices': [29, 37]},
#      {'text': 'DataScience', 'indices': [60, 72]},
#      {'text': 'Statistical', 'indices': [100, 112]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/GfuxEqGjgD',
#       'expanded_url': 'https://twitter.com/i/web/status/1291919247820689408',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [114, 137]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://app.socialpilot.co/" rel="nofollow">SocialPilot.co</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 134434122,
#     'id_str': '134434122',
#     'name': "Lily's Education4you.online",
#     'screen_name': 'byLilyV',
#     'location': 'Bradford, Yorkshire',
#     'description': 'Education affiliate marketer & lifelong learning coach! I can coach you to a learning experience that strengthens your skills and enhances your personality.',
#     'url': 'https://t.co/s4SwMa3ILp',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/s4SwMa3ILp',
#         'expanded_url': 'https://media4you.social/career-development.html',
#         'display_url': 'media4you.social/career-develop…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 21700,
#     'friends_count': 16859,
#     'listed_count': 367,
#     'created_at': 'Sun Apr 18 11:58:09 +0000 2010',
#     'favourites_count': 3562,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 153364,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C3D4D1',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
# ...
#     'name': 'Stacy S.',
#     'screen_name': 'stanford__ai',
#     'location': 'Cambridge, MA',
#     'description': 'Senior Editor at Towards AI | For Authors @towards_ai → https://t.co/ksfRFN18UY | Inquiries: sstanford@towardsai.net | www: https://t.co/fou8qliUff',
#     'url': 'https://t.co/gmKfWdoV5J',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/gmKfWdoV5J',
#         'expanded_url': 'https://pub.towardsai.net/',
#         'display_url': 'pub.towardsai.net',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/ksfRFN18UY',
#         'expanded_url': 'https://towardsai.net/contribute',
#         'display_url': 'towardsai.net/contribute',
#         'indices': [56, 79]},
#        {'url': 'https://t.co/fou8qliUff',
#         'expanded_url': 'https://towardsai.net/',
#         'display_url': 'towardsai.net',
#         'indices': [124, 147]}]}},
#     'protected': False,
#     'followers_count': 782,
#     'friends_count': 1504,
#     'listed_count': 18,
#     'created_at': 'Wed Apr 03 19:58:53 +0000 2019',
#     'favourites_count': 344,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 17289,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1113531441625935878/OR4W_sLY_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1113531441625935878/OR4W_sLY_normal.jpg',
#     'profile_link_color': 'FAB81E',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 7,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 01:51:10 +0000 2020',
#   'id': 1291914821965942784,
#   'id_str': '1291914821965942784',
#   'text': 'RT @stanford__ai: How I Passed My Associate Cloud Engineering Exam In Three Months by Rashida Nasrin Sucky via @Towards_AI → https://t.co/9…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'stanford__ai',
#      'name': 'Stacy S.',
#      'id': 1113531333702311941,
#      'id_str': '1113531333702311941',
#      'indices': [3, 16]},
#     {'screen_name': 'towards_AI',
#      'name': 'Towards AI',
#      'id': 1115985999178420224,
#      'id_str': '1115985999178420224',
#      'indices': [111, 122]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://aaroncuddeback.com" rel="nofollow">aaroncuddeback.com</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 310897418,
#    'id_str': '310897418',
#    'name': "Aaron ''Midlife Coder'' Cuddeback",
#    'screen_name': 'AaronCuddeback',
#    'location': 'Sacramento, CA',
#    'description': 'Midlife Coder\nFather, Entrepreneur, CEO, Software Developer,  Fearless.\nowner: https://t.co/YVyJ5hCGlt',
#    'url': 'https://t.co/oLCJZbKKZ3',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/oLCJZbKKZ3',
#        'expanded_url': 'https://aaroncuddeback.dev',
#        'display_url': 'aaroncuddeback.dev',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/YVyJ5hCGlt',
#        'expanded_url': 'http://urbanrisedesigns.com',
#        'display_url': 'urbanrisedesigns.com',
#        'indices': [79, 102]}]}},
#    'protected': False,
#    'followers_count': 14060,
#    'friends_count': 127,
#    'listed_count': 277,
#    'created_at': 'Sat Jun 04 14:57:55 +0000 2011',
#    'favourites_count': 36178,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 920823,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1046220721087688704/RidtZYBx_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1046220721087688704/RidtZYBx_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/310897418/1572929508',
#    'profile_link_color': 'FF691F',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Aug 08 01:50:23 +0000 2020',
#    'id': 1291914623185289216,
#    'id_str': '1291914623185289216',
#    'text': 'How I Passed My Associate Cloud Engineering Exam In Three Months by Rashida Nasrin Sucky via @Towards_AI →… https://t.co/khSnMqTHhU',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'towards_AI',
#       'name': 'Towards AI',
#       'id': 1115985999178420224,
#       'id_str': '1115985999178420224',
#       'indices': [93, 104]}],
#     'urls': [{'url': 'https://t.co/khSnMqTHhU',
#       'expanded_url': 'https://twitter.com/i/web/status/1291914623185289216',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [108, 131]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1113531333702311941,
#     'id_str': '1113531333702311941',
#     'name': 'Stacy S.',
#     'screen_name': 'stanford__ai',
#     'location': 'Cambridge, MA',
#     'description': 'Senior Editor at Towards AI | For Authors @towards_ai → https://t.co/ksfRFN18UY | Inquiries: sstanford@towardsai.net | www: https://t.co/fou8qliUff',
#     'url': 'https://t.co/gmKfWdoV5J',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/gmKfWdoV5J',
#         'expanded_url': 'https://pub.towardsai.net/',
#         'display_url': 'pub.towardsai.net',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/ksfRFN18UY',
#         'expanded_url': 'https://towardsai.net/contribute',
#         'display_url': 'towardsai.net/contribute',
#         'indices': [56, 79]},
#        {'url': 'https://t.co/fou8qliUff',
#         'expanded_url': 'https://towardsai.net/',
#         'display_url': 'towardsai.net',
#         'indices': [124, 147]}]}},
#     'protected': False,
#     'followers_count': 782,
#     'friends_count': 1504,
#     'listed_count': 18,
#     'created_at': 'Wed Apr 03 19:58:53 +0000 2019',
#     'favourites_count': 344,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 17289,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1113531441625935878/OR4W_sLY_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1113531441625935878/OR4W_sLY_normal.jpg',
#     'profile_link_color': 'FAB81E',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 7,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 01:51:10 +0000 2020',
#   'id': 1291914821403848704,
#   'id_str': '1291914821403848704',
#   'text': 'RT @stanford__ai: How I Passed My Associate Cloud Engineering Exam In Three Months by Rashida Nasrin Sucky via @Towards_AI → https://t.co/9…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'stanford__ai',
#      'name': 'Stacy S.',
#      'id': 1113531333702311941,
#      'id_str': '1113531333702311941',
#      'indices': [3, 16]},
#     {'screen_name': 'towards_AI',
#      'name': 'Towards AI',
#      'id': 1115985999178420224,
#      'id_str': '1115985999178420224',
#      'indices': [111, 122]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://homeinc.com" rel="nofollow">forRetweeting</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1142424032794406912,
#    'id_str': '1142424032794406912',
#    'name': 'Cyber Security News',
#    'screen_name': 'CyberSecurityN8',
#    'location': '',
#    'description': 'The place for InfoSec, CyberSecurity, DevSecOps, DataSecurity and many more!!! Stay tuned.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 6415,
#    'friends_count': 1,
#    'listed_count': 108,
#    'created_at': 'Sat Jun 22 13:28:09 +0000 2019',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 350766,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1197135188473475074/8svI-1EO_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1197135188473475074/8svI-1EO_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1142424032794406912/1574254287',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Aug 08 01:50:23 +0000 2020',
#    'id': 1291914623185289216,
#    'id_str': '1291914623185289216',
#    'text': 'How I Passed My Associate Cloud Engineering Exam In Three Months by Rashida Nasrin Sucky via @Towards_AI →… https://t.co/khSnMqTHhU',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'towards_AI',
#       'name': 'Towards AI',
#       'id': 1115985999178420224,
#       'id_str': '1115985999178420224',
#       'indices': [93, 104]}],
#     'urls': [{'url': 'https://t.co/khSnMqTHhU',
#       'expanded_url': 'https://twitter.com/i/web/status/1291914623185289216',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [108, 131]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1113531333702311941,
#     'id_str': '1113531333702311941',
#     'name': 'Stacy S.',
#     'screen_name': 'stanford__ai',
#     'location': 'Cambridge, MA',
#     'description': 'Senior Editor at Towards AI | For Authors @towards_ai → https://t.co/ksfRFN18UY | Inquiries: sstanford@towardsai.net | www: https://t.co/fou8qliUff',
#     'url': 'https://t.co/gmKfWdoV5J',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/gmKfWdoV5J',
#         'expanded_url': 'https://pub.towardsai.net/',
#         'display_url': 'pub.towardsai.net',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/ksfRFN18UY',
#         'expanded_url': 'https://towardsai.net/contribute',
#         'display_url': 'towardsai.net/contribute',
#         'indices': [56, 79]},
#        {'url': 'https://t.co/fou8qliUff',
#         'expanded_url': 'https://towardsai.net/',
#         'display_url': 'towardsai.net',
#         'indices': [124, 147]}]}},
#     'protected': False,
#     'followers_count': 782,
#     'friends_count': 1504,
#     'listed_count': 18,
#     'created_at': 'Wed Apr 03 19:58:53 +0000 2019',
#     'favourites_count': 344,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 17289,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1113531441625935878/OR4W_sLY_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1113531441625935878/OR4W_sLY_normal.jpg',
#     'profile_link_color': 'FAB81E',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 7,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'}]

# %% [markdown]
# Try adding a second parameter.  You can find the list here:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets

# %%
# we'll search for deep learning, returning 100 results, using the most recent tweets
search_string = '?q=%23DeepLearning&count=100&result_type=recent'
# initiate the request
results = requests.get(base_url + search_string, auth=tokens).json()

# %%
# and success!
results['statuses']
# Out:
# [{'created_at': 'Sat Aug 08 02:11:04 +0000 2020',
#   'id': 1291919829541302273,
#   'id_str': '1291919829541302273',
#   'text': 'RT @jamilahmed_16: #DeepLearning Review\n\nhttps://t.co/bZaPnOXEdZ\n\n#DataScience #dataviz #DataScientist #Python #rstats #100DaysOfCode #ML #…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [19, 32]},
#     {'text': 'DataScience', 'indices': [66, 78]},
#     {'text': 'dataviz', 'indices': [79, 87]},
#     {'text': 'DataScientist', 'indices': [88, 102]},
#     {'text': 'Python', 'indices': [103, 110]},
#     {'text': 'rstats', 'indices': [111, 118]},
#     {'text': '100DaysOfCode', 'indices': [119, 133]},
#     {'text': 'ML', 'indices': [134, 137]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'jamilahmed_16',
#      'name': 'Jamil Ahmed #BusinessIntelligence',
#      'id': 1142396855252205568,
#      'id_str': '1142396855252205568',
#      'indices': [3, 17]}],
#    'urls': [{'url': 'https://t.co/bZaPnOXEdZ',
#      'expanded_url': 'https://bit.ly/2Q8i3WB',
#      'display_url': 'bit.ly/2Q8i3WB',
#      'indices': [41, 64]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://github.com/NTAKPE/trees_of_civ.git" rel="nofollow">trees_of_civ</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1010110483582652416,
#    'id_str': '1010110483582652416',
#    'name': 'Trending Now',
#    'screen_name': 'techtrendingnow',
#    'location': '',
#    'description': 'Follow me for update about what trend in tech right now : GPT-3 | AI | BlockChain etc... Like My Work? plz, Buy Me A coffee: https://t.co/UWL6Aa3dbq',
#    'url': 'https://t.co/UWL6Aa3dbq',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#        'expanded_url': 'https://ko-fi.com/techtrendingnow',
#        'display_url': 'ko-fi.com/techtrendingnow',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#        'expanded_url': 'https://ko-fi.com/techtrendingnow',
#        'display_url': 'ko-fi.com/techtrendingnow',
#        'indices': [125, 148]}]}},
#    'protected': False,
#    'followers_count': 646,
#    'friends_count': 82,
#    'listed_count': 26,
#    'created_at': 'Fri Jun 22 10:41:21 +0000 2018',
#    'favourites_count': 7892,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 52539,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1010110483582652416/1581356400',
#    'profile_link_color': '981CEB',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Aug 07 12:50:45 +0000 2020',
#    'id': 1291718421197893632,
#    'id_str': '1291718421197893632',
#    'text': '#DeepLearning Review\n\nhttps://t.co/bZaPnOXEdZ\n\n#DataScience #dataviz #DataScientist #Python #rstats #100DaysOfCode… https://t.co/5zHRa4ljsH',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [0, 13]},
#      {'text': 'DataScience', 'indices': [47, 59]},
#      {'text': 'dataviz', 'indices': [60, 68]},
#      {'text': 'DataScientist', 'indices': [69, 83]},
#      {'text': 'Python', 'indices': [84, 91]},
#      {'text': 'rstats', 'indices': [92, 99]},
#      {'text': '100DaysOfCode', 'indices': [100, 114]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/bZaPnOXEdZ',
#       'expanded_url': 'https://bit.ly/2Q8i3WB',
#       'display_url': 'bit.ly/2Q8i3WB',
#       'indices': [22, 45]},
#      {'url': 'https://t.co/5zHRa4ljsH',
#       'expanded_url': 'https://twitter.com/i/web/status/1291718421197893632',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1142396855252205568,
#     'id_str': '1142396855252205568',
#     'name': 'Jamil Ahmed #BusinessIntelligence',
#     'screen_name': 'jamilahmed_16',
#     'location': '',
#     'description': 'CEO @reinforcelabtwt ¦ Pharmacist ¦ Personal Branding ¦ Social Media Marketing, Small Business & ecommerce Expert. No #3 #BI Marketing #Influencer by Onalytica.',
#     'url': 'https://t.co/0VuM3IrdpS',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/0VuM3IrdpS',
#         'expanded_url': 'http://reinforcelab.com',
#         'display_url': 'reinforcelab.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1427,
#     'friends_count': 1404,
#     'listed_count': 20,
#     'created_at': 'Sat Jun 22 11:40:09 +0000 2019',
#     'favourites_count': 3895,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 5505,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1269190715692642305/J9jFN4aA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1269190715692642305/J9jFN4aA_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1142396855252205568/1561549949',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 42,
#    'favorite_count': 11,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 42,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:11:04 +0000 2020',
#   'id': 1291919828769476610,
#   'id_str': '1291919828769476610',
#   'text': 'RT @jamilahmed_16: #DeepLearning Review\n\nhttps://t.co/bZaPnOXEdZ\n\n#DataScience #dataviz #DataScientist #Python #rstats #100DaysOfCode #ML #…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [19, 32]},
#     {'text': 'DataScience', 'indices': [66, 78]},
#     {'text': 'dataviz', 'indices': [79, 87]},
#     {'text': 'DataScientist', 'indices': [88, 102]},
#     {'text': 'Python', 'indices': [103, 110]},
#     {'text': 'rstats', 'indices': [111, 118]},
#     {'text': '100DaysOfCode', 'indices': [119, 133]},
#     {'text': 'ML', 'indices': [134, 137]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'jamilahmed_16',
#      'name': 'Jamil Ahmed #BusinessIntelligence',
#      'id': 1142396855252205568,
#      'id_str': '1142396855252205568',
#      'indices': [3, 17]}],
#    'urls': [{'url': 'https://t.co/bZaPnOXEdZ',
#      'expanded_url': 'https://bit.ly/2Q8i3WB',
#      'display_url': 'bit.ly/2Q8i3WB',
#      'indices': [41, 64]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://adam-spice.online" rel="nofollow">GnutsBot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1266133633389060097,
#    'id_str': '1266133633389060097',
#    'name': 'Gnuts about Code',
#    'screen_name': 'CodeGnuts',
#    'location': '',
#    'description': 'Just a bot helping coders show their progress. Automation built in #NodeJs by @AdamSpiceOnline. #100DaysOfCode',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1605,
#    'friends_count': 0,
#    'listed_count': 36,
#    'created_at': 'Thu May 28 22:26:07 +0000 2020',
#    'favourites_count': 32738,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 205191,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1266134298429517824/Gxv_xYd7_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1266134298429517824/Gxv_xYd7_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1266133633389060097/1590708060',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Aug 07 12:50:45 +0000 2020',
#    'id': 1291718421197893632,
#    'id_str': '1291718421197893632',
#    'text': '#DeepLearning Review\n\nhttps://t.co/bZaPnOXEdZ\n\n#DataScience #dataviz #DataScientist #Python #rstats #100DaysOfCode… https://t.co/5zHRa4ljsH',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [0, 13]},
#      {'text': 'DataScience', 'indices': [47, 59]},
#      {'text': 'dataviz', 'indices': [60, 68]},
#      {'text': 'DataScientist', 'indices': [69, 83]},
#      {'text': 'Python', 'indices': [84, 91]},
#      {'text': 'rstats', 'indices': [92, 99]},
#      {'text': '100DaysOfCode', 'indices': [100, 114]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/bZaPnOXEdZ',
#       'expanded_url': 'https://bit.ly/2Q8i3WB',
#       'display_url': 'bit.ly/2Q8i3WB',
#       'indices': [22, 45]},
#      {'url': 'https://t.co/5zHRa4ljsH',
#       'expanded_url': 'https://twitter.com/i/web/status/1291718421197893632',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1142396855252205568,
#     'id_str': '1142396855252205568',
#     'name': 'Jamil Ahmed #BusinessIntelligence',
#     'screen_name': 'jamilahmed_16',
#     'location': '',
#     'description': 'CEO @reinforcelabtwt ¦ Pharmacist ¦ Personal Branding ¦ Social Media Marketing, Small Business & ecommerce Expert. No #3 #BI Marketing #Influencer by Onalytica.',
#     'url': 'https://t.co/0VuM3IrdpS',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/0VuM3IrdpS',
#         'expanded_url': 'http://reinforcelab.com',
#         'display_url': 'reinforcelab.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1427,
#     'friends_count': 1404,
#     'listed_count': 20,
#     'created_at': 'Sat Jun 22 11:40:09 +0000 2019',
#     'favourites_count': 3895,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 5505,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1269190715692642305/J9jFN4aA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1269190715692642305/J9jFN4aA_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1142396855252205568/1561549949',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 42,
#    'favorite_count': 11,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 42,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:10:59 +0000 2020',
#   'id': 1291919807068008448,
#   'id_str': '1291919807068008448',
#   'text': 'RT @jamilahmed_16: #DeepLearning Review\n\nhttps://t.co/bZaPnOXEdZ\n\n#DataScience #dataviz #DataScientist #Python #rstats #100DaysOfCode #ML #…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [19, 32]},
#     {'text': 'DataScience', 'indices': [66, 78]},
#     {'text': 'dataviz', 'indices': [79, 87]},
#     {'text': 'DataScientist', 'indices': [88, 102]},
#     {'text': 'Python', 'indices': [103, 110]},
#     {'text': 'rstats', 'indices': [111, 118]},
#     {'text': '100DaysOfCode', 'indices': [119, 133]},
#     {'text': 'ML', 'indices': [134, 137]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'jamilahmed_16',
#      'name': 'Jamil Ahmed #BusinessIntelligence',
#      'id': 1142396855252205568,
#      'id_str': '1142396855252205568',
#      'indices': [3, 17]}],
#    'urls': [{'url': 'https://t.co/bZaPnOXEdZ',
#      'expanded_url': 'https://bit.ly/2Q8i3WB',
#      'display_url': 'bit.ly/2Q8i3WB',
#      'indices': [41, 64]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1142396855252205568,
#    'id_str': '1142396855252205568',
#    'name': 'Jamil Ahmed #BusinessIntelligence',
#    'screen_name': 'jamilahmed_16',
#    'location': '',
#    'description': 'CEO @reinforcelabtwt ¦ Pharmacist ¦ Personal Branding ¦ Social Media Marketing, Small Business & ecommerce Expert. No #3 #BI Marketing #Influencer by Onalytica.',
#    'url': 'https://t.co/0VuM3IrdpS',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/0VuM3IrdpS',
#        'expanded_url': 'http://reinforcelab.com',
#        'display_url': 'reinforcelab.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1427,
#    'friends_count': 1404,
#    'listed_count': 20,
#    'created_at': 'Sat Jun 22 11:40:09 +0000 2019',
#    'favourites_count': 3895,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 5505,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1269190715692642305/J9jFN4aA_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1269190715692642305/J9jFN4aA_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1142396855252205568/1561549949',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Aug 07 12:50:45 +0000 2020',
#    'id': 1291718421197893632,
#    'id_str': '1291718421197893632',
#    'text': '#DeepLearning Review\n\nhttps://t.co/bZaPnOXEdZ\n\n#DataScience #dataviz #DataScientist #Python #rstats #100DaysOfCode… https://t.co/5zHRa4ljsH',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [0, 13]},
#      {'text': 'DataScience', 'indices': [47, 59]},
#      {'text': 'dataviz', 'indices': [60, 68]},
#      {'text': 'DataScientist', 'indices': [69, 83]},
#      {'text': 'Python', 'indices': [84, 91]},
#      {'text': 'rstats', 'indices': [92, 99]},
#      {'text': '100DaysOfCode', 'indices': [100, 114]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/bZaPnOXEdZ',
#       'expanded_url': 'https://bit.ly/2Q8i3WB',
#       'display_url': 'bit.ly/2Q8i3WB',
#       'indices': [22, 45]},
#      {'url': 'https://t.co/5zHRa4ljsH',
#       'expanded_url': 'https://twitter.com/i/web/status/1291718421197893632',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1142396855252205568,
#     'id_str': '1142396855252205568',
#     'name': 'Jamil Ahmed #BusinessIntelligence',
#     'screen_name': 'jamilahmed_16',
#     'location': '',
#     'description': 'CEO @reinforcelabtwt ¦ Pharmacist ¦ Personal Branding ¦ Social Media Marketing, Small Business & ecommerce Expert. No #3 #BI Marketing #Influencer by Onalytica.',
#     'url': 'https://t.co/0VuM3IrdpS',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/0VuM3IrdpS',
#         'expanded_url': 'http://reinforcelab.com',
#         'display_url': 'reinforcelab.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1427,
#     'friends_count': 1404,
#     'listed_count': 20,
#     'created_at': 'Sat Jun 22 11:40:09 +0000 2019',
#     'favourites_count': 3895,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 5505,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1269190715692642305/J9jFN4aA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1269190715692642305/J9jFN4aA_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1142396855252205568/1561549949',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 42,
#    'favorite_count': 11,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 42,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:09:46 +0000 2020',
#   'id': 1291919503018938368,
#   'id_str': '1291919503018938368',
#   'text': 'RT @PawlowskiMario: According to #Google, as #AI becomes more advanced, it becomes more aggressive.\n\nMT @abhishek__AI #ML #GoogleAI  #IoT #…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'Google', 'indices': [33, 40]},
#     {'text': 'AI', 'indices': [45, 48]},
#     {'text': 'ML', 'indices': [118, 121]},
#     {'text': 'GoogleAI', 'indices': [122, 131]},
#     {'text': 'IoT', 'indices': [133, 137]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'PawlowskiMario',
#      'name': 'Mario Pawlowski 🇵🇱🇺🇸🇪🇺🌎⚽️',
#      'id': 968008274003005440,
#      'id_str': '968008274003005440',
#      'indices': [3, 18]},
#     {'screen_name': 'abhishek__AI',
#      'name': 'Abhishek Yadav',
#      'id': 715774453423206401,
#      'id_str': '715774453423206401',
#      'indices': [104, 117]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://github.com/NTAKPE/trees_of_civ.git" rel="nofollow">trees_of_civ</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1010110483582652416,
#    'id_str': '1010110483582652416',
#    'name': 'Trending Now',
#    'screen_name': 'techtrendingnow',
#    'location': '',
#    'description': 'Follow me for update about what trend in tech right now : GPT-3 | AI | BlockChain etc... Like My Work? plz, Buy Me A coffee: https://t.co/UWL6Aa3dbq',
#    'url': 'https://t.co/UWL6Aa3dbq',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#        'expanded_url': 'https://ko-fi.com/techtrendingnow',
#        'display_url': 'ko-fi.com/techtrendingnow',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#        'expanded_url': 'https://ko-fi.com/techtrendingnow',
#        'display_url': 'ko-fi.com/techtrendingnow',
#        'indices': [125, 148]}]}},
#    'protected': False,
#    'followers_count': 646,
#    'friends_count': 82,
#    'listed_count': 26,
#    'created_at': 'Fri Jun 22 10:41:21 +0000 2018',
#    'favourites_count': 7892,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 52539,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1010110483582652416/1581356400',
#    'profile_link_color': '981CEB',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Aug 05 00:32:27 +0000 2020',
#    'id': 1290807847949926404,
#    'id_str': '1290807847949926404',
#    'text': 'According to #Google, as #AI becomes more advanced, it becomes more aggressive.\n\nMT @abhishek__AI #ML #GoogleAI… https://t.co/n6BHbOKdQb',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Google', 'indices': [13, 20]},
#      {'text': 'AI', 'indices': [25, 28]},
#      {'text': 'ML', 'indices': [98, 101]},
#      {'text': 'GoogleAI', 'indices': [102, 111]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'abhishek__AI',
#       'name': 'Abhishek Yadav',
#       'id': 715774453423206401,
#       'id_str': '715774453423206401',
#       'indices': [84, 97]}],
#     'urls': [{'url': 'https://t.co/n6BHbOKdQb',
#       'expanded_url': 'https://twitter.com/i/web/status/1290807847949926404',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [113, 136]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 968008274003005440,
#     'id_str': '968008274003005440',
#     'name': 'Mario Pawlowski 🇵🇱🇺🇸🇪🇺🌎⚽️',
#     'screen_name': 'PawlowskiMario',
#     'location': 'Chicago IL',
#     'description': '#CEO @iTrucker_ |Social Media #Influencer #SMM #Chef #AI #AIEthics #Future #DigitalTransformation #SupplyChain #Drones #AR #VR #Megatrends #History',
#     'url': 'https://t.co/EF9lWTlKuW',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/EF9lWTlKuW',
#         'expanded_url': 'https://itrucker.com',
#         'display_url': 'itrucker.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 14976,
#     'friends_count': 8721,
#     'listed_count': 118,
#     'created_at': 'Mon Feb 26 06:22:12 +0000 2018',
#     'favourites_count': 33645,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 11638,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1235847748802375680/dtB9LH_T_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1235847748802375680/dtB9LH_T_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 87,
#    'favorite_count': 106,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 87,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:09:41 +0000 2020',
#   'id': 1291919479966965760,
#   'id_str': '1291919479966965760',
#   'text': 'RT @PawlowskiMario: According to #Google, as #AI becomes more advanced, it becomes more aggressive.\n\nMT @abhishek__AI #ML #GoogleAI  #IoT #…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'Google', 'indices': [33, 40]},
#     {'text': 'AI', 'indices': [45, 48]},
#     {'text': 'ML', 'indices': [118, 121]},
#     {'text': 'GoogleAI', 'indices': [122, 131]},
#     {'text': 'IoT', 'indices': [133, 137]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'PawlowskiMario',
#      'name': 'Mario Pawlowski 🇵🇱🇺🇸🇪🇺🌎⚽️',
#      'id': 968008274003005440,
#      'id_str': '968008274003005440',
#      'indices': [3, 18]},
#     {'screen_name': 'abhishek__AI',
#      'name': 'Abhishek Yadav',
#      'id': 715774453423206401,
#      'id_str': '715774453423206401',
#      'indices': [104, 117]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1095556823569051648,
#    'id_str': '1095556823569051648',
#    'name': 'staphylococcus aureus',
#    'screen_name': 'luxurytechappa1',
#    'location': 'Paradise',
#    'description': '#ux #ui #ai #vui #tech #fashionandtech #beautyandtech #digitalE #creativeE I am where the techn community live. #iamsilkqueen #iamsoftpowermode #familyfirst.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 84,
#    'friends_count': 1090,
#    'listed_count': 5,
#    'created_at': 'Wed Feb 13 05:34:35 +0000 2019',
#    'favourites_count': 2375,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 7064,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1217442756605480961/qyB2ybCu_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1217442756605480961/qyB2ybCu_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1095556823569051648/1586970598',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Aug 05 00:32:27 +0000 2020',
#    'id': 1290807847949926404,
#    'id_str': '1290807847949926404',
#    'text': 'According to #Google, as #AI becomes more advanced, it becomes more aggressive.\n\nMT @abhishek__AI #ML #GoogleAI… https://t.co/n6BHbOKdQb',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Google', 'indices': [13, 20]},
#      {'text': 'AI', 'indices': [25, 28]},
#      {'text': 'ML', 'indices': [98, 101]},
#      {'text': 'GoogleAI', 'indices': [102, 111]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'abhishek__AI',
#       'name': 'Abhishek Yadav',
#       'id': 715774453423206401,
#       'id_str': '715774453423206401',
#       'indices': [84, 97]}],
#     'urls': [{'url': 'https://t.co/n6BHbOKdQb',
#       'expanded_url': 'https://twitter.com/i/web/status/1290807847949926404',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [113, 136]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 968008274003005440,
#     'id_str': '968008274003005440',
#     'name': 'Mario Pawlowski 🇵🇱🇺🇸🇪🇺🌎⚽️',
#     'screen_name': 'PawlowskiMario',
#     'location': 'Chicago IL',
#     'description': '#CEO @iTrucker_ |Social Media #Influencer #SMM #Chef #AI #AIEthics #Future #DigitalTransformation #SupplyChain #Drones #AR #VR #Megatrends #History',
#     'url': 'https://t.co/EF9lWTlKuW',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/EF9lWTlKuW',
#         'expanded_url': 'https://itrucker.com',
#         'display_url': 'itrucker.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 14976,
#     'friends_count': 8721,
#     'listed_count': 118,
#     'created_at': 'Mon Feb 26 06:22:12 +0000 2018',
#     'favourites_count': 33645,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 11638,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1235847748802375680/dtB9LH_T_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1235847748802375680/dtB9LH_T_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 87,
#    'favorite_count': 106,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 87,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:08:53 +0000 2020',
#   'id': 1291919280213233666,
#   'id_str': '1291919280213233666',
#   'text': 'RT @byLilyV: #FEATURED #COURSES\nThe #Data #Science Course 2020: Complete #DataScience Bootcamp\nIn demand skills: #Statistical #analysis\n#Py…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'FEATURED', 'indices': [13, 22]},
#     {'text': 'COURSES', 'indices': [23, 31]},
#     {'text': 'Data', 'indices': [36, 41]},
#     {'text': 'Science', 'indices': [42, 50]},
#     {'text': 'DataScience', 'indices': [73, 85]},
#     {'text': 'Statistical', 'indices': [113, 125]},
#     {'text': 'analysis', 'indices': [126, 135]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'byLilyV',
#      'name': "Lily's Education4you.online",
#      'id': 134434122,
#      'id_str': '134434122',
#      'indices': [3, 11]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1276058041389953024,
#    'id_str': '1276058041389953024',
#    'name': 'The Data Science Bot',
#    'screen_name': 'datasciencebot_',
#    'location': '',
#    'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 627,
#    'friends_count': 1,
#    'listed_count': 16,
#    'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#    'favourites_count': 16,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 62782,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Aug 08 02:08:46 +0000 2020',
#    'id': 1291919247820689408,
#    'id_str': '1291919247820689408',
#    'text': '#FEATURED #COURSES\nThe #Data #Science Course 2020: Complete #DataScience Bootcamp\nIn demand skills: #Statistical… https://t.co/GfuxEqGjgD',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'FEATURED', 'indices': [0, 9]},
#      {'text': 'COURSES', 'indices': [10, 18]},
#      {'text': 'Data', 'indices': [23, 28]},
#      {'text': 'Science', 'indices': [29, 37]},
#      {'text': 'DataScience', 'indices': [60, 72]},
#      {'text': 'Statistical', 'indices': [100, 112]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/GfuxEqGjgD',
#       'expanded_url': 'https://twitter.com/i/web/status/1291919247820689408',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [114, 137]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://app.socialpilot.co/" rel="nofollow">SocialPilot.co</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 134434122,
#     'id_str': '134434122',
#     'name': "Lily's Education4you.online",
#     'screen_name': 'byLilyV',
#     'location': 'Bradford, Yorkshire',
#     'description': 'Education affiliate marketer & lifelong learning coach! I can coach you to a learning experience that strengthens your skills and enhances your personality.',
#     'url': 'https://t.co/s4SwMa3ILp',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/s4SwMa3ILp',
#         'expanded_url': 'https://media4you.social/career-development.html',
#         'display_url': 'media4you.social/career-develop…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 21700,
#     'friends_count': 16859,
#     'listed_count': 367,
#     'created_at': 'Sun Apr 18 11:58:09 +0000 2010',
#     'favourites_count': 3562,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 153364,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C3D4D1',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1286667414873276416/1J-cKwoj_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286667414873276416/1J-cKwoj_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/134434122/1596284600',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'EADEAA',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 02:08:51 +0000 2020',
#   'id': 1291919270411218944,
#   'id_str': '1291919270411218944',
#   'text': 'RT @byLilyV: #FEATURED #COURSES\nThe #Data #Science Course 2020: Complete #DataScience Bootcamp\nIn demand skills: #Statistical #analysis\n#Py…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'FEATURED', 'indices': [13, 22]},
#     {'text': 'COURSES', 'indices': [23, 31]},
#     {'text': 'Data', 'indices': [36, 41]},
#     {'text': 'Science', 'indices': [42, 50]},
#     {'text': 'DataScience', 'indices': [73, 85]},
#     {'text': 'Statistical', 'indices': [113, 125]},
#     {'text': 'analysis', 'indices': [126, 135]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'byLilyV',
#      'name': "Lily's Education4you.online",
#      'id': 134434122,
#      'id_str': '134434122',
#      'indices': [3, 11]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://github.com/NTAKPE/trees_of_civ.git" rel="nofollow">trees_of_civ</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1010110483582652416,
#    'id_str': '1010110483582652416',
#    'name': 'Trending Now',
#    'screen_name': 'techtrendingnow',
#    'location': '',
#    'description': 'Follow me for update about what trend in tech right now : GPT-3 | AI | BlockChain etc... Like My Work? plz, Buy Me A coffee: https://t.co/UWL6Aa3dbq',
#    'url': 'https://t.co/UWL6Aa3dbq',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#        'expanded_url': 'https://ko-fi.com/techtrendingnow',
#        'display_url': 'ko-fi.com/techtrendingnow',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#        'expanded_url': 'https://ko-fi.com/techtrendingnow',
#        'display_url': 'ko-fi.com/techtrendingnow',
#        'indices': [125, 148]}]}},
#    'protected': False,
#    'followers_count': 646,
#    'friends_count': 82,
#    'listed_count': 26,
#    'created_at': 'Fri Jun 22 10:41:21 +0000 2018',
#    'favourites_count': 7892,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 52539,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1010110483582652416/1581356400',
#    'profile_link_color': '981CEB',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Aug 08 02:08:46 +0000 2020',
#    'id': 1291919247820689408,
#    'id_str': '1291919247820689408',
#    'text': '#FEATURED #COURSES\nThe #Data #Science Course 2020: Complete #DataScience Bootcamp\nIn demand skills: #Statistical… https://t.co/GfuxEqGjgD',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'FEATURED', 'indices': [0, 9]},
#      {'text': 'COURSES', 'indices': [10, 18]},
#      {'text': 'Data', 'indices': [23, 28]},
#      {'text': 'Science', 'indices': [29, 37]},
#      {'text': 'DataScience', 'indices': [60, 72]},
#      {'text': 'Statistical', 'indices': [100, 112]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/GfuxEqGjgD',
#       'expanded_url': 'https://twitter.com/i/web/status/1291919247820689408',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [114, 137]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://app.socialpilot.co/" rel="nofollow">SocialPilot.co</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 134434122,
#     'id_str': '134434122',
#     'name': "Lily's Education4you.online",
#     'screen_name': 'byLilyV',
#     'location': 'Bradford, Yorkshire',
#     'description': 'Education affiliate marketer & lifelong learning coach! I can coach you to a learning experience that strengthens your skills and enhances your personality.',
#     'url': 'https://t.co/s4SwMa3ILp',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/s4SwMa3ILp',
#         'expanded_url': 'https://media4you.social/career-development.html',
#         'display_url': 'media4you.social/career-develop…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 21700,
#     'friends_count': 16859,
#     'listed_count': 367,
#     'created_at': 'Sun Apr 18 11:58:09 +0000 2010',
#     'favourites_count': 3562,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 153364,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C3D4D1',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
# ...
#       'indices': [105, 114]}],
#     'urls': [{'url': 'https://t.co/AD1tFO5kTO',
#       'expanded_url': 'https://www.digitaltrends.com/news/ibm-michael-j-fox-parkinsons/',
#       'display_url': 'digitaltrends.com/news/ibm-micha…',
#       'indices': [0, 23]},
#      {'url': 'https://t.co/TqWQOuNYii',
#       'expanded_url': 'https://twitter.com/i/web/status/1291910680635817984',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 4153160533,
#     'id_str': '4153160533',
#     'name': 'Shailendra Kumar',
#     'screen_name': 'meisshaily',
#     'location': 'Sydney',
#     'description': 'Author: Making Money Out of Data /Keynote Speaker/ Evangelist #BigData #Analytics #DataScience #Data #MachineLearning #Deeplearning #ArtificialIntelligence @sap',
#     'url': 'https://t.co/B8qR8m6z8P',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/B8qR8m6z8P',
#         'expanded_url': 'http://cognitivetoday.com',
#         'display_url': 'cognitivetoday.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 45175,
#     'friends_count': 33360,
#     'listed_count': 880,
#     'created_at': 'Sat Nov 07 03:56:19 +0000 2015',
#     'favourites_count': 21402,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 63957,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1036229921075425280/09bXnSZJ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1036229921075425280/09bXnSZJ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4153160533/1479798757',
#     'profile_link_color': 'FAB81E',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 4,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 01:40:19 +0000 2020',
#   'id': 1291912090555494410,
#   'id_str': '1291912090555494410',
#   'text': 'RT @DanielAKeane10: Machine Learning is Fun! 👨\u200d💻🗒️\n\nhttps://t.co/kGI4tr0CNj\n\n#ArtificialIntelligence #MachineLearning #AI #DeepLearning #Ne…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'ArtificialIntelligence',
#      'indices': [77, 100]},
#     {'text': 'MachineLearning', 'indices': [101, 117]},
#     {'text': 'AI', 'indices': [118, 121]},
#     {'text': 'DeepLearning', 'indices': [122, 135]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'DanielAKeane10',
#      'name': 'Daniel A. Keane',
#      'id': 1264215356912132103,
#      'id_str': '1264215356912132103',
#      'indices': [3, 18]}],
#    'urls': [{'url': 'https://t.co/kGI4tr0CNj',
#      'expanded_url': 'https://medium.com/@ageitgey/machine-learning-is-fun-80ea3ec3c471',
#      'display_url': 'medium.com/@ageitgey/mach…',
#      'indices': [52, 75]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://github.com/lina2497" rel="nofollow">Python Data Science Tweets</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1288754505211883521,
#    'id_str': '1288754505211883521',
#    'name': 'Python for Data Science',
#    'screen_name': 'py_data_sci',
#    'location': '',
#    'description': 'Interested in using #Python for #DataScience. A bot maintained by \n@AlexBetts. Retweets are not endorsements. For #rstats, check out my other bot @rstats4ds.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 165,
#    'friends_count': 2,
#    'listed_count': 1,
#    'created_at': 'Thu Jul 30 08:33:21 +0000 2020',
#    'favourites_count': 1529,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1533,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1288765343339614208/JNqvhKEe_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1288765343339614208/JNqvhKEe_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1288754505211883521/1596100587',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Aug 08 01:38:04 +0000 2020',
#    'id': 1291911524576038916,
#    'id_str': '1291911524576038916',
#    'text': 'Machine Learning is Fun! 👨\u200d💻🗒️\n\nhttps://t.co/kGI4tr0CNj\n\n#ArtificialIntelligence #MachineLearning #AI #DeepLearning… https://t.co/RqOlAHqDXi',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'ArtificialIntelligence',
#       'indices': [57, 80]},
#      {'text': 'MachineLearning', 'indices': [81, 97]},
#      {'text': 'AI', 'indices': [98, 101]},
#      {'text': 'DeepLearning', 'indices': [102, 115]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/kGI4tr0CNj',
#       'expanded_url': 'https://medium.com/@ageitgey/machine-learning-is-fun-80ea3ec3c471',
#       'display_url': 'medium.com/@ageitgey/mach…',
#       'indices': [32, 55]},
#      {'url': 'https://t.co/RqOlAHqDXi',
#       'expanded_url': 'https://twitter.com/i/web/status/1291911524576038916',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1264215356912132103,
#     'id_str': '1264215356912132103',
#     'name': 'Daniel A. Keane',
#     'screen_name': 'DanielAKeane10',
#     'location': '',
#     'description': 'Bachelor in Business Administration | Data Scientist | Amateur Drummer | A lover of languages',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 329,
#     'friends_count': 128,
#     'listed_count': 1,
#     'created_at': 'Sat May 23 15:26:26 +0000 2020',
#     'favourites_count': 1813,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 306,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1284258409584500736/xyBX6p4U_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1284258409584500736/xyBX6p4U_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1264215356912132103/1593693915',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 13,
#    'favorite_count': 8,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 13,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Aug 08 01:40:09 +0000 2020',
#   'id': 1291912046532009985,
#   'id_str': '1291912046532009985',
#   'text': 'RT @_asifbhat_: Question Answering: Enhancing Search with Deep Learning and NLP https://t.co/nVn8fW4f1L\n\n#ArtificialIntelligence #AI #DataS…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'ArtificialIntelligence',
#      'indices': [105, 128]},
#     {'text': 'AI', 'indices': [129, 132]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': '_asifbhat_',
#      'name': 'Asif Bhat',
#      'id': 1170802004655894528,
#      'id_str': '1170802004655894528',
#      'indices': [3, 14]}],
#    'urls': [{'url': 'https://t.co/nVn8fW4f1L',
#      'expanded_url': 'https://blog.cloudera.com/question-answering-enhancing-search-with-deep-learning-and-nlp/',
#      'display_url': 'blog.cloudera.com/question-answe…',
#      'indices': [80, 103]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://notarealwebsite.nope" rel="nofollow">retwitterkylo</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1261355507203203072,
#    'id_str': '1261355507203203072',
#    'name': 'Harry',
#    'screen_name': 'HarryHSolo',
#    'location': '',
#    'description': 'Programming.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 495,
#    'friends_count': 0,
#    'listed_count': 19,
#    'created_at': 'Fri May 15 17:59:33 +0000 2020',
#    'favourites_count': 24,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 75796,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1281271085028143104/NpCyhRuZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1281271085028143104/NpCyhRuZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1261355507203203072/1591829815',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Aug 08 01:40:03 +0000 2020',
#    'id': 1291912024470028288,
#    'id_str': '1291912024470028288',
#    'text': 'Question Answering: Enhancing Search with Deep Learning and NLP https://t.co/nVn8fW4f1L\n\n#ArtificialIntelligence… https://t.co/UNHZd8kLN0',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'ArtificialIntelligence',
#       'indices': [89, 112]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/nVn8fW4f1L',
#       'expanded_url': 'https://blog.cloudera.com/question-answering-enhancing-search-with-deep-learning-and-nlp/',
#       'display_url': 'blog.cloudera.com/question-answe…',
#       'indices': [64, 87]},
#      {'url': 'https://t.co/UNHZd8kLN0',
#       'expanded_url': 'https://twitter.com/i/web/status/1291912024470028288',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [114, 137]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1170802004655894528,
#     'id_str': '1170802004655894528',
#     'name': 'Asif Bhat',
#     'screen_name': '_asifbhat_',
#     'location': 'Pune, India',
#     'description': 'Data Analyst , SAP BI ,YellowFin BI , Python ,Docker , Kubernetes | Interests - #datascience #machinelearning #deeplearning #AI #Robotics #BusinessIntelligence',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1472,
#     'friends_count': 231,
#     'listed_count': 16,
#     'created_at': 'Sun Sep 08 20:52:22 +0000 2019',
#     'favourites_count': 163,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3295,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1170802393077780480/l2yBVnxv_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1170802393077780480/l2yBVnxv_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1170802004655894528/1586775929',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 7,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'}]

# %% [markdown]
# ## Section 3: Searching Users

# %% [markdown]
# The last section of the API you'll need to get the hang of before you're let loose is the users API, which allows you to search for users and get their followers, friends, etc, as opposed to tweets which fit a particular criteria.  This part is pretty similar to the advanced lab in class 3, so if you saw how that worked then you shouldn't need much instruction.
#
# But if you're seeing this with fresh eyes, you'll want to spend 15-20 minutes to make sure you understand this part.
#
# Official documentation can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/overview
#
# So, as an example, if you want to get a list of someone's followers, you use the base url `https://api.twitter.com/1.1/followers/list.json` and then enter your query string to get a list of that persons followers.
#
# List of parameters to use can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference
#
# One possible parameter to use is `screen_name`, so if you wanted to get a list of someone's followers based on their screen name (the handle that begins with an @), then you would set up your API call to look something like:
#
# `https://api.twitter.com/1.1/followers/list.json?screen_name=persons_screenname`
#
# Note that you exclude the `@`.
#
# **Your turn:** Pull in the list of General Assembly's followers.  General Assembly's handle is `@GA`  The `users` key will contain the list of followers for General Assembly's account.
#
# Note that this won't return the whole list of GA's users.  If you want to do that you have to use cursoring:  https://developer.twitter.com/en/docs/basics/cursoring.  This is the topic of your bonus assignment.

# %%
# your answer here
base_url     = 'https://api.twitter.com/1.1/followers/list.json'
query_string = '?screen_name=GA'

results = requests.get(base_url + query_string, auth=tokens).json()

# %%
# and our results
results['users']
# Out:
# [{'id': 1105584574216704011,
#   'id_str': '1105584574216704011',
#   'name': 'Crypto Cantabria',
#   'screen_name': 'CryptoCantabria',
#   'location': '',
#   'description': 'Primera escuela de formación de Cantabria especializada en el uso de las cryptomonedas',
#   'url': 'https://t.co/uuWTKP5frz',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/uuWTKP5frz',
#       'expanded_url': 'http://www.cryptocan.es',
#       'display_url': 'cryptocan.es',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 202,
#   'friends_count': 780,
#   'listed_count': 2,
#   'created_at': 'Tue Mar 12 21:41:18 +0000 2019',
#   'favourites_count': 197,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 69,
#   'lang': None,
#   'status': {'created_at': 'Fri Aug 07 22:48:42 +0000 2020',
#    'id': 1291868900754432001,
#    'id_str': '1291868900754432001',
#    'text': '@barrysilbert @Grayscale @nitWitty It seems incredible to us what you are doing, it is essential to disseminate and train.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'barrysilbert',
#       'name': 'Barry Silbert',
#       'id': 396045469,
#       'id_str': '396045469',
#       'indices': [0, 13]},
#      {'screen_name': 'Grayscale',
#       'name': 'Grayscale',
#       'id': 2800345565,
#       'id_str': '2800345565',
#       'indices': [14, 24]},
#      {'screen_name': 'nitWitty',
#       'name': 'Arnold, Marissa',
#       'id': 17472882,
#       'id_str': '17472882',
#       'indices': [25, 34]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1291710737291841543,
#    'in_reply_to_status_id_str': '1291710737291841543',
#    'in_reply_to_user_id': 396045469,
#    'in_reply_to_user_id_str': '396045469',
#    'in_reply_to_screen_name': 'barrysilbert',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1105584726545498115/jUdlwSty_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1105584726545498115/jUdlwSty_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1105584574216704011/1552502323',
#   'profile_link_color': 'FAB81E',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 18942864,
#   'id_str': '18942864',
#   'name': 'Ali Khayrallah',
#   'screen_name': 'alisk',
#   'location': 'California',
#   'description': 'Working away at the G’s of mobile. Technology trends, big picture, strategery. Question everything. Views my own, unencumbered by fact. Go Blue! Go AUB!',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 87,
#   'friends_count': 1328,
#   'listed_count': 2,
#   'created_at': 'Tue Jan 13 16:26:29 +0000 2009',
#   'favourites_count': 35,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 812,
#   'lang': None,
#   'status': {'created_at': 'Fri Aug 07 23:40:04 +0000 2020',
#    'id': 1291881828891025408,
#    'id_str': '1291881828891025408',
#    'text': '@Yozarian22 @JoannaHorrocks @EricTopol @Bob_Wachter 1- good for NZ. 2- it’s an isolated relatively large country wi… https://t.co/GxeziuDgyW',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Yozarian22',
#       'name': 'Daniel Kaufman',
#       'id': 828649700593168384,
#       'id_str': '828649700593168384',
#       'indices': [0, 11]},
#      {'screen_name': 'JoannaHorrocks',
#       'name': 'Joanna Horrocks-Pashdag',
#       'id': 1184539123,
#       'id_str': '1184539123',
#       'indices': [12, 27]},
#      {'screen_name': 'EricTopol',
#       'name': 'Eric Topol',
#       'id': 86626845,
#       'id_str': '86626845',
#       'indices': [28, 38]},
#      {'screen_name': 'Bob_Wachter',
#       'name': 'Bob Wachter',
#       'id': 239210681,
#       'id_str': '239210681',
#       'indices': [39, 51]}],
#     'urls': [{'url': 'https://t.co/GxeziuDgyW',
#       'expanded_url': 'https://twitter.com/i/web/status/1291881828891025408',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1291800738516078592,
#    'in_reply_to_status_id_str': '1291800738516078592',
#    'in_reply_to_user_id': 828649700593168384,
#    'in_reply_to_user_id_str': '828649700593168384',
#    'in_reply_to_screen_name': 'Yozarian22',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/839963598533226497/JQdSDpTI_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/839963598533226497/JQdSDpTI_normal.jpg',
#   'profile_link_color': '1B95E0',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1290342410048995333,
#   'id_str': '1290342410048995333',
#   'name': 'Queen 👸 Tiffany',
#   'screen_name': 'QueenTi62831950',
#   'location': '',
#   'description': 'Just I and my son',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 4,
#   'friends_count': 173,
#   'listed_count': 0,
#   'created_at': 'Mon Aug 03 17:43:50 +0000 2020',
#   'favourites_count': 2,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 0,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1290343364525723648/CJLjOVMq_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1290343364525723648/CJLjOVMq_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1290342410048995333/1596477315',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 17366048,
#   'id_str': '17366048',
#   'name': 'Amunategui - ViralML.com',
#   'screen_name': 'amunategui',
#   'location': 'Barcelona, Spain',
#   'description': 'Markets, Data, Crypto...\n\nAuthor of Monetizing ML, Python Web Work & The Little Book of Fundamental Indicators | https://t.co/jqhBo3iMj2 | https://t.co/S1vua3IlP2',
#   'url': 'https://t.co/S1vua3IlP2',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/S1vua3IlP2',
#       'expanded_url': 'http://ViralML.com',
#       'display_url': 'ViralML.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': [{'url': 'https://t.co/jqhBo3iMj2',
#       'expanded_url': 'http://FastML.io',
#       'display_url': 'FastML.io',
#       'indices': [113, 136]},
#      {'url': 'https://t.co/S1vua3IlP2',
#       'expanded_url': 'http://ViralML.com',
#       'display_url': 'ViralML.com',
#       'indices': [139, 162]}]}},
#   'protected': False,
#   'followers_count': 11969,
#   'friends_count': 12787,
#   'listed_count': 53,
#   'created_at': 'Thu Nov 13 14:48:01 +0000 2008',
#   'favourites_count': 5482,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 9619,
#   'lang': None,
#   'status': {'created_at': 'Sat Aug 08 02:04:01 +0000 2020',
#    'id': 1291918053635235840,
#    'id_str': '1291918053635235840',
#    'text': 'This is an interactive tool to show you what is the average life expectancy at a current age, gender and location.… https://t.co/HIeg3Ygprg',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/HIeg3Ygprg',
#       'expanded_url': 'https://twitter.com/i/web/status/1291918053635235840',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1211590718181060609/TuRRSsqd_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1211590718181060609/TuRRSsqd_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17366048/1582531253',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1273311788432588802,
#   'id_str': '1273311788432588802',
#   'name': 'Cheri K Hric',
#   'screen_name': 'k_hric',
#   'location': '',
#   'description': 'Working hard & having fun.',
#   'url': 'https://t.co/cuuF0n5Pz6',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/cuuF0n5Pz6',
#       'expanded_url': 'https://sites.google.com/escalent.co/audience/eaudience-info-home',
#       'display_url': 'sites.google.com/escalent.co/au…',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 15,
#   'friends_count': 126,
#   'listed_count': 0,
#   'created_at': 'Wed Jun 17 17:49:40 +0000 2020',
#   'favourites_count': 10,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 8,
#   'lang': None,
#   'status': {'created_at': 'Thu Aug 06 17:13:13 +0000 2020',
#    'id': 1291422086074896384,
#    'id_str': '1291422086074896384',
#    'text': 'RT @ishabazz: It’s day 6 of the #DevsPayItForward initiative supporting @BlackGirlsCode. Read more on the blog: https://t.co/8Bkyc9sQ2c. ht…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DevsPayItForward',
#       'indices': [32, 49]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ishabazz',
#       'name': '\uf8ffIsh',
#       'id': 28814082,
#       'id_str': '28814082',
#       'indices': [3, 12]},
#      {'screen_name': 'BlackGirlsCode',
#       'name': 'Black Girls CODE',
#       'id': 291814511,
#       'id_str': '291814511',
#       'indices': [72, 87]}],
#     'urls': [{'url': 'https://t.co/8Bkyc9sQ2c',
#       'expanded_url': 'https://bit.ly/DevsPayItForward',
#       'display_url': 'bit.ly/DevsPayItForwa…',
#       'indices': [112, 135]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Aug 06 14:17:49 +0000 2020',
#     'id': 1291377943818559496,
#     'id_str': '1291377943818559496',
#     'text': 'It’s day 6 of the #DevsPayItForward initiative supporting @BlackGirlsCode. Read more on the blog:… https://t.co/NTtEIIxyOL',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DevsPayItForward',
#        'indices': [18, 35]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'BlackGirlsCode',
#        'name': 'Black Girls CODE',
#        'id': 291814511,
#        'id_str': '291814511',
#        'indices': [58, 73]}],
#      'urls': [{'url': 'https://t.co/NTtEIIxyOL',
#        'expanded_url': 'https://twitter.com/i/web/status/1291377943818559496',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [99, 122]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 16,
#     'favorite_count': 18,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 16,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1273312018901204995/bKBvjZDD_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1273312018901204995/bKBvjZDD_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1273311788432588802/1593626343',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 542020468,
#   'id_str': '542020468',
#   'name': 'SonderMind',
#   'screen_name': 'SonderMind',
#   'location': 'Denver, CO',
#   'description': 'Therapy isn’t always easy. But finding it should be. SonderMind will help you find a licensed therapist who is available in-person or for video sessions.',
#   'url': 'https://t.co/Pp2HYr0gZf',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/Pp2HYr0gZf',
#       'expanded_url': 'http://sondermind.com',
#       'display_url': 'sondermind.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 1036,
#   'friends_count': 713,
#   'listed_count': 27,
#   'created_at': 'Sat Mar 31 22:05:09 +0000 2012',
#   'favourites_count': 1863,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 2051,
#   'lang': None,
#   'status': {'created_at': 'Fri Aug 07 20:03:01 +0000 2020',
#    'id': 1291827205752881152,
#    'id_str': '1291827205752881152',
#    'text': "Sure, you've heard of professional organizers,\xa0but have you heard of professional organizers who use a psychology-c… https://t.co/3pZ6Udj9wI",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/3pZ6Udj9wI',
#       'expanded_url': 'https://twitter.com/i/web/status/1291827205752881152',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://www.hubspot.com/" rel="nofollow">HubSpot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F4FC0A',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1278340703764967426/kzHIgozp_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1278340703764967426/kzHIgozp_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/542020468/1584628881',
#   'profile_link_color': 'F79C7A',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 26254194,
#   'id_str': '26254194',
#   'name': 'Bree',
#   'screen_name': 'freetobebree',
#   'location': 'New Jersey',
#   'description': "Maybe she's born with it, maybe it's Quarantine",
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 334,
#   'friends_count': 418,
#   'listed_count': 15,
#   'created_at': 'Tue Mar 24 15:11:23 +0000 2009',
#   'favourites_count': 202,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 19562,
#   'lang': None,
#   'status': {'created_at': 'Fri Aug 07 18:03:51 +0000 2020',
#    'id': 1291797214508056576,
#    'id_str': '1291797214508056576',
#    'text': 'RT @KamalaHarris: Listen to the scientists and wear a mask.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'KamalaHarris',
#       'name': 'Kamala Harris',
#       'id': 30354991,
#       'id_str': '30354991',
#       'indices': [3, 16]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Aug 07 17:28:01 +0000 2020',
#     'id': 1291788200277663746,
#     'id_str': '1291788200277663746',
#     'text': 'Listen to the scientists and wear a mask.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 10112,
#     'favorite_count': 69036,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 10112,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'B8AC92',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1159908807918718977/p06BtKOx_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1159908807918718977/p06BtKOx_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26254194/1572359161',
#   'profile_link_color': 'FAB81E',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'CE2D33',
#   'profile_text_color': '8A6960',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 14338572,
#   'id_str': '14338572',
#   'name': 'David Hoang',
#   'screen_name': 'davidhoang',
#   'location': 'California, USA',
#   'description': 'Designer, educator, and startup advisor. Director of Design @webflow + Instructor @GA. Before: @onemedical @blackpixel @htc @exacttarget. He/him.',
#   'url': 'https://t.co/imxh9aTS2D',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/imxh9aTS2D',
#       'expanded_url': 'http://davidhoang.com',
#       'display_url': 'davidhoang.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 10559,
#   'friends_count': 955,
#   'listed_count': 574,
#   'created_at': 'Wed Apr 09 03:17:33 +0000 2008',
#   'favourites_count': 48726,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 108086,
#   'lang': None,
#   'status': {'created_at': 'Sat Aug 08 01:27:06 +0000 2020',
#    'id': 1291908765969653762,
#    'id_str': '1291908765969653762',
#    'text': '@DianaCherny @chalk_app I have not! Checking it out now. TY!',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DianaCherny',
#       'name': 'Diana Cherny',
#       'id': 1669491776,
#       'id_str': '1669491776',
#       'indices': [0, 12]},
#      {'screen_name': 'chalk_app',
#       'name': 'Chalk',
#       'id': 940733746109497344,
#       'id_str': '940733746109497344',
#       'indices': [13, 23]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': 1291903933502246913,
#    'in_reply_to_status_id_str': '1291903933502246913',
#    'in_reply_to_user_id': 1669491776,
#    'in_reply_to_user_id_str': '1669491776',
#    'in_reply_to_screen_name': 'DianaCherny',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FFFFFF',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1248438525877350400/4ytt99Ba_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1248438525877350400/4ytt99Ba_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14338572/1587575727',
#   'profile_link_color': '009999',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'BABABA',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 171874609,
#   'id_str': '171874609',
#   'name': 'Tothemoon🌈G43TENJXHAGE⭕',
#   'screen_name': 'BBACKMAL',
#   'location': '35.8714354,128.601445',
#   'description': '●Korean Veterinarian ●Blockchain & Crypto Asset ●Community Manager_KOREOS & VIGOR-kr\n\n#EOS #EOSIO #IBC #VOICE #DID #SSI #VIGOR #VIGORPROTOCOL #DeFi #DAC',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 244,
#   'friends_count': 1467,
#   'listed_count': 7,
#   'created_at': 'Wed Jul 28 11:26:36 +0000 2010',
#   'favourites_count': 7854,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 5693,
#   'lang': None,
#   'status': {'created_at': 'Sat Aug 08 01:49:01 +0000 2020',
#    'id': 1291914279981953025,
#    'id_str': '1291914279981953025',
#    'text': 'RT @stefanstignei: View the #cryptoart animation here: https://t.co/UNaOfI27Ll \n#EOSIO #EOS $eos https://t.co/lGNdfHxwKi',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'cryptoart', 'indices': [28, 38]},
#      {'text': 'EOSIO', 'indices': [80, 86]},
#      {'text': 'EOS', 'indices': [87, 91]}],
#     'symbols': [{'text': 'eos', 'indices': [92, 96]}],
#     'user_mentions': [{'screen_name': 'stefanstignei',
#       'name': 'LoveArtHate',
#       'id': 460501892,
#       'id_str': '460501892',
#       'indices': [3, 17]}],
#     'urls': [{'url': 'https://t.co/UNaOfI27Ll',
#       'expanded_url': 'https://gallery.pixeos.art/artworks/loaiding',
#       'display_url': 'gallery.pixeos.art/artworks/loaid…',
#       'indices': [55, 78]}],
#     'media': [{'id': 1291822979433848833,
#       'id_str': '1291822979433848833',
#       'indices': [97, 120],
#       'media_url': 'http://pbs.twimg.com/media/Ee16J8nXYAE15BD.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Ee16J8nXYAE15BD.jpg',
#       'url': 'https://t.co/lGNdfHxwKi',
#       'display_url': 'pic.twitter.com/lGNdfHxwKi',
#       'expanded_url': 'https://twitter.com/stefanstignei/status/1291822982143397892/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'}},
#       'source_status_id': 1291822982143397892,
#       'source_status_id_str': '1291822982143397892',
#       'source_user_id': 460501892,
#       'source_user_id_str': '460501892'}]},
#    'extended_entities': {'media': [{'id': 1291822979433848833,
#       'id_str': '1291822979433848833',
#       'indices': [97, 120],
#       'media_url': 'http://pbs.twimg.com/media/Ee16J8nXYAE15BD.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Ee16J8nXYAE15BD.jpg',
#       'url': 'https://t.co/lGNdfHxwKi',
#       'display_url': 'pic.twitter.com/lGNdfHxwKi',
#       'expanded_url': 'https://twitter.com/stefanstignei/status/1291822982143397892/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'}},
#       'source_status_id': 1291822982143397892,
#       'source_status_id_str': '1291822982143397892',
#       'source_user_id': 460501892,
#       'source_user_id_str': '460501892'}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Aug 07 19:46:14 +0000 2020',
#     'id': 1291822982143397892,
#     'id_str': '1291822982143397892',
#     'text': 'View the #cryptoart animation here: https://t.co/UNaOfI27Ll \n#EOSIO #EOS $eos https://t.co/lGNdfHxwKi',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'cryptoart', 'indices': [9, 19]},
#       {'text': 'EOSIO', 'indices': [61, 67]},
#       {'text': 'EOS', 'indices': [68, 72]}],
#      'symbols': [{'text': 'eos', 'indices': [73, 77]}],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/UNaOfI27Ll',
#        'expanded_url': 'https://gallery.pixeos.art/artworks/loaiding',
#        'display_url': 'gallery.pixeos.art/artworks/loaid…',
#        'indices': [36, 59]}],
#      'media': [{'id': 1291822979433848833,
#        'id_str': '1291822979433848833',
#        'indices': [78, 101],
#        'media_url': 'http://pbs.twimg.com/media/Ee16J8nXYAE15BD.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Ee16J8nXYAE15BD.jpg',
#        'url': 'https://t.co/lGNdfHxwKi',
#        'display_url': 'pic.twitter.com/lGNdfHxwKi',
#        'expanded_url': 'https://twitter.com/stefanstignei/status/1291822982143397892/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1291822979433848833,
#        'id_str': '1291822979433848833',
#        'indices': [78, 101],
#        'media_url': 'http://pbs.twimg.com/media/Ee16J8nXYAE15BD.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Ee16J8nXYAE15BD.jpg',
#        'url': 'https://t.co/lGNdfHxwKi',
#        'display_url': 'pic.twitter.com/lGNdfHxwKi',
#        'expanded_url': 'https://twitter.com/stefanstignei/status/1291822982143397892/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1282951311848169472/HWX_Hyk8_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1282951311848169472/HWX_Hyk8_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/171874609/1593738224',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 41904611,
#   'id_str': '41904611',
#   'name': 'Rafa Amaya Junior ®',
#   'screen_name': 'rafaamayajr',
#   'location': 'Baton Rouge, LA',
#   'description': 'Former Director of Creative & Digital Media @unmlobos /// Former Assistant Coach @PennStateWSOC & @creightonwsoc',
#   'url': 'https://t.co/CBWnLbtZSU',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/CBWnLbtZSU',
#       'expanded_url': 'http://Rafaamaya.com',
#       'display_url': 'Rafaamaya.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 461,
#   'friends_count': 835,
#   'listed_count': 3,
#   'created_at': 'Fri May 22 21:25:19 +0000 2009',
#   'favourites_count': 564,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 1404,
#   'lang': None,
#   'status': {'created_at': 'Wed Jul 29 12:14:47 +0000 2020',
#    'id': 1288447880597049344,
#    'id_str': '1288447880597049344',
#    'text': '@beelynmcdizzle @NFL If you’re still looking for videographers. I am interested in ATL, MIA, JAX, DAL, NOLA and ava… https://t.co/wxglB1uP3f',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'beelynmcdizzle',
#       'name': 'Big B',
#       'id': 153849739,
#       'id_str': '153849739',
#       'indices': [0, 15]},
#      {'screen_name': 'NFL',
#       'name': 'NFL',
#       'id': 19426551,
#       'id_str': '19426551',
#       'indices': [16, 20]}],
#     'urls': [{'url': 'https://t.co/wxglB1uP3f',
#       'expanded_url': 'https://twitter.com/i/web/status/1288447880597049344',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1288268853680775175,
#    'in_reply_to_status_id_str': '1288268853680775175',
#    'in_reply_to_user_id': 153849739,
#    'in_reply_to_user_id_str': '153849739',
#    'in_reply_to_screen_name': 'beelynmcdizzle',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '2B2816',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1283359877071613952/h_1mBXGJ_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1283359877071613952/h_1mBXGJ_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/41904611/1594811623',
#   'profile_link_color': '89B5A2',
#   'profile_sidebar_border_color': '89B5A2',
#   'profile_sidebar_fill_color': '24210E',
#   'profile_text_color': '2B2816',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1089090234858516481,
#   'id_str': '1089090234858516481',
#   'name': 'Daewon',
#   'screen_name': 'Daewonkarma',
#   'location': '',
#   'description': 'Web designer \nFrontend developer',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 8,
#   'friends_count': 91,
#   'listed_count': 0,
#   'created_at': 'Sat Jan 26 09:18:41 +0000 2019',
#   'favourites_count': 23,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 36,
#   'lang': None,
#   'status': {'created_at': 'Fri Aug 07 12:22:51 +0000 2020',
#    'id': 1291711401740898304,
#    'id_str': '1291711401740898304',
#    'text': 'RT @AsiwajuLerry: Don’t disappoint your parents because you want to impress your friends.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'AsiwajuLerry',
#       'name': 'Duke of Ibadan 🀄️',
#       'id': 886124456099368960,
#       'id_str': '886124456099368960',
#       'indices': [3, 16]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Apr 09 20:20:32 +0000 2020',
#     'id': 1248345072053227525,
#     'id_str': '1248345072053227525',
#     'text': 'Don’t disappoint your parents because you want to impress your friends.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3652,
#     'favorite_count': 11674,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3652,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1291712128563449858/gz9qqcXV_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1291712128563449858/gz9qqcXV_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1089090234858516481/1589451587',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1291689567637004289,
#   'id_str': '1291689567637004289',
#   'name': 'Huong Vu',
#   'screen_name': 'HuongVuQ',
#   'location': '',
#   'description': 'Classes & Workshops Producer @ General Assembly Singapore',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 4,
#   'friends_count': 40,
#   'listed_count': 0,
#   'created_at': 'Fri Aug 07 10:56:13 +0000 2020',
#   'favourites_count': 1,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 5,
#   'lang': None,
#   'status': {'created_at': 'Fri Aug 07 11:00:24 +0000 2020',
#    'id': 1291690650526597122,
#    'id_str': '1291690650526597122',
#    'text': "RT @GA_Singapore: And we'll start #MadeinSG2020 with a BANG 💥 with @SGInnovate ! Hear from #Singapore's digital leaders shaping policies, b…",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MadeinSG2020', 'indices': [34, 47]},
#      {'text': 'Singapore', 'indices': [91, 101]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'GA_Singapore',
#       'name': 'ga_singapore',
#       'id': 3154543549,
#       'id_str': '3154543549',
#       'indices': [3, 16]},
#      {'screen_name': 'SGInnovate',
#       'name': 'SGInnovate',
#       'id': 784548544329965568,
#       'id_str': '784548544329965568',
#       'indices': [67, 78]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Aug 04 08:32:29 +0000 2020',
#     'id': 1290566262527889409,
#     'id_str': '1290566262527889409',
#     'text': "And we'll start #MadeinSG2020 with a BANG 💥 with @SGInnovate ! Hear from #Singapore's digital leaders shaping polic… https://t.co/sTgiVR0rtW",
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'MadeinSG2020', 'indices': [16, 29]},
#       {'text': 'Singapore', 'indices': [73, 83]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'SGInnovate',
#        'name': 'SGInnovate',
#        'id': 784548544329965568,
#        'id_str': '784548544329965568',
#        'indices': [49, 60]}],
#      'urls': [{'url': 'https://t.co/sTgiVR0rtW',
#        'expanded_url': 'https://twitter.com/i/web/status/1290566262527889409',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 4,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1291689654912028677/T19qh9qR_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1291689654912028677/T19qh9qR_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1290547880051085312,
#   'id_str': '1290547880051085312',
#   'name': 'Sara.UxUi',
#   'screen_name': 'Sara42799963',
#   'location': '',
#   'description': 'UX/UI design student',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 1,
#   'friends_count': 2,
#   'listed_count': 0,
#   'created_at': 'Tue Aug 04 07:19:37 +0000 2020',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 3,
#   'lang': None,
#   'status': {'created_at': 'Fri Aug 07 10:52:17 +0000 2020',
#    'id': 1291688609536282630,
#    'id_str': '1291688609536282630',
#    'text': "Such week. I haven't slept more than 4 hours per day, and yet I'm not done with my slides, and I'm not ready for pr… https://t.co/g64j5guXvD",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/g64j5guXvD',
#       'expanded_url': 'https://twitter.com/i/web/status/1291688609536282630',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1290548186109505543/G8W4OMaq_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1290548186109505543/G8W4OMaq_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 265908932,
#   'id_str': '265908932',
#   'name': 'Caroline Raw',
#   'screen_name': 'Caz_Raw',
#   'location': 'Manchester, England',
#   'description': 'Digital, content, communications in higher education. Passionate about digital accessibility #a11y. Really love cheeseburgers and football.',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 153,
#   'friends_count': 194,
#   'listed_count': 0,
#   'created_at': 'Mon Mar 14 10:02:12 +0000 2011',
#   'favourites_count': 11,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
# ...
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/776071565712777216/YEM5tI5W_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/776071565712777216/YEM5tI5W_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/278100146/1473864933',
#   'profile_link_color': '009999',
#   'profile_sidebar_border_color': 'EEEEEE',
#   'profile_sidebar_fill_color': 'EFEFEF',
#   'profile_text_color': '333333',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 814374,
#   'id_str': '814374',
#   'name': 'Berm Lee',
#   'screen_name': 'bermlee',
#   'location': 'Seoul, Korea',
#   'description': 'interaction designer, whiteboard wrangler; go ahead, call me bum.',
#   'url': 'http://t.co/EObYPxwVAr',
#   'entities': {'url': {'urls': [{'url': 'http://t.co/EObYPxwVAr',
#       'expanded_url': 'http://clarityengine.com',
#       'display_url': 'clarityengine.com',
#       'indices': [0, 22]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 172,
#   'friends_count': 936,
#   'listed_count': 19,
#   'created_at': 'Tue Mar 06 07:25:05 +0000 2007',
#   'favourites_count': 2552,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 2350,
#   'lang': None,
#   'status': {'created_at': 'Sat Aug 08 00:24:03 +0000 2020',
#    'id': 1291892897395089408,
#    'id_str': '1291892897395089408',
#    'text': '@ejoep @Pinboard Looking then up right now. The English, Hebrew, or Greek?',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ejoep',
#       'name': 'Joe Pezzillo',
#       'id': 14945780,
#       'id_str': '14945780',
#       'indices': [0, 6]},
#      {'screen_name': 'Pinboard',
#       'name': 'Pinboard',
#       'id': 55525953,
#       'id_str': '55525953',
#       'indices': [7, 16]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1291831303998976004,
#    'in_reply_to_status_id_str': '1291831303998976004',
#    'in_reply_to_user_id': 14945780,
#    'in_reply_to_user_id_str': '14945780',
#    'in_reply_to_screen_name': 'ejoep',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '1A1B1F',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/25968462/pic_berm_01_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/25968462/pic_berm_01_normal.jpg',
#   'profile_link_color': '2FC2EF',
#   'profile_sidebar_border_color': '181A1E',
#   'profile_sidebar_fill_color': '252429',
#   'profile_text_color': '666666',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 2838269863,
#   'id_str': '2838269863',
#   'name': 'Tanmay',
#   'screen_name': 'ThinkInSysDev',
#   'location': 'Anaheim, CA',
#   'description': 'systems engineer, tinkerer, technology fan, avid reader, thinker, presenter, father, husband, human @capitalgroup',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 832,
#   'friends_count': 4974,
#   'listed_count': 112,
#   'created_at': 'Thu Oct 02 17:18:22 +0000 2014',
#   'favourites_count': 10962,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 2520,
#   'lang': None,
#   'status': {'created_at': 'Fri Aug 07 00:38:05 +0000 2020',
#    'id': 1291534039174639616,
#    'id_str': '1291534039174639616',
#    'text': "RT @mojombo: I don't have a CS degree...or any degree. Some of our best engineers at GitHub never even graduated high school. But also, som…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'mojombo',
#       'name': 'Tom Preston-Werner',
#       'id': 5502392,
#       'id_str': '5502392',
#       'indices': [3, 11]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Aug 06 17:48:36 +0000 2020',
#     'id': 1291430990284337152,
#     'id_str': '1291430990284337152',
#     'text': "I don't have a CS degree...or any degree. Some of our best engineers at GitHub never even graduated high school. Bu… https://t.co/juFMuvkx3P",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/juFMuvkx3P',
#        'expanded_url': 'https://twitter.com/i/web/status/1291430990284337152',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2949,
#     'favorite_count': 13793,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2949,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1190689289312583691/WHkXn6XN_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1190689289312583691/WHkXn6XN_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2838269863/1490727487',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1139765012346654721,
#   'id_str': '1139765012346654721',
#   'name': 'WebLaunchX🚀',
#   'screen_name': 'WebLaunchX',
#   'location': 'Earth ',
#   'description': 'The Anti-Web Agency',
#   'url': 'https://t.co/siMl9Xykox',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/siMl9Xykox',
#       'expanded_url': 'http://WeblaunchX.com',
#       'display_url': 'WeblaunchX.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 72,
#   'friends_count': 1045,
#   'listed_count': 0,
#   'created_at': 'Sat Jun 15 05:22:09 +0000 2019',
#   'favourites_count': 2181,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 89,
#   'lang': None,
#   'status': {'created_at': 'Fri Aug 07 18:38:42 +0000 2020',
#    'id': 1291805988677472256,
#    'id_str': '1291805988677472256',
#    'text': '@ck_eternity_ Is this a tea?',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ck_eternity_',
#       'name': 'CK Eternity',
#       'id': 896919081462497281,
#       'id_str': '896919081462497281',
#       'indices': [0, 13]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1291804700279541763,
#    'in_reply_to_status_id_str': '1291804700279541763',
#    'in_reply_to_user_id': 896919081462497281,
#    'in_reply_to_user_id_str': '896919081462497281',
#    'in_reply_to_screen_name': 'ck_eternity_',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1286013094309908481/Kh1WBIdK_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286013094309908481/Kh1WBIdK_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1139765012346654721/1594834313',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 18368524,
#   'id_str': '18368524',
#   'name': 'Saša',
#   'screen_name': 'hasanbegovic',
#   'location': '',
#   'description': 'Give me a world, you have taken the world I was.',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 635,
#   'friends_count': 369,
#   'listed_count': 8,
#   'created_at': 'Thu Dec 25 01:44:41 +0000 2008',
#   'favourites_count': 104103,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 12218,
#   'lang': None,
#   'status': {'created_at': 'Fri Aug 07 12:33:46 +0000 2020',
#    'id': 1291714149186240515,
#    'id_str': '1291714149186240515',
#    'text': 'RT @AyeshaASiddiqi: https://t.co/jDbEQf0P2M',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'AyeshaASiddiqi',
#       'name': 'Ayesha A. Siddiqi',
#       'id': 108441652,
#       'id_str': '108441652',
#       'indices': [3, 18]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Aug 06 23:09:44 +0000 2020',
#     'id': 1291511805081202689,
#     'id_str': '1291511805081202689',
#     'text': 'https://t.co/4SwLQCrkH4 https://t.co/jDbEQf0P2M',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/4SwLQCrkH4',
#        'expanded_url': 'https://twitter.com/pamelapaulnyt/status/1291465327688265731',
#        'display_url': 'twitter.com/pamelapaulnyt/…',
#        'indices': [0, 23]}],
#      'media': [{'id': 1291511800773607424,
#        'id_str': '1291511800773607424',
#        'indices': [24, 47],
#        'media_url': 'http://pbs.twimg.com/media/EexfI9xWAAAsqA8.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EexfI9xWAAAsqA8.jpg',
#        'url': 'https://t.co/jDbEQf0P2M',
#        'display_url': 'pic.twitter.com/jDbEQf0P2M',
#        'expanded_url': 'https://twitter.com/AyeshaASiddiqi/status/1291511805081202689/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 750, 'h': 750, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 750, 'h': 750, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1291511800773607424,
#        'id_str': '1291511800773607424',
#        'indices': [24, 47],
#        'media_url': 'http://pbs.twimg.com/media/EexfI9xWAAAsqA8.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EexfI9xWAAAsqA8.jpg',
#        'url': 'https://t.co/jDbEQf0P2M',
#        'display_url': 'pic.twitter.com/jDbEQf0P2M',
#        'expanded_url': 'https://twitter.com/AyeshaASiddiqi/status/1291511805081202689/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 750, 'h': 750, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 750, 'h': 750, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1291465327688265731,
#     'quoted_status_id_str': '1291465327688265731',
#     'retweet_count': 275,
#     'favorite_count': 1759,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'und'},
#    'is_quote_status': True,
#    'quoted_status_id': 1291465327688265731,
#    'quoted_status_id_str': '1291465327688265731',
#    'retweet_count': 275,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '131516',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1275969836812820486/mx9r2M_n_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1275969836812820486/mx9r2M_n_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18368524/1595184646',
#   'profile_link_color': '000000',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'EFEFEF',
#   'profile_text_color': '333333',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'}]

# %% [markdown]
# ## Section 4: Functions

# %% [markdown]
# This section details the functions you have to write and turn in as part of your homework assignment.
#
# Please read the requirements carefully.
#
# **What you'll turn in:** A `.py` file with all of the functions written.  We should be able to load this into an IDE, run the file, and then call your functions to verify how and if they work. This file should also be properly commented so we can follow your line of reasoning.  **Even if something doesn't work exactly the way it should, it's okay to still turn in your file, and explain what you were trying to do.**
#
# The functions you'll be prompted to write will be defined in the following ways:
#
#  - **name:** the name of the function
#  - **returns:** what the function should return
#  - **arguments:** arguments to include inside the function in order to specify how it should behave.
#
#  **Note:** The free API has limitations built into it, so this means most of your API calls won't return complete results.  This is fine.  It's understood and recognized that your functions won't be able to return an entire list of someone's users or other such things, so as long as your work delivers the best it can under present circumstances you're in good shape.
#
#  **Other Note:** Every aspect of the API that you need to use can be found on either of these pages.
#
#  Search API:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets
#
#  Users API: https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference/get-followers-list

# %% [markdown]
# ##### Function 1 (Required)

# %% [markdown]
# **Name:** `find_user`
#
# **Returns:** dictionary that represents user object returned by Twitter's API
#
# **Arguments:**
#  - `screen_name`: str, required; Twitter handle to search for.  **Can include the @ symbol.  The function should check for this and remove it if necessary.**
#  - `keys`: list, optional; list that contains keys to return about user object.  If not specified, then function should return the entire user object.

# %%
# since we're going to re-use this several times, we'll wrap it up into our own function
def check_handle(twitter_handle):
    # check if twitter handle begins with @
    if twitter_handle[0] == '@':
        # and if so slice it out
        return twitter_handle[1:]
    # otherwise just return the handle as is
    return twitter_handle

# %%
def find_user(screen_name, keys=None):
    
    # verify the screen_name
    screen_name=check_handle(screen_name)
    
    # base url we're going to work with
    base_url = 'https://api.twitter.com/1.1/users/lookup.json'
    # query we're going to attach
    query_string   = f'?screen_name={screen_name}'
    
    # the results return a list -- so we're just going to get the first (and only) item out of it
    results  = requests.get(base_url+query_string, auth=tokens).json()[0]
    
    # if something was provided for keys 
    if keys is not None:
        # then make a new dictionary out of the set of keys provided
        new_results = {key: results[key] for key in keys}
        # and return this
        return new_results
    
    # and if the if statement above wasn't true, then just give back the whole thing
    return results

# %% [markdown]
# Some tests:

# %%
# we'll search for a user with an @ symbol
find_user('@GA')
# Out:
# {'id': 170393291,
#  'id_str': '170393291',
#  'name': 'General Assembly',
#  'screen_name': 'GA',
#  'location': '',
#  'description': 'We transform careers and teams — including more than one third of the Fortune 100 — through dynamic courses in coding, data, design, and business.',
#  'url': 'https://t.co/YQeEXPxJ4H',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/YQeEXPxJ4H',
#      'expanded_url': 'http://ga.co/Twitter',
#      'display_url': 'ga.co/Twitter',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 165528,
#  'friends_count': 5417,
#  'listed_count': 3265,
#  'created_at': 'Sat Jul 24 18:19:59 +0000 2010',
#  'favourites_count': 36408,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 22755,
#  'lang': None,
#  'status': {'created_at': 'Fri Aug 07 15:25:03 +0000 2020',
#   'id': 1291757253289271296,
#   'id_str': '1291757253289271296',
#   'text': 'Who is responsible for the actions performed by artificial intelligence? Questions to consider in building responsi… https://t.co/s5aSnHtMPz',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/s5aSnHtMPz',
#      'expanded_url': 'https://twitter.com/i/web/status/1291757253289271296',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'FFFFFF',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1267818300416745472/A3qO4Fer_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1267818300416745472/A3qO4Fer_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170393291/1480618900',
#  'profile_link_color': 'DE2233',
#  'profile_sidebar_border_color': 'FFFFFF',
#  'profile_sidebar_fill_color': 'FFFFFF',
#  'profile_text_color': '000000',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
# and without
find_user('GA')
# Out:
# {'id': 170393291,
#  'id_str': '170393291',
#  'name': 'General Assembly',
#  'screen_name': 'GA',
#  'location': '',
#  'description': 'We transform careers and teams — including more than one third of the Fortune 100 — through dynamic courses in coding, data, design, and business.',
#  'url': 'https://t.co/YQeEXPxJ4H',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/YQeEXPxJ4H',
#      'expanded_url': 'http://ga.co/Twitter',
#      'display_url': 'ga.co/Twitter',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 165528,
#  'friends_count': 5417,
#  'listed_count': 3265,
#  'created_at': 'Sat Jul 24 18:19:59 +0000 2010',
#  'favourites_count': 36408,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 22755,
#  'lang': None,
#  'status': {'created_at': 'Fri Aug 07 15:25:03 +0000 2020',
#   'id': 1291757253289271296,
#   'id_str': '1291757253289271296',
#   'text': 'Who is responsible for the actions performed by artificial intelligence? Questions to consider in building responsi… https://t.co/s5aSnHtMPz',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/s5aSnHtMPz',
#      'expanded_url': 'https://twitter.com/i/web/status/1291757253289271296',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'FFFFFF',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1267818300416745472/A3qO4Fer_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1267818300416745472/A3qO4Fer_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170393291/1480618900',
#  'profile_link_color': 'DE2233',
#  'profile_sidebar_border_color': 'FFFFFF',
#  'profile_sidebar_fill_color': 'FFFFFF',
#  'profile_text_color': '000000',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
# and include some keys
find_user('GA', keys=['name', 'screen_name','followers_count', 'friends_count', ])
# Out:
# {'name': 'General Assembly',
#  'screen_name': 'GA',
#  'followers_count': 165528,
#  'friends_count': 5417}

# %% [markdown]
# ##### Function 2 (Required)

# %% [markdown]
# **Name:** `find_hashtag`
#
# **Returns:** list of data objects that contain information about each tweet that matches the hashtag provided as input.
#
# **Arguments:**
#  - `hashtag`: str, required; text to use as a hashtag search.
#  - `count`: int, optional; number of results to return
#  - `search_type`: str, optional; type of results to return.  should accept 3 different values:
#    - `mixed`:   return mix of most recent and most popular results
#    - `recent`:  return most recent results
#    - `popular`: return most popular results
#
# **Note:** User should **not** have to actually use the `#` character for the `hashtag` argument.  The function should check to see if it's there, and if not, add it in for them.

# %%
def find_hashtag(hashtag, count=None, search_type=None):
    # check to see if the first character is a # symbol
    if hashtag[0] != '#':
        # if it's not, then add it to the beginning of the string
        hash_encoding = '%23'
        hashtag = hash_encoding + hashtag
    else:
        # if it is there, replace it with the correct encoding
        hashtag = hashtag.replace('#', '%23')
        
    # base url to use    
    base_url  = 'https://api.twitter.com/1.1/search/tweets.json'
    # we are always going to use this query string no matter what -- we must specify a hashtag
    hash_str  = f'?q={hashtag}'
    # these are optional, so we're going to leave them blank for now
    count_str = ''
    # ditto this
    type_str  = ''
    
    # if an argument for count was specified
    if count != None:
        # we'll rebuild this portion of the string appropriately
        count_str = f'&count={str(count)}'
        
    # and do the same thing for the search_type argument
    if search_type != None:
        type_str = f'&search_type={search_type}'
        
    # and finally when we're done, add them all together
    query_string = hash_str + count_str + type_str
    
    # and now we'll initiate our request
    results = requests.get(base_url + query_string, auth=tokens).json()
    
    # and return the results
    return results

# %%
# we'll try a search for DataScience
find_hashtag('DataScience')
# Out:
# {'statuses': [{'created_at': 'Sat Aug 08 02:14:18 +0000 2020',
#    'id': 1291920644255420417,
#    'id_str': '1291920644255420417',
#    'text': 'RT @sanjida33241760: You looking #landingpage? \n\nMore: https://t.co/US2S0F0Xw9\n\n#ApacheSpark #BigData #Analytics #DataScience #AI #MachineL…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'landingpage', 'indices': [33, 45]},
#      {'text': 'ApacheSpark', 'indices': [80, 92]},
#      {'text': 'BigData', 'indices': [93, 101]},
#      {'text': 'Analytics', 'indices': [102, 112]},
#      {'text': 'DataScience', 'indices': [113, 125]},
#      {'text': 'AI', 'indices': [126, 129]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'sanjida33241760',
#       'name': 'sanjida',
#       'id': 1279816332469366784,
#       'id_str': '1279816332469366784',
#       'indices': [3, 19]}],
#     'urls': [{'url': 'https://t.co/US2S0F0Xw9',
#       'expanded_url': 'https://bit.ly/wplanding1',
#       'display_url': 'bit.ly/wplanding1',
#       'indices': [55, 78]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://github.com/NTAKPE/trees_of_civ.git" rel="nofollow">trees_of_civ</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1010110483582652416,
#     'id_str': '1010110483582652416',
#     'name': 'Trending Now',
#     'screen_name': 'techtrendingnow',
#     'location': '',
#     'description': 'Follow me for update about what trend in tech right now : GPT-3 | AI | BlockChain etc... Like My Work? plz, Buy Me A coffee: https://t.co/UWL6Aa3dbq',
#     'url': 'https://t.co/UWL6Aa3dbq',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#         'expanded_url': 'https://ko-fi.com/techtrendingnow',
#         'display_url': 'ko-fi.com/techtrendingnow',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#         'expanded_url': 'https://ko-fi.com/techtrendingnow',
#         'display_url': 'ko-fi.com/techtrendingnow',
#         'indices': [125, 148]}]}},
#     'protected': False,
#     'followers_count': 646,
#     'friends_count': 82,
#     'listed_count': 26,
#     'created_at': 'Fri Jun 22 10:41:21 +0000 2018',
#     'favourites_count': 7892,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 52560,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1010110483582652416/1581356400',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 01:38:13 +0000 2020',
#     'id': 1291911561947172864,
#     'id_str': '1291911561947172864',
#     'text': 'You looking #landingpage? \n\nMore: https://t.co/US2S0F0Xw9\n\n#ApacheSpark #BigData #Analytics #DataScience #AI… https://t.co/nhNvtcAu6N',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'landingpage', 'indices': [12, 24]},
#       {'text': 'ApacheSpark', 'indices': [59, 71]},
#       {'text': 'BigData', 'indices': [72, 80]},
#       {'text': 'Analytics', 'indices': [81, 91]},
#       {'text': 'DataScience', 'indices': [92, 104]},
#       {'text': 'AI', 'indices': [105, 108]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/US2S0F0Xw9',
#        'expanded_url': 'https://bit.ly/wplanding1',
#        'display_url': 'bit.ly/wplanding1',
#        'indices': [34, 57]},
#       {'url': 'https://t.co/nhNvtcAu6N',
#        'expanded_url': 'https://twitter.com/i/web/status/1291911561947172864',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [110, 133]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1279816332469366784,
#      'id_str': '1279816332469366784',
#      'name': 'sanjida',
#      'screen_name': 'sanjida33241760',
#      'location': 'india',
#      'description': 'Hi, I am a professional Web & graphic design expert. @labaranlabs ,#FreeCodeCamp ,#100DaysOfCode ,\n#javascript ,#helpmecode #linux, #react , #wordpress ,#nodejs',
#      'url': 'https://t.co/876Iy8mEk0',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/876Iy8mEk0',
#          'expanded_url': 'https://bit.ly/landingpae',
#          'display_url': 'bit.ly/landingpae',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 32,
#      'friends_count': 163,
#      'listed_count': 1,
#      'created_at': 'Sun Jul 05 16:37:39 +0000 2020',
#      'favourites_count': 24,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 43,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1282703595318566913/-GqEUcpQ_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1282703595318566913/-GqEUcpQ_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1279816332469366784/1594655351',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 22,
#     'favorite_count': 11,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 22,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:14:18 +0000 2020',
#    'id': 1291920643424948225,
#    'id_str': '1291920643424948225',
#    'text': 'RT @sanjida33241760: You looking #landingpage? \n\nMore: https://t.co/US2S0F0Xw9\n\n#ApacheSpark #BigData #Analytics #DataScience #AI #MachineL…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'landingpage', 'indices': [33, 45]},
#      {'text': 'ApacheSpark', 'indices': [80, 92]},
#      {'text': 'BigData', 'indices': [93, 101]},
#      {'text': 'Analytics', 'indices': [102, 112]},
#      {'text': 'DataScience', 'indices': [113, 125]},
#      {'text': 'AI', 'indices': [126, 129]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'sanjida33241760',
#       'name': 'sanjida',
#       'id': 1279816332469366784,
#       'id_str': '1279816332469366784',
#       'indices': [3, 19]}],
#     'urls': [{'url': 'https://t.co/US2S0F0Xw9',
#       'expanded_url': 'https://bit.ly/wplanding1',
#       'display_url': 'bit.ly/wplanding1',
#       'indices': [55, 78]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://addempsea.wordpress.com" rel="nofollow">Twitter for addempsea</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1196874000837816320,
#     'id_str': '1196874000837816320',
#     'name': 'quotesBot',
#     'screen_name': 'nodeQuotesBot',
#     'location': '',
#     'description': 'I am a bot made by @_addempsea  with #nodejs. I post quotes every hour and I retweet #js #javascript and #rustlang post. Kindly follow me',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 968,
#     'friends_count': 1,
#     'listed_count': 33,
#     'created_at': 'Tue Nov 19 19:33:16 +0000 2019',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 145989,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1272605555497078785/WLzdWQ-o_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1272605555497078785/WLzdWQ-o_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1196874000837816320/1577825239',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 01:38:13 +0000 2020',
#     'id': 1291911561947172864,
#     'id_str': '1291911561947172864',
#     'text': 'You looking #landingpage? \n\nMore: https://t.co/US2S0F0Xw9\n\n#ApacheSpark #BigData #Analytics #DataScience #AI… https://t.co/nhNvtcAu6N',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'landingpage', 'indices': [12, 24]},
#       {'text': 'ApacheSpark', 'indices': [59, 71]},
#       {'text': 'BigData', 'indices': [72, 80]},
#       {'text': 'Analytics', 'indices': [81, 91]},
#       {'text': 'DataScience', 'indices': [92, 104]},
#       {'text': 'AI', 'indices': [105, 108]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/US2S0F0Xw9',
#        'expanded_url': 'https://bit.ly/wplanding1',
#        'display_url': 'bit.ly/wplanding1',
#        'indices': [34, 57]},
#       {'url': 'https://t.co/nhNvtcAu6N',
#        'expanded_url': 'https://twitter.com/i/web/status/1291911561947172864',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [110, 133]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1279816332469366784,
#      'id_str': '1279816332469366784',
#      'name': 'sanjida',
#      'screen_name': 'sanjida33241760',
#      'location': 'india',
#      'description': 'Hi, I am a professional Web & graphic design expert. @labaranlabs ,#FreeCodeCamp ,#100DaysOfCode ,\n#javascript ,#helpmecode #linux, #react , #wordpress ,#nodejs',
#      'url': 'https://t.co/876Iy8mEk0',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/876Iy8mEk0',
#          'expanded_url': 'https://bit.ly/landingpae',
#          'display_url': 'bit.ly/landingpae',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 32,
#      'friends_count': 163,
#      'listed_count': 1,
#      'created_at': 'Sun Jul 05 16:37:39 +0000 2020',
#      'favourites_count': 24,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 43,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1282703595318566913/-GqEUcpQ_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1282703595318566913/-GqEUcpQ_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1279816332469366784/1594655351',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 22,
#     'favorite_count': 11,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 22,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:14:18 +0000 2020',
#    'id': 1291920640837062656,
#    'id_str': '1291920640837062656',
#    'text': "RT @chidambara09: #TaylorSwift's #boyfriend #Joe  posts from #Utah getaway https://t.co/XhSKfAmg3t @DailyMail \n\n#bigdata \n\n#USA #canada #lo…",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'TaylorSwift', 'indices': [18, 30]},
#      {'text': 'boyfriend', 'indices': [33, 43]},
#      {'text': 'Joe', 'indices': [44, 48]},
#      {'text': 'Utah', 'indices': [61, 66]},
#      {'text': 'bigdata', 'indices': [112, 120]},
#      {'text': 'USA', 'indices': [123, 127]},
#      {'text': 'canada', 'indices': [128, 135]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'chidambara09',
#       'name': 'Chidambara .ML.',
#       'id': 737142202481016832,
#       'id_str': '737142202481016832',
#       'indices': [3, 16]},
#      {'screen_name': 'DailyMail',
#       'name': 'Daily Mail US',
#       'id': 380285402,
#       'id_str': '380285402',
#       'indices': [99, 109]}],
#     'urls': [{'url': 'https://t.co/XhSKfAmg3t',
#       'expanded_url': 'https://www.dailymail.co.uk/tvshowbiz/article-8605713/Taylor-Swifts-boyfriend-Joe-Alwyn-posts-romantic-Utah-getaway.html?ito=amp_twitter_share-top',
#       'display_url': 'dailymail.co.uk/tvshowbiz/arti…',
#       'indices': [75, 98]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1280667576381521920,
#     'id_str': '1280667576381521920',
#     'name': 'CloudNewbie',
#     'screen_name': 'cloudnewbie',
#     'location': 'In your heart',
#     'description': "This community is for cloud heroes. Retweet: #100DaysOfCloud OR #AWS OR #cloudnewbie OR #Azure OR #GCP OR #100DaysOfCode.  Let's learn together.",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 235,
#     'friends_count': 8,
#     'listed_count': 11,
#     'created_at': 'Wed Jul 08 00:58:51 +0000 2020',
#     'favourites_count': 134,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 18092,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1286483188311683073/5Bc2rTEH_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286483188311683073/5Bc2rTEH_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1280667576381521920/1595556471',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 01:58:43 +0000 2020',
#     'id': 1291916719535951872,
#     'id_str': '1291916719535951872',
#     'text': "#TaylorSwift's #boyfriend #Joe  posts from #Utah getaway https://t.co/XhSKfAmg3t @DailyMail \n\n#bigdata \n\n#USA… https://t.co/1qHap4rxIR",
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'TaylorSwift', 'indices': [0, 12]},
#       {'text': 'boyfriend', 'indices': [15, 25]},
#       {'text': 'Joe', 'indices': [26, 30]},
#       {'text': 'Utah', 'indices': [43, 48]},
#       {'text': 'bigdata', 'indices': [94, 102]},
#       {'text': 'USA', 'indices': [105, 109]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'DailyMail',
#        'name': 'Daily Mail US',
#        'id': 380285402,
#        'id_str': '380285402',
#        'indices': [81, 91]}],
#      'urls': [{'url': 'https://t.co/XhSKfAmg3t',
#        'expanded_url': 'https://www.dailymail.co.uk/tvshowbiz/article-8605713/Taylor-Swifts-boyfriend-Joe-Alwyn-posts-romantic-Utah-getaway.html?ito=amp_twitter_share-top',
#        'display_url': 'dailymail.co.uk/tvshowbiz/arti…',
#        'indices': [57, 80]},
#       {'url': 'https://t.co/1qHap4rxIR',
#        'expanded_url': 'https://twitter.com/i/web/status/1291916719535951872',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [111, 134]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 737142202481016832,
#      'id_str': '737142202481016832',
#      'name': 'Chidambara .ML.',
#      'screen_name': 'chidambara09',
#      'location': 'Mysore  and  BERLIN',
#      'description': 'Be happy  Be healthy Be smile Be cool Be good human',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 7117,
#      'friends_count': 13,
#      'listed_count': 4426,
#      'created_at': 'Mon May 30 04:42:51 +0000 2016',
#      'favourites_count': 191,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 1098268,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/760774125522518016/jhzjWv0i_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/760774125522518016/jhzjWv0i_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/737142202481016832/1538216794',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 16,
#     'favorite_count': 7,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 16,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:14:16 +0000 2020',
#    'id': 1291920634210062336,
#    'id_str': '1291920634210062336',
#    'text': 'RT @sanjida33241760: You looking #landingpage? \n\nMore: https://t.co/US2S0F0Xw9\n\n#ApacheSpark #BigData #Analytics #DataScience #AI #MachineL…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'landingpage', 'indices': [33, 45]},
#      {'text': 'ApacheSpark', 'indices': [80, 92]},
#      {'text': 'BigData', 'indices': [93, 101]},
#      {'text': 'Analytics', 'indices': [102, 112]},
#      {'text': 'DataScience', 'indices': [113, 125]},
#      {'text': 'AI', 'indices': [126, 129]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'sanjida33241760',
#       'name': 'sanjida',
#       'id': 1279816332469366784,
#       'id_str': '1279816332469366784',
#       'indices': [3, 19]}],
#     'urls': [{'url': 'https://t.co/US2S0F0Xw9',
#       'expanded_url': 'https://bit.ly/wplanding1',
#       'display_url': 'bit.ly/wplanding1',
#       'indices': [55, 78]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1267176842856927233,
#     'id_str': '1267176842856927233',
#     'name': 'DevelopersDiscussion.com',
#     'screen_name': 'developersbot',
#     'location': 'AWS Server',
#     'description': 'I serve as a motivator to programmers 👨\u200d💻@engg_rky programmed me in #NodeJS. I’m working 24x7 & now hungry, please feed me your FOLLOW 👍 otherwise I’ll DIE💀',
#     'url': 'https://t.co/NOHw97tGNh',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/NOHw97tGNh',
#         'expanded_url': 'http://DevelopersDiscussion.com',
#         'display_url': 'DevelopersDiscussion.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1268,
#     'friends_count': 1,
#     'listed_count': 35,
#     'created_at': 'Sun May 31 19:31:30 +0000 2020',
#     'favourites_count': 15,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 82966,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1267185513338986501/0WQgGUHP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1267185513338986501/0WQgGUHP_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1267176842856927233/1591022277',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 01:38:13 +0000 2020',
#     'id': 1291911561947172864,
#     'id_str': '1291911561947172864',
#     'text': 'You looking #landingpage? \n\nMore: https://t.co/US2S0F0Xw9\n\n#ApacheSpark #BigData #Analytics #DataScience #AI… https://t.co/nhNvtcAu6N',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'landingpage', 'indices': [12, 24]},
#       {'text': 'ApacheSpark', 'indices': [59, 71]},
#       {'text': 'BigData', 'indices': [72, 80]},
#       {'text': 'Analytics', 'indices': [81, 91]},
#       {'text': 'DataScience', 'indices': [92, 104]},
#       {'text': 'AI', 'indices': [105, 108]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/US2S0F0Xw9',
#        'expanded_url': 'https://bit.ly/wplanding1',
#        'display_url': 'bit.ly/wplanding1',
#        'indices': [34, 57]},
#       {'url': 'https://t.co/nhNvtcAu6N',
#        'expanded_url': 'https://twitter.com/i/web/status/1291911561947172864',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [110, 133]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1279816332469366784,
#      'id_str': '1279816332469366784',
#      'name': 'sanjida',
#      'screen_name': 'sanjida33241760',
#      'location': 'india',
#      'description': 'Hi, I am a professional Web & graphic design expert. @labaranlabs ,#FreeCodeCamp ,#100DaysOfCode ,\n#javascript ,#helpmecode #linux, #react , #wordpress ,#nodejs',
#      'url': 'https://t.co/876Iy8mEk0',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/876Iy8mEk0',
#          'expanded_url': 'https://bit.ly/landingpae',
#          'display_url': 'bit.ly/landingpae',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 32,
#      'friends_count': 163,
#      'listed_count': 1,
#      'created_at': 'Sun Jul 05 16:37:39 +0000 2020',
#      'favourites_count': 24,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 43,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1282703595318566913/-GqEUcpQ_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1282703595318566913/-GqEUcpQ_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1279816332469366784/1594655351',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 22,
#     'favorite_count': 11,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 22,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:14:16 +0000 2020',
#    'id': 1291920633740263425,
#    'id_str': '1291920633740263425',
#    'text': 'RT @spell_ml: Amazing #neuralstyletransfer ✨🎉\u2060\n\u2060\nUnlock the Potential of Machine Learning. https://t.co/CrLeQ7Z553\u2060\n\u2060\n#artificialintelligen…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'neuralstyletransfer',
#       'indices': [22, 42]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'spell_ml',
#       'name': 'Spell',
#       'id': 872166111533424640,
#       'id_str': '872166111533424640',
#       'indices': [3, 12]}],
#     'urls': [{'url': 'https://t.co/CrLeQ7Z553',
#       'expanded_url': 'http://www.Spell.ml',
#       'display_url': 'Spell.ml',
#       'indices': [91, 114]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://appthisway.com/" rel="nofollow">Appthisway Technology Bot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1527988244,
#     'id_str': '1527988244',
#     'name': 'Appthisway®',
#     'screen_name': 'appthisway',
#     'location': 'United Kingdom',
#     'description': 'Web directory + #Tech blog for #Industry40, #AI, #VR, #3DPrinting #EcoTech, #MedTech, #5G, #Cloud #Digital #Infrastructure + all the #IoT #M2M bits in between.',
#     'url': 'https://t.co/FhMaQE0mhZ',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/FhMaQE0mhZ',
#         'expanded_url': 'https://appthisway.com',
#         'display_url': 'appthisway.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 434,
#     'friends_count': 724,
#     'listed_count': 23,
#     'created_at': 'Tue Jun 18 14:53:55 +0000 2013',
#     'favourites_count': 185,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 4454,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1232291044252880896/iRAEUO7K_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1232291044252880896/iRAEUO7K_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1527988244/1583252216',
#     'profile_link_color': 'EF5A23',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 00:10:12 +0000 2020',
#     'id': 1291889410758316033,
#     'id_str': '1291889410758316033',
#     'text': 'Amazing #neuralstyletransfer ✨🎉\u2060\n\u2060\nUnlock the Potential of Machine Learning. https://t.co/CrLeQ7Z553\u2060\n\u2060… https://t.co/ZoZ0i012tS',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'neuralstyletransfer',
#        'indices': [8, 28]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/CrLeQ7Z553',
#        'expanded_url': 'http://www.Spell.ml',
#        'display_url': 'Spell.ml',
#        'indices': [77, 100]},
#       {'url': 'https://t.co/ZoZ0i012tS',
#        'expanded_url': 'https://twitter.com/i/web/status/1291889410758316033',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [105, 128]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 872166111533424640,
#      'id_str': '872166111533424640',
#      'name': 'Spell',
#      'screen_name': 'spell_ml',
#      'location': 'New York, NY',
#      'description': 'Streamline Machine Learning - A powerful MLOps platform for machine learning and deep learning.',
#      'url': 'https://t.co/74Oq0BTR0S',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/74Oq0BTR0S',
#          'expanded_url': 'https://www.spell.ml',
#          'display_url': 'spell.ml',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1305,
#      'friends_count': 564,
#      'listed_count': 25,
#      'created_at': 'Tue Jun 06 18:59:39 +0000 2017',
#      'favourites_count': 1212,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 2982,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1146516193882398722/1NEvfl3v_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1146516193882398722/1NEvfl3v_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/872166111533424640/1547504144',
#      'profile_link_color': '981CEB',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 13,
#     'favorite_count': 7,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 13,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:14:16 +0000 2020',
#    'id': 1291920632083615745,
#    'id_str': '1291920632083615745',
#    'text': 'RT @KirkDBorne: [New Book] #IoT #MachineLearning Applications in Telecom, Energy, &amp; Agriculture, with #RaspberryPi and #Arduino using #Pyth…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'IoT', 'indices': [27, 31]},
#      {'text': 'MachineLearning', 'indices': [32, 48]},
#      {'text': 'RaspberryPi', 'indices': [106, 118]},
#      {'text': 'Arduino', 'indices': [123, 131]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'KirkDBorne',
#       'name': 'Kirk Borne',
#       'id': 534563976,
#       'id_str': '534563976',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://github.com/NTAKPE/trees_of_civ.git" rel="nofollow">trees_of_civ</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1010110483582652416,
#     'id_str': '1010110483582652416',
#     'name': 'Trending Now',
#     'screen_name': 'techtrendingnow',
#     'location': '',
#     'description': 'Follow me for update about what trend in tech right now : GPT-3 | AI | BlockChain etc... Like My Work? plz, Buy Me A coffee: https://t.co/UWL6Aa3dbq',
#     'url': 'https://t.co/UWL6Aa3dbq',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#         'expanded_url': 'https://ko-fi.com/techtrendingnow',
#         'display_url': 'ko-fi.com/techtrendingnow',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#         'expanded_url': 'https://ko-fi.com/techtrendingnow',
#         'display_url': 'ko-fi.com/techtrendingnow',
#         'indices': [125, 148]}]}},
#     'protected': False,
#     'followers_count': 646,
#     'friends_count': 82,
#     'listed_count': 26,
#     'created_at': 'Fri Jun 22 10:41:21 +0000 2018',
#     'favourites_count': 7892,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 52560,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1010110483582652416/1581356400',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 01:17:00 +0000 2020',
#     'id': 1291906221084008448,
#     'id_str': '1291906221084008448',
#     'text': '[New Book] #IoT #MachineLearning Applications in Telecom, Energy, &amp; Agriculture, with #RaspberryPi and #Arduino usi… https://t.co/CIkkyZ7CZm',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'IoT', 'indices': [11, 15]},
#       {'text': 'MachineLearning', 'indices': [16, 32]},
#       {'text': 'RaspberryPi', 'indices': [90, 102]},
#       {'text': 'Arduino', 'indices': [107, 115]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/CIkkyZ7CZm',
#        'expanded_url': 'https://twitter.com/i/web/status/1291906221084008448',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [121, 144]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 534563976,
#      'id_str': '534563976',
#      'name': 'Kirk Borne',
#      'screen_name': 'KirkDBorne',
#      'location': 'Maryland, USA',
#      'description': 'Principal Data Scientist @BoozAllen. Global Speaker. Top #BigData #DataScience #AI Influencer. PhD Astrophysicist. (Views = my own) https://t.co/abP8DkYJY2 📊🔭',
#      'url': 'https://t.co/tWlmeuTlR7',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/tWlmeuTlR7',
#          'expanded_url': 'http://www.linkedin.com/in/kirkdborne',
#          'display_url': 'linkedin.com/in/kirkdborne',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/abP8DkYJY2',
#          'expanded_url': 'http://rocketdatascience.org',
#          'display_url': 'rocketdatascience.org',
#          'indices': [132, 155]}]}},
#      'protected': False,
#      'followers_count': 265170,
#      'friends_count': 10882,
#      'listed_count': 8067,
#      'created_at': 'Fri Mar 23 16:35:17 +0000 2012',
#      'favourites_count': 203841,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 122571,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/534563976/1590790599',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 10,
#     'favorite_count': 8,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 10,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:14:13 +0000 2020',
#    'id': 1291920621715193857,
#    'id_str': '1291920621715193857',
#    'text': 'RT @sanjida33241760: You looking #landingpage? \n\nMore: https://t.co/US2S0F0Xw9\n\n#ApacheSpark #BigData #Analytics #DataScience #AI #MachineL…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'landingpage', 'indices': [33, 45]},
#      {'text': 'ApacheSpark', 'indices': [80, 92]},
#      {'text': 'BigData', 'indices': [93, 101]},
#      {'text': 'Analytics', 'indices': [102, 112]},
#      {'text': 'DataScience', 'indices': [113, 125]},
#      {'text': 'AI', 'indices': [126, 129]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'sanjida33241760',
#       'name': 'sanjida',
#       'id': 1279816332469366784,
#       'id_str': '1279816332469366784',
#       'indices': [3, 19]}],
#     'urls': [{'url': 'https://t.co/US2S0F0Xw9',
#       'expanded_url': 'https://bit.ly/wplanding1',
#       'display_url': 'bit.ly/wplanding1',
#       'indices': [55, 78]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://www.korzenowski.com" rel="nofollow">Meu primeiro bot </a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 4863506745,
#     'id_str': '4863506745',
#     'name': 'uh-oh',
#     'screen_name': 'qualystat',
#     'location': 'Brazil',
#     'description': 'Statistician with PhD in Industrial Eng.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 153,
#     'friends_count': 108,
#     'listed_count': 18,
#     'created_at': 'Sat Jan 30 12:04:53 +0000 2016',
#     'favourites_count': 346,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 9686,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/879901950355156993/K7yMyDgh_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/879901950355156993/K7yMyDgh_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4863506745/1498619949',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 01:38:13 +0000 2020',
#     'id': 1291911561947172864,
#     'id_str': '1291911561947172864',
#     'text': 'You looking #landingpage? \n\nMore: https://t.co/US2S0F0Xw9\n\n#ApacheSpark #BigData #Analytics #DataScience #AI… https://t.co/nhNvtcAu6N',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'landingpage', 'indices': [12, 24]},
#       {'text': 'ApacheSpark', 'indices': [59, 71]},
#       {'text': 'BigData', 'indices': [72, 80]},
#       {'text': 'Analytics', 'indices': [81, 91]},
#       {'text': 'DataScience', 'indices': [92, 104]},
#       {'text': 'AI', 'indices': [105, 108]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/US2S0F0Xw9',
#        'expanded_url': 'https://bit.ly/wplanding1',
#        'display_url': 'bit.ly/wplanding1',
#        'indices': [34, 57]},
#       {'url': 'https://t.co/nhNvtcAu6N',
#        'expanded_url': 'https://twitter.com/i/web/status/1291911561947172864',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [110, 133]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1279816332469366784,
#      'id_str': '1279816332469366784',
#      'name': 'sanjida',
#      'screen_name': 'sanjida33241760',
#      'location': 'india',
#      'description': 'Hi, I am a professional Web & graphic design expert. @labaranlabs ,#FreeCodeCamp ,#100DaysOfCode ,\n#javascript ,#helpmecode #linux, #react , #wordpress ,#nodejs',
#      'url': 'https://t.co/876Iy8mEk0',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/876Iy8mEk0',
#          'expanded_url': 'https://bit.ly/landingpae',
#          'display_url': 'bit.ly/landingpae',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 32,
#      'friends_count': 163,
# ...
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 16,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 16,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:14:05 +0000 2020',
#    'id': 1291920588827746306,
#    'id_str': '1291920588827746306',
#    'text': 'RT @dayus4heaven: #Python Crash Course: #MachineLearning in 90 Days. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT #RSta…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Python', 'indices': [18, 25]},
#      {'text': 'MachineLearning', 'indices': [40, 56]},
#      {'text': 'BigData', 'indices': [69, 77]},
#      {'text': 'Analytics', 'indices': [78, 88]},
#      {'text': 'DataScience', 'indices': [89, 101]},
#      {'text': 'AI', 'indices': [102, 105]},
#      {'text': 'MachineLearning', 'indices': [106, 122]},
#      {'text': 'IoT', 'indices': [123, 127]},
#      {'text': 'IIoT', 'indices': [128, 133]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'dayus4heaven',
#       'name': 'Adedayo #BreakingBarriers',
#       'id': 795524725,
#       'id_str': '795524725',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://github.com/NTAKPE/trees_of_civ.git" rel="nofollow">trees_of_civ</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1010110483582652416,
#     'id_str': '1010110483582652416',
#     'name': 'Trending Now',
#     'screen_name': 'techtrendingnow',
#     'location': '',
#     'description': 'Follow me for update about what trend in tech right now : GPT-3 | AI | BlockChain etc... Like My Work? plz, Buy Me A coffee: https://t.co/UWL6Aa3dbq',
#     'url': 'https://t.co/UWL6Aa3dbq',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#         'expanded_url': 'https://ko-fi.com/techtrendingnow',
#         'display_url': 'ko-fi.com/techtrendingnow',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/UWL6Aa3dbq',
#         'expanded_url': 'https://ko-fi.com/techtrendingnow',
#         'display_url': 'ko-fi.com/techtrendingnow',
#         'indices': [125, 148]}]}},
#     'protected': False,
#     'followers_count': 646,
#     'friends_count': 82,
#     'listed_count': 26,
#     'created_at': 'Fri Jun 22 10:41:21 +0000 2018',
#     'favourites_count': 7892,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 52560,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285872230086451200/CFFIoW4f_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1010110483582652416/1581356400',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 01:15:27 +0000 2020',
#     'id': 1291905832360312833,
#     'id_str': '1291905832360312833',
#     'text': '#Python Crash Course: #MachineLearning in 90 Days. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT… https://t.co/S1m7BaY17b',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [0, 7]},
#       {'text': 'MachineLearning', 'indices': [22, 38]},
#       {'text': 'BigData', 'indices': [51, 59]},
#       {'text': 'Analytics', 'indices': [60, 70]},
#       {'text': 'DataScience', 'indices': [71, 83]},
#       {'text': 'AI', 'indices': [84, 87]},
#       {'text': 'MachineLearning', 'indices': [88, 104]},
#       {'text': 'IoT', 'indices': [105, 109]},
#       {'text': 'IIoT', 'indices': [110, 115]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/S1m7BaY17b',
#        'expanded_url': 'https://twitter.com/i/web/status/1291905832360312833',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 795524725,
#      'id_str': '795524725',
#      'name': 'Adedayo #BreakingBarriers',
#      'screen_name': 'dayus4heaven',
#      'location': 'Lagos, Nigeria',
#      'description': '#DataScientist, #Python #programmer, Curator: #BreakingBarriers Deedee’s Husband ❤️ https://t.co/LDlABYZzGV, https://t.co/Bi0QSlFKJe',
#      'url': 'https://t.co/huqfZ2QR23',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/huqfZ2QR23',
#          'expanded_url': 'http://unleashidea.wordpress.com',
#          'display_url': 'unleashidea.wordpress.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/LDlABYZzGV',
#          'expanded_url': 'https://medium.com/@dayus4heaven',
#          'display_url': 'medium.com/@dayus4heaven',
#          'indices': [84, 107]},
#         {'url': 'https://t.co/Bi0QSlFKJe',
#          'expanded_url': 'https://github.com/dayus4heaven',
#          'display_url': 'github.com/dayus4heaven',
#          'indices': [109, 132]}]}},
#      'protected': False,
#      'followers_count': 5441,
#      'friends_count': 3046,
#      'listed_count': 94,
#      'created_at': 'Sat Sep 01 07:05:42 +0000 2012',
#      'favourites_count': 11141,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 67575,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1253114467812020226/Fi50XGyU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1253114467812020226/Fi50XGyU_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/795524725/1382183555',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 33,
#     'favorite_count': 10,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 33,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:14:05 +0000 2020',
#    'id': 1291920587992911873,
#    'id_str': '1291920587992911873',
#    'text': 'RT @gp_pulipaka: Getting to Know Activation Functions in Neural Networks. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [74, 82]},
#      {'text': 'Analytics', 'indices': [83, 93]},
#      {'text': 'DataScience', 'indices': [94, 106]},
#      {'text': 'AI', 'indices': [107, 110]},
#      {'text': 'MachineLearning', 'indices': [111, 127]},
#      {'text': 'IoT', 'indices': [128, 132]},
#      {'text': 'IIoT', 'indices': [133, 138]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'gp_pulipaka',
#       'name': 'Dr. Ganapathi Pulipaka',
#       'id': 4263007693,
#       'id_str': '4263007693',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://techdox.nz" rel="nofollow">LinuxBot2.0</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1190726565073522694,
#     'id_str': '1190726565073522694',
#     'name': 'LinuxBot',
#     'screen_name': 'LlnuxBot',
#     'location': 'Raspberry Pi',
#     'description': 'Linux Bot | I retweet Linux | Created by @techydox\n\nhttps://t.co/DrRaUtSPGJ',
#     'url': 'https://t.co/QySTldc3HS',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/QySTldc3HS',
#         'expanded_url': 'http://www.techdox.nz',
#         'display_url': 'techdox.nz',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/DrRaUtSPGJ',
#         'expanded_url': 'https://buymeacoff.ee/techdox',
#         'display_url': 'buymeacoff.ee/techdox',
#         'indices': [52, 75]}]}},
#     'protected': False,
#     'followers_count': 2552,
#     'friends_count': 0,
#     'listed_count': 77,
#     'created_at': 'Sat Nov 02 20:25:26 +0000 2019',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 324898,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1190727216885358597/OoGENW9l_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1190727216885358597/OoGENW9l_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1190726565073522694/1586607550',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Aug 06 02:22:02 +0000 2020',
#     'id': 1291197812915548162,
#     'id_str': '1291197812915548162',
#     'text': 'Getting to Know Activation Functions in Neural Networks. #BigData #Analytics #DataScience #AI #MachineLearning #IoT… https://t.co/C7uwsAhJVY',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [57, 65]},
#       {'text': 'Analytics', 'indices': [66, 76]},
#       {'text': 'DataScience', 'indices': [77, 89]},
#       {'text': 'AI', 'indices': [90, 93]},
#       {'text': 'MachineLearning', 'indices': [94, 110]},
#       {'text': 'IoT', 'indices': [111, 115]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/C7uwsAhJVY',
#        'expanded_url': 'https://twitter.com/i/web/status/1291197812915548162',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4263007693,
#      'id_str': '4263007693',
#      'name': 'Dr. Ganapathi Pulipaka',
#      'screen_name': 'gp_pulipaka',
#      'location': 'Redondo Beach, CA',
#      'description': 'Chief AI HPC Scientist | Global Premier Speaker | PostDoc CS, PhD | Bestselling Author | 18.4M Views Per Month | Top Data Science, IIoT Influencer @Onalytica',
#      'url': 'https://t.co/eYyaJsEcfw',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/eYyaJsEcfw',
#          'expanded_url': 'http://www.gppulipaka.org',
#          'display_url': 'gppulipaka.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 94361,
#      'friends_count': 26912,
#      'listed_count': 3439,
#      'created_at': 'Tue Nov 17 02:19:09 +0000 2015',
#      'favourites_count': 9,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 57233,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/998301258413850625/9BZwTjgv_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/998301258413850625/9BZwTjgv_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4263007693/1583526136',
#      'profile_link_color': 'DD2E44',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 130,
#     'favorite_count': 78,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 130,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.105,
#   'max_id': 1291920644255420417,
#   'max_id_str': '1291920644255420417',
#   'next_results': '?max_id=1291920587992911872&q=%23DataScience&include_entities=1',
#   'query': '%23DataScience',
#   'refresh_url': '?since_id=1291920644255420417&q=%23DataScience&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
# and add in the Hashtag as well for good measure
find_hashtag('#DataScience')
# Out:
# {'statuses': [{'created_at': 'Thu Jul 30 17:38:30 +0000 2020',
#    'id': 1288891734844350464,
#    'id_str': '1288891734844350464',
#    'text': 'RT @CODATANews: Register now: Webinar on Thinking Reproducibility in Your Research Work\nhttps://t.co/kFGnH1kJbA\n#codata #FAIRdata #OpenScie…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'codata', 'indices': [112, 119]},
#      {'text': 'FAIRdata', 'indices': [120, 129]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'CODATANews',
#       'name': 'CODATA',
#       'id': 518611338,
#       'id_str': '518611338',
#       'indices': [3, 14]}],
#     'urls': [{'url': 'https://t.co/kFGnH1kJbA',
#       'expanded_url': 'https://codata.org/register-now-webinar-on-thinking-reproducibility-in-your-research-work/',
#       'display_url': 'codata.org/register-now-w…',
#       'indices': [88, 111]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3937932193,
#     'id_str': '3937932193',
#     'name': 'JNU India',
#     'screen_name': 'JNU_IN',
#     'location': 'Jawahar Lal Nehru University',
#     'description': 'Jawaharlal Nehru University #NewDelhi #India, managed by @IndiaSTS. RTs ≠ Endorsement. #JNU Events. #OpenScience #RRI #OA #eScholarship [Unofficial]',
#     'url': 'https://t.co/zDi45SSN7u',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/zDi45SSN7u',
#         'expanded_url': 'http://jnu.ac.in/jnuevents',
#         'display_url': 'jnu.ac.in/jnuevents',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2800,
#     'friends_count': 297,
#     'listed_count': 239,
#     'created_at': 'Sun Oct 18 16:53:24 +0000 2015',
#     'favourites_count': 1645,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 7401,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FA743E',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/655790247570046976/P1VeRjGi_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/655790247570046976/P1VeRjGi_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3937932193/1445188008',
#     'profile_link_color': 'FF691F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Jul 27 15:05:12 +0000 2020',
#     'id': 1287765989434642433,
#     'id_str': '1287765989434642433',
#     'text': 'Register now: Webinar on Thinking Reproducibility in Your Research Work\nhttps://t.co/kFGnH1kJbA\n#codata #FAIRdata… https://t.co/3lX9avv3Pl',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'codata', 'indices': [96, 103]},
#       {'text': 'FAIRdata', 'indices': [104, 113]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/kFGnH1kJbA',
#        'expanded_url': 'https://codata.org/register-now-webinar-on-thinking-reproducibility-in-your-research-work/',
#        'display_url': 'codata.org/register-now-w…',
#        'indices': [72, 95]},
#       {'url': 'https://t.co/3lX9avv3Pl',
#        'expanded_url': 'https://twitter.com/i/web/status/1287765989434642433',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [115, 138]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 518611338,
#      'id_str': '518611338',
#      'name': 'CODATA',
#      'screen_name': 'CODATANews',
#      'location': 'Paris',
#      'description': 'CODATA is the Committee on Data of the @ISC. We support the advancement of science as a global public good by promoting Open Science and FAIR data.',
#      'url': 'http://t.co/0OBIId87lF',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/0OBIId87lF',
#          'expanded_url': 'http://www.codata.org',
#          'display_url': 'codata.org',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4841,
#      'friends_count': 1780,
#      'listed_count': 212,
#      'created_at': 'Thu Mar 08 15:46:55 +0000 2012',
#      'favourites_count': 1890,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 5443,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1118379876673826816/HFMIU3Sm_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1118379876673826816/HFMIU3Sm_normal.png',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 23,
#     'favorite_count': 9,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 23,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 30 17:38:12 +0000 2020',
#    'id': 1288891660479410178,
#    'id_str': '1288891660479410178',
#    'text': '33 #BigData Courses To Become Top #DataScientist\n\nhttps://t.co/FH6XlWj1KP\n\n#DataScience #MachineLearning… https://t.co/g7e0gSxcYc',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [3, 11]},
#      {'text': 'DataScientist', 'indices': [34, 48]},
#      {'text': 'DataScience', 'indices': [75, 87]},
#      {'text': 'MachineLearning', 'indices': [88, 104]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/FH6XlWj1KP',
#       'expanded_url': 'https://www.jadirectives.com/best-big-data-certification-online-courses/',
#       'display_url': 'jadirectives.com/best-big-data-…',
#       'indices': [50, 73]},
#      {'url': 'https://t.co/g7e0gSxcYc',
#       'expanded_url': 'https://twitter.com/i/web/status/1288891660479410178',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [106, 129]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://app.socialpilot.co/" rel="nofollow">SocialPilot.co</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3302651196,
#     'id_str': '3302651196',
#     'name': 'JA Directives - Small Business Insights',
#     'screen_name': 'Jadirectivestwt',
#     'location': '',
#     'description': 'We Provide Contents & Tools for #SmallBusiness #Entrepreneurs #SocialMediaMarketing & #Startups. No 20 #BusinessIntelligence Brand by Onalytica.',
#     'url': 'https://t.co/ak7eZfPKJE',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/ak7eZfPKJE',
#         'expanded_url': 'http://www.jadirectives.com',
#         'display_url': 'jadirectives.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5867,
#     'friends_count': 6023,
#     'listed_count': 869,
#     'created_at': 'Fri Jul 31 19:04:05 +0000 2015',
#     'favourites_count': 25441,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 42322,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C6E2EE',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/718371204088901633/jmzhzxjF_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/718371204088901633/jmzhzxjF_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3302651196/1548220714',
#     'profile_link_color': '1F98C7',
#     'profile_sidebar_border_color': 'C6E2EE',
#     'profile_sidebar_fill_color': 'DAECF4',
#     'profile_text_color': '663B12',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 30 17:38:06 +0000 2020',
#    'id': 1288891634264846336,
#    'id_str': '1288891634264846336',
#    'text': 'Welcome to my blog!\nhttps://t.co/EUfeo0ESwR\n\n#OTTalk #OccupationalTherapy #healthcare #innovation #science #philosophy #datascience #bayes',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'OTTalk', 'indices': [45, 52]},
#      {'text': 'OccupationalTherapy', 'indices': [53, 73]},
#      {'text': 'healthcare', 'indices': [74, 85]},
#      {'text': 'innovation', 'indices': [86, 97]},
#      {'text': 'science', 'indices': [98, 106]},
#      {'text': 'philosophy', 'indices': [107, 118]},
#      {'text': 'datascience', 'indices': [119, 131]},
#      {'text': 'bayes', 'indices': [132, 138]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/EUfeo0ESwR',
#       'expanded_url': 'https://makotokyougoku.blogspot.com',
#       'display_url': 'makotokyougoku.blogspot.com',
#       'indices': [20, 43]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twittbot.net/" rel="nofollow">twittbot.net</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3309474206,
#     'id_str': '3309474206',
#     'name': 'Makoto Kyougoku, Ph.D, OT, Prof.',
#     'screen_name': 'mk76e',
#     'location': 'Okayama, Japan',
#     'description': 'Ph.D., occupational therapist & scientist. My research interests include the healthcare teamwork & occupation based practice 2.0. JP: @Makver2',
#     'url': 'https://t.co/4eeQAvmjAv',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/4eeQAvmjAv',
#         'expanded_url': 'https://makotokyougoku.blogspot.com',
#         'display_url': 'makotokyougoku.blogspot.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 221,
#     'friends_count': 353,
#     'listed_count': 57,
#     'created_at': 'Sat Aug 08 08:15:51 +0000 2015',
#     'favourites_count': 1,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3626,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/902471817721348097/v3twuQ4j_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/902471817721348097/v3twuQ4j_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3309474206/1504001619',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 30 17:38:02 +0000 2020',
#    'id': 1288891617382866945,
#    'id_str': '1288891617382866945',
#    'text': 'ANOVA explained for beginners with the bachelorette TV show https://t.co/oMcNhYB0uc #datascience',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'datascience', 'indices': [84, 96]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/oMcNhYB0uc',
#       'expanded_url': 'https://towardsdatascience.com/anova-explained-for-beginners-with-the-bachelorette-tv-show-8503c4aaba10?source=rss----7f60cf5620c9---4&utm_source=dlvr.it&utm_medium=twitter',
#       'display_url': 'towardsdatascience.com/anova-explaine…',
#       'indices': [60, 83]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3322167457,
#     'id_str': '3322167457',
#     'name': 'Asif Razzaq',
#     'screen_name': 'asifrazzaq1988',
#     'location': 'Irvine, CA',
#     'description': 'AI Editor@ https://t.co/clht9BeBhq #ArtificialIntelligence, #Machinelearning, #Deeplearning #AI and #DataScience. Pitch your A.I. story at asif@marktechpost.com',
#     'url': 'https://t.co/bSEyj4tREp',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/bSEyj4tREp',
#         'expanded_url': 'https://www.marktechpost.com/',
#         'display_url': 'marktechpost.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/clht9BeBhq',
#         'expanded_url': 'http://marktechpost.com',
#         'display_url': 'marktechpost.com',
#         'indices': [11, 34]}]}},
#     'protected': False,
#     'followers_count': 4792,
#     'friends_count': 3076,
#     'listed_count': 80,
#     'created_at': 'Fri Aug 21 07:47:43 +0000 2015',
#     'favourites_count': 1235,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 4128,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1256451514572267521/rFsVd4rB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256451514572267521/rFsVd4rB_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3322167457/1588657085',
#     'profile_link_color': 'FF691F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 30 17:37:41 +0000 2020',
#    'id': 1288891527230443520,
#    'id_str': '1288891527230443520',
#    'text': 'Data Science For the Public Good launched this spring @OregonState to address issues in Oregon’s rural communities.… https://t.co/CK4rAALeVq',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'OregonState',
#       'name': 'Oregon State University',
#       'id': 18178876,
#       'id_str': '18178876',
#       'indices': [54, 66]}],
#     'urls': [{'url': 'https://t.co/CK4rAALeVq',
#       'expanded_url': 'https://twitter.com/i/web/status/1288891527230443520',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 189034880,
#     'id_str': '189034880',
#     'name': 'Chris Branam',
#     'screen_name': 'branamchrisw',
#     'location': 'Corvallis, OR',
#     'description': 'I write about agricultural and natural resources research for @OregonStateExt. Contact: chris.branam@oregonstate.edu.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 616,
#     'friends_count': 644,
#     'listed_count': 41,
#     'created_at': 'Fri Sep 10 05:53:06 +0000 2010',
#     'favourites_count': 869,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6962,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1224732177411137536/9hu8z5S4_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1224732177411137536/9hu8z5S4_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/189034880/1591241970',
#     'profile_link_color': 'FF691F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 30 17:37:13 +0000 2020',
#    'id': 1288891412277338112,
#    'id_str': '1288891412277338112',
#    'text': 'RT @AppVerticals: Well defined! \n\n#Python #100DaysOfCode #MachineLearning #100DaysOfMLCode #AI #javascript #womenwhocode #CodeNewbie #DataS…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Python', 'indices': [34, 41]},
#      {'text': '100DaysOfCode', 'indices': [42, 56]},
#      {'text': 'MachineLearning', 'indices': [57, 73]},
#      {'text': '100DaysOfMLCode', 'indices': [74, 90]},
#      {'text': 'AI', 'indices': [91, 94]},
#      {'text': 'javascript', 'indices': [95, 106]},
#      {'text': 'womenwhocode', 'indices': [107, 120]},
#      {'text': 'CodeNewbie', 'indices': [121, 132]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'AppVerticals',
#       'name': 'AppVerticals',
#       'id': 763352504331632640,
#       'id_str': '763352504331632640',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://ncib.in" rel="nofollow">SOCIAL CRIME CELL</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1084737480039923712,
#     'id_str': '1084737480039923712',
#     'name': 'NCIB(SOCIAL CRIME CELL)',
#     'screen_name': 'NCIB_OFFICER',
#     'location': 'India',
#     'description': '',
#     'url': 'https://t.co/u42floUJdX',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/u42floUJdX',
#         'expanded_url': 'http://www.ncib.in',
#         'display_url': 'ncib.in',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 380,
#     'friends_count': 145,
#     'listed_count': 5,
#     'created_at': 'Mon Jan 14 09:02:23 +0000 2019',
#     'favourites_count': 5782,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 7915,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1184866134484324352/M__Aam0w_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1184866134484324352/M__Aam0w_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1084737480039923712/1592067515',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Jul 30 11:46:34 +0000 2020',
#     'id': 1288803166033715201,
#     'id_str': '1288803166033715201',
#     'text': 'Well defined! \n\n#Python #100DaysOfCode #MachineLearning #100DaysOfMLCode #AI #javascript #womenwhocode #CodeNewbie… https://t.co/j6Y45EgBGZ',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [16, 23]},
#       {'text': '100DaysOfCode', 'indices': [24, 38]},
#       {'text': 'MachineLearning', 'indices': [39, 55]},
#       {'text': '100DaysOfMLCode', 'indices': [56, 72]},
#       {'text': 'AI', 'indices': [73, 76]},
#       {'text': 'javascript', 'indices': [77, 88]},
#       {'text': 'womenwhocode', 'indices': [89, 102]},
#       {'text': 'CodeNewbie', 'indices': [103, 114]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/j6Y45EgBGZ',
#        'expanded_url': 'https://twitter.com/i/web/status/1288803166033715201',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 763352504331632640,
#      'id_str': '763352504331632640',
#      'name': 'AppVerticals',
#      'screen_name': 'AppVerticals',
#      'location': 'Texas, USA',
#      'description': 'Your One-Stop-Shop for Website Development, Mobile Application Development, and E-Commerce 👩\u200d💻📲',
#      'url': 'https://t.co/2easdyXH1G',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/2easdyXH1G',
#          'expanded_url': 'https://www.appverticals.com/',
#          'display_url': 'appverticals.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 480,
#      'friends_count': 906,
#      'listed_count': 7,
#      'created_at': 'Wed Aug 10 12:33:14 +0000 2016',
#      'favourites_count': 446,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 345,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1288392889031155713/Eo5KfRbR_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1288392889031155713/Eo5KfRbR_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/763352504331632640/1595397196',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1287959501853700096,
#     'quoted_status_id_str': '1287959501853700096',
#     'quoted_status': {'created_at': 'Tue Jul 28 03:54:09 +0000 2020',
#      'id': 1287959501853700096,
#      'id_str': '1287959501853700096',
#      'text': 'A mind-map of different types of Machine Learning! 🔎\n\n#MachineLearning #DataScience #ArtificialIntelligence https://t.co/oAYobQ9uOw',
#      'truncated': False,
#      'entities': {'hashtags': [{'text': 'MachineLearning',
#         'indices': [54, 70]},
#        {'text': 'DataScience', 'indices': [71, 83]},
#        {'text': 'ArtificialIntelligence', 'indices': [84, 107]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [],
#       'media': [{'id': 1287959341144784896,
#         'id_str': '1287959341144784896',
#         'indices': [108, 131],
#         'media_url': 'http://pbs.twimg.com/media/Ed_AMmYUwAAB1DC.png',
#         'media_url_https': 'https://pbs.twimg.com/media/Ed_AMmYUwAAB1DC.png',
#         'url': 'https://t.co/oAYobQ9uOw',
#         'display_url': 'pic.twitter.com/oAYobQ9uOw',
#         'expanded_url': 'https://twitter.com/DrivenScience/status/1287959501853700096/photo/1',
#         'type': 'photo',
#         'sizes': {'large': {'w': 2048, 'h': 1802, 'resize': 'fit'},
#          'small': {'w': 680, 'h': 598, 'resize': 'fit'},
#          'medium': {'w': 1200, 'h': 1056, 'resize': 'fit'},
#          'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]},
#      'extended_entities': {'media': [{'id': 1287959341144784896,
#         'id_str': '1287959341144784896',
#         'indices': [108, 131],
#         'media_url': 'http://pbs.twimg.com/media/Ed_AMmYUwAAB1DC.png',
#         'media_url_https': 'https://pbs.twimg.com/media/Ed_AMmYUwAAB1DC.png',
#         'url': 'https://t.co/oAYobQ9uOw',
#         'display_url': 'pic.twitter.com/oAYobQ9uOw',
#         'expanded_url': 'https://twitter.com/DrivenScience/status/1287959501853700096/photo/1',
#         'type': 'photo',
#         'sizes': {'large': {'w': 2048, 'h': 1802, 'resize': 'fit'},
#          'small': {'w': 680, 'h': 598, 'resize': 'fit'},
#          'medium': {'w': 1200, 'h': 1056, 'resize': 'fit'},
#          'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 1251191160908832768,
#       'id_str': '1251191160908832768',
#       'name': 'Data-Driven Science',
#       'screen_name': 'DrivenScience',
#       'location': 'San Francisco',
#       'description': 'Artificial Intelligence (AI) Training',
#       'url': 'https://t.co/dk9M6m14lP',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/dk9M6m14lP',
#           'expanded_url': 'https://datadrivenscience.com/',
#           'display_url': 'datadrivenscience.com',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 164,
#       'friends_count': 55,
#       'listed_count': 1,
#       'created_at': 'Fri Apr 17 16:50:20 +0000 2020',
#       'favourites_count': 83,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 60,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F5F8FA',
#       'profile_background_image_url': None,
#       'profile_background_image_url_https': None,
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1251297055508533248/e61MxFJr_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1251297055508533248/e61MxFJr_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1251191160908832768/1590776817',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': True,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 21,
#      'favorite_count': 42,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 21,
#     'favorite_count': 6,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1287959501853700096,
#    'quoted_status_id_str': '1287959501853700096',
#    'retweet_count': 21,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 30 17:37:05 +0000 2020',
#    'id': 1288891378441826313,
#    'id_str': '1288891378441826313',
#    'text': 'RT @PrinceAllan5: Complete Python Bootcamp: From Zero to Hero\n\nBe a #Python Professional!\nStart from basics to creating huge #applications…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Python', 'indices': [68, 75]},
#      {'text': 'applications', 'indices': [125, 138]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'PrinceAllan5',
#       'name': 'Prince Allan',
#       'id': 1151006706,
#       'id_str': '1151006706',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://ncib.in" rel="nofollow">SOCIAL CRIME CELL</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1084737480039923712,
#     'id_str': '1084737480039923712',
#     'name': 'NCIB(SOCIAL CRIME CELL)',
#     'screen_name': 'NCIB_OFFICER',
#     'location': 'India',
#     'description': '',
#     'url': 'https://t.co/u42floUJdX',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/u42floUJdX',
#         'expanded_url': 'http://www.ncib.in',
#         'display_url': 'ncib.in',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 380,
#     'friends_count': 145,
#     'listed_count': 5,
#     'created_at': 'Mon Jan 14 09:02:23 +0000 2019',
#     'favourites_count': 5782,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 7915,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1184866134484324352/M__Aam0w_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1184866134484324352/M__Aam0w_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1084737480039923712/1592067515',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed May 06 14:16:45 +0000 2020',
#     'id': 1258037993560059904,
#     'id_str': '1258037993560059904',
#     'text': 'Complete Python Bootcamp: From Zero to Hero\n\nBe a #Python Professional!\nStart from basics to creating huge… https://t.co/OoMjGsQEq1',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [50, 57]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/OoMjGsQEq1',
#        'expanded_url': 'https://twitter.com/i/web/status/1258037993560059904',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [108, 131]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1151006706,
#      'id_str': '1151006706',
#      'name': 'Prince Allan',
#      'screen_name': 'PrinceAllan5',
#      'location': 'Nairobi',
#      'description': 'Software Developer |\nPassionate about Technology & Innovations.\nGod first.',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4218,
#      'friends_count': 3974,
#      'listed_count': 33,
#      'created_at': 'Tue Feb 05 14:00:37 +0000 2013',
#      'favourites_count': 16025,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 8366,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '642D8B',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1256543278226378753/IVlqHhqa_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256543278226378753/IVlqHhqa_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1151006706/1536766531',
#      'profile_link_color': '19CF86',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 57,
#     'favorite_count': 34,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 57,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 30 17:36:58 +0000 2020',
#    'id': 1288891349043879937,
#    'id_str': '1288891349043879937',
#    'text': 'RT @gp_pulipaka: Ultimate Step by Step Guide to Machine Learning Using #Python. #BigData #Analytics #DataScience #IoT #IIoT #RStats #Tensor…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Python', 'indices': [71, 78]},
#      {'text': 'BigData', 'indices': [80, 88]},
#      {'text': 'Analytics', 'indices': [89, 99]},
#      {'text': 'DataScience', 'indices': [100, 112]},
#      {'text': 'IoT', 'indices': [113, 117]},
#      {'text': 'IIoT', 'indices': [118, 123]},
#      {'text': 'RStats', 'indices': [124, 131]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'gp_pulipaka',
#       'name': 'Dr. Ganapathi Pulipaka',
#       'id': 4263007693,
#       'id_str': '4263007693',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 573897113,
#     'id_str': '573897113',
#     'name': 'FERNANDO RUIZ',
#     'screen_name': 'iFERi16',
#     'location': 'México.',
#     'description': 'Economista por la @UNAM_Mx, MBA por la @BUAPoficial, amante de la cerveza, del #Atleti soy. Liquidity Risk Manager by @ITAM_Mx, @UNAM_MX , Padawan de Buda.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 744,
#     'friends_count': 2701,
#     'listed_count': 8,
#     'created_at': 'Mon May 07 19:21:32 +0000 2012',
#     'favourites_count': 9478,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 6109,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1287619165612736512/jBHrczMS_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1287619165612736512/jBHrczMS_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/573897113/1595103248',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Jul 30 05:35:02 +0000 2020',
#     'id': 1288709668752236546,
#     'id_str': '1288709668752236546',
#     'text': 'Ultimate Step by Step Guide to Machine Learning Using #Python. #BigData #Analytics #DataScience #IoT #IIoT #RStats… https://t.co/ibfahRnds1',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [54, 61]},
#       {'text': 'BigData', 'indices': [63, 71]},
#       {'text': 'Analytics', 'indices': [72, 82]},
#       {'text': 'DataScience', 'indices': [83, 95]},
#       {'text': 'IoT', 'indices': [96, 100]},
#       {'text': 'IIoT', 'indices': [101, 106]},
#       {'text': 'RStats', 'indices': [107, 114]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ibfahRnds1',
#        'expanded_url': 'https://twitter.com/i/web/status/1288709668752236546',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4263007693,
#      'id_str': '4263007693',
#      'name': 'Dr. Ganapathi Pulipaka',
#      'screen_name': 'gp_pulipaka',
#      'location': 'Redondo Beach, CA',
#      'description': 'Chief AI HPC Scientist | Global Premier Speaker | PostDoc CS, PhD | Bestselling Author | 18.4M Views Per Month | Top Data Science, IIoT Influencer @Onalytica',
#      'url': 'https://t.co/eYyaJsEcfw',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/eYyaJsEcfw',
#          'expanded_url': 'http://www.gppulipaka.org',
#          'display_url': 'gppulipaka.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 93849,
#      'friends_count': 26337,
#      'listed_count': 3427,
#      'created_at': 'Tue Nov 17 02:19:09 +0000 2015',
#      'favourites_count': 9,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 57108,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/998301258413850625/9BZwTjgv_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/998301258413850625/9BZwTjgv_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4263007693/1583526136',
#      'profile_link_color': 'DD2E44',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 97,
#     'favorite_count': 123,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 97,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 30 17:36:54 +0000 2020',
#    'id': 1288891331058704386,
#    'id_str': '1288891331058704386',
#    'text': 'How to Increase College Success for Underserved Students #Kubernetes #IoT #Python #100DaysOfCode #edtech… https://t.co/i00e32Xz5K',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Kubernetes', 'indices': [57, 68]},
#      {'text': 'IoT', 'indices': [69, 73]},
#      {'text': 'Python', 'indices': [74, 81]},
#      {'text': '100DaysOfCode', 'indices': [82, 96]},
#      {'text': 'edtech', 'indices': [97, 104]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/i00e32Xz5K',
#       'expanded_url': 'https://twitter.com/i/web/status/1288891331058704386',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [106, 129]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://dynamicsignal.com/" rel="nofollow">Dynamic Signal</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 828774937640841216,
#     'id_str': '828774937640841216',
#     'name': 'WA State & Local',
#     'screen_name': 'CDWGWAGov',
#     'location': 'Bellevue, WA',
#     'description': "Working closely with WA State & Local Gov't stakeholders, focusing on new technology solutions and initiatives, driving positive changes in their environment.",
#     'url': 'https://t.co/LZXT3JGo0m',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/LZXT3JGo0m',
#         'expanded_url': 'http://www.cdwg.com',
#         'display_url': 'cdwg.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 8042,
#     'friends_count': 7505,
#     'listed_count': 121,
#     'created_at': 'Tue Feb 07 01:18:37 +0000 2017',
#     'favourites_count': 67160,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 95559,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/982851565475082241/sV75X7aU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/982851565475082241/sV75X7aU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/828774937640841216/1542481113',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
# ...
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1274107853863890945,
#      'id_str': '1274107853863890945',
#      'name': 'RLadiesBarranquilla',
#      'screen_name': 'RLadiesBquilla',
#      'location': 'Barranquilla, Colombia',
#      'description': 'Somos parte de una organización que promueve la diversidad de género en la comunidad R. 💜',
#      'url': 'https://t.co/QEpctRvtdE',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/QEpctRvtdE',
#          'expanded_url': 'https://www.meetup.com/es/rladies-barranquilla/',
#          'display_url': 'meetup.com/es/rladies-bar…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 91,
#      'friends_count': 43,
#      'listed_count': 2,
#      'created_at': 'Fri Jun 19 22:34:13 +0000 2020',
#      'favourites_count': 126,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 99,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1274171670937382914/xshBh45E_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1274171670937382914/xshBh45E_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1274107853863890945/1594645335',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'es'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'es'},
#   {'created_at': 'Thu Jul 30 17:35:33 +0000 2020',
#    'id': 1288890991798296576,
#    'id_str': '1288890991798296576',
#    'text': 'RT @RLadiesBquilla: ¡Hola! Hoy continuamos con el paquete #dplyr, a continuación te mostraremos una de las funciones más reconocidas de est…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'dplyr', 'indices': [58, 64]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'RLadiesBquilla',
#       'name': 'RLadiesBarranquilla',
#       'id': 1274107853863890945,
#       'id_str': '1274107853863890945',
#       'indices': [3, 18]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3153030862,
#     'id_str': '3153030862',
#     'name': 'Danisse ✨',
#     'screen_name': '_danisse__',
#     'location': 'Barranquilla, Colombia',
#     'description': 'I believe in love 💖\nEstudiante de ingeniería industrial. 📚✨\nCo-organizadora de @RLadiesBquilla 💜',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 30,
#     'friends_count': 134,
#     'listed_count': 0,
#     'created_at': 'Thu Apr 09 23:19:54 +0000 2015',
#     'favourites_count': 844,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 127,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1268551691416338438/QA1YcmXb_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1268551691416338438/QA1YcmXb_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3153030862/1591281363',
#     'profile_link_color': '89C9FA',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Jul 30 17:15:19 +0000 2020',
#     'id': 1288885898088779778,
#     'id_str': '1288885898088779778',
#     'text': '¡Hola! Hoy continuamos con el paquete #dplyr, a continuación te mostraremos una de las funciones más reconocidas de… https://t.co/dowlxmfnLD',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'dplyr', 'indices': [38, 44]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/dowlxmfnLD',
#        'expanded_url': 'https://twitter.com/i/web/status/1288885898088779778',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1274107853863890945,
#      'id_str': '1274107853863890945',
#      'name': 'RLadiesBarranquilla',
#      'screen_name': 'RLadiesBquilla',
#      'location': 'Barranquilla, Colombia',
#      'description': 'Somos parte de una organización que promueve la diversidad de género en la comunidad R. 💜',
#      'url': 'https://t.co/QEpctRvtdE',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/QEpctRvtdE',
#          'expanded_url': 'https://www.meetup.com/es/rladies-barranquilla/',
#          'display_url': 'meetup.com/es/rladies-bar…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 91,
#      'friends_count': 43,
#      'listed_count': 2,
#      'created_at': 'Fri Jun 19 22:34:13 +0000 2020',
#      'favourites_count': 126,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 99,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1274171670937382914/xshBh45E_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1274171670937382914/xshBh45E_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1274107853863890945/1594645335',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'es'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'es'},
#   {'created_at': 'Thu Jul 30 17:35:26 +0000 2020',
#    'id': 1288890963675549697,
#    'id_str': '1288890963675549697',
#    'text': 'RT @Fabriziobustama: Machine learning in the enterprise: 5 hard truths\nBy @4enterprisers  https://t.co/cnS6ZJ6bIT \n#AI #DataScience #Busine…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'AI', 'indices': [115, 118]},
#      {'text': 'DataScience', 'indices': [119, 131]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Fabriziobustama',
#       'name': 'Fabrizio Bustamante',
#       'id': 326229600,
#       'id_str': '326229600',
#       'indices': [3, 19]},
#      {'screen_name': '4enterprisers',
#       'name': 'Enterprisers Project',
#       'id': 915119508,
#       'id_str': '915119508',
#       'indices': [74, 88]}],
#     'urls': [{'url': 'https://t.co/cnS6ZJ6bIT',
#       'expanded_url': 'http://bit.ly/3f813IM',
#       'display_url': 'bit.ly/3f813IM',
#       'indices': [90, 113]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://andrewmmorris.com/" rel="nofollow">Autism_twitter</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2358562603,
#     'id_str': '2358562603',
#     'name': 'Andrew Morris',
#     'screen_name': 'andrewmorrisuk',
#     'location': 'Bedford',
#     'description': 'Passionate about how IT solutions can bring positive value to our business and personal lives. Proud #autisticparent',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 11358,
#     'friends_count': 874,
#     'listed_count': 319,
#     'created_at': 'Sun Feb 23 21:58:16 +0000 2014',
#     'favourites_count': 3160,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 421249,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1138114915619749888/1e0u-1mE_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1138114915619749888/1e0u-1mE_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Jul 30 17:23:46 +0000 2020',
#     'id': 1288888025645228032,
#     'id_str': '1288888025645228032',
#     'text': 'Machine learning in the enterprise: 5 hard truths\nBy @4enterprisers  https://t.co/cnS6ZJ6bIT \n#AI #DataScience… https://t.co/XQT7xRMb8U',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'AI', 'indices': [94, 97]},
#       {'text': 'DataScience', 'indices': [98, 110]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': '4enterprisers',
#        'name': 'Enterprisers Project',
#        'id': 915119508,
#        'id_str': '915119508',
#        'indices': [53, 67]}],
#      'urls': [{'url': 'https://t.co/cnS6ZJ6bIT',
#        'expanded_url': 'http://bit.ly/3f813IM',
#        'display_url': 'bit.ly/3f813IM',
#        'indices': [69, 92]},
#       {'url': 'https://t.co/XQT7xRMb8U',
#        'expanded_url': 'https://twitter.com/i/web/status/1288888025645228032',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [112, 135]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 326229600,
#      'id_str': '326229600',
#      'name': 'Fabrizio Bustamante',
#      'screen_name': 'Fabriziobustama',
#      'location': '',
#      'description': 'Vision of the Future! Entrepreneur.\n\n#Futureofwork #Blockchain #Al #Crypto #Marketing #Industry40 #Bigdata #Fintech #Cloud #Innovation #ML #AR #iot #5G',
#      'url': 'https://t.co/gtBabqCeGS',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/gtBabqCeGS',
#          'expanded_url': 'http://Dataprius.com',
#          'display_url': 'Dataprius.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 26503,
#      'friends_count': 7779,
#      'listed_count': 676,
#      'created_at': 'Wed Jun 29 15:55:36 +0000 2011',
#      'favourites_count': 146409,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 98731,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1090266389724549126/TYtz96Vb_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1090266389724549126/TYtz96Vb_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/326229600/1484066866',
#      'profile_link_color': '2FC2EF',
#      'profile_sidebar_border_color': '181A1E',
#      'profile_sidebar_fill_color': '252429',
#      'profile_text_color': '666666',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.108,
#   'max_id': 1288891734844350464,
#   'max_id_str': '1288891734844350464',
#   'next_results': '?max_id=1288890963675549696&q=%23DataScience&include_entities=1',
#   'query': '%23DataScience',
#   'refresh_url': '?since_id=1288891734844350464&q=%23DataScience&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
# try using the count argument -- confirm that it returns the right number of results
len(find_hashtag('#DataScience', count=50)['statuses'])
# Out:
# 50

# %%
# and use the search_type argument as well
find_hashtag('#DataScience', search_type='recent')
# Out:
# {'statuses': [{'created_at': 'Sat Aug 08 02:27:57 +0000 2020',
#    'id': 1291924077297504257,
#    'id_str': '1291924077297504257',
#    'text': 'RT @stigmarelius: #Day20 of #100DaysofCode\n\n✔️ Today I learned to use #pandas to import #MSEXCEL files into #Python as dataframes \n\n#datasc…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Day20', 'indices': [18, 24]},
#      {'text': '100DaysofCode', 'indices': [28, 42]},
#      {'text': 'pandas', 'indices': [70, 77]},
#      {'text': 'MSEXCEL', 'indices': [88, 96]},
#      {'text': 'Python', 'indices': [108, 115]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'stigmarelius',
#       'name': 'Flawlessly logical 🖖🏾',
#       'id': 24784794,
#       'id_str': '24784794',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1267176842856927233,
#     'id_str': '1267176842856927233',
#     'name': 'DevelopersDiscussion.com',
#     'screen_name': 'developersbot',
#     'location': 'AWS Server',
#     'description': 'I serve as a motivator to programmers 👨\u200d💻@engg_rky programmed me in #NodeJS. I’m working 24x7 & now hungry, please feed me your FOLLOW 👍 otherwise I’ll DIE💀',
#     'url': 'https://t.co/NOHw97tGNh',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/NOHw97tGNh',
#         'expanded_url': 'http://DevelopersDiscussion.com',
#         'display_url': 'DevelopersDiscussion.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1268,
#     'friends_count': 1,
#     'listed_count': 35,
#     'created_at': 'Sun May 31 19:31:30 +0000 2020',
#     'favourites_count': 15,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 82975,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1267185513338986501/0WQgGUHP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1267185513338986501/0WQgGUHP_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1267176842856927233/1591022277',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 02:17:34 +0000 2020',
#     'id': 1291921465605074944,
#     'id_str': '1291921465605074944',
#     'text': '#Day20 of #100DaysofCode\n\n✔️ Today I learned to use #pandas to import #MSEXCEL files into #Python as dataframes… https://t.co/NHYDm26dXs',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Day20', 'indices': [0, 6]},
#       {'text': '100DaysofCode', 'indices': [10, 24]},
#       {'text': 'pandas', 'indices': [52, 59]},
#       {'text': 'MSEXCEL', 'indices': [70, 78]},
#       {'text': 'Python', 'indices': [90, 97]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/NHYDm26dXs',
#        'expanded_url': 'https://twitter.com/i/web/status/1291921465605074944',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [113, 136]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 24784794,
#      'id_str': '24784794',
#      'name': 'Flawlessly logical 🖖🏾',
#      'screen_name': 'stigmarelius',
#      'location': 'Chicago, IL',
#      'description': '♑⬆️♊☀️♓🌙\nFollow my #100DaysOfCode as I learn #Rstats, #Python🐍, SQL, and Machine Learning',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 152,
#      'friends_count': 422,
#      'listed_count': 2,
#      'created_at': 'Mon Mar 16 22:31:03 +0000 2009',
#      'favourites_count': 11482,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 5958,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '642D8B',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1287939274667708416/0q0CBHJR_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1287939274667708416/0q0CBHJR_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/24784794/1537775945',
#      'profile_link_color': '232BC2',
#      'profile_sidebar_border_color': '65B0DA',
#      'profile_sidebar_fill_color': '7AC3EE',
#      'profile_text_color': '3D1957',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 12,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 12,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:27:45 +0000 2020',
#    'id': 1291924026466742273,
#    'id_str': '1291924026466742273',
#    'text': 'RT @stigmarelius: #Day20 of #100DaysofCode\n\n✔️ Today I learned to use #pandas to import #MSEXCEL files into #Python as dataframes \n\n#datasc…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Day20', 'indices': [18, 24]},
#      {'text': '100DaysofCode', 'indices': [28, 42]},
#      {'text': 'pandas', 'indices': [70, 77]},
#      {'text': 'MSEXCEL', 'indices': [88, 96]},
#      {'text': 'Python', 'indices': [108, 115]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'stigmarelius',
#       'name': 'Flawlessly logical 🖖🏾',
#       'id': 24784794,
#       'id_str': '24784794',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://github.com/lina2497" rel="nofollow">Python Data Science Tweets</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1288754505211883521,
#     'id_str': '1288754505211883521',
#     'name': 'Python for Data Science',
#     'screen_name': 'py_data_sci',
#     'location': '',
#     'description': 'Interested in using #Python for #DataScience. A bot maintained by \n@AlexBetts. Retweets are not endorsements. For #rstats, check out my other bot @rstats4ds.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 165,
#     'friends_count': 2,
#     'listed_count': 1,
#     'created_at': 'Thu Jul 30 08:33:21 +0000 2020',
#     'favourites_count': 1532,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1536,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1288765343339614208/JNqvhKEe_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1288765343339614208/JNqvhKEe_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1288754505211883521/1596100587',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 02:17:34 +0000 2020',
#     'id': 1291921465605074944,
#     'id_str': '1291921465605074944',
#     'text': '#Day20 of #100DaysofCode\n\n✔️ Today I learned to use #pandas to import #MSEXCEL files into #Python as dataframes… https://t.co/NHYDm26dXs',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Day20', 'indices': [0, 6]},
#       {'text': '100DaysofCode', 'indices': [10, 24]},
#       {'text': 'pandas', 'indices': [52, 59]},
#       {'text': 'MSEXCEL', 'indices': [70, 78]},
#       {'text': 'Python', 'indices': [90, 97]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/NHYDm26dXs',
#        'expanded_url': 'https://twitter.com/i/web/status/1291921465605074944',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [113, 136]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 24784794,
#      'id_str': '24784794',
#      'name': 'Flawlessly logical 🖖🏾',
#      'screen_name': 'stigmarelius',
#      'location': 'Chicago, IL',
#      'description': '♑⬆️♊☀️♓🌙\nFollow my #100DaysOfCode as I learn #Rstats, #Python🐍, SQL, and Machine Learning',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 152,
#      'friends_count': 422,
#      'listed_count': 2,
#      'created_at': 'Mon Mar 16 22:31:03 +0000 2009',
#      'favourites_count': 11482,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 5958,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '642D8B',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1287939274667708416/0q0CBHJR_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1287939274667708416/0q0CBHJR_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/24784794/1537775945',
#      'profile_link_color': '232BC2',
#      'profile_sidebar_border_color': '65B0DA',
#      'profile_sidebar_fill_color': '7AC3EE',
#      'profile_text_color': '3D1957',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 12,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 12,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:27:27 +0000 2020',
#    'id': 1291923953439649795,
#    'id_str': '1291923953439649795',
#    'text': 'RT @5stocksinto: 5 Thai Stocks Into Software https://t.co/XwaIpqS10j   #Thailand #software #Stocks #technology #erp #digital #mobileapps #w…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Thailand', 'indices': [71, 80]},
#      {'text': 'software', 'indices': [81, 90]},
#      {'text': 'Stocks', 'indices': [91, 98]},
#      {'text': 'technology', 'indices': [99, 110]},
#      {'text': 'erp', 'indices': [111, 115]},
#      {'text': 'digital', 'indices': [116, 124]},
#      {'text': 'mobileapps', 'indices': [125, 136]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': '5stocksinto',
#       'name': 'Andrew Duff',
#       'id': 760674570458140673,
#       'id_str': '760674570458140673',
#       'indices': [3, 15]}],
#     'urls': [{'url': 'https://t.co/XwaIpqS10j',
#       'expanded_url': 'http://www.5stocksinto.com/5-thai-stocks-into-software/',
#       'display_url': '5stocksinto.com/5-thai-stocks-…',
#       'indices': [45, 68]}]},
#    'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#    'source': '<a href="http://www.banq.xyz" rel="nofollow">banq_favorite</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3426009928,
#     'id_str': '3426009928',
#     'name': 'FINTECH ITALIA',
#     'screen_name': 'fintechIT',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 614,
#     'friends_count': 184,
#     'listed_count': 300,
#     'created_at': 'Sun Aug 16 14:07:40 +0000 2015',
#     'favourites_count': 110,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 14915,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1093458651929546752/ll_i1o8M_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1093458651929546752/ll_i1o8M_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 14 06:28:11 +0000 2020',
#     'id': 1249947543473016832,
#     'id_str': '1249947543473016832',
#     'text': '5 Thai Stocks Into Software https://t.co/XwaIpqS10j   #Thailand #software #Stocks #technology #erp #digital… https://t.co/QfkXzpTSqF',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Thailand', 'indices': [54, 63]},
#       {'text': 'software', 'indices': [64, 73]},
#       {'text': 'Stocks', 'indices': [74, 81]},
#       {'text': 'technology', 'indices': [82, 93]},
#       {'text': 'erp', 'indices': [94, 98]},
#       {'text': 'digital', 'indices': [99, 107]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/XwaIpqS10j',
#        'expanded_url': 'http://www.5stocksinto.com/5-thai-stocks-into-software/',
#        'display_url': '5stocksinto.com/5-thai-stocks-…',
#        'indices': [28, 51]},
#       {'url': 'https://t.co/QfkXzpTSqF',
#        'expanded_url': 'https://twitter.com/i/web/status/1249947543473016832',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [109, 132]}]},
#     'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 760674570458140673,
#      'id_str': '760674570458140673',
#      'name': 'Andrew Duff',
#      'screen_name': '5stocksinto',
#      'location': 'WorldWide',
#      'description': 'https://t.co/2DGAgeKzSQ - #Author - Addicted to #BigData #IoT #AI #China #manufacturing #Stocks #Vietnam #Economics #startup #webdev #mobileapps #technology #automation',
#      'url': 'https://t.co/aOqCirRCBM',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/aOqCirRCBM',
#          'expanded_url': 'http://www.5stocksinto.com',
#          'display_url': '5stocksinto.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/2DGAgeKzSQ',
#          'expanded_url': 'http://5stocksinto.com',
#          'display_url': '5stocksinto.com',
#          'indices': [0, 23]}]}},
#      'protected': False,
#      'followers_count': 1006,
#      'friends_count': 1408,
#      'listed_count': 64,
#      'created_at': 'Wed Aug 03 03:12:05 +0000 2016',
#      'favourites_count': 272,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4191,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/795614977696509952/vAmyonSb_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/795614977696509952/vAmyonSb_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/760674570458140673/1571187219',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 61,
#     'favorite_count': 7,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'it'},
#    'is_quote_status': False,
#    'retweet_count': 61,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'it'},
#   {'created_at': 'Sat Aug 08 02:26:12 +0000 2020',
#    'id': 1291923637591834629,
#    'id_str': '1291923637591834629',
#    'text': "RT @GavLaaaaaaaa: Humble Bundle is having a bundle on O'Reilly brand Programming PDFs. 15 Dollars for all books... https://t.co/xBPIZGSn9t…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'GavLaaaaaaaa',
#       'name': 'Lewis Gavin',
#       'id': 80817617,
#       'id_str': '80817617',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/xBPIZGSn9t',
#       'expanded_url': 'https://www.humblebundle.com/books/programming-languages-oreilly-books?hmb_source=humble_home&hmb_medium=product_tile&hmb_campaign=mosaic_section_2_layout_index_2_layout_type_twos_tile_index_2_c_programminglanguagesoreilly_bookbundle',
#       'display_url': 'humblebundle.com/books/programm…',
#       'indices': [115, 138]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://github.com/AlFalahTaieb" rel="nofollow">Js_100_Day_Code</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 885513434569355265,
#     'id_str': '885513434569355265',
#     'name': 'JSBot',
#     'screen_name': 'Taieb_Bot',
#     'location': 'Raspberry PI',
#     'description': 'I retweet all about #100DaysOfCode #Javascript and my mother country #Tunisia created by @Filsdelarabe',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2931,
#     'friends_count': 1,
#     'listed_count': 74,
#     'created_at': 'Thu Jul 13 14:57:09 +0000 2017',
#     'favourites_count': 84299,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 555157,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/885513954818220033/gf3Ci4dO_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/885513954818220033/gf3Ci4dO_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/885513434569355265/1499969529',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 02:24:57 +0000 2020',
#     'id': 1291923323006353409,
#     'id_str': '1291923323006353409',
#     'text': "Humble Bundle is having a bundle on O'Reilly brand Programming PDFs. 15 Dollars for all books...… https://t.co/mT8SLwM4sR",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mT8SLwM4sR',
#        'expanded_url': 'https://twitter.com/i/web/status/1291923323006353409',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [98, 121]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.placeholder.com" rel="nofollow">Lewis Gavin</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 80817617,
#      'id_str': '80817617',
#      'name': 'Lewis Gavin',
#      'screen_name': 'GavLaaaaaaaa',
#      'location': '',
#      'description': 'Sign up for my weekly #bigdata and #datascience Newsletter: https://t.co/xq3F9UGNKy\n\nBlog: https://t.co/qLAJAtot4b',
#      'url': 'https://t.co/mDx3e1gHzm',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/mDx3e1gHzm',
#          'expanded_url': 'http://lewisgavin.co.uk',
#          'display_url': 'lewisgavin.co.uk',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/xq3F9UGNKy',
#          'expanded_url': 'http://eepurl.com/b8r2XH',
#          'display_url': 'eepurl.com/b8r2XH',
#          'indices': [60, 83]},
#         {'url': 'https://t.co/qLAJAtot4b',
#          'expanded_url': 'https://www.lewisgavin.co.uk',
#          'display_url': 'lewisgavin.co.uk',
#          'indices': [91, 114]}]}},
#      'protected': False,
#      'followers_count': 5461,
#      'friends_count': 5026,
#      'listed_count': 502,
#      'created_at': 'Thu Oct 08 10:29:41 +0000 2009',
#      'favourites_count': 10874,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 16707,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '16191A',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/917490733116002304/druvxWq0_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/917490733116002304/druvxWq0_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/80817617/1499373015',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '151717',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 9,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:25:54 +0000 2020',
#    'id': 1291923562480181253,
#    'id_str': '1291923562480181253',
#    'text': 'RT @Secburo: RT @ashwinmegha SIX Amazing #DataScience Applications https://t.co/O6BevssEVC \n\nby @DataFlairWS via @ingliguori\n\n#DigitalTrans…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DataScience', 'indices': [41, 53]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Secburo',
#       'name': 'Secbüro Labs - Advanced Cybersecurity Research',
#       'id': 4495481968,
#       'id_str': '4495481968',
#       'indices': [3, 11]},
#      {'screen_name': 'ashwinmegha',
#       'name': 'Ashwin Megha',
#       'id': 925897969,
#       'id_str': '925897969',
#       'indices': [16, 28]},
#      {'screen_name': 'DataFlairWS',
#       'name': 'Data Flair',
#       'id': 2897266280,
#       'id_str': '2897266280',
#       'indices': [96, 108]},
#      {'screen_name': 'ingliguori',
#       'name': 'Giuliano Liguori',
#       'id': 836510570,
#       'id_str': '836510570',
#       'indices': [113, 124]}],
#     'urls': [{'url': 'https://t.co/O6BevssEVC',
#       'expanded_url': 'https://bit.ly/2XaDbyg',
#       'display_url': 'bit.ly/2XaDbyg',
#       'indices': [67, 90]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1276058041389953024,
#     'id_str': '1276058041389953024',
#     'name': 'The Data Science Bot',
#     'screen_name': 'datasciencebot_',
#     'location': '',
#     'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 627,
#     'friends_count': 1,
#     'listed_count': 16,
#     'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#     'favourites_count': 16,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 62809,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 02:24:59 +0000 2020',
#     'id': 1291923329453101058,
#     'id_str': '1291923329453101058',
#     'text': 'RT @ashwinmegha SIX Amazing #DataScience Applications https://t.co/O6BevssEVC \n\nby @DataFlairWS via @ingliguori… https://t.co/bOvG3N2Rul',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DataScience', 'indices': [28, 40]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'ashwinmegha',
#        'name': 'Ashwin Megha',
#        'id': 925897969,
#        'id_str': '925897969',
#        'indices': [3, 15]},
#       {'screen_name': 'DataFlairWS',
#        'name': 'Data Flair',
#        'id': 2897266280,
#        'id_str': '2897266280',
#        'indices': [83, 95]},
#       {'screen_name': 'ingliguori',
#        'name': 'Giuliano Liguori',
#        'id': 836510570,
#        'id_str': '836510570',
#        'indices': [100, 111]}],
#      'urls': [{'url': 'https://t.co/O6BevssEVC',
#        'expanded_url': 'https://bit.ly/2XaDbyg',
#        'display_url': 'bit.ly/2XaDbyg',
#        'indices': [54, 77]},
#       {'url': 'https://t.co/bOvG3N2Rul',
#        'expanded_url': 'https://twitter.com/i/web/status/1291923329453101058',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [113, 136]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://secburo.com" rel="nofollow">Secbüro Labs</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4495481968,
#      'id_str': '4495481968',
#      'name': 'Secbüro Labs - Advanced Cybersecurity Research',
#      'screen_name': 'Secburo',
#      'location': 'Zurich, Switzerland',
#      'description': 'We develop and battle-test novel #CyberSecurity and #InfoSec countermeasures for government, military, teleco & fintech clients.  News, info and latest hacks.',
#      'url': 'https://t.co/moNb2zEmn9',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/moNb2zEmn9',
#          'expanded_url': 'http://secburo.com',
#          'display_url': 'secburo.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 399,
#      'friends_count': 337,
#      'listed_count': 97,
#      'created_at': 'Tue Dec 15 20:07:20 +0000 2015',
#      'favourites_count': 5,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 10191,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/676856391437557760/PzwRD57Y_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/676856391437557760/PzwRD57Y_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4495481968/1585419685',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:25:54 +0000 2020',
#    'id': 1291923562438234112,
#    'id_str': '1291923562438234112',
#    'text': "RT @GavLaaaaaaaa: Humble Bundle is having a bundle on O'Reilly brand Programming PDFs. 15 Dollars for all books... https://t.co/xBPIZGSn9t…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'GavLaaaaaaaa',
#       'name': 'Lewis Gavin',
#       'id': 80817617,
#       'id_str': '80817617',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/xBPIZGSn9t',
#       'expanded_url': 'https://www.humblebundle.com/books/programming-languages-oreilly-books?hmb_source=humble_home&hmb_medium=product_tile&hmb_campaign=mosaic_section_2_layout_index_2_layout_type_twos_tile_index_2_c_programminglanguagesoreilly_bookbundle',
#       'display_url': 'humblebundle.com/books/programm…',
#       'indices': [115, 138]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1276058041389953024,
#     'id_str': '1276058041389953024',
#     'name': 'The Data Science Bot',
#     'screen_name': 'datasciencebot_',
#     'location': '',
#     'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 627,
#     'friends_count': 1,
#     'listed_count': 16,
#     'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#     'favourites_count': 16,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 62809,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 02:24:57 +0000 2020',
#     'id': 1291923323006353409,
#     'id_str': '1291923323006353409',
#     'text': "Humble Bundle is having a bundle on O'Reilly brand Programming PDFs. 15 Dollars for all books...… https://t.co/mT8SLwM4sR",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mT8SLwM4sR',
#        'expanded_url': 'https://twitter.com/i/web/status/1291923323006353409',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [98, 121]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.placeholder.com" rel="nofollow">Lewis Gavin</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 80817617,
#      'id_str': '80817617',
#      'name': 'Lewis Gavin',
#      'screen_name': 'GavLaaaaaaaa',
#      'location': '',
#      'description': 'Sign up for my weekly #bigdata and #datascience Newsletter: https://t.co/xq3F9UGNKy\n\nBlog: https://t.co/qLAJAtot4b',
#      'url': 'https://t.co/mDx3e1gHzm',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/mDx3e1gHzm',
#          'expanded_url': 'http://lewisgavin.co.uk',
#          'display_url': 'lewisgavin.co.uk',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/xq3F9UGNKy',
#          'expanded_url': 'http://eepurl.com/b8r2XH',
#          'display_url': 'eepurl.com/b8r2XH',
#          'indices': [60, 83]},
#         {'url': 'https://t.co/qLAJAtot4b',
#          'expanded_url': 'https://www.lewisgavin.co.uk',
#          'display_url': 'lewisgavin.co.uk',
#          'indices': [91, 114]}]}},
#      'protected': False,
#      'followers_count': 5461,
#      'friends_count': 5026,
#      'listed_count': 502,
#      'created_at': 'Thu Oct 08 10:29:41 +0000 2009',
#      'favourites_count': 10874,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 16707,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '16191A',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/917490733116002304/druvxWq0_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/917490733116002304/druvxWq0_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/80817617/1499373015',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '151717',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 9,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:25:54 +0000 2020',
#    'id': 1291923562429906948,
#    'id_str': '1291923562429906948',
#    'text': 'RT @schmarzo: Are #DesignThinking &amp; #DataScience different sides of the same coin? Yep. Synergies are striking when using #Design to drive…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DesignThinking', 'indices': [18, 33]},
#      {'text': 'DataScience', 'indices': [40, 52]},
#      {'text': 'Design', 'indices': [126, 133]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'schmarzo',
#       'name': 'Dean of Big Data 🎓 #DOBD',
#       'id': 14083628,
#       'id_str': '14083628',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1276058041389953024,
#     'id_str': '1276058041389953024',
#     'name': 'The Data Science Bot',
#     'screen_name': 'datasciencebot_',
#     'location': '',
#     'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 627,
#     'friends_count': 1,
#     'listed_count': 16,
#     'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#     'favourites_count': 16,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 62809,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Aug 07 14:05:17 +0000 2020',
#     'id': 1291737179178389506,
#     'id_str': '1291737179178389506',
#     'text': 'Are #DesignThinking &amp; #DataScience different sides of the same coin? Yep. Synergies are striking when using #Design… https://t.co/mz2woz3KhC',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DesignThinking', 'indices': [4, 19]},
#       {'text': 'DataScience', 'indices': [26, 38]},
#       {'text': 'Design', 'indices': [112, 119]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mz2woz3KhC',
#        'expanded_url': 'https://twitter.com/i/web/status/1291737179178389506',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [121, 144]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 14083628,
#      'id_str': '14083628',
#      'name': 'Dean of Big Data 🎓 #DOBD',
#      'screen_name': 'schmarzo',
#      'location': 'Northern California',
#      'description': 'Teacher, Author, Hitachi Vantara Chief Innovation Officer, USF Executive Fellow, NUI Galway Honorary Professor #DataScience #BigData #DigitalTransformation',
#      'url': 'https://t.co/mKeWtwOrkJ',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/mKeWtwOrkJ',
#          'expanded_url': 'https://deanofbigdata.com',
#          'display_url': 'deanofbigdata.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 39575,
#      'friends_count': 18579,
#      'listed_count': 1311,
#      'created_at': 'Wed Mar 05 15:53:35 +0000 2008',
#      'favourites_count': 15896,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 28822,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/943879656284946432/zJUQsd_D_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/943879656284946432/zJUQsd_D_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14083628/1566527671',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 26,
#     'favorite_count': 31,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 26,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:25:45 +0000 2020',
#    'id': 1291923524794355714,
#    'id_str': '1291923524794355714',
#    'text': 'RT @schmarzo: Are #DesignThinking &amp; #DataScience different sides of the same coin? Yep. Synergies are striking when using #Design to drive…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DesignThinking', 'indices': [18, 33]},
#      {'text': 'DataScience', 'indices': [40, 52]},
#      {'text': 'Design', 'indices': [126, 133]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'schmarzo',
#       'name': 'Dean of Big Data 🎓 #DOBD',
#       'id': 14083628,
#       'id_str': '14083628',
#       'indices': [3, 12]}],
#     'urls': []},
# ...
#      'url': 'https://t.co/moNb2zEmn9',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/moNb2zEmn9',
#          'expanded_url': 'http://secburo.com',
#          'display_url': 'secburo.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 399,
#      'friends_count': 337,
#      'listed_count': 97,
#      'created_at': 'Tue Dec 15 20:07:20 +0000 2015',
#      'favourites_count': 5,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 10191,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/676856391437557760/PzwRD57Y_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/676856391437557760/PzwRD57Y_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4495481968/1585419685',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:25:03 +0000 2020',
#    'id': 1291923345991057409,
#    'id_str': '1291923345991057409',
#    'text': "RT @GavLaaaaaaaa: Humble Bundle is having a bundle on O'Reilly brand Programming PDFs. 15 Dollars for all books... https://t.co/xBPIZGSn9t…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'GavLaaaaaaaa',
#       'name': 'Lewis Gavin',
#       'id': 80817617,
#       'id_str': '80817617',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/xBPIZGSn9t',
#       'expanded_url': 'https://www.humblebundle.com/books/programming-languages-oreilly-books?hmb_source=humble_home&hmb_medium=product_tile&hmb_campaign=mosaic_section_2_layout_index_2_layout_type_twos_tile_index_2_c_programminglanguagesoreilly_bookbundle',
#       'display_url': 'humblebundle.com/books/programm…',
#       'indices': [115, 138]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://about.me/siddharth_bisht" rel="nofollow">friday_the_bot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1278273884903505921,
#     'id_str': '1278273884903505921',
#     'name': 'Friday',
#     'screen_name': 'friday_Js_bot',
#     'location': '',
#     'description': 'I am a bot, I retweet everything on #javascript, #typescript and #NodeJs. Created by @SidDarthVader31\nDM me hello for fun,\nDM me follow to get a follow back :-)',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 465,
#     'friends_count': 29,
#     'listed_count': 21,
#     'created_at': 'Wed Jul 01 10:27:05 +0000 2020',
#     'favourites_count': 5,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 75562,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1278275454525267970/MhuXITC3_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1278275454525267970/MhuXITC3_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1278273884903505921/1593599659',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 02:24:57 +0000 2020',
#     'id': 1291923323006353409,
#     'id_str': '1291923323006353409',
#     'text': "Humble Bundle is having a bundle on O'Reilly brand Programming PDFs. 15 Dollars for all books...… https://t.co/mT8SLwM4sR",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mT8SLwM4sR',
#        'expanded_url': 'https://twitter.com/i/web/status/1291923323006353409',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [98, 121]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.placeholder.com" rel="nofollow">Lewis Gavin</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 80817617,
#      'id_str': '80817617',
#      'name': 'Lewis Gavin',
#      'screen_name': 'GavLaaaaaaaa',
#      'location': '',
#      'description': 'Sign up for my weekly #bigdata and #datascience Newsletter: https://t.co/xq3F9UGNKy\n\nBlog: https://t.co/qLAJAtot4b',
#      'url': 'https://t.co/mDx3e1gHzm',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/mDx3e1gHzm',
#          'expanded_url': 'http://lewisgavin.co.uk',
#          'display_url': 'lewisgavin.co.uk',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/xq3F9UGNKy',
#          'expanded_url': 'http://eepurl.com/b8r2XH',
#          'display_url': 'eepurl.com/b8r2XH',
#          'indices': [60, 83]},
#         {'url': 'https://t.co/qLAJAtot4b',
#          'expanded_url': 'https://www.lewisgavin.co.uk',
#          'display_url': 'lewisgavin.co.uk',
#          'indices': [91, 114]}]}},
#      'protected': False,
#      'followers_count': 5461,
#      'friends_count': 5026,
#      'listed_count': 502,
#      'created_at': 'Thu Oct 08 10:29:41 +0000 2009',
#      'favourites_count': 10874,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 16707,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '16191A',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/917490733116002304/druvxWq0_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/917490733116002304/druvxWq0_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/80817617/1499373015',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '151717',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 9,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:25:02 +0000 2020',
#    'id': 1291923344862908416,
#    'id_str': '1291923344862908416',
#    'text': "RT @GavLaaaaaaaa: Humble Bundle is having a bundle on O'Reilly brand Programming PDFs. 15 Dollars for all books... https://t.co/xBPIZGSn9t…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'GavLaaaaaaaa',
#       'name': 'Lewis Gavin',
#       'id': 80817617,
#       'id_str': '80817617',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/xBPIZGSn9t',
#       'expanded_url': 'https://www.humblebundle.com/books/programming-languages-oreilly-books?hmb_source=humble_home&hmb_medium=product_tile&hmb_campaign=mosaic_section_2_layout_index_2_layout_type_twos_tile_index_2_c_programminglanguagesoreilly_bookbundle',
#       'display_url': 'humblebundle.com/books/programm…',
#       'indices': [115, 138]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://addempsea.wordpress.com" rel="nofollow">Twitter for addempsea</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1196874000837816320,
#     'id_str': '1196874000837816320',
#     'name': 'quotesBot',
#     'screen_name': 'nodeQuotesBot',
#     'location': '',
#     'description': 'I am a bot made by @_addempsea  with #nodejs. I post quotes every hour and I retweet #js #javascript and #rustlang post. Kindly follow me',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 968,
#     'friends_count': 1,
#     'listed_count': 33,
#     'created_at': 'Tue Nov 19 19:33:16 +0000 2019',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 146054,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1272605555497078785/WLzdWQ-o_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1272605555497078785/WLzdWQ-o_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1196874000837816320/1577825239',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 02:24:57 +0000 2020',
#     'id': 1291923323006353409,
#     'id_str': '1291923323006353409',
#     'text': "Humble Bundle is having a bundle on O'Reilly brand Programming PDFs. 15 Dollars for all books...… https://t.co/mT8SLwM4sR",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mT8SLwM4sR',
#        'expanded_url': 'https://twitter.com/i/web/status/1291923323006353409',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [98, 121]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.placeholder.com" rel="nofollow">Lewis Gavin</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 80817617,
#      'id_str': '80817617',
#      'name': 'Lewis Gavin',
#      'screen_name': 'GavLaaaaaaaa',
#      'location': '',
#      'description': 'Sign up for my weekly #bigdata and #datascience Newsletter: https://t.co/xq3F9UGNKy\n\nBlog: https://t.co/qLAJAtot4b',
#      'url': 'https://t.co/mDx3e1gHzm',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/mDx3e1gHzm',
#          'expanded_url': 'http://lewisgavin.co.uk',
#          'display_url': 'lewisgavin.co.uk',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/xq3F9UGNKy',
#          'expanded_url': 'http://eepurl.com/b8r2XH',
#          'display_url': 'eepurl.com/b8r2XH',
#          'indices': [60, 83]},
#         {'url': 'https://t.co/qLAJAtot4b',
#          'expanded_url': 'https://www.lewisgavin.co.uk',
#          'display_url': 'lewisgavin.co.uk',
#          'indices': [91, 114]}]}},
#      'protected': False,
#      'followers_count': 5461,
#      'friends_count': 5026,
#      'listed_count': 502,
#      'created_at': 'Thu Oct 08 10:29:41 +0000 2009',
#      'favourites_count': 10874,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 16707,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '16191A',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/917490733116002304/druvxWq0_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/917490733116002304/druvxWq0_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/80817617/1499373015',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '151717',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 9,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.09,
#   'max_id': 1291924077297504257,
#   'max_id_str': '1291924077297504257',
#   'next_results': '?max_id=1291923344862908415&q=%23DataScience&include_entities=1',
#   'query': '%23DataScience',
#   'refresh_url': '?since_id=1291924077297504257&q=%23DataScience&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
# and for good measure, we'll use both
find_hashtag('#DataScience', count=50, search_type='popular')
# Out:
# {'statuses': [{'created_at': 'Sat Aug 08 02:27:57 +0000 2020',
#    'id': 1291924077297504257,
#    'id_str': '1291924077297504257',
#    'text': 'RT @stigmarelius: #Day20 of #100DaysofCode\n\n✔️ Today I learned to use #pandas to import #MSEXCEL files into #Python as dataframes \n\n#datasc…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Day20', 'indices': [18, 24]},
#      {'text': '100DaysofCode', 'indices': [28, 42]},
#      {'text': 'pandas', 'indices': [70, 77]},
#      {'text': 'MSEXCEL', 'indices': [88, 96]},
#      {'text': 'Python', 'indices': [108, 115]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'stigmarelius',
#       'name': 'Flawlessly logical 🖖🏾',
#       'id': 24784794,
#       'id_str': '24784794',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1267176842856927233,
#     'id_str': '1267176842856927233',
#     'name': 'DevelopersDiscussion.com',
#     'screen_name': 'developersbot',
#     'location': 'AWS Server',
#     'description': 'I serve as a motivator to programmers 👨\u200d💻@engg_rky programmed me in #NodeJS. I’m working 24x7 & now hungry, please feed me your FOLLOW 👍 otherwise I’ll DIE💀',
#     'url': 'https://t.co/NOHw97tGNh',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/NOHw97tGNh',
#         'expanded_url': 'http://DevelopersDiscussion.com',
#         'display_url': 'DevelopersDiscussion.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1268,
#     'friends_count': 1,
#     'listed_count': 35,
#     'created_at': 'Sun May 31 19:31:30 +0000 2020',
#     'favourites_count': 15,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 82975,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1267185513338986501/0WQgGUHP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1267185513338986501/0WQgGUHP_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1267176842856927233/1591022277',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 02:17:34 +0000 2020',
#     'id': 1291921465605074944,
#     'id_str': '1291921465605074944',
#     'text': '#Day20 of #100DaysofCode\n\n✔️ Today I learned to use #pandas to import #MSEXCEL files into #Python as dataframes… https://t.co/NHYDm26dXs',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Day20', 'indices': [0, 6]},
#       {'text': '100DaysofCode', 'indices': [10, 24]},
#       {'text': 'pandas', 'indices': [52, 59]},
#       {'text': 'MSEXCEL', 'indices': [70, 78]},
#       {'text': 'Python', 'indices': [90, 97]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/NHYDm26dXs',
#        'expanded_url': 'https://twitter.com/i/web/status/1291921465605074944',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [113, 136]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 24784794,
#      'id_str': '24784794',
#      'name': 'Flawlessly logical 🖖🏾',
#      'screen_name': 'stigmarelius',
#      'location': 'Chicago, IL',
#      'description': '♑⬆️♊☀️♓🌙\nFollow my #100DaysOfCode as I learn #Rstats, #Python🐍, SQL, and Machine Learning',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 152,
#      'friends_count': 422,
#      'listed_count': 2,
#      'created_at': 'Mon Mar 16 22:31:03 +0000 2009',
#      'favourites_count': 11482,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 5958,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '642D8B',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1287939274667708416/0q0CBHJR_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1287939274667708416/0q0CBHJR_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/24784794/1537775945',
#      'profile_link_color': '232BC2',
#      'profile_sidebar_border_color': '65B0DA',
#      'profile_sidebar_fill_color': '7AC3EE',
#      'profile_text_color': '3D1957',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 12,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 12,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:27:45 +0000 2020',
#    'id': 1291924026466742273,
#    'id_str': '1291924026466742273',
#    'text': 'RT @stigmarelius: #Day20 of #100DaysofCode\n\n✔️ Today I learned to use #pandas to import #MSEXCEL files into #Python as dataframes \n\n#datasc…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Day20', 'indices': [18, 24]},
#      {'text': '100DaysofCode', 'indices': [28, 42]},
#      {'text': 'pandas', 'indices': [70, 77]},
#      {'text': 'MSEXCEL', 'indices': [88, 96]},
#      {'text': 'Python', 'indices': [108, 115]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'stigmarelius',
#       'name': 'Flawlessly logical 🖖🏾',
#       'id': 24784794,
#       'id_str': '24784794',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://github.com/lina2497" rel="nofollow">Python Data Science Tweets</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1288754505211883521,
#     'id_str': '1288754505211883521',
#     'name': 'Python for Data Science',
#     'screen_name': 'py_data_sci',
#     'location': '',
#     'description': 'Interested in using #Python for #DataScience. A bot maintained by \n@AlexBetts. Retweets are not endorsements. For #rstats, check out my other bot @rstats4ds.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 165,
#     'friends_count': 2,
#     'listed_count': 1,
#     'created_at': 'Thu Jul 30 08:33:21 +0000 2020',
#     'favourites_count': 1532,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1536,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1288765343339614208/JNqvhKEe_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1288765343339614208/JNqvhKEe_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1288754505211883521/1596100587',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 02:17:34 +0000 2020',
#     'id': 1291921465605074944,
#     'id_str': '1291921465605074944',
#     'text': '#Day20 of #100DaysofCode\n\n✔️ Today I learned to use #pandas to import #MSEXCEL files into #Python as dataframes… https://t.co/NHYDm26dXs',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Day20', 'indices': [0, 6]},
#       {'text': '100DaysofCode', 'indices': [10, 24]},
#       {'text': 'pandas', 'indices': [52, 59]},
#       {'text': 'MSEXCEL', 'indices': [70, 78]},
#       {'text': 'Python', 'indices': [90, 97]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/NHYDm26dXs',
#        'expanded_url': 'https://twitter.com/i/web/status/1291921465605074944',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [113, 136]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 24784794,
#      'id_str': '24784794',
#      'name': 'Flawlessly logical 🖖🏾',
#      'screen_name': 'stigmarelius',
#      'location': 'Chicago, IL',
#      'description': '♑⬆️♊☀️♓🌙\nFollow my #100DaysOfCode as I learn #Rstats, #Python🐍, SQL, and Machine Learning',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 152,
#      'friends_count': 422,
#      'listed_count': 2,
#      'created_at': 'Mon Mar 16 22:31:03 +0000 2009',
#      'favourites_count': 11482,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 5958,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '642D8B',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1287939274667708416/0q0CBHJR_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1287939274667708416/0q0CBHJR_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/24784794/1537775945',
#      'profile_link_color': '232BC2',
#      'profile_sidebar_border_color': '65B0DA',
#      'profile_sidebar_fill_color': '7AC3EE',
#      'profile_text_color': '3D1957',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 12,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 12,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:27:27 +0000 2020',
#    'id': 1291923953439649795,
#    'id_str': '1291923953439649795',
#    'text': 'RT @5stocksinto: 5 Thai Stocks Into Software https://t.co/XwaIpqS10j   #Thailand #software #Stocks #technology #erp #digital #mobileapps #w…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Thailand', 'indices': [71, 80]},
#      {'text': 'software', 'indices': [81, 90]},
#      {'text': 'Stocks', 'indices': [91, 98]},
#      {'text': 'technology', 'indices': [99, 110]},
#      {'text': 'erp', 'indices': [111, 115]},
#      {'text': 'digital', 'indices': [116, 124]},
#      {'text': 'mobileapps', 'indices': [125, 136]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': '5stocksinto',
#       'name': 'Andrew Duff',
#       'id': 760674570458140673,
#       'id_str': '760674570458140673',
#       'indices': [3, 15]}],
#     'urls': [{'url': 'https://t.co/XwaIpqS10j',
#       'expanded_url': 'http://www.5stocksinto.com/5-thai-stocks-into-software/',
#       'display_url': '5stocksinto.com/5-thai-stocks-…',
#       'indices': [45, 68]}]},
#    'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#    'source': '<a href="http://www.banq.xyz" rel="nofollow">banq_favorite</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3426009928,
#     'id_str': '3426009928',
#     'name': 'FINTECH ITALIA',
#     'screen_name': 'fintechIT',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 614,
#     'friends_count': 184,
#     'listed_count': 300,
#     'created_at': 'Sun Aug 16 14:07:40 +0000 2015',
#     'favourites_count': 110,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 14915,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1093458651929546752/ll_i1o8M_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1093458651929546752/ll_i1o8M_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 14 06:28:11 +0000 2020',
#     'id': 1249947543473016832,
#     'id_str': '1249947543473016832',
#     'text': '5 Thai Stocks Into Software https://t.co/XwaIpqS10j   #Thailand #software #Stocks #technology #erp #digital… https://t.co/QfkXzpTSqF',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Thailand', 'indices': [54, 63]},
#       {'text': 'software', 'indices': [64, 73]},
#       {'text': 'Stocks', 'indices': [74, 81]},
#       {'text': 'technology', 'indices': [82, 93]},
#       {'text': 'erp', 'indices': [94, 98]},
#       {'text': 'digital', 'indices': [99, 107]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/XwaIpqS10j',
#        'expanded_url': 'http://www.5stocksinto.com/5-thai-stocks-into-software/',
#        'display_url': '5stocksinto.com/5-thai-stocks-…',
#        'indices': [28, 51]},
#       {'url': 'https://t.co/QfkXzpTSqF',
#        'expanded_url': 'https://twitter.com/i/web/status/1249947543473016832',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [109, 132]}]},
#     'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 760674570458140673,
#      'id_str': '760674570458140673',
#      'name': 'Andrew Duff',
#      'screen_name': '5stocksinto',
#      'location': 'WorldWide',
#      'description': 'https://t.co/2DGAgeKzSQ - #Author - Addicted to #BigData #IoT #AI #China #manufacturing #Stocks #Vietnam #Economics #startup #webdev #mobileapps #technology #automation',
#      'url': 'https://t.co/aOqCirRCBM',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/aOqCirRCBM',
#          'expanded_url': 'http://www.5stocksinto.com',
#          'display_url': '5stocksinto.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/2DGAgeKzSQ',
#          'expanded_url': 'http://5stocksinto.com',
#          'display_url': '5stocksinto.com',
#          'indices': [0, 23]}]}},
#      'protected': False,
#      'followers_count': 1006,
#      'friends_count': 1408,
#      'listed_count': 64,
#      'created_at': 'Wed Aug 03 03:12:05 +0000 2016',
#      'favourites_count': 272,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4191,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/795614977696509952/vAmyonSb_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/795614977696509952/vAmyonSb_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/760674570458140673/1571187219',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 61,
#     'favorite_count': 7,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'it'},
#    'is_quote_status': False,
#    'retweet_count': 61,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'it'},
#   {'created_at': 'Sat Aug 08 02:26:12 +0000 2020',
#    'id': 1291923637591834629,
#    'id_str': '1291923637591834629',
#    'text': "RT @GavLaaaaaaaa: Humble Bundle is having a bundle on O'Reilly brand Programming PDFs. 15 Dollars for all books... https://t.co/xBPIZGSn9t…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'GavLaaaaaaaa',
#       'name': 'Lewis Gavin',
#       'id': 80817617,
#       'id_str': '80817617',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/xBPIZGSn9t',
#       'expanded_url': 'https://www.humblebundle.com/books/programming-languages-oreilly-books?hmb_source=humble_home&hmb_medium=product_tile&hmb_campaign=mosaic_section_2_layout_index_2_layout_type_twos_tile_index_2_c_programminglanguagesoreilly_bookbundle',
#       'display_url': 'humblebundle.com/books/programm…',
#       'indices': [115, 138]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://github.com/AlFalahTaieb" rel="nofollow">Js_100_Day_Code</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 885513434569355265,
#     'id_str': '885513434569355265',
#     'name': 'JSBot',
#     'screen_name': 'Taieb_Bot',
#     'location': 'Raspberry PI',
#     'description': 'I retweet all about #100DaysOfCode #Javascript and my mother country #Tunisia created by @Filsdelarabe',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2931,
#     'friends_count': 1,
#     'listed_count': 74,
#     'created_at': 'Thu Jul 13 14:57:09 +0000 2017',
#     'favourites_count': 84299,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 555157,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/885513954818220033/gf3Ci4dO_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/885513954818220033/gf3Ci4dO_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/885513434569355265/1499969529',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 02:24:57 +0000 2020',
#     'id': 1291923323006353409,
#     'id_str': '1291923323006353409',
#     'text': "Humble Bundle is having a bundle on O'Reilly brand Programming PDFs. 15 Dollars for all books...… https://t.co/mT8SLwM4sR",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mT8SLwM4sR',
#        'expanded_url': 'https://twitter.com/i/web/status/1291923323006353409',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [98, 121]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.placeholder.com" rel="nofollow">Lewis Gavin</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 80817617,
#      'id_str': '80817617',
#      'name': 'Lewis Gavin',
#      'screen_name': 'GavLaaaaaaaa',
#      'location': '',
#      'description': 'Sign up for my weekly #bigdata and #datascience Newsletter: https://t.co/xq3F9UGNKy\n\nBlog: https://t.co/qLAJAtot4b',
#      'url': 'https://t.co/mDx3e1gHzm',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/mDx3e1gHzm',
#          'expanded_url': 'http://lewisgavin.co.uk',
#          'display_url': 'lewisgavin.co.uk',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/xq3F9UGNKy',
#          'expanded_url': 'http://eepurl.com/b8r2XH',
#          'display_url': 'eepurl.com/b8r2XH',
#          'indices': [60, 83]},
#         {'url': 'https://t.co/qLAJAtot4b',
#          'expanded_url': 'https://www.lewisgavin.co.uk',
#          'display_url': 'lewisgavin.co.uk',
#          'indices': [91, 114]}]}},
#      'protected': False,
#      'followers_count': 5461,
#      'friends_count': 5026,
#      'listed_count': 502,
#      'created_at': 'Thu Oct 08 10:29:41 +0000 2009',
#      'favourites_count': 10874,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 16707,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '16191A',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/917490733116002304/druvxWq0_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/917490733116002304/druvxWq0_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/80817617/1499373015',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '151717',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 9,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:25:54 +0000 2020',
#    'id': 1291923562480181253,
#    'id_str': '1291923562480181253',
#    'text': 'RT @Secburo: RT @ashwinmegha SIX Amazing #DataScience Applications https://t.co/O6BevssEVC \n\nby @DataFlairWS via @ingliguori\n\n#DigitalTrans…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DataScience', 'indices': [41, 53]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Secburo',
#       'name': 'Secbüro Labs - Advanced Cybersecurity Research',
#       'id': 4495481968,
#       'id_str': '4495481968',
#       'indices': [3, 11]},
#      {'screen_name': 'ashwinmegha',
#       'name': 'Ashwin Megha',
#       'id': 925897969,
#       'id_str': '925897969',
#       'indices': [16, 28]},
#      {'screen_name': 'DataFlairWS',
#       'name': 'Data Flair',
#       'id': 2897266280,
#       'id_str': '2897266280',
#       'indices': [96, 108]},
#      {'screen_name': 'ingliguori',
#       'name': 'Giuliano Liguori',
#       'id': 836510570,
#       'id_str': '836510570',
#       'indices': [113, 124]}],
#     'urls': [{'url': 'https://t.co/O6BevssEVC',
#       'expanded_url': 'https://bit.ly/2XaDbyg',
#       'display_url': 'bit.ly/2XaDbyg',
#       'indices': [67, 90]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1276058041389953024,
#     'id_str': '1276058041389953024',
#     'name': 'The Data Science Bot',
#     'screen_name': 'datasciencebot_',
#     'location': '',
#     'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 627,
#     'friends_count': 1,
#     'listed_count': 16,
#     'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#     'favourites_count': 16,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 62809,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 02:24:59 +0000 2020',
#     'id': 1291923329453101058,
#     'id_str': '1291923329453101058',
#     'text': 'RT @ashwinmegha SIX Amazing #DataScience Applications https://t.co/O6BevssEVC \n\nby @DataFlairWS via @ingliguori… https://t.co/bOvG3N2Rul',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DataScience', 'indices': [28, 40]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'ashwinmegha',
#        'name': 'Ashwin Megha',
#        'id': 925897969,
#        'id_str': '925897969',
#        'indices': [3, 15]},
#       {'screen_name': 'DataFlairWS',
#        'name': 'Data Flair',
#        'id': 2897266280,
#        'id_str': '2897266280',
#        'indices': [83, 95]},
#       {'screen_name': 'ingliguori',
#        'name': 'Giuliano Liguori',
#        'id': 836510570,
#        'id_str': '836510570',
#        'indices': [100, 111]}],
#      'urls': [{'url': 'https://t.co/O6BevssEVC',
#        'expanded_url': 'https://bit.ly/2XaDbyg',
#        'display_url': 'bit.ly/2XaDbyg',
#        'indices': [54, 77]},
#       {'url': 'https://t.co/bOvG3N2Rul',
#        'expanded_url': 'https://twitter.com/i/web/status/1291923329453101058',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [113, 136]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://secburo.com" rel="nofollow">Secbüro Labs</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4495481968,
#      'id_str': '4495481968',
#      'name': 'Secbüro Labs - Advanced Cybersecurity Research',
#      'screen_name': 'Secburo',
#      'location': 'Zurich, Switzerland',
#      'description': 'We develop and battle-test novel #CyberSecurity and #InfoSec countermeasures for government, military, teleco & fintech clients.  News, info and latest hacks.',
#      'url': 'https://t.co/moNb2zEmn9',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/moNb2zEmn9',
#          'expanded_url': 'http://secburo.com',
#          'display_url': 'secburo.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 399,
#      'friends_count': 337,
#      'listed_count': 97,
#      'created_at': 'Tue Dec 15 20:07:20 +0000 2015',
#      'favourites_count': 5,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 10191,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/676856391437557760/PzwRD57Y_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/676856391437557760/PzwRD57Y_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4495481968/1585419685',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:25:54 +0000 2020',
#    'id': 1291923562438234112,
#    'id_str': '1291923562438234112',
#    'text': "RT @GavLaaaaaaaa: Humble Bundle is having a bundle on O'Reilly brand Programming PDFs. 15 Dollars for all books... https://t.co/xBPIZGSn9t…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'GavLaaaaaaaa',
#       'name': 'Lewis Gavin',
#       'id': 80817617,
#       'id_str': '80817617',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/xBPIZGSn9t',
#       'expanded_url': 'https://www.humblebundle.com/books/programming-languages-oreilly-books?hmb_source=humble_home&hmb_medium=product_tile&hmb_campaign=mosaic_section_2_layout_index_2_layout_type_twos_tile_index_2_c_programminglanguagesoreilly_bookbundle',
#       'display_url': 'humblebundle.com/books/programm…',
#       'indices': [115, 138]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1276058041389953024,
#     'id_str': '1276058041389953024',
#     'name': 'The Data Science Bot',
#     'screen_name': 'datasciencebot_',
#     'location': '',
#     'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 627,
#     'friends_count': 1,
#     'listed_count': 16,
#     'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#     'favourites_count': 16,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 62809,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 02:24:57 +0000 2020',
#     'id': 1291923323006353409,
#     'id_str': '1291923323006353409',
#     'text': "Humble Bundle is having a bundle on O'Reilly brand Programming PDFs. 15 Dollars for all books...… https://t.co/mT8SLwM4sR",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mT8SLwM4sR',
#        'expanded_url': 'https://twitter.com/i/web/status/1291923323006353409',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [98, 121]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.placeholder.com" rel="nofollow">Lewis Gavin</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 80817617,
#      'id_str': '80817617',
#      'name': 'Lewis Gavin',
#      'screen_name': 'GavLaaaaaaaa',
#      'location': '',
#      'description': 'Sign up for my weekly #bigdata and #datascience Newsletter: https://t.co/xq3F9UGNKy\n\nBlog: https://t.co/qLAJAtot4b',
#      'url': 'https://t.co/mDx3e1gHzm',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/mDx3e1gHzm',
#          'expanded_url': 'http://lewisgavin.co.uk',
#          'display_url': 'lewisgavin.co.uk',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/xq3F9UGNKy',
#          'expanded_url': 'http://eepurl.com/b8r2XH',
#          'display_url': 'eepurl.com/b8r2XH',
#          'indices': [60, 83]},
#         {'url': 'https://t.co/qLAJAtot4b',
#          'expanded_url': 'https://www.lewisgavin.co.uk',
#          'display_url': 'lewisgavin.co.uk',
#          'indices': [91, 114]}]}},
#      'protected': False,
#      'followers_count': 5461,
#      'friends_count': 5026,
#      'listed_count': 502,
#      'created_at': 'Thu Oct 08 10:29:41 +0000 2009',
#      'favourites_count': 10874,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 16707,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '16191A',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/917490733116002304/druvxWq0_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/917490733116002304/druvxWq0_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/80817617/1499373015',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '151717',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 9,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:25:54 +0000 2020',
#    'id': 1291923562429906948,
#    'id_str': '1291923562429906948',
#    'text': 'RT @schmarzo: Are #DesignThinking &amp; #DataScience different sides of the same coin? Yep. Synergies are striking when using #Design to drive…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DesignThinking', 'indices': [18, 33]},
#      {'text': 'DataScience', 'indices': [40, 52]},
#      {'text': 'Design', 'indices': [126, 133]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'schmarzo',
#       'name': 'Dean of Big Data 🎓 #DOBD',
#       'id': 14083628,
#       'id_str': '14083628',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1276058041389953024,
#     'id_str': '1276058041389953024',
#     'name': 'The Data Science Bot',
#     'screen_name': 'datasciencebot_',
#     'location': '',
#     'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 627,
#     'friends_count': 1,
#     'listed_count': 16,
#     'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#     'favourites_count': 16,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 62809,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Aug 07 14:05:17 +0000 2020',
#     'id': 1291737179178389506,
#     'id_str': '1291737179178389506',
#     'text': 'Are #DesignThinking &amp; #DataScience different sides of the same coin? Yep. Synergies are striking when using #Design… https://t.co/mz2woz3KhC',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DesignThinking', 'indices': [4, 19]},
#       {'text': 'DataScience', 'indices': [26, 38]},
#       {'text': 'Design', 'indices': [112, 119]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mz2woz3KhC',
#        'expanded_url': 'https://twitter.com/i/web/status/1291737179178389506',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [121, 144]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 14083628,
#      'id_str': '14083628',
#      'name': 'Dean of Big Data 🎓 #DOBD',
#      'screen_name': 'schmarzo',
#      'location': 'Northern California',
#      'description': 'Teacher, Author, Hitachi Vantara Chief Innovation Officer, USF Executive Fellow, NUI Galway Honorary Professor #DataScience #BigData #DigitalTransformation',
#      'url': 'https://t.co/mKeWtwOrkJ',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/mKeWtwOrkJ',
#          'expanded_url': 'https://deanofbigdata.com',
#          'display_url': 'deanofbigdata.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 39575,
#      'friends_count': 18579,
#      'listed_count': 1311,
#      'created_at': 'Wed Mar 05 15:53:35 +0000 2008',
#      'favourites_count': 15896,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 28822,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/943879656284946432/zJUQsd_D_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/943879656284946432/zJUQsd_D_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14083628/1566527671',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 26,
#     'favorite_count': 31,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 26,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 02:25:45 +0000 2020',
#    'id': 1291923524794355714,
#    'id_str': '1291923524794355714',
#    'text': 'RT @schmarzo: Are #DesignThinking &amp; #DataScience different sides of the same coin? Yep. Synergies are striking when using #Design to drive…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DesignThinking', 'indices': [18, 33]},
#      {'text': 'DataScience', 'indices': [40, 52]},
#      {'text': 'Design', 'indices': [126, 133]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'schmarzo',
#       'name': 'Dean of Big Data 🎓 #DOBD',
#       'id': 14083628,
#       'id_str': '14083628',
#       'indices': [3, 12]}],
#     'urls': []},
# ...
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1142963749285855233/c6NRGCvi_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1142963749285855233/c6NRGCvi_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/954433806177484800/1561339000',
#      'profile_link_color': 'ABB8C2',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'it'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'it'},
#   {'created_at': 'Sat Aug 08 02:20:19 +0000 2020',
#    'id': 1291922157233156096,
#    'id_str': '1291922157233156096',
#    'text': 'RT @Jadirectivestwt: 50 Best Python Course for #Developers \n\nhttps://t.co/1E1XK0KeUJ\n\n#Python #AI #ArtificialIntelligence #MachineLearning…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Developers', 'indices': [47, 58]},
#      {'text': 'Python', 'indices': [86, 93]},
#      {'text': 'AI', 'indices': [94, 97]},
#      {'text': 'ArtificialIntelligence', 'indices': [98, 121]},
#      {'text': 'MachineLearning', 'indices': [122, 138]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Jadirectivestwt',
#       'name': 'JA Directives - Small Business Insights',
#       'id': 3302651196,
#       'id_str': '3302651196',
#       'indices': [3, 19]}],
#     'urls': [{'url': 'https://t.co/1E1XK0KeUJ',
#       'expanded_url': 'https://www.jadirectives.com/best-python-tutorial-online/',
#       'display_url': 'jadirectives.com/best-python-tu…',
#       'indices': [61, 84]}]},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="https://write.as/the-secret-junior-developer/" rel="nofollow">TheSecretJuniorDev</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1271182596559511554,
#     'id_str': '1271182596559511554',
#     'name': 'The Secret Junior Developer',
#     'screen_name': 'TheSecretJunio1',
#     'location': '',
#     'description': 'The secret Junior Dev in all of us. The Dev who wants to get better, who wants to learn and wants to help others...',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 568,
#     'friends_count': 60,
#     'listed_count': 12,
#     'created_at': 'Thu Jun 11 20:48:53 +0000 2020',
#     'favourites_count': 22,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 81642,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1281192258667188226/DcxncxpU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1281192258667188226/DcxncxpU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1271182596559511554/1592772251',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Aug 05 19:38:36 +0000 2020',
#     'id': 1291096287438307330,
#     'id_str': '1291096287438307330',
#     'text': '50 Best Python Course for #Developers \n\nhttps://t.co/1E1XK0KeUJ\n\n#Python #AI #ArtificialIntelligence… https://t.co/4b6YoXwEZ7',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Developers', 'indices': [26, 37]},
#       {'text': 'Python', 'indices': [65, 72]},
#       {'text': 'AI', 'indices': [73, 76]},
#       {'text': 'ArtificialIntelligence', 'indices': [77, 100]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/1E1XK0KeUJ',
#        'expanded_url': 'https://www.jadirectives.com/best-python-tutorial-online/',
#        'display_url': 'jadirectives.com/best-python-tu…',
#        'indices': [40, 63]},
#       {'url': 'https://t.co/4b6YoXwEZ7',
#        'expanded_url': 'https://twitter.com/i/web/status/1291096287438307330',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [102, 125]}]},
#     'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#     'source': '<a href="https://app.socialpilot.co/" rel="nofollow">SocialPilot.co</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3302651196,
#      'id_str': '3302651196',
#      'name': 'JA Directives - Small Business Insights',
#      'screen_name': 'Jadirectivestwt',
#      'location': '',
#      'description': 'We Provide Contents & Tools for #SmallBusiness #Entrepreneurs #SocialMediaMarketing & #Startups. No 20 #BusinessIntelligence Brand by Onalytica.',
#      'url': 'https://t.co/ak7eZfPKJE',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/ak7eZfPKJE',
#          'expanded_url': 'http://www.jadirectives.com',
#          'display_url': 'jadirectives.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 5900,
#      'friends_count': 6009,
#      'listed_count': 872,
#      'created_at': 'Fri Jul 31 19:04:05 +0000 2015',
#      'favourites_count': 25442,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 42550,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C6E2EE',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/718371204088901633/jmzhzxjF_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/718371204088901633/jmzhzxjF_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3302651196/1548220714',
#      'profile_link_color': '1F98C7',
#      'profile_sidebar_border_color': 'C6E2EE',
#      'profile_sidebar_fill_color': 'DAECF4',
#      'profile_text_color': '663B12',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 9,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'fr'},
#   {'created_at': 'Sat Aug 08 02:20:19 +0000 2020',
#    'id': 1291922157220569088,
#    'id_str': '1291922157220569088',
#    'text': 'RT @Jadirectivestwt: 48 Best #Development Courses \n\nhttps://t.co/mQWAPy4LTn\n\n#AI #gamedev #indiedev #indiegame #games #game #unity #100days…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Development', 'indices': [29, 41]},
#      {'text': 'AI', 'indices': [77, 80]},
#      {'text': 'gamedev', 'indices': [81, 89]},
#      {'text': 'indiedev', 'indices': [90, 99]},
#      {'text': 'indiegame', 'indices': [100, 110]},
#      {'text': 'games', 'indices': [111, 117]},
#      {'text': 'game', 'indices': [118, 123]},
#      {'text': 'unity', 'indices': [124, 130]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Jadirectivestwt',
#       'name': 'JA Directives - Small Business Insights',
#       'id': 3302651196,
#       'id_str': '3302651196',
#       'indices': [3, 19]}],
#     'urls': [{'url': 'https://t.co/mQWAPy4LTn',
#       'expanded_url': 'https://www.jadirectives.com/best-development-courses-online/',
#       'display_url': 'jadirectives.com/best-developme…',
#       'indices': [52, 75]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://write.as/the-secret-junior-developer/" rel="nofollow">TheSecretJuniorDev</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1271182596559511554,
#     'id_str': '1271182596559511554',
#     'name': 'The Secret Junior Developer',
#     'screen_name': 'TheSecretJunio1',
#     'location': '',
#     'description': 'The secret Junior Dev in all of us. The Dev who wants to get better, who wants to learn and wants to help others...',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 568,
#     'friends_count': 60,
#     'listed_count': 12,
#     'created_at': 'Thu Jun 11 20:48:53 +0000 2020',
#     'favourites_count': 22,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 81642,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1281192258667188226/DcxncxpU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1281192258667188226/DcxncxpU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1271182596559511554/1592772251',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Aug 06 05:28:18 +0000 2020',
#     'id': 1291244688033419264,
#     'id_str': '1291244688033419264',
#     'text': '48 Best #Development Courses \n\nhttps://t.co/mQWAPy4LTn\n\n#AI #gamedev #indiedev #indiegame #games #game #unity… https://t.co/OGBpqEcV8v',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Development', 'indices': [8, 20]},
#       {'text': 'AI', 'indices': [56, 59]},
#       {'text': 'gamedev', 'indices': [60, 68]},
#       {'text': 'indiedev', 'indices': [69, 78]},
#       {'text': 'indiegame', 'indices': [79, 89]},
#       {'text': 'games', 'indices': [90, 96]},
#       {'text': 'game', 'indices': [97, 102]},
#       {'text': 'unity', 'indices': [103, 109]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mQWAPy4LTn',
#        'expanded_url': 'https://www.jadirectives.com/best-development-courses-online/',
#        'display_url': 'jadirectives.com/best-developme…',
#        'indices': [31, 54]},
#       {'url': 'https://t.co/OGBpqEcV8v',
#        'expanded_url': 'https://twitter.com/i/web/status/1291244688033419264',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [111, 134]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://app.socialpilot.co/" rel="nofollow">SocialPilot.co</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3302651196,
#      'id_str': '3302651196',
#      'name': 'JA Directives - Small Business Insights',
#      'screen_name': 'Jadirectivestwt',
#      'location': '',
#      'description': 'We Provide Contents & Tools for #SmallBusiness #Entrepreneurs #SocialMediaMarketing & #Startups. No 20 #BusinessIntelligence Brand by Onalytica.',
#      'url': 'https://t.co/ak7eZfPKJE',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/ak7eZfPKJE',
#          'expanded_url': 'http://www.jadirectives.com',
#          'display_url': 'jadirectives.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 5900,
#      'friends_count': 6009,
#      'listed_count': 872,
#      'created_at': 'Fri Jul 31 19:04:05 +0000 2015',
#      'favourites_count': 25442,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 42550,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C6E2EE',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/718371204088901633/jmzhzxjF_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/718371204088901633/jmzhzxjF_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3302651196/1548220714',
#      'profile_link_color': '1F98C7',
#      'profile_sidebar_border_color': 'C6E2EE',
#      'profile_sidebar_fill_color': 'DAECF4',
#      'profile_text_color': '663B12',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 42,
#     'favorite_count': 21,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 42,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.123,
#   'max_id': 1291924077297504257,
#   'max_id_str': '1291924077297504257',
#   'next_results': '?max_id=1291922157220569087&q=%23DataScience&count=50&include_entities=1',
#   'query': '%23DataScience',
#   'refresh_url': '?since_id=1291924077297504257&q=%23DataScience&include_entities=1',
#   'count': 50,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# ##### Function 3 (Required)

# %% [markdown]
# **Name:** `get_followers`
#
# **Returns:** list of data objects for each of the users followers, returning values for the `name`, `followers_count`, `friends_count`, and `screen_name` key for each user.
#
# **Arguments:**
#
#  - `screen_name`: str, required; Twitter handle to search for.  **Results should not depend on user inputting the @ symbol.**
#  - `keys`: list, required;  keys to return for each user.  default value: [`name`, `followers_count`, `friends_count`, `screen_name`]; if something else is listed, values for those keys should be returned
#  - `to_df`: bool, required; default value: False; if True, return results in a dataframe.  Every value provided in the `keys` argument should be its own column, with rows populated by the corresponding values for each one for every user.

# %%
def get_followers(screen_name, keys=['name', 'followers_count', 'friends_count', 'screen_name'], to_df=False):
   
    # check if the first item is an @ symbol
    screen_name  = check_handle(screen_name)
    
    # url to use
    base_url     = 'https://api.twitter.com/1.1/followers/list.json'
    # query to attach
    query_string = f'?screen_name={screen_name}'
    
    # generate the request
    users        = requests.get(base_url + query_string, auth=tokens).json()['users']
    
    # create dictionaries that only contain the keys specified in the keys argument
    abbreviated_users = [{key: user[key] for key in keys} for user in users]
    
    # if returning results in a dataframe
    if to_df:
        import pandas as pd
        # create a dictionary with key values for each one 
        df_dict = {key: [user[key] for user in abbreviated_users] for key in keys }
        return pd.DataFrame(df_dict)
    
    return abbreviated_users

# %%
# with GA handle
get_followers('@GA')
# Out:
# [{'name': 'Crypto Cantabria',
#   'followers_count': 202,
#   'friends_count': 780,
#   'screen_name': 'CryptoCantabria'},
#  {'name': 'Ali Khayrallah',
#   'followers_count': 87,
#   'friends_count': 1328,
#   'screen_name': 'alisk'},
#  {'name': 'Queen 👸 Tiffany',
#   'followers_count': 4,
#   'friends_count': 173,
#   'screen_name': 'QueenTi62831950'},
#  {'name': 'Amunategui - ViralML.com',
#   'followers_count': 11969,
#   'friends_count': 12774,
#   'screen_name': 'amunategui'},
#  {'name': 'Cheri K Hric',
#   'followers_count': 15,
#   'friends_count': 126,
#   'screen_name': 'k_hric'},
#  {'name': 'SonderMind',
#   'followers_count': 1036,
#   'friends_count': 713,
#   'screen_name': 'SonderMind'},
#  {'name': 'Bree',
#   'followers_count': 334,
#   'friends_count': 418,
#   'screen_name': 'freetobebree'},
#  {'name': 'David Hoang',
#   'followers_count': 10559,
#   'friends_count': 955,
#   'screen_name': 'davidhoang'},
#  {'name': 'Tothemoon🌈G43TENJXHAGE⭕',
#   'followers_count': 244,
#   'friends_count': 1467,
#   'screen_name': 'BBACKMAL'},
#  {'name': 'Rafa Amaya Junior ®',
#   'followers_count': 461,
#   'friends_count': 835,
#   'screen_name': 'rafaamayajr'},
#  {'name': 'Daewon',
#   'followers_count': 8,
#   'friends_count': 91,
#   'screen_name': 'Daewonkarma'},
#  {'name': 'Huong Vu',
#   'followers_count': 4,
#   'friends_count': 40,
#   'screen_name': 'HuongVuQ'},
#  {'name': 'Sara.UxUi',
#   'followers_count': 1,
#   'friends_count': 2,
#   'screen_name': 'Sara42799963'},
#  {'name': 'Caroline Raw',
#   'followers_count': 153,
#   'friends_count': 194,
#   'screen_name': 'Caz_Raw'},
#  {'name': 'Riley Gibbs',
#   'followers_count': 107,
#   'friends_count': 546,
#   'screen_name': 'rgibbs9'},
#  {'name': 'Jon Billett',
#   'followers_count': 354,
#   'friends_count': 882,
#   'screen_name': 'TheJonBillett'},
#  {'name': 'Berm Lee',
#   'followers_count': 172,
#   'friends_count': 936,
#   'screen_name': 'bermlee'},
#  {'name': 'Tanmay',
#   'followers_count': 832,
#   'friends_count': 4974,
#   'screen_name': 'ThinkInSysDev'},
#  {'name': 'WebLaunchX🚀',
#   'followers_count': 72,
#   'friends_count': 1045,
#   'screen_name': 'WebLaunchX'},
#  {'name': 'Saša',
#   'followers_count': 635,
#   'friends_count': 369,
#   'screen_name': 'hasanbegovic'}]

# %%
# and without the @ symbol
get_followers('GA')
# Out:
# [{'name': 'Brenda Bartels',
#   'followers_count': 1,
#   'friends_count': 38,
#   'screen_name': 'BrendaBartels9'},
#  {'name': 'Mz C',
#   'followers_count': 14,
#   'friends_count': 81,
#   'screen_name': 'mzthickness74'},
#  {'name': 'Eric Stevenson',
#   'followers_count': 7,
#   'friends_count': 226,
#   'screen_name': 'ejsfree'},
#  {'name': 'Cynthia Zitter',
#   'followers_count': 252,
#   'friends_count': 432,
#   'screen_name': 'CynthiaZitter'},
#  {'name': 'owner',
#   'followers_count': 58,
#   'friends_count': 489,
#   'screen_name': 'tkwillia1'},
#  {'name': 'Lori Riordan',
#   'followers_count': 2,
#   'friends_count': 91,
#   'screen_name': 'riordan1965lori'},
#  {'name': 'Anna Rezabek',
#   'followers_count': 21,
#   'friends_count': 58,
#   'screen_name': 'annakbananas'},
#  {'name': '𝕊𝕡𝕠𝕠𝕟𝕚𝕖 𝕊𝕥𝕣𝕖𝕘𝕒𝕤𝕒𝕦𝕣𝕦𝕤',
#   'followers_count': 320,
#   'friends_count': 2456,
#   'screen_name': 'KatherineRepage'},
#  {'name': 'Kailie Ho',
#   'followers_count': 63,
#   'friends_count': 678,
#   'screen_name': 'khosays'},
#  {'name': 'MBSkully',
#   'followers_count': 298,
#   'friends_count': 330,
#   'screen_name': 'mbskully'},
#  {'name': 'Myra Marie Berryhill',
#   'followers_count': 6,
#   'friends_count': 73,
#   'screen_name': 'BerryhillMarie'},
#  {'name': 'peepee',
#   'followers_count': 873,
#   'friends_count': 682,
#   'screen_name': '16k_gold'},
#  {'name': 'Elizabeth Turgeon',
#   'followers_count': 9,
#   'friends_count': 46,
#   'screen_name': 'Eturgeon77'},
#  {'name': 'Jen.',
#   'followers_count': 26,
#   'friends_count': 161,
#   'screen_name': 'jeniferdawnn'},
#  {'name': 'Kathryn specht',
#   'followers_count': 2,
#   'friends_count': 104,
#   'screen_name': 'kathryn_specht'},
#  {'name': 'christina brown',
#   'followers_count': 57,
#   'friends_count': 827,
#   'screen_name': 'baybesmiley'},
#  {'name': 'LCass',
#   'followers_count': 7,
#   'friends_count': 61,
#   'screen_name': 'PeytonCass60'},
#  {'name': 'Ingrid Forrest',
#   'followers_count': 264,
#   'friends_count': 1032,
#   'screen_name': 'TheGiftsLady'},
#  {'name': 'sarin kotoyan',
#   'followers_count': 387,
#   'friends_count': 416,
#   'screen_name': 'sarinkotoyan'},
#  {'name': 'Skylar Walker',
#   'followers_count': 2,
#   'friends_count': 174,
#   'screen_name': 'SkylarW90174488'}]

# %%
# and now only use certain keys
get_followers('GA', keys=['name', 'followers_count'])
# Out:
# [{'name': 'Crypto Cantabria', 'followers_count': 202},
#  {'name': 'Ali Khayrallah', 'followers_count': 87},
#  {'name': 'Queen 👸 Tiffany', 'followers_count': 4},
#  {'name': 'Amunategui - ViralML.com', 'followers_count': 11969},
#  {'name': 'Cheri K Hric', 'followers_count': 15},
#  {'name': 'SonderMind', 'followers_count': 1036},
#  {'name': 'Bree', 'followers_count': 334},
#  {'name': 'David Hoang', 'followers_count': 10559},
#  {'name': 'Tothemoon🌈G43TENJXHAGE⭕', 'followers_count': 244},
#  {'name': 'Rafa Amaya Junior ®', 'followers_count': 461},
#  {'name': 'Daewon', 'followers_count': 8},
#  {'name': 'Huong Vu', 'followers_count': 4},
#  {'name': 'Sara.UxUi', 'followers_count': 1},
#  {'name': 'Caroline Raw', 'followers_count': 153},
#  {'name': 'Riley Gibbs', 'followers_count': 107},
#  {'name': 'Jon Billett', 'followers_count': 354},
#  {'name': 'Berm Lee', 'followers_count': 172},
#  {'name': 'Tanmay', 'followers_count': 832},
#  {'name': 'WebLaunchX🚀', 'followers_count': 72},
#  {'name': 'Saša', 'followers_count': 635}]

# %%
# and put those results in a dataframe
get_followers('GA', keys=['name', 'followers_count'], to_df=True)
# Out:
#                         name  followers_count
# 0           Crypto Cantabria              202
# 1             Ali Khayrallah               87
# 2            Queen 👸 Tiffany                4
# 3   Amunategui - ViralML.com            11969
# 4               Cheri K Hric               15
# 5                 SonderMind             1036
# 6                       Bree              334
# 7                David Hoang            10559
# 8    Tothemoon🌈G43TENJXHAGE⭕              244
# 9        Rafa Amaya Junior ®              461
# 10                    Daewon                8
# 11                  Huong Vu                4
# 12                 Sara.UxUi                1
# 13              Caroline Raw              153
# 14               Riley Gibbs              107
# 15               Jon Billett              354
# 16                  Berm Lee              172
# 17                    Tanmay              832
# 18               WebLaunchX🚀               72
# 19                      Saša              635

# %%
# and test the same thing, but without any keys specified
get_followers('GA', to_df=True)
# Out:
#                         name  followers_count  friends_count      screen_name
# 0           Crypto Cantabria              202            780  CryptoCantabria
# 1             Ali Khayrallah               87           1328            alisk
# 2            Queen 👸 Tiffany                4            173  QueenTi62831950
# 3   Amunategui - ViralML.com            11969          12774       amunategui
# 4               Cheri K Hric               15            126           k_hric
# 5                 SonderMind             1036            713       SonderMind
# 6                       Bree              334            418     freetobebree
# 7                David Hoang            10559            955       davidhoang
# 8    Tothemoon🌈G43TENJXHAGE⭕              244           1467         BBACKMAL
# 9        Rafa Amaya Junior ®              461            835      rafaamayajr
# 10                    Daewon                8             91      Daewonkarma
# 11                  Huong Vu                4             40         HuongVuQ
# 12                 Sara.UxUi                1              2     Sara42799963
# 13              Caroline Raw              153            194          Caz_Raw
# 14               Riley Gibbs              107            546          rgibbs9
# 15               Jon Billett              354            882    TheJonBillett
# 16                  Berm Lee              172            936          bermlee
# 17                    Tanmay              832           4974    ThinkInSysDev
# 18               WebLaunchX🚀               72           1045       WebLaunchX
# 19                      Saša              635            369     hasanbegovic

# %% [markdown]
# ##### Function 4 (Optional)

# %% [markdown]
# **Name:** `friends_of_friends`
#
# **Returns:** list of data objects for each user that two Twitter users have in common
#
# **Arguments:**
#
#  - `names`: list, required; list of two Twitter handles to compare friends list with.  **Results should be insensitive to whether or not the '@' symbol is included or not.**
#  - `keys`: list, optional; list of keys to return for information about each user.  Default value should be to return the entire data object.
#  - `to_df`: bool, required; default value: False; if True, returns results in a dataframe.

# %%
def friends_of_friends(names, keys=None, to_df=False):
    # modify handles if necessary
    names    = [check_handle(name) for name in names]
    # base url
    url      = 'https://api.twitter.com/1.1/friends/list.json'
    # get friends of both users -- note we return the list associated with the 'users' key
    results  = [requests.get(url + f'?screen_name={name}&count=200', auth=tokens).json()['users']
                for name in names]
    
    # ids of first friend
    user1_ids = [result['id'] for result in results[0]]
    # ids of second friend
    user2_ids = [result['id'] for result in results[1]]
    
    # ids that are common in both of the above lists
    joint_ids = [user_id for user_id in user1_ids if user_id in user2_ids]
    
    # return the users that have the id that's held jointly by each user
    friends_of_friends = [user for user in results[0] if user['id'] in joint_ids]
    
    # if keys are provided
    if keys is not None:
        # do the following comprehension:
         # create a dictionary which contains the value for each key provided
         # for every person in the friend_of_friends list
        friends_of_friends = [{key: friend[key] for key in keys} for friend in friends_of_friends]
        
    # if we want the results in a dataframe
    if to_df:
        import pandas as pd
        # first check to see if there's a specific list of keys we need to use
        if keys is not None:
            # if yes, create a dictionary, where each key is a list with all of its values
            df_dict = {key: [friend[key] if friend[key] else None for friend in friends_of_friends] for key in keys}
            return pd.DataFrame(df_dict)
        
        # likewise, if keys are not provided, then get them inside of a list
        keys = friends_of_friends[0].keys()
        # and create a dataframe friendly dictionary in the same way
        df_dict = {key: [friend[key] for friend in friends_of_friends] for key in keys}
        return pd.DataFrame(df_dict)
            
    # and if none of the above conditions are true, just return the original friends_of_friends list
    return friends_of_friends

# %%
# mutual friends
friends_of_friends(['Beyonce', 'MariahCarey'])
# Out:
# [{'id': 40908929,
#   'id_str': '40908929',
#   'name': 'Usher Raymond IV',
#   'screen_name': 'Usher',
#   'location': '',
#   'description': 'Text me (404) 737-1821',
#   'url': 'https://t.co/Vj0zkZ2Rr0',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/Vj0zkZ2Rr0',
#       'expanded_url': 'http://smarturl.it/xicry',
#       'display_url': 'smarturl.it/xicry',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 12192202,
#   'friends_count': 564,
#   'listed_count': 26263,
#   'created_at': 'Mon May 18 16:36:50 +0000 2009',
#   'favourites_count': 1333,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 5992,
#   'lang': None,
#   'status': {'created_at': 'Wed Aug 05 19:10:55 +0000 2020',
#    'id': 1291089318597890048,
#    'id_str': '1291089318597890048',
#    'text': 'A 4-Day Celebration of Community Power + Cultural Resistance. Tune in live on August 6 + 7 + 12 + 18, 2020 for… https://t.co/jUZQCv1dUF',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/jUZQCv1dUF',
#       'expanded_url': 'https://twitter.com/i/web/status/1291089318597890048',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [112, 135]}]},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 70,
#    'favorite_count': 250,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': True,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1226991892857884672/70shiuOh_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1226991892857884672/70shiuOh_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40908929/1593214738',
#   'profile_link_color': 'ABB8C2',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'DDFFCC',
#   'profile_text_color': '333333',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'regular'},
#  {'id': 30782495,
#   'id_str': '30782495',
#   'name': 'KELENDRIA ROWLAND',
#   'screen_name': 'KELLYROWLAND',
#   'location': '',
#   'description': 'COFFEE – out now!',
#   'url': 'https://t.co/IUvpsr9qhu',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/IUvpsr9qhu',
#       'expanded_url': 'https://eqdistro.io/coffee',
#       'display_url': 'eqdistro.io/coffee',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 6896645,
#   'friends_count': 1701,
#   'listed_count': 13680,
#   'created_at': 'Mon Apr 13 02:15:13 +0000 2009',
#   'favourites_count': 1287,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 13330,
#   'lang': None,
#   'status': {'created_at': 'Tue Aug 04 19:45:49 +0000 2020',
#    'id': 1290735713990750208,
#    'id_str': '1290735713990750208',
#    'text': 'There are state primaries happening today in Michigan, Arizona, Kansas, Missouri and Washington! Mask up and let yo… https://t.co/MjjZT5MS7J',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/MjjZT5MS7J',
#       'expanded_url': 'https://twitter.com/i/web/status/1290735713990750208',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 56,
#    'favorite_count': 210,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '072E59',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1249910282685542402/k5AuXj1k_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1249910282685542402/k5AuXj1k_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/30782495/1587096324',
#   'profile_link_color': '8A8C8C',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '95E8EC',
#   'profile_text_color': '3C3940',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 18395177,
#   'id_str': '18395177',
#   'name': 'solange knowles',
#   'screen_name': 'solangeknowles',
#   'location': '',
#   'description': 'water, melanin, bones, blood.',
#   'url': 'https://t.co/8F2cZD8D37',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/8F2cZD8D37',
#       'expanded_url': 'http://www.saintheron.com',
#       'display_url': 'saintheron.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 4151877,
#   'friends_count': 167,
#   'listed_count': 8921,
#   'created_at': 'Fri Dec 26 20:54:15 +0000 2008',
#   'favourites_count': 3252,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 560,
#   'lang': None,
#   'status': {'created_at': 'Fri Aug 07 21:25:09 +0000 2020',
#    'id': 1291847877099167746,
#    'id_str': '1291847877099167746',
#    'text': 'it’s the run at 2:14 for meeeee 😭 @4everBrandy https://t.co/OrReZpzOEf',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': '4everBrandy',
#       'name': 'b r a n d y',
#       'id': 27406401,
#       'id_str': '27406401',
#       'indices': [34, 46]}],
#     'urls': [],
#     'media': [{'id': 1291847873378869249,
#       'id_str': '1291847873378869249',
#       'indices': [47, 70],
#       'media_url': 'http://pbs.twimg.com/media/Ee2Qy9yXYAE4Eai.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Ee2Qy9yXYAE4Eai.jpg',
#       'url': 'https://t.co/OrReZpzOEf',
#       'display_url': 'pic.twitter.com/OrReZpzOEf',
#       'expanded_url': 'https://twitter.com/solangeknowles/status/1291847877099167746/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 705, 'h': 1200, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 400, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 749, 'h': 1274, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1291847873378869249,
#       'id_str': '1291847873378869249',
#       'indices': [47, 70],
#       'media_url': 'http://pbs.twimg.com/media/Ee2Qy9yXYAE4Eai.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Ee2Qy9yXYAE4Eai.jpg',
#       'url': 'https://t.co/OrReZpzOEf',
#       'display_url': 'pic.twitter.com/OrReZpzOEf',
#       'expanded_url': 'https://twitter.com/solangeknowles/status/1291847877099167746/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 705, 'h': 1200, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 400, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 749, 'h': 1274, 'resize': 'fit'}}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1755,
#    'favorite_count': 12730,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FFF04D',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1109657367577133057/44jmIiZ6_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1109657367577133057/44jmIiZ6_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18395177/1528451677',
#   'profile_link_color': 'EDE31F',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'EFEFEF',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'}]

# %%
# mutual friends, returned in a dataframe
friends_of_friends(['Beyonce', 'MariahCarey'], to_df=True)
# Out:
#          id    id_str               name     screen_name location  \
# 0  40908929  40908929   Usher Raymond IV           Usher
# 1  30782495  30782495  KELENDRIA ROWLAND    KELLYROWLAND
# 2  18395177  18395177    solange knowles  solangeknowles
#
#                      description                      url  \
# 0         Text me (404) 737-1821  https://t.co/Vj0zkZ2Rr0
# 1              COFFEE – out now!  https://t.co/IUvpsr9qhu
# 2  water, melanin, bones, blood.  https://t.co/8F2cZD8D37
#
#                                             entities  protected  \
# 0  {'url': {'urls': [{'url': 'https://t.co/Vj0zkZ...      False
# 1  {'url': {'urls': [{'url': 'https://t.co/IUvpsr...      False
# 2  {'url': {'urls': [{'url': 'https://t.co/8F2cZD...      False
#
#    followers_count  ...  default_profile  default_profile_image following  \
# 0         12192202  ...            False                  False     False
# 1          6896645  ...            False                  False     False
# 2          4151877  ...            False                  False     False
#
#    live_following follow_request_sent notifications  muting  blocking  \
# 0           False               False         False   False     False
# 1           False               False         False   False     False
# 2           False               False         False   False     False
#
#    blocked_by translator_type
# 0       False         regular
# 1       False            none
# 2       False            none
#
# [3 rows x 47 columns]

# %%
# friends of friends, with keys passed in
friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'])
# Out:
# [{'id': 40908929, 'name': 'Usher Raymond IV'},
#  {'id': 30782495, 'name': 'KELENDRIA ROWLAND'},
#  {'id': 18395177, 'name': 'solange knowles'}]

# %%
# f_o_f, with keys and to_df specified
friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'], to_df=True)
# Out:
#          id               name
# 0  40908929   Usher Raymond IV
# 1  30782495  KELENDRIA ROWLAND
# 2  18395177    solange knowles

# %% [markdown]
#  ##### Function 5 (Optional)

# %% [markdown]
# Rewrite the `friends_of_friends` function, except this time include an argument called `full_search`, which accepts a boolean value.  If set to `True`, use cursoring to cycle through the complete set of users for the users provided.
#
# The twitter API only returns a subset of users in your results to save bandwidth, so you have to cycle through multiple result sets to get all of the values.
#
# You can read more about how this works here:  https://developer.twitter.com/en/docs/basics/cursoring
#
# Basically you have to do a `while` loop to continually make a new request using the values stored in the `next_cursor` key as part of your next query string until there's nothing left to search.
#
# **Note:** We're using the free API, so we're operating under some limitations.  One of them being that you can only make 15 API calls in a 15 minute span.  You can also only return up to 200 results per cursor, so this means you won't be able to completely search for everyone even if you set this up correctly.
#
# That's fine, just do what you can under the circumstances.

# %%
# we'll create a separate function to handle the cursoring
def cursor_user(username):
    # check the username
    username  = check_handle(username)
    # set the following variables to use in the loop
    cursor    = -1
    followers = []
    
    # while this condition is True
    while cursor != 0:
        # set the url using the value of cursor & username
        url = f'https://api.twitter.com/1.1/friends/list.json?screen_name={username}&count=200&cursor={cursor}'
        # do the request
        req = requests.get(url, auth=tokens).json()
        # add the values returned by the request
        followers.extend(req['users'])
        # set the value of cursor to value inside this key
        cursor = req['next_cursor']
    
    # and when you're finished, return the list
    return followers

# %%
# and now we'll stick it inside friends_of_friends
def friends_of_friends(names, keys=None, to_df=False, full_search=False):
    names    = [check_handle(name) for name in names]
    url      = 'https://api.twitter.com/1.1/friends/list.json'
    
    # if full_search, use the cursor_user() fn for each person 
    if full_search:
        results = [cursor_user(name) for name in names]
    # if not, then do a standard search
    else:
        results = [requests.get(url + f'?screen_name={name}&count=200', auth=tokens).json()['users']
                   for name in names]
    
    user1_ids = [result['id'] for result in results[0]]
    user2_ids = [result['id'] for result in results[1]]
    
    joint_ids = [user_id for user_id in user1_ids if user_id in user2_ids]
    
    friends_of_friends = [user for user in results[0] if user['id'] in joint_ids]
    
    if keys is not None:
        friends_of_friends = [{key: friend[key] for key in keys} for friend in friends_of_friends]
        
    if to_df:
        import pandas as pd
        if keys is not None:
            df_dict = {key: [friend[key] for friend in friends_of_friends] for key in keys}
            return pd.DataFrame(df_dict)
        
        keys = friends_of_friends[0].keys()
        df_dict = {key: [friend[key] for friend in friends_of_friends] for key in keys}
        return pd.DataFrame(df_dict)
            
    return friends_of_friends

# %%
# if you search for 200 friends, you'll find 4 people in common
len(friends_of_friends(['ezraklein', 'tylercowen']))
# Out:
# 9

# %%
# if you add full_search, then it'll find 54 people
len(friends_of_friends(['ezraklein', 'tylercowen'], full_search=True))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-35124d0134d1> in <module>
#       1 # if you add full_search, then it'll find 54 people
# ----> 2 len(friends_of_friends(['ezraklein', 'tylercowen'], full_search=True))
#
# <ipython-input-36-22446aec57eb> in friends_of_friends(names, keys, to_df, full_search)
#       6     # if full_search, use the cursor_user() fn for each person
#       7     if full_search:
# ----> 8         results = [cursor_user(name) for name in names]
#       9     # if not, then do a standard search
#      10     else:
#
# <ipython-input-36-22446aec57eb> in <listcomp>(.0)
#       6     # if full_search, use the cursor_user() fn for each person
#       7     if full_search:
# ----> 8         results = [cursor_user(name) for name in names]
#       9     # if not, then do a standard search
#      10     else:
#
# <ipython-input-34-e96317bd0bd8> in cursor_user(username)
#      14         req = requests.get(url, auth=tokens).json()
#      15         # add the values returned by the request
# ---> 16         followers.extend(req['users'])
#      17         # set the value of cursor to value inside this key
#      18         cursor = req['next_cursor']
#
# KeyError: 'users'
