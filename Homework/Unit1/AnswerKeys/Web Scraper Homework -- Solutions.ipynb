# %% [markdown]
# ### Solutions for Web Scraping Homework

# %%
# imports
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
# connect to homework
i = 30
url = f'https://www.yelp.com/search?find_desc=Restaurants&find_loc=London%2C+United+Kingdom&ns=1&start={i}'
req = requests.get(url).text
scraper = BeautifulSoup(req)
restaurants = scraper.find_all('div', {'class': classes[1]})

# %%
classes = 'lemon--div__373c0__1mboc container__373c0__3HMKB hoverable__373c0__VqkG7 margin-t3__373c0__1l90z margin-b3__373c0__q1DuY padding-t3__373c0__1gw9E padding-r3__373c0__57InZ padding-b3__373c0__342DA padding-l3__373c0__1scQ0 border--top__373c0__3gXLy border--right__373c0__1n3Iv border--bottom__373c0__3qNtD border--left__373c0__d1B7K border-color--default__373c0__3-ifU'.split()

# %%
len(restaurants)
# Out:
# 30

# %% [markdown]
# ### Scraping Titles, Categories

# %%
restaurant_links = [restaurant.find_all('a', {'class': 'link-color--inherit__373c0__3dzpk'}) for restaurant in restaurants]
titles = [link.text for link_group in restaurant_links for link in link_group if 'biz' in link['href']]

# %%
# no list comprehension
titles = []
for link_group in restaurant_links:
    for link in link_group:
        if 'biz' in link['href']:
            titles.append(link.text)

# %%
# restaurant categories
list_of_cats = []
for link_groups in restaurant_links:
    restaurant_cats = []
    for link in link_groups:
        if 'find_desc' in link['href']:
            restaurant_cats.append(link.text)
    list_of_cats.append(restaurant_cats)
    
category_one = []
category_two = []
category_three = []
category_four = []
there_are_lists = True

master_list = []
i = 0
while there_are_lists:
    cat_list = []
    for restaurant in list_of_cats:
            try:
                cat_list.append(restaurant[i])
            except:
                cat_list.append(None)
    there_are_lists = any(cat_list)
    if there_are_lists:
        master_list.append(cat_list)
        i += 1

# %%
master_list[2]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  'Cajun/Creole',
#  None,
#  None,
#  'Gastropubs',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'British',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Cocktail Bars',
#  None,
#  'Noodles',
#  'Cocktail Bars',
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# ### Scraping Phone Numbers, Neighborhoods, Reviews

# %%
# paragraphs
restaurant_paragraphs = [restaurant.find_all('p') for restaurant in restaurants]

# %%
# get the phone numbers
phone_numbers = [paragraph_group[0].text if paragraph_group[0].text.replace(' ', '').isdigit() else None for paragraph_group in restaurant_paragraphs]

# %%
# without a comprehension
phone_numbers = []
for paragraph_group in restaurant_paragraphs:
    if paragraph_group[0].text.replace(' ', '').isdigit():
        phone_numbers.append(paragraph_group[0].text)
    else:
        phone_numbers.append(None)

# %%
# finding out neighborhoods
neighborhoods = []
for paragraph_group in restaurant_paragraphs:
    if paragraph_group[-2].text != 'Delivery':
        neighborhoods.append(paragraph_group[-2].text)
    else:
        neighborhoods.append(paragraph_group[-3].text)

# %%
# reviews -- sometimes they are missing, hence the check
reviews = []
for idx, paragraph_group in enumerate(restaurant_paragraphs):
    if idx == len(restaurant_paragraphs) - 1:
        reviews.append(paragraph_group[1][3].text.replace('\xa0more', ''))
    else: 
        if '\xa0more' in paragraph_group[-1].text:
                reviews.append(paragraph_group[-1].text.replace('\xa0more', ''))
        else:
            reviews.append(None)

# %% [markdown]
# ### Scraping Price Ranges, Addresses

# %%
restaurant_spans = [restaurant.find_all('span') for restaurant in restaurants]

# %%
# number of reviews
num_reviews = [int(span_group[4].text) if span_group[4].text.isdigit() else None for span_group in restaurant_spans]

# %%
# price ranges -- sometimes they have blanks:
price_ranges = []
for span_group in restaurant_spans:
    if '\xA3' in span_group[5].text:
        price_ranges.append(span_group[5].text)
    elif '\xA3' in span_group[6].text:
        price_ranges.append(span_group[6].text)
    else:
        price_ranges.append(None)

# %%
# for addresses

# helper function to check if a given piece of text is an address or not
def is_address(text):
    text = text.split()
    try:
        # accommodates for values like 34-66, 4/6, etc
        if text[0].replace('-', '').replace('/', '').isdigit() and text[-1].isalpha():
            return True
        else:
            return False
    except:
        return False

addresses = []
for span_group in restaurant_spans:
    has_address = False
    for group in span_group:
        if is_address(group.text):
            has_address = True
            address = group.text
    if has_address:
        addresses.append(address)
    else:
        addresses.append(None)

# %% [markdown]
# ### Scraping Average Rating

# %%
# get all the divs
restaurant_divs = [restaurant.find_all('div', {'role': 'img'}) for restaurant in restaurants]

# %%
restaurant_ratings = [float(str(restaurant[0]).split('"')[1].split()[0]) for restaurant in restaurant_divs]

# %% [markdown]
# ### Final DataFrame

# %%
# neighborhoods
neighborhoods = [paragraph_group[-2].text for paragraph_group in restaurant_paragraphs[:-1]]
neighborhoods.append(restaurant_paragraphs[-1][-1][-2].text)

# %%
df_dict = {
    'Name': titles,
    'PhoneNumber': phone_numbers,
    'Address': addresses,
    'Neighborhood': neighborhoods,
    'PriceRange': price_ranges,
    'AvgRating': restaurant_ratings,
    'NumRatings': num_reviews,
    'CategoryOne': category_one,
    'CategoryTwo': category_two,
    'CategoryThree': category_three,
    'Review': reviews
}

df = pd.DataFrame(df_dict)
df
# Out:
#                                              Name    PhoneNumber  \
# 0                     Dinner by Heston Blumenthal  020 7201 3833
# 1                                           Kazan  020 7233 7100
# 2              Wright Brothers - South Kensington  020 7581 0131
# 3                                       Barrafina  020 7440 1456
# 4                                  Belgo Centraal  020 7813 2233
# 5                              Lanzhou Noodle Bar  020 7467 4546
# 6                                Laughing Halibut  020 7799 2844
# 7                             Duck & Waffle Local  020 3900 4444
# 8                              Yasmeen Restaurant  020 7624 2921
# 9                                       Barrafina  020 7440 1456
# 10                                    The Ledbury  020 7792 9090
# 11                                      Piccolino  020 7287 4029
# 12                                   Smoking Goat           None
# 13                                      Roti Chai  020 7408 0101
# 14                                     Steak & Co  020 7839 8100
# 15                                           Naru  020 7379 7962
# 16                                 The George Inn  020 7407 2056
# 17                          Homeslice Neal’s Yard  020 3151 7488
# 18                                         Wahaca  020 7734 0195
# 19                     St John Bar and Restaurant  020 7251 0848
# 20  Czechoslovak National House Club & Restaurant  020 7372 1193
# 21                                           José  020 7403 4902
# 22                                        Hoppers           None
# 23                         The Palomar Restaurant  020 7439 8777
# 24                 Honest Burgers Meard St - Soho  020 3609 9524
# 25                                         Negril  020 8674 8798
# 26                               The Ninth London  020 3019 0880
# 27                                           Kiln           None
# 28                            Da Mario Restaurant  020 7584 9078
# 29                                      Silk Road  020 7703 4832
#
#                         Address      Neighborhood PriceRange  AvgRating  \
# 0              66 Knightsbridge         Hyde Park       ££££        4.5
# 1             93-94 Wilton Road          Victoria         ££        4.5
# 2          56 Old Brompton Road  South Kensington         ££        4.5
# 3                 43 Drury Lane     Covent Garden         ££        4.5
# 4             50 Earlham Street     Covent Garden         ££        4.0
# 5          33 Cranbourne Street     Covent Garden          £        4.0
# 6            38 Strutton Ground       Westminster         ££        4.0
# 7                  52 Haymarket  Leicester Square         ££        4.5
# 8            1 Blenheim Terrace    St John's Wood         ££        5.0
# 9                26 Dean Street              Soho        £££        4.0
# 10             127 Ledbury Road      Notting Hill       ££££        4.5
# 11             21 Heddon Street           Mayfair         ££        4.0
# 12    64 Shoreditch High Street        Shoreditch         ££        4.5
# 13         3 Portman Mews South        Marylebone         ££        4.0
# 14       3/5 Charing Cross Road  Leicester Square         ££        4.0
# 15        230 Shaftsbury Avenue     Covent Garden         ££        4.0
# 16    75-77 Borough High Street           Borough         ££        4.0
# 17               13 Neal's Yard     Covent Garden         ££        4.5
# 18            80 Wardour Street              Soho         ££        4.0
# 19            26 St John Street        Farringdon        £££        4.0
# 20                74 W End Lane    West Hampstead         ££        4.0
# 21        104 Bermondsey Street           Borough         ££        4.5
# 22              49 Frith Street              Soho         ££        4.5
# 23             34 Rupert Street         Chinatown        £££        4.5
# 24                         None              Soho         ££        4.5
# 25             132 Brixton Hill      Brixton Hill         ££        4.0
# 26          22 Charlotte Street         Fitzrovia        £££        4.5
# 27             58 Brewer Street              Soho         ££        4.5
# 28           15 Gloucester Road        Kensington         ££        4.5
# 29  49 Camberwell Church Street         Hyde Park         ££        4.5
#
#     NumRatings         CategoryOne    CategoryTwo CategoryThree  \
# 0          289             British           None          None
# 1          112             Turkish           None          None
# 2           22             Seafood           None          None
# 3           61             Spanish     Tapas Bars          None
# 4          319             Belgian           None          None
# 5          351             Chinese        Noodles          None
# 6          243        Fish & Chips           None          None
# 7          142                Bars        Waffles          None
# 8           14            Lebanese  Mediterranean          None
# 9           37  Tapas/Small Plates        Spanish          None
# 10         168     Modern European           None          None
# 11          47             Italian           None          None
# 12          30                Thai           None          None
# 13         297              Indian          Kebab          None
# 14         110         Steakhouses        British          None
# 15          65              Korean           None          None
# 16         142                Pubs        British          None
# 17         227               Pizza           None          None
# 18         311             Mexican           None          None
# 19         294             British           Bars          None
# 20          26               Czech           None          None
# 21          82             Spanish     Tapas Bars          None
# 22         113          Sri Lankan   Asian Fusion          None
# 23         104      Middle Eastern  Mediterranean          None
# 24         276             Burgers           None          None
# 25          54           Caribbean           None          None
# 26          22       Mediterranean         French          None
# 27          51             Noodles           Thai          None
# 28         139             Italian           None          None
# 29          43             Chinese           None          None
#
#                                                Review
# 0   “Still our favourite restaurant in London! Din...
# 1   “Absolutely delicious food, best Turkish food ...
# 2   “Dinner at Wright Bros was a great way to wrap...
# 3   “A stone's throw from our hotel, we walked ove...
# 4   “Don't let the entrance fool you! When you wal...
# 5   “We got to our hotel somewhere in between earl...
# 6   “Just plain YES! Go here if you want to enjoy ...
# 7   “My first review of 2020! I was in Europe for ...
# 8   “The only sad part of my review is that we onl...
# 9   “A lovely spot with authentic tapas and a dive...
# 10  “Modern & English, The Ledbury is a fantastic ...
# 11  “If I could give a one word review I would. Fa...
# 12  “Food was good. Drinks were delicious but I fe...
# 13  “Instead of the tapas (or chaat as we might ca...
# 14  “If I could give this place 10 stars I would. ...
# 15  “A good traditional Korean restaurant. \nWe we...
# 16  “It was a great location in an alley with a lo...
# 17  “I always start with the standard slice at any...
# 18  “I stumbled upon Wahaca walking home from work...
# 19  “Great meal, started with the bone marrow and ...
# 20  “Really hardy meals that are not that expensiv...
# 21  “Wow.  What a great find. Thanks yelp.  Everyt...
# 22  “Had a friend recommend I try Hoppers when I c...
# 23  “Unmatched flavors and service!\n\nHighly reco...
# 24  “Best burgers  \nAmazing and friendly staff.\n...
# 25  “Casual, relaxed atmosphere and very satisfyin...
# 26  “The Ninth is a great date spot in London. It ...
# 27  “Environment: Limited seating and busy til the...
# 28  “Easily, hands down, my favorite (er, *favouri...
# 29  “Still our favourite restaurant in London! Din...

# %% [markdown]
# ### Final Answer, That Loops Through The Entire Website

# %%
pd.DataFrame(df_dict)
# Out:
#                                              Name    PhoneNumber  \
# 0                     Dinner by Heston Blumenthal  020 7201 3833
# 1                                           Kazan  020 7233 7100
# 2              Wright Brothers - South Kensington  020 7581 0131
# 3                                       Barrafina  020 7440 1456
# 4                                  Belgo Centraal  020 7813 2233
# 5                              Lanzhou Noodle Bar  020 7467 4546
# 6                                Laughing Halibut  020 7799 2844
# 7                             Duck & Waffle Local  020 3900 4444
# 8                              Yasmeen Restaurant  020 7624 2921
# 9                                       Barrafina  020 7440 1456
# 10                                    The Ledbury  020 7792 9090
# 11                                      Piccolino  020 7287 4029
# 12                                   Smoking Goat           None
# 13                                      Roti Chai  020 7408 0101
# 14                                     Steak & Co  020 7839 8100
# 15                                           Naru  020 7379 7962
# 16                                 The George Inn  020 7407 2056
# 17                          Homeslice Neal’s Yard  020 3151 7488
# 18                                         Wahaca  020 7734 0195
# 19                     St John Bar and Restaurant  020 7251 0848
# 20  Czechoslovak National House Club & Restaurant  020 7372 1193
# 21                                           José  020 7403 4902
# 22                                        Hoppers           None
# 23                         The Palomar Restaurant  020 7439 8777
# 24                 Honest Burgers Meard St - Soho  020 3609 9524
# 25                                         Negril  020 8674 8798
# 26                               The Ninth London  020 3019 0880
# 27                                           Kiln           None
# 28                            Da Mario Restaurant  020 7584 9078
# 29                                      Silk Road  020 7703 4832
#
#                         Address      Neighborhood PriceRange  AvgRating  \
# 0              66 Knightsbridge         Hyde Park       ££££        4.5
# 1             93-94 Wilton Road          Victoria         ££        4.5
# 2          56 Old Brompton Road  South Kensington         ££        4.5
# 3                 43 Drury Lane     Covent Garden         ££        4.5
# 4             50 Earlham Street     Covent Garden         ££        4.0
# 5          33 Cranbourne Street     Covent Garden          £        4.0
# 6            38 Strutton Ground       Westminster         ££        4.0
# 7                  52 Haymarket  Leicester Square         ££        4.5
# 8            1 Blenheim Terrace    St John's Wood         ££        5.0
# 9                26 Dean Street              Soho        £££        4.0
# 10             127 Ledbury Road      Notting Hill       ££££        4.5
# 11             21 Heddon Street           Mayfair         ££        4.0
# 12    64 Shoreditch High Street        Shoreditch         ££        4.5
# 13         3 Portman Mews South        Marylebone         ££        4.0
# 14       3/5 Charing Cross Road  Leicester Square         ££        4.0
# 15        230 Shaftsbury Avenue     Covent Garden         ££        4.0
# 16    75-77 Borough High Street           Borough         ££        4.0
# 17               13 Neal's Yard     Covent Garden         ££        4.5
# 18            80 Wardour Street              Soho         ££        4.0
# 19            26 St John Street        Farringdon        £££        4.0
# 20                74 W End Lane    West Hampstead         ££        4.0
# 21        104 Bermondsey Street           Borough         ££        4.5
# 22              49 Frith Street              Soho         ££        4.5
# 23             34 Rupert Street         Chinatown        £££        4.5
# 24                         None              Soho         ££        4.5
# 25             132 Brixton Hill      Brixton Hill         ££        4.0
# 26          22 Charlotte Street         Fitzrovia        £££        4.5
# 27             58 Brewer Street              Soho         ££        4.5
# 28           15 Gloucester Road        Kensington         ££        4.5
# 29  49 Camberwell Church Street         Hyde Park         ££        4.5
#
#     NumRatings         CategoryOne    CategoryTwo CategoryThree  \
# 0          289             British           None          None
# 1          112             Turkish           None          None
# 2           22             Seafood           None          None
# 3           61             Spanish     Tapas Bars          None
# 4          319             Belgian           None          None
# 5          351             Chinese        Noodles          None
# 6          243        Fish & Chips           None          None
# 7          142                Bars        Waffles          None
# 8           14            Lebanese  Mediterranean          None
# 9           37  Tapas/Small Plates        Spanish          None
# 10         168     Modern European           None          None
# 11          47             Italian           None          None
# 12          30                Thai           None          None
# 13         297              Indian          Kebab          None
# 14         110         Steakhouses        British          None
# 15          65              Korean           None          None
# 16         142                Pubs        British          None
# 17         227               Pizza           None          None
# 18         311             Mexican           None          None
# 19         294             British           Bars          None
# 20          26               Czech           None          None
# 21          82             Spanish     Tapas Bars          None
# 22         113          Sri Lankan   Asian Fusion          None
# 23         104      Middle Eastern  Mediterranean          None
# 24         276             Burgers           None          None
# 25          54           Caribbean           None          None
# 26          22       Mediterranean         French          None
# 27          51             Noodles           Thai          None
# 28         139             Italian           None          None
# 29          43             Chinese           None          None
#
#                                                Review
# 0   “Still our favourite restaurant in London! Din...
# 1   “Absolutely delicious food, best Turkish food ...
# 2   “Dinner at Wright Bros was a great way to wrap...
# 3   “A stone's throw from our hotel, we walked ove...
# 4   “Don't let the entrance fool you! When you wal...
# 5   “We got to our hotel somewhere in between earl...
# 6   “Just plain YES! Go here if you want to enjoy ...
# 7   “My first review of 2020! I was in Europe for ...
# 8   “The only sad part of my review is that we onl...
# 9   “A lovely spot with authentic tapas and a dive...
# 10  “Modern & English, The Ledbury is a fantastic ...
# 11  “If I could give a one word review I would. Fa...
# 12  “Food was good. Drinks were delicious but I fe...
# 13  “Instead of the tapas (or chaat as we might ca...
# 14  “If I could give this place 10 stars I would. ...
# 15  “A good traditional Korean restaurant. \nWe we...
# 16  “It was a great location in an alley with a lo...
# 17  “I always start with the standard slice at any...
# 18  “I stumbled upon Wahaca walking home from work...
# 19  “Great meal, started with the bone marrow and ...
# 20  “Really hardy meals that are not that expensiv...
# 21  “Wow.  What a great find. Thanks yelp.  Everyt...
# 22  “Had a friend recommend I try Hoppers when I c...
# 23  “Unmatched flavors and service!\n\nHighly reco...
# 24  “Best burgers  \nAmazing and friendly staff.\n...
# 25  “Casual, relaxed atmosphere and very satisfyin...
# 26  “The Ninth is a great date spot in London. It ...
# 27  “Environment: Limited seating and busy til the...
# 28  “Easily, hands down, my favorite (er, *favouri...
# 29  “Still our favourite restaurant in London! Din...

# %%
i = 0
num_round = 1
total_titles = []
total_phone_numbers = []
total_addresses = []
total_neighborhoods = []
total_price_ranges = []
total_restaurant_ratings = []
total_num_reviews = []
total_category_one = []
total_category_two = []
total_category_three = []
total_reviews = []
looping = True

# helper function to check if a given piece of text is an address or not
def is_address(text):
    text = text.split()
    try:
        # accommodates for values like 34-66, 4/6, etc
        if text[0].replace('-', '').replace('/', '').isdigit() and text[-1].isalpha():
            return True
        else:
            return False
    except:
        return False

while looping:
    url = f'https://www.yelp.com/search?find_desc=Restaurants&find_loc=London%2C+United+Kingdom&ns=1&start={i}'
    req = requests.get(url)
    scraper = BeautifulSoup(req.text)
    restaurants = scraper.find_all('div', {'class': 'container__373c0__3HMKB'})
    if len(restaurants) == 0:
        print("No more restaurants found.  Breaking the loop.")
        break
    
    #### Getting All Links, Code for Titles and Categories
    restaurant_links = [restaurant.find_all('a', {'class': 'link-color--inherit__373c0__3dzpk'}) for restaurant in restaurants]
    titles = [link.text for link_group in restaurant_links for link in link_group if 'biz' in link['href']]
    total_titles.extend(titles)
    
    # restaurant categories
    list_of_cats = []
    for link_groups in restaurant_links:
        restaurant_cats = []
        for link in link_groups:
            if 'find_desc' in link['href']:
                restaurant_cats.append(link.text)
        list_of_cats.append(restaurant_cats)
    category_one = []
    category_two = []
    category_three = []
    for cat in list_of_cats:
        for idx in range(3):
            if idx == 0:
                try:
                    category_one.append(cat[idx])
                except:
                    category_one.append(None)
            if idx == 1:
                try:
                    category_two.append(cat[idx])
                except:
                    category_two.append(None)
            if idx == 2:
                try:
                    category_three.append(cat[idx])
                except:
                    category_three.append(None)
    total_category_one.extend(category_one)
    total_category_two.extend(category_two)
    total_category_three.extend(category_three)
                    
    # getting all the paragraphs within each restaurant
    restaurant_paragraphs = [restaurant.find_all('p') for restaurant in restaurants]
    
    # get the phone numbers
    phone_numbers = [paragraph_group[0].text if paragraph_group[0].text.replace(' ', '').isdigit() else None for paragraph_group in restaurant_paragraphs]
    total_phone_numbers.extend(phone_numbers)
    
    # get the neighborhoods
    neighborhoods = []
    for paragraph_group in restaurant_paragraphs:
        if '\xa0more' in paragraph_group[-1].text:
            if paragraph_group[-2].text != 'Delivery':
                neighborhoods.append(paragraph_group[-2].text)
            else:
                neighborhoods.append(paragraph_group[-3].text)
        else:
            if paragraph_group[-1].text != 'Delivery':
                neighborhoods.append(paragraph_group[-1].text)
            else:
                neighborhoods.append(paragraph_group[-2].text)
            
    total_neighborhoods.extend(neighborhoods)
    
    # get the reviews
    reviews = []
    for paragraph_group in restaurant_paragraphs:
        if '\xa0more' in paragraph_group[-1].text:
            reviews.append(paragraph_group[-1].text.replace('\xa0more', ''))
        else:
            reviews.append(None)
                
    total_reviews.extend(reviews)
    
    # get all the spans in a given page
    restaurant_spans = [restaurant.find_all('span') for restaurant in restaurants]
    
    # get the number of reviews
    num_reviews = [int(span_group[4].text) if span_group[4].text.isdigit() else None for span_group in restaurant_spans]
    total_num_reviews.extend(num_reviews)
    
    # get the price ranges
    price_ranges = []
    for span_group in restaurant_spans:
        if '\xA3' in span_group[5].text:
            price_ranges.append(span_group[5].text)
        elif '\xA3' in span_group[6].text:
            price_ranges.append(span_group[6].text)
        else:
            price_ranges.append(None)
    total_price_ranges.extend(price_ranges)
            
    # get the addresses
    addresses = []
    for span_group in restaurant_spans:
        has_address = False
        for group in span_group:
            if is_address(group.text):
                has_address = True
                address = group.text
        if has_address:
            addresses.append(address)
        else:
            addresses.append(None)
    total_addresses.extend(addresses)
            
    # get all the rating divs
    restaurant_divs = [restaurant.find_all('div', {'role': 'img'}) for restaurant in restaurants]
    
    # and get the restaurant ratings
    restaurant_ratings = [float(str(restaurant[0]).split('"')[1].split()[0]) for restaurant in restaurant_divs]
    total_restaurant_ratings.extend(restaurant_ratings)
    
    print(f'Finished Round {num_round}, value of i: {i}')
    i += 30
    num_round += 1
    
df_dict = {
    'Name': total_titles,
    'PhoneNumber': total_phone_numbers,
    'Address': total_addresses,
    'Neighborhood': total_neighborhoods,
    'PriceRange': total_price_ranges,
    'AvgRating': total_restaurant_ratings,
    'NumRatings': total_num_reviews,
    'CategoryOne': total_category_one,
    'CategoryTwo': total_category_two,
    'CategoryThree': total_category_three,
    'Review': total_reviews
}

df = pd.DataFrame(df_dict)
df
# Out:
# Finished Round 1, value of i: 0
# No more restaurants found.  Breaking the loop.
#                            Name    PhoneNumber                       Address  \
# 0                       Dishoom  020 7420 9320  12 Upper Saint Martin's Lane
# 1            The Mayfair Chippy  020 7741 2233        14 North Audley Street
# 2           Ffiona’s Restaurant  020 7937 4152   51 Kensington Church Street
# 3                     Flat Iron           None                17 Beak Street
# 4      Restaurant Gordon Ramsay  020 7352 4441        68 Royal Hospital Road
# 5   The Fat Bear - Temp. CLOSED  020 7236 2498                61 Carter Lane
# 6                       Dishoom  020 7420 9322              22 Kingly Street
# 7                   Mother Mash  020 7494 9644              26 Ganton Street
# 8               The Queens Arms  020 7834 3313                11 Warwick Way
# 9              The Grazing Goat  020 7724 7243           6 New Quebec Street
# 10                      Padella           None            6 Southwark Street
# 11                 The Victoria  020 7724 1191                          None
# 12   Gordon Ramsay Street Pizza  020 3030 4050               10 Bread Street
# 13                        Abeno  020 7405 3211              47 Museum Street
# 14                Duck & Waffle  020 3640 7310               110 Bishopsgate
# 15          The Pig and Butcher  020 7226 8304             80 Liverpool Road
# 16            The Golden Chippy  020 8692 4333        62 Greenwich High Road
# 17                 Shoryu Ramen           None               9 Regent Street
# 18          The Colonel Fawcett  020 7267 9829             1 Randolph Street
# 19      Ye Olde Cheshire Cheese  020 7353 6170              145 Fleet Street
# 20           Lanzhou Noodle Bar  020 7467 4546          33 Cranbourne Street
# 21                       Sketch  020 7659 4500              9 Conduit Street
# 22                   BAO - Soho  020 3019 2200           53 Lexington Street
# 23                     Yauatcha  020 7494 8888        15-17 Broadwick Street
# 24        Hawksmoor Seven Dials  020 7420 9390             11 Langley Street
# 25                      Dishoom  020 7420 9324             7 Boundary Street
# 26                    Barrafina  020 7440 1456                 43 Drury Lane
# 27           The Churchill Arms  020 7727 4242  119 Kensington Church Street
# 28                     The Shed  020 7229 4024    122 Palace Gardens Terrace
# 29                         NOPI  020 7494 9584          21-22 Warwick Street
#
#      Neighborhood PriceRange  AvgRating  NumRatings             CategoryOne  \
# 0   Covent Garden         ££        4.5        1842                  Indian
# 1         Mayfair         ££        4.5         276            Fish & Chips
# 2      Kensington         ££        4.5         270                 British
# 3            Soho         ££        4.5         377             Steakhouses
# 4         Chelsea       ££££        4.5         204                  French
# 5     Blackfriars         ££        4.5         122  American (Traditional)
# 6            Soho         ££        4.5         544                  Indian
# 7            Soho         ££        4.0         468                 British
# 8        Victoria         ££        4.5         118                 British
# 9      Marylebone         ££        4.0         240              Gastropubs
# 10  London Bridge         ££        4.5         202                 Italian
# 11     Paddington         ££        4.5         212                    Pubs
# 12       The City         ££        4.5          30                   Pizza
# 13     Bloomsbury         ££        4.5         101                Japanese
# 14        Aldgate        £££        4.0         701         Modern European
# 15      Islington         ££        4.5         109                 British
# 16       Deptford         ££        5.0         108            Fish & Chips
# 17     St James's         ££        4.0         375                Japanese
# 18    Camden Town         ££        4.5          26              Gastropubs
# 19    Blackfriars         ££        4.0         353                    Pubs
# 20  Covent Garden          £        4.0         351                 Chinese
# 21        Mayfair        £££        4.0         831                  French
# 22           Soho         ££        4.0         183               Taiwanese
# 23           Soho        £££        4.0         482                 Dim Sum
# 24  Covent Garden        £££        4.5         342                 British
# 25     Shoreditch         ££        4.5         492                  Indian
# 26  Covent Garden         ££        4.5          61                 Spanish
# 27   Notting Hill         ££        4.0         358                    Pubs
# 28   Notting Hill         ££        4.5          78                 British
# 29           Soho        £££        4.5         271           Mediterranean
#
#            CategoryTwo  CategoryThree  \
# 0                 None           None
# 1                 None           None
# 2                 None           None
# 3                 None           None
# 4              British           None
# 5            Soul Food   Cajun/Creole
# 6                 None           None
# 7                 None           None
# 8                 Pubs     Gastropubs
# 9              British           None
# 10                None           None
# 11             British           None
# 12                Bars           None
# 13                None           None
# 14                Bars        British
# 15          Gastropubs           None
# 16                None           None
# 17                None           None
# 18                None           None
# 19             British           None
# 20             Noodles           None
# 21     Modern European  Cocktail Bars
# 22                None           None
# 23             Seafood        Noodles
# 24         Steakhouses  Cocktail Bars
# 25  Breakfast & Brunch           None
# 26          Tapas Bars           None
# 27                Thai           None
# 28                None           None
# 29                None           None
#
#                                                Review
# 0   “Kicking off our first international trip with...
# 1   “I had the Mayfair Classic during my visit to ...
# 2   “Ffiona's is easily my favorite restaurant in ...
# 3   “Ok guys...here is how it is. We were in Londo...
# 4   “Compared to Michelin 3-star restaurants in Ca...
# 5   “A most enjoyable experience. I had personally...
# 6   “I visited Dishoom during my recent London tri...
# 7   “Soho is full of culture and amazing places to...
# 8   “The staff at The Queens Arms were amazing ton...
# 9   “Sometimes it's just the little things.  It wa...
# 10  “A great dining experience even in COVID times...
# 11                                               None
# 12  “We love pizza and really like Chef Ramsey. We...
# 13  “This place was amazing! Some of the best serv...
# 14  “This place is a must see when in London! Do n...
# 15  “Dined here pre-Covid-19 on my last 2 trips to...
# 16  “The hype is REAL! The Golden Chippy is truly ...
# 17  “I am so excited to write this review! Today I...
# 18  “The Colonel Fawcett's slogan "Camden's Best K...
# 19  “What I love about London is how much of a tim...
# 20  “We got to our hotel somewhere in between earl...
# 21  “Having received it's 3rd star in 2020, sketch...
# 22  “The best restaurant we tried while traveling ...
# 23  “Well... had to try this high end dim sum plac...
# 24  “Everything superb!  We were for Sh day roast ...
# 25  “I went to two different Dishoom. One for brea...
# 26  “A stone's throw from our hotel, we walked ove...
# 27  “Awesome pub located close by Kensington which...
# 28  “I honestly loved this restaurant!\nThe locati...
# 29  “10/10 recommend!\nGood cocktails to have as a...
