# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('/Users/alinaurs/GA-one/ClassMaterial/Unit2/Data/housing.csv')

# %%
df.head()
# Out:
#    CRIM    ZN  INDUS  CHAS  NOX   RM   AGE  DIS  RAD  TAX  PTRATIO      B  \
# 0  0.01 18.00   2.31     0 0.54 6.58 65.20 4.09    1  296    15.30 396.90
# 1  0.03  0.00   7.07     0 0.47 6.42 78.90 4.97    2  242    17.80 396.90
# 2  0.03  0.00   7.07     0 0.47 7.18 61.10 4.97    2  242    17.80 392.83
# 3  0.03  0.00   2.18     0 0.46 7.00 45.80 6.06    3  222    18.70 394.63
# 4  0.07  0.00   2.18     0 0.46 7.15 54.20 6.06    3  222    18.70 396.90
#
#    LSTAT  PRICE
# 0   4.98  24.00
# 1   9.14  21.60
# 2   4.03  34.70
# 3   2.94  33.40
# 4   5.33  36.20

# %%
df.shape
# Out:
# (506, 14)

# %%
df.hist(figsize=(12,12));

# %%
df.describe()
# Out:
#         CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD    TAX  \
# count 506.00 506.00 506.00 506.00 506.00 506.00 506.00 506.00 506.00 506.00
# mean    3.61  11.36  11.14   0.07   0.55   6.28  68.57   3.80   9.55 408.24
# std     8.60  23.32   6.86   0.25   0.12   0.70  28.15   2.11   8.71 168.54
# min     0.01   0.00   0.46   0.00   0.39   3.56   2.90   1.13   1.00 187.00
# 25%     0.08   0.00   5.19   0.00   0.45   5.89  45.02   2.10   4.00 279.00
# 50%     0.26   0.00   9.69   0.00   0.54   6.21  77.50   3.21   5.00 330.00
# 75%     3.68  12.50  18.10   0.00   0.62   6.62  94.07   5.19  24.00 666.00
# max    88.98 100.00  27.74   1.00   0.87   8.78 100.00  12.13  24.00 711.00
#
#        PTRATIO      B  LSTAT  PRICE
# count   506.00 506.00 506.00 506.00
# mean     18.46 356.67  12.65  22.53
# std       2.16  91.29   7.14   9.20
# min      12.60   0.32   1.73   5.00
# 25%      17.40 375.38   6.95  17.02
# 50%      19.05 391.44  11.36  21.20
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(df, size=1.5);
plt.show()
# Out:
# /Users/alinaurs/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
col_study = ['CRIM', 'ZN', 'RM', 'LSTAT','PRICE']

# %%
sns.pairplot(df[col_study], size=1.5);
plt.show()

# %%
col_study = ['CRIM', 'INDUS', 'NOX', 'LSTAT','PRICE']

# %%
sns.pairplot(df[col_study], size=1.5);
plt.show()

# %%
col_study = ['PTRATIO', 'B','LSTAT','PRICE']

# %%
sns.pairplot(df[col_study], size=1.5);
plt.show()

# %%
df.corr()
# Out:
#          CRIM    ZN  INDUS  CHAS   NOX    RM   AGE   DIS   RAD   TAX  PTRATIO  \
# CRIM     1.00 -0.20   0.41 -0.06  0.42 -0.22  0.35 -0.38  0.63  0.58     0.29
# ZN      -0.20  1.00  -0.53 -0.04 -0.52  0.31 -0.57  0.66 -0.31 -0.31    -0.39
# INDUS    0.41 -0.53   1.00  0.06  0.76 -0.39  0.64 -0.71  0.60  0.72     0.38
# CHAS    -0.06 -0.04   0.06  1.00  0.09  0.09  0.09 -0.10 -0.01 -0.04    -0.12
# NOX      0.42 -0.52   0.76  0.09  1.00 -0.30  0.73 -0.77  0.61  0.67     0.19
# RM      -0.22  0.31  -0.39  0.09 -0.30  1.00 -0.24  0.21 -0.21 -0.29    -0.36
# AGE      0.35 -0.57   0.64  0.09  0.73 -0.24  1.00 -0.75  0.46  0.51     0.26
# DIS     -0.38  0.66  -0.71 -0.10 -0.77  0.21 -0.75  1.00 -0.49 -0.53    -0.23
# RAD      0.63 -0.31   0.60 -0.01  0.61 -0.21  0.46 -0.49  1.00  0.91     0.46
# TAX      0.58 -0.31   0.72 -0.04  0.67 -0.29  0.51 -0.53  0.91  1.00     0.46
# PTRATIO  0.29 -0.39   0.38 -0.12  0.19 -0.36  0.26 -0.23  0.46  0.46     1.00
# ...

# %%
pd.options.display.float_format = '{:,.3f}'.format

# %%
df.corr()
# Out:
#           CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD    TAX  \
# CRIM     1.000 -0.200  0.407 -0.056  0.421 -0.219  0.353 -0.380  0.626  0.583
# ZN      -0.200  1.000 -0.534 -0.043 -0.517  0.312 -0.570  0.664 -0.312 -0.315
# INDUS    0.407 -0.534  1.000  0.063  0.764 -0.392  0.645 -0.708  0.595  0.721
# CHAS    -0.056 -0.043  0.063  1.000  0.091  0.091  0.087 -0.099 -0.007 -0.036
# NOX      0.421 -0.517  0.764  0.091  1.000 -0.302  0.731 -0.769  0.611  0.668
# RM      -0.219  0.312 -0.392  0.091 -0.302  1.000 -0.240  0.205 -0.210 -0.292
# AGE      0.353 -0.570  0.645  0.087  0.731 -0.240  1.000 -0.748  0.456  0.506
# DIS     -0.380  0.664 -0.708 -0.099 -0.769  0.205 -0.748  1.000 -0.495 -0.534
# RAD      0.626 -0.312  0.595 -0.007  0.611 -0.210  0.456 -0.495  1.000  0.910
# TAX      0.583 -0.315  0.721 -0.036  0.668 -0.292  0.506 -0.534  0.910  1.000
# PTRATIO  0.290 -0.392  0.383 -0.122  0.189 -0.356  0.262 -0.232  0.465  0.461
# ...

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
df.corr()
# Out:
#          CRIM    ZN  INDUS  CHAS   NOX    RM   AGE   DIS   RAD   TAX  PTRATIO  \
# CRIM     1.00 -0.20   0.41 -0.06  0.42 -0.22  0.35 -0.38  0.63  0.58     0.29
# ZN      -0.20  1.00  -0.53 -0.04 -0.52  0.31 -0.57  0.66 -0.31 -0.31    -0.39
# INDUS    0.41 -0.53   1.00  0.06  0.76 -0.39  0.64 -0.71  0.60  0.72     0.38
# CHAS    -0.06 -0.04   0.06  1.00  0.09  0.09  0.09 -0.10 -0.01 -0.04    -0.12
# NOX      0.42 -0.52   0.76  0.09  1.00 -0.30  0.73 -0.77  0.61  0.67     0.19
# RM      -0.22  0.31  -0.39  0.09 -0.30  1.00 -0.24  0.21 -0.21 -0.29    -0.36
# AGE      0.35 -0.57   0.64  0.09  0.73 -0.24  1.00 -0.75  0.46  0.51     0.26
# DIS     -0.38  0.66  -0.71 -0.10 -0.77  0.21 -0.75  1.00 -0.49 -0.53    -0.23
# RAD      0.63 -0.31   0.60 -0.01  0.61 -0.21  0.46 -0.49  1.00  0.91     0.46
# TAX      0.58 -0.31   0.72 -0.04  0.67 -0.29  0.51 -0.53  0.91  1.00     0.46
# PTRATIO  0.29 -0.39   0.38 -0.12  0.19 -0.36  0.26 -0.23  0.46  0.46     1.00
# ...

# %%
#sns.heatmap?

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df[['CRIM', 'RM', 'INDUS', 'LSTAT','PRICE']].corr(), annot=True)
plt.show()

# %%
X =df['RM'].values.reshape(-1,1)

# %%
y = df['PRICE'].values

# %%
from sklearn.linear_model import LinearRegression

# %%
model= LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([9.10210898])

# %%
model.intercept_
# Out:
# -34.670620776438554

# %%
plt.figure(figsize=(12,10));
sns.regplot(X, y);
plt.xlabel('average number of rooms per dwelling')
plt.ylabel("Median values of ownerm-occupied homes in $1000's")
plt.show();

# %%
sns.jointplot(x='RM', y='PRICE', data=df, kind='reg', size=10);
plt.show
# Out:
# /Users/alinaurs/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:2264: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = df['LSTAT'].values.reshape(-1,1)
y = df['PRICE'].values
model.fit(X,y)
plt.figure(figsize=(12,10));
sns.regplot(X, y);
plt.xlabel('%lower status of the population')
plt.ylabel("Median values of ownerm-occupied homes in $1000's")
plt.show();

# %%
sns.jointplot(x='LSTAT', y='PRICE', data=df, kind='reg', size=10);
plt.show();
# Out:
# /Users/alinaurs/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:2264: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
X = df['RM'].values.reshape(-1,1)
y = df['PRICE'].values

# %%
from sklearn.linear_model import RANSACRegressor

# %%
ransac = RANSACRegressor()

# %%
ransac.fit(X, y)
# Out:
# RANSACRegressor()

# %%
inlier_mask = ransac.inlier_mask_
outlier_mask = np.logical_not(inlier_mask)

# %%
np.arange(3, 10, 1)
# Out:
# array([3, 4, 5, 6, 7, 8, 9])

# %%
line_X = np.arange(3,10,1)
line_y_ransac = ransac.predict(line_X.reshape(-1,1))

# %%
sns.set(style='darkgrid', context='notebook')
plt.figure(figsize=(12,10));
plt.scatter(X[inlier_mask], y[inlier_mask],
           c='blue', marker='o', label='Inliers')
plt.scatter(X[outlier_mask], y[outlier_mask],
           c='brown', marker='s', label='Outliers')
plt.plot(line_X, line_y_ransac, color='red')
plt.xlabel('RM')
plt.ylabel("PRICE")
plt.legend(loc='upper right')
plt.show()

# %%
ransac.estimator_.coef_
# Out:
# array([10.87893552])

# %%
ransac.estimator_.intercept_
# Out:
# -45.30271003603524

# %%
X = df['LSTAT'].values.reshape(-1,1)
y = df['PRICE'].values
ransac.fit(X,y)
inlier_mask =ransac.inlier_mask_
outlier_mask = np.logical_not(inlier_mask)
line_X = np.arange(0, 40, 1)
line_y_ransac = ransac.predict(line_X.reshape(-1, 1))

# %%
sns.set(style='darkgrid', context='notebook')
plt.figure(figsize=(12,10));
plt.scatter(X[inlier_mask], y[inlier_mask],
           c='blue', marker='o', label='Inliers')
plt.scatter(X[outlier_mask], y[outlier_mask],
           c='brown', marker='s', label='Outliers')
plt.plot(line_X, line_y_ransac, color='red')
plt.xlabel('LSTAT')
plt.ylabel("PRICE")
plt.legend(loc='upper right')
plt.show()

# %%
ransac.estimator_.coef_
# Out:
# array([-0.86511051])

# %%
ransac.estimator_.intercept_
# Out:
# 30.762042508172954

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
reg = linear_model.LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.shape
# Out:
# (339, 1)

# %%
X_test.shape
# Out:
# (167, 1)

# %%
y_train.shape
# Out:
# (339,)

# %%
y_test.shape
# Out:
# (167,)

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbm = GradientBoostingRegressor(n_estimators=1000)

# %%
gbm.fit(X, y)
gbm.score(X, y)
# Out:
# 0.9510800016605692

# %%
gbm.fit(X_train, y_train)
gbm.score(X_test, y_test)
# Out:
# 0.4230257136024167

# %%
X_train.shape, y_train.shape
# Out:
# ((339, 1), (339,))

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.33, random_state=42)

# %%
gbm.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(n_estimators=1000)

# %%
gbm.score(X_val, y_val)
# Out:
# 0.4464176266641966

# %%
gbm.set_params(n_estimators=100)
# Out:
# GradientBoostingRegressor()

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(estimator=gbm, X=X_train, y=y_train, cv=10)
# Out:
# array([0.5467139 , 0.01431129, 0.32564612, 0.38756052, 0.66022652,
#        0.71385929, 0.85851112, 0.68442858, 0.62146319, 0.79487783])

# %%
scores
# Out:
# array([0.41121673, 0.39241172, 0.63528791, 0.01895478, 0.3243449 ])

# %%
# !pip install category-encoders

# %%
import category_encoders as ce

# %%
ore = ce.OrdinalEncoder()

# %%
X_train
# Out:
# array([[12.64],
#        [24.56],
#        [ 4.59],
#        [10.29],
#        [29.93],
#        [29.53],
#        [15.55],
#        [ 8.1 ],
#        [14.8 ],
#        [11.32],
#        [28.28],
#        [ 3.01],
#        [ 5.33],
#        [12.13],
#        [13.99],
#        [13.44],
#        [ 8.88],
#        [27.71],
#        [22.88],
#        [15.71],
#        [ 6.15],
#        [23.6 ],
#        [19.37],
#        [12.43],
#        [16.03],
#        [25.41],
#        [ 6.47],
#        [29.68],
#        [ 6.92],
#        [14.79],
#        [14.19],
#        [ 7.51],
#        [12.43],
#        [ 5.7 ],
#        [13.11],
#        [14.09],
#        [11.48],
#        [ 7.79],
#        [15.69],
#        [24.1 ],
#        [12.73],
#        [ 7.44],
#        [ 5.19],
#        [13.33],
#        [17.79],
#        [ 9.68],
#        [ 6.48],
#        [30.81],
#        [20.85],
#        [34.02],
#        [ 9.52],
#        [ 8.43],
#        [ 6.27],
#        [ 6.65],
#        [29.97],
# ...

# %%
ore.fit_transform(X_train)
# Out:
#         0
# 0   12.64
# 1   24.56
# 2    4.59
# 3   10.29
# 4   29.93
# ..    ...
# 222  5.33
# 223  5.64
# 224  3.11
# 225  9.74
# 226  4.21
#
# [227 rows x 1 columns]

# %%
X_test
# Out:
# array([[ 9.04],
#        [ 3.53],
#        [18.07],
#        [ 5.52],
#        [17.27],
#        [11.97],
#        [18.33],
#        [24.16],
#        [12.87],
#        [14.33],
#        [17.92],
#        [17.1 ],
#        [36.98],
#        [12.34],
#        [11.74],
#        [11.66],
#        [17.58],
#        [30.62],
#        [ 2.97],
#        [18.13],
#        [ 6.59],
#        [ 7.19],
#        [22.6 ],
#        [ 9.67],
#        [15.7 ],
#        [18.14],
#        [ 9.1 ],
#        [18.71],
#        [17.27],
#        [14.1 ],
#        [14.69],
#        [ 7.2 ],
#        [13.44],
#        [10.19],
#        [21.32],
#        [15.79],
#        [ 4.03],
#        [ 9.8 ],
#        [14.66],
#        [ 7.54],
#        [21.14],
#        [ 7.53],
#        [ 2.88],
#        [13.09],
#        [ 8.81],
#        [17.11],
#        [18.35],
#        [ 6.72],
#        [16.29],
#        [ 4.98],
#        [13.27],
#        [ 4.59],
#        [18.72],
#        [ 7.67],
#        [ 3.16],
# ...

# %%
ore.transform(X_test)
# Out:
#         0
# 0    9.04
# 1    3.53
# 2   18.07
# 3    5.52
# 4   17.27
# ..    ...
# 162 13.00
# 163  6.87
# 164 10.45
# 165 11.98
# 166  5.91
#
# [167 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
ore.category_mapping
# Out:
# []

# %%
from sklearn.pipeline import make_pipeline

# %%
gbm
# Out:
# GradientBoostingRegressor()

# %%
ore
# Out:
# OrdinalEncoder(cols=[], mapping=[])

# %%
pipe = make_pipeline(ore, gbm)

# %%
X_train
# Out:
# array([[18.03],
#        [14.81],
#        [19.15],
#        [13.35],
#        [12.27],
#        [ 8.77],
#        [ 4.59],
#        [14.36],
#        [15.37],
#        [10.45],
#        [ 5.33],
#        [ 2.87],
#        [ 7.73],
#        [29.29],
#        [34.77],
#        [24.56],
#        [17.6 ],
#        [ 4.16],
#        [ 9.71],
#        [17.44],
#        [34.41],
#        [ 3.73],
#        [ 8.1 ],
#        [14.19],
#        [11.1 ],
#        [15.1 ],
#        [16.35],
#        [26.77],
#        [ 5.03],
#        [ 6.56],
#        [15.55],
#        [15.02],
#        [27.8 ],
#        [ 8.16],
#        [12.12],
#        [ 9.93],
#        [ 6.93],
#        [ 7.51],
#        [ 9.52],
#        [ 9.81],
#        [ 3.32],
#        [ 4.56],
#        [ 5.25],
#        [ 6.78],
#        [ 5.98],
#        [18.13],
#        [ 3.54],
#        [13.61],
#        [ 7.85],
#        [ 8.67],
#        [10.42],
#        [13.27],
#        [19.77],
#        [ 3.92],
#        [ 7.26],
# ...

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('ordinalencoder', OrdinalEncoder(cols=[], mapping=[])),
#                 ('gradientboostingregressor', GradientBoostingRegressor())])

# %%
pipe.predict(X_test)
# Out:
# array([23.18092132, 33.86566399, 16.67130298, 26.83646609, 16.24971241,
#        21.16114778, 16.67130298, 12.06964883, 20.84103242, 20.84103242,
#        16.67130298, 16.71548325, 13.24578682, 20.84103242, 21.16114778,
#        21.16114778, 17.04429228,  9.84327018, 47.63052203, 16.67130298,
#        31.4761301 , 26.74041098, 11.40240061, 23.85182119, 16.73799167,
#        16.67130298, 23.18092132, 17.31531886, 16.24971241, 20.84103242,
#        18.69505114, 26.74041098, 20.84103242, 21.37286232, 13.02198479,
#        18.69499167, 39.00882933, 23.24882569, 18.69505114, 26.35307529,
#        13.02198479, 26.35307529, 39.21032276, 20.84103242, 24.54778326,
#        16.71548325, 16.67130298, 25.9255904 , 16.71548325, 32.69918212,
#        20.84103242, 35.04728936, 17.31531886, 26.66065245, 47.74456198,
#        21.37286232, 16.71548325, 47.74456198, 23.85182119, 17.00558801,
#        23.85182119, 30.15107929, 46.53226783, 21.16114778, 31.39452434,
# ...

# %%
pipe.score(X_test, y_test)
# Out:
# 0.5498663987372265

# %%
cross_val_score(estimator=pipe, X=X_train, y=y_train, cv=10)
# Out:
# array([0.71257526, 0.72051247, 0.41778631, 0.72755765, 0.75990219,
#        0.67453845, 0.56438627, 0.44246981, 0.64939034, 0.32582767])

# %%
gbm = GradientBoostingRegressor()
gbm.fit(X, y)
# Out:
# GradientBoostingRegressor()

# %%
gbm.score(X, y)
# Out:
# 0.8057960635005381

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.shape
# Out:
# (339, 1)

# %%
X_test.shape
# Out:
# (167, 1)

# %%
df.head()
# Out:
#    CRIM    ZN  INDUS  CHAS  NOX   RM   AGE  DIS  RAD  TAX  PTRATIO      B  \
# 0  0.01 18.00   2.31     0 0.54 6.58 65.20 4.09    1  296    15.30 396.90
# 1  0.03  0.00   7.07     0 0.47 6.42 78.90 4.97    2  242    17.80 396.90
# 2  0.03  0.00   7.07     0 0.47 7.18 61.10 4.97    2  242    17.80 392.83
# 3  0.03  0.00   2.18     0 0.46 7.00 45.80 6.06    3  222    18.70 394.63
# 4  0.07  0.00   2.18     0 0.46 7.15 54.20 6.06    3  222    18.70 396.90
#
#    LSTAT  PRICE
# 0   4.98  24.00
# 1   9.14  21.60
# 2   4.03  34.70
# 3   2.94  33.40
# 4   5.33  36.20

# %%
max_depth = [2, 3, 4, 5]
learning_rate = [.001, .01, .1]
num_trees = [100, 500, 1000]
cv_scores = []

for depth in max_depth:
    for rate in learning_rate:
        for tree in num_trees:
            print(f"Testing model with: depth: {depth}, rate: {rate}, trees: {tree}")
            pipe.steps[1][1].set_params(max_depth=depth, learning_rate=rate, n_estimators=tree)
            scores = cross_val_score(estimator=pipe, X=X_train, y=y_train, cv=5)
            cv_scores.append((scores.mean(), depth, rate, tree))
# Out:
# Testing model with: depth: 2, rate: 0.001, trees: 100
# Testing model with: depth: 2, rate: 0.001, trees: 500
# Testing model with: depth: 2, rate: 0.001, trees: 1000
# Testing model with: depth: 2, rate: 0.01, trees: 100
# Testing model with: depth: 2, rate: 0.01, trees: 500
# Testing model with: depth: 2, rate: 0.01, trees: 1000
# Testing model with: depth: 2, rate: 0.1, trees: 100
# Testing model with: depth: 2, rate: 0.1, trees: 500
# Testing model with: depth: 2, rate: 0.1, trees: 1000
# Testing model with: depth: 3, rate: 0.001, trees: 100
# Testing model with: depth: 3, rate: 0.001, trees: 500
# Testing model with: depth: 3, rate: 0.001, trees: 1000
# Testing model with: depth: 3, rate: 0.01, trees: 100
# Testing model with: depth: 3, rate: 0.01, trees: 500
# Testing model with: depth: 3, rate: 0.01, trees: 1000
# Testing model with: depth: 3, rate: 0.1, trees: 100
# Testing model with: depth: 3, rate: 0.1, trees: 500
# Testing model with: depth: 3, rate: 0.1, trees: 1000
# ...

# %%
max_trees = [100, 500, 1000]
max_depth = [2, 3, 4, 5, 6]
learning_rates = [.001, .01, .1]
cv_scores = []

for trees in max_trees:
    for depth in max_depth:
        for rate in learning_rates:
            print(f"Fitting with parameters: trees: {trees}, depth: {depth}, learing rate: {rate}")
            pipe.steps[1][1].set_params(n_estimators=trees, max_depth=depth, learning_rate=rate)
            scores = cross_val_score(estimator=pipe, X=X_train, y=y_train, cv=5)
            cv_scores.append((scores.mean(), trees, depth, rate))
# Out:
# Fitting with parameters: trees: 100, depth: 2, learing rate: 0.001
# Fitting with parameters: trees: 100, depth: 2, learing rate: 0.01
# Fitting with parameters: trees: 100, depth: 2, learing rate: 0.1
# Fitting with parameters: trees: 100, depth: 3, learing rate: 0.001
# Fitting with parameters: trees: 100, depth: 3, learing rate: 0.01
# Fitting with parameters: trees: 100, depth: 3, learing rate: 0.1
# Fitting with parameters: trees: 100, depth: 4, learing rate: 0.001
# Fitting with parameters: trees: 100, depth: 4, learing rate: 0.01
# Fitting with parameters: trees: 100, depth: 4, learing rate: 0.1
# Fitting with parameters: trees: 100, depth: 5, learing rate: 0.001
# Fitting with parameters: trees: 100, depth: 5, learing rate: 0.01
# Fitting with parameters: trees: 100, depth: 5, learing rate: 0.1
# Fitting with parameters: trees: 100, depth: 6, learing rate: 0.001
# Fitting with parameters: trees: 100, depth: 6, learing rate: 0.01
# ...

# %%
pipe
# Out:
# Pipeline(steps=[('ordinalencoder', OrdinalEncoder(cols=[], mapping=[])),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=6, n_estimators=1000))])
